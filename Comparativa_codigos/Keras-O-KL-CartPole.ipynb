# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import gym
import scipy.signal
import time

# %%
def discounted_cumulative_sums(x, discount):
    # Discounted cumulative sums of vectors for computing rewards-to-go and advantage estimates
    return scipy.signal.lfilter([1], [1, float(-discount)], x[::-1], axis=0)[::-1]


class Buffer:
    # Buffer for storing trajectories
    def __init__(self, observation_dimensions, size, gamma=0.99, lam=0.95):
        # Buffer initialization
        self.observation_buffer = np.zeros(
            (size, observation_dimensions), dtype=np.float32
        )
        self.action_buffer = np.zeros(size, dtype=np.int32)
        self.advantage_buffer = np.zeros(size, dtype=np.float32)
        self.reward_buffer = np.zeros(size, dtype=np.float32)
        self.return_buffer = np.zeros(size, dtype=np.float32)
        self.value_buffer = np.zeros(size, dtype=np.float32)
        self.logprobability_buffer = np.zeros(size, dtype=np.float32)
        self.gamma, self.lam = gamma, lam
        self.pointer, self.trajectory_start_index = 0, 0

    def store(self, observation, action, reward, value, logprobability):
        # Append one step of agent-environment interaction
        self.observation_buffer[self.pointer] = observation
        self.action_buffer[self.pointer] = action
        self.reward_buffer[self.pointer] = reward
        self.value_buffer[self.pointer] = value
        self.logprobability_buffer[self.pointer] = logprobability
        self.pointer += 1

    def finish_trajectory(self, last_value=0):
        # Finish the trajectory by computing advantage estimates and rewards-to-go
        path_slice = slice(self.trajectory_start_index, self.pointer)
        rewards = np.append(self.reward_buffer[path_slice], last_value)
        values = np.append(self.value_buffer[path_slice], last_value)

        deltas = rewards[:-1] + self.gamma * values[1:] - values[:-1]

        self.advantage_buffer[path_slice] = discounted_cumulative_sums(
            deltas, self.gamma * self.lam
        )
        self.return_buffer[path_slice] = discounted_cumulative_sums(
            rewards, self.gamma
        )[:-1]

        self.trajectory_start_index = self.pointer

    def get(self):
        # Get all data of the buffer and normalize the advantages
        self.pointer, self.trajectory_start_index = 0, 0
        advantage_mean, advantage_std = (
            np.mean(self.advantage_buffer),
            np.std(self.advantage_buffer),
        )
        self.advantage_buffer = (self.advantage_buffer - advantage_mean) / advantage_std
        return (
            self.observation_buffer,
            self.action_buffer,
            self.advantage_buffer,
            self.return_buffer,
            self.logprobability_buffer,
        )


def mlp(x, sizes, activation=tf.tanh, output_activation=None):
    # Build a feedforward neural network
    for size in sizes[:-1]:
        x = layers.Dense(units=size, activation=activation)(x)
    return layers.Dense(units=sizes[-1], activation=output_activation)(x)


def logprobabilities(logits, a):
    # Compute the log-probabilities of taking actions a by using the logits (i.e. the output of the actor)
    logprobabilities_all = tf.nn.log_softmax(logits)
    logprobability = tf.reduce_sum(
        tf.one_hot(a, num_actions) * logprobabilities_all, axis=1
    )
    return logprobability


# Sample action from actor
@tf.function
def sample_action(observation):
    logits = actor(observation)
    action = tf.squeeze(tf.random.categorical(logits, 1), axis=1)
    return logits, action


# Train the policy by maxizing the PPO-Clip objective
@tf.function
def train_policy(
    observation_buffer, action_buffer, logprobability_buffer, advantage_buffer
):

    with tf.GradientTape() as tape:  # Record operations for automatic differentiation.
        ratio = tf.exp(
            logprobabilities(actor(observation_buffer), action_buffer)
            - logprobability_buffer
        )
        min_advantage = tf.where(
            advantage_buffer > 0,
            (1 + clip_ratio) * advantage_buffer,
            (1 - clip_ratio) * advantage_buffer,
        )

        policy_loss = -tf.reduce_mean(
            tf.minimum(ratio * advantage_buffer, min_advantage)
        )
    policy_grads = tape.gradient(policy_loss, actor.trainable_variables)
    policy_optimizer.apply_gradients(zip(policy_grads, actor.trainable_variables))

    kl = tf.reduce_mean(
        logprobability_buffer
        - logprobabilities(actor(observation_buffer), action_buffer)
    )
    kl = tf.reduce_sum(kl)
    return kl


# Train the value function by regression on mean-squared error
@tf.function
def train_value_function(observation_buffer, return_buffer):
    with tf.GradientTape() as tape:  # Record operations for automatic differentiation.
        value_loss = tf.reduce_mean((return_buffer - critic(observation_buffer)) ** 2)
    value_grads = tape.gradient(value_loss, critic.trainable_variables)
    value_optimizer.apply_gradients(zip(value_grads, critic.trainable_variables))

# %%
# Hyperparameters of the PPO algorithm
steps_per_epoch = 4000
epochs = 300
gamma = 0.99
clip_ratio = 0.2
policy_learning_rate = 3e-4
value_function_learning_rate = 1e-3
train_policy_iterations = 80
train_value_iterations = 80
lam = 0.97
target_kl = 0.01
hidden_sizes = (64, 64)

# True if you want to render the environment
render = False

# %%
# Initialize the environment and get the dimensionality of the
# observation space and the number of possible actions
env = gym.make("CartPole-v0")
observation_dimensions = env.observation_space.shape[0]
num_actions = env.action_space.n

# Initialize the buffer
buffer = Buffer(observation_dimensions, steps_per_epoch)

# Initialize the actor and the critic as keras models
observation_input = keras.Input(shape=(observation_dimensions,), dtype=tf.float32)
logits = mlp(observation_input, list(hidden_sizes) + [num_actions], tf.tanh, None)
actor = keras.Model(inputs=observation_input, outputs=logits)
value = tf.squeeze(
    mlp(observation_input, list(hidden_sizes) + [1], tf.tanh, None), axis=1
)
critic = keras.Model(inputs=observation_input, outputs=value)

# Initialize the policy and the value function optimizers
policy_optimizer = keras.optimizers.Adam(learning_rate=policy_learning_rate)
value_optimizer = keras.optimizers.Adam(learning_rate=value_function_learning_rate)

# Initialize the observation, episode return and episode length
observation, episode_return, episode_length = env.reset(), 0, 0

# %%
# Iterate over the number of epochs
scores = []
start = time.time()
num_episodes = 1
fin = False
for epoch in range(epochs):
    # Initialize the sum of the returns, lengths and number of episodes for each epoch

    

    # Iterate over the steps of each epoch
    for t in range(steps_per_epoch):
        if render:
            env.render()

        # Get the logits, action, and take one step in the environment
        observation = observation.reshape(1, -1)
        logits, action = sample_action(observation)
        observation_new, reward, done, _ = env.step(action[0].numpy())
        episode_return += reward
        episode_length += 1

        # Get the value and log-probability of the action
        value_t = critic(observation)
        logprobability_t = logprobabilities(logits, action)

        # Store obs, act, rew, v_t, logp_pi_t
        buffer.store(observation, action, reward, value_t, logprobability_t)

        # Update the observation
        observation = observation_new

        # Finish trajectory if reached to a terminal state
        terminal = done
        if terminal:
            last_value = 0 if done else critic(observation.reshape(1, -1))
            buffer.finish_trajectory(last_value)
            scores.append(episode_return)
            if num_episodes >= 100:
                average = sum(scores[-100:])/100
                print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(num_episodes, episode_return, average))
                if average > 195:
                    fin = True
                    break
            else:
                average = sum(scores)/len(scores)
                print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(num_episodes, episode_return, average))
                
            num_episodes += 1
            observation, episode_return, episode_length = env.reset(), 0, 0
    if fin:
        break
    # Get values from the buffer
    (
        observation_buffer,
        action_buffer,
        advantage_buffer,
        return_buffer,
        logprobability_buffer,
    ) = buffer.get()

    # Update the policy and implement early stopping using KL divergence
    for _ in range(train_policy_iterations):
        kl = train_policy(
            observation_buffer, action_buffer, logprobability_buffer, advantage_buffer
        )
        if kl > 1.5 * target_kl:
            # Early Stopping
            break

    # Update the value function
    for _ in range(train_value_iterations):
        train_value_function(observation_buffer, return_buffer)
print((time.time()-start)/60)
# Out:
# Episode:     1		score:   27.00		average:   27.00
# Episode:     2		score:   26.00		average:   26.50
# Episode:     3		score:   21.00		average:   24.67
# Episode:     4		score:   12.00		average:   21.50
# Episode:     5		score:   22.00		average:   21.60
# Episode:     6		score:    8.00		average:   19.33
# Episode:     7		score:   24.00		average:   20.00
# Episode:     8		score:   22.00		average:   20.25
# Episode:     9		score:   86.00		average:   27.56
# Episode:    10		score:   56.00		average:   30.40
# Episode:    11		score:   18.00		average:   29.27
# Episode:    12		score:   12.00		average:   27.83
# Episode:    13		score:   16.00		average:   26.92
# Episode:    14		score:   20.00		average:   26.43
# Episode:    15		score:   24.00		average:   26.27
# Episode:    16		score:   12.00		average:   25.38
# Episode:    17		score:   13.00		average:   24.65
# Episode:    18		score:   30.00		average:   24.94
# Episode:    19		score:   15.00		average:   24.42
# Episode:    20		score:   20.00		average:   24.20
# Episode:    21		score:   12.00		average:   23.62
# Episode:    22		score:   21.00		average:   23.50
# Episode:    23		score:   12.00		average:   23.00
# Episode:    24		score:   11.00		average:   22.50
# Episode:    25		score:   15.00		average:   22.20
# Episode:    26		score:   37.00		average:   22.77
# Episode:    27		score:   25.00		average:   22.85
# Episode:    28		score:   40.00		average:   23.46
# Episode:    29		score:   34.00		average:   23.83
# Episode:    30		score:    9.00		average:   23.33
# Episode:    31		score:   19.00		average:   23.19
# Episode:    32		score:   13.00		average:   22.88
# Episode:    33		score:   26.00		average:   22.97
# Episode:    34		score:   20.00		average:   22.88
# Episode:    35		score:   12.00		average:   22.57
# Episode:    36		score:   20.00		average:   22.50
# Episode:    37		score:   13.00		average:   22.24
# Episode:    38		score:   11.00		average:   21.95
# Episode:    39		score:   19.00		average:   21.87
# Episode:    40		score:   21.00		average:   21.85
# Episode:    41		score:   10.00		average:   21.56
# Episode:    42		score:   16.00		average:   21.43
# Episode:    43		score:   11.00		average:   21.19
# Episode:    44		score:   11.00		average:   20.95
# Episode:    45		score:   27.00		average:   21.09
# Episode:    46		score:   19.00		average:   21.04
# Episode:    47		score:   24.00		average:   21.11
# Episode:    48		score:   14.00		average:   20.96
# Episode:    49		score:   11.00		average:   20.76
# Episode:    50		score:   17.00		average:   20.68
# Episode:    51		score:   11.00		average:   20.49
# Episode:    52		score:   11.00		average:   20.31
# Episode:    53		score:   11.00		average:   20.13
# Episode:    54		score:   21.00		average:   20.15
# Episode:    55		score:   23.00		average:   20.20
# Episode:    56		score:   10.00		average:   20.02
# Episode:    57		score:   14.00		average:   19.91
# Episode:    58		score:   25.00		average:   20.00
# Episode:    59		score:   35.00		average:   20.25
# Episode:    60		score:   24.00		average:   20.32
# Episode:    61		score:   17.00		average:   20.26
# Episode:    62		score:   15.00		average:   20.18
# Episode:    63		score:   21.00		average:   20.19
# Episode:    64		score:   16.00		average:   20.12
# Episode:    65		score:   17.00		average:   20.08
# Episode:    66		score:   19.00		average:   20.06
# Episode:    67		score:   10.00		average:   19.91
# Episode:    68		score:   14.00		average:   19.82
# Episode:    69		score:   21.00		average:   19.84
# Episode:    70		score:   12.00		average:   19.73
# Episode:    71		score:   19.00		average:   19.72
# Episode:    72		score:   35.00		average:   19.93
# Episode:    73		score:   14.00		average:   19.85
# Episode:    74		score:   16.00		average:   19.80
# Episode:    75		score:   11.00		average:   19.68
# Episode:    76		score:   15.00		average:   19.62
# Episode:    77		score:   16.00		average:   19.57
# Episode:    78		score:   11.00		average:   19.46
# Episode:    79		score:    9.00		average:   19.33
# Episode:    80		score:   10.00		average:   19.21
# Episode:    81		score:    9.00		average:   19.09
# Episode:    82		score:   32.00		average:   19.24
# Episode:    83		score:   23.00		average:   19.29
# Episode:    84		score:   20.00		average:   19.30
# Episode:    85		score:   18.00		average:   19.28
# Episode:    86		score:   16.00		average:   19.24
# Episode:    87		score:   17.00		average:   19.22
# Episode:    88		score:   21.00		average:   19.24
# Episode:    89		score:   11.00		average:   19.15
# Episode:    90		score:   11.00		average:   19.06
# Episode:    91		score:   12.00		average:   18.98
# Episode:    92		score:   28.00		average:   19.08
# Episode:    93		score:   18.00		average:   19.06
# Episode:    94		score:   11.00		average:   18.98
# Episode:    95		score:   28.00		average:   19.07
# Episode:    96		score:    9.00		average:   18.97
# Episode:    97		score:   14.00		average:   18.92
# Episode:    98		score:   11.00		average:   18.84
# Episode:    99		score:   23.00		average:   18.88
# Episode:   100		score:   11.00		average:   18.80
# Episode:   101		score:   15.00		average:   18.68
# Episode:   102		score:   15.00		average:   18.57
# Episode:   103		score:   18.00		average:   18.54
# Episode:   104		score:   14.00		average:   18.56
# Episode:   105		score:   14.00		average:   18.48
# Episode:   106		score:   10.00		average:   18.50
# Episode:   107		score:   12.00		average:   18.38
# Episode:   108		score:   13.00		average:   18.29
# Episode:   109		score:   20.00		average:   17.63
# Episode:   110		score:   24.00		average:   17.31
# Episode:   111		score:   13.00		average:   17.26
# Episode:   112		score:   12.00		average:   17.26
# Episode:   113		score:   11.00		average:   17.21
# Episode:   114		score:   21.00		average:   17.22
# Episode:   115		score:   15.00		average:   17.13
# Episode:   116		score:   27.00		average:   17.28
# Episode:   117		score:   12.00		average:   17.27
# Episode:   118		score:   13.00		average:   17.10
# Episode:   119		score:   16.00		average:   17.11
# Episode:   120		score:   24.00		average:   17.15
# Episode:   121		score:   11.00		average:   17.14
# Episode:   122		score:   41.00		average:   17.34
# Episode:   123		score:   23.00		average:   17.45
# Episode:   124		score:   11.00		average:   17.45
# Episode:   125		score:   12.00		average:   17.42
# Episode:   126		score:   23.00		average:   17.28
# Episode:   127		score:    9.00		average:   17.12
# Episode:   128		score:   25.00		average:   16.97
# Episode:   129		score:   18.00		average:   16.81
# Episode:   130		score:   23.00		average:   16.95
# Episode:   131		score:   10.00		average:   16.86
# Episode:   132		score:   18.00		average:   16.91
# Episode:   133		score:   25.00		average:   16.90
# Episode:   134		score:   10.00		average:   16.80
# Episode:   135		score:   17.00		average:   16.85
# Episode:   136		score:   33.00		average:   16.98
# Episode:   137		score:   17.00		average:   17.02
# Episode:   138		score:   11.00		average:   17.02
# Episode:   139		score:   18.00		average:   17.01
# Episode:   140		score:   13.00		average:   16.93
# Episode:   141		score:   26.00		average:   17.09
# Episode:   142		score:   13.00		average:   17.06
# Episode:   143		score:   11.00		average:   17.06
# Episode:   144		score:   34.00		average:   17.29
# Episode:   145		score:   22.00		average:   17.24
# Episode:   146		score:   28.00		average:   17.33
# Episode:   147		score:   14.00		average:   17.23
# Episode:   148		score:   29.00		average:   17.38
# Episode:   149		score:   11.00		average:   17.38
# Episode:   150		score:   27.00		average:   17.48
# Episode:   151		score:   48.00		average:   17.85
# Episode:   152		score:   24.00		average:   17.98
# Episode:   153		score:   11.00		average:   17.98
# Episode:   154		score:   55.00		average:   18.32
# Episode:   155		score:   12.00		average:   18.21
# Episode:   156		score:    9.00		average:   18.20
# Episode:   157		score:   11.00		average:   18.17
# Episode:   158		score:   15.00		average:   18.07
# Episode:   159		score:   11.00		average:   17.83
# Episode:   160		score:   17.00		average:   17.76
# Episode:   161		score:   16.00		average:   17.75
# Episode:   162		score:   18.00		average:   17.78
# Episode:   163		score:   23.00		average:   17.80
# Episode:   164		score:   22.00		average:   17.86
# Episode:   165		score:   10.00		average:   17.79
# Episode:   166		score:   12.00		average:   17.72
# Episode:   167		score:   55.00		average:   18.17
# Episode:   168		score:   17.00		average:   18.20
# Episode:   169		score:   15.00		average:   18.14
# Episode:   170		score:   23.00		average:   18.25
# Episode:   171		score:    9.00		average:   18.15
# Episode:   172		score:   19.00		average:   17.99
# Episode:   173		score:   11.00		average:   17.96
# Episode:   174		score:   16.00		average:   17.96
# Episode:   175		score:   40.00		average:   18.25
# Episode:   176		score:   27.00		average:   18.37
# Episode:   177		score:   21.00		average:   18.42
# Episode:   178		score:   20.00		average:   18.51
# Episode:   179		score:   12.00		average:   18.54
# Episode:   180		score:   15.00		average:   18.59
# Episode:   181		score:   19.00		average:   18.69
# Episode:   182		score:   25.00		average:   18.62
# Episode:   183		score:   16.00		average:   18.55
# Episode:   184		score:   19.00		average:   18.54
# Episode:   185		score:   24.00		average:   18.60
# Episode:   186		score:   14.00		average:   18.58
# Episode:   187		score:   10.00		average:   18.51
# Episode:   188		score:   26.00		average:   18.56
# Episode:   189		score:   16.00		average:   18.61
# Episode:   190		score:   31.00		average:   18.81
# Episode:   191		score:    8.00		average:   18.77
# Episode:   192		score:   13.00		average:   18.62
# Episode:   193		score:   22.00		average:   18.66
# Episode:   194		score:   14.00		average:   18.69
# Episode:   195		score:   11.00		average:   18.52
# Episode:   196		score:   13.00		average:   18.56
# Episode:   197		score:   13.00		average:   18.55
# Episode:   198		score:   30.00		average:   18.74
# Episode:   199		score:   20.00		average:   18.71
# Episode:   200		score:   53.00		average:   19.13
# Episode:   201		score:   27.00		average:   19.25
# Episode:   202		score:   12.00		average:   19.22
# Episode:   203		score:   38.00		average:   19.42
# Episode:   204		score:   22.00		average:   19.50
# Episode:   205		score:   12.00		average:   19.48
# Episode:   206		score:   17.00		average:   19.55
# Episode:   207		score:   17.00		average:   19.60
# Episode:   208		score:   12.00		average:   19.59
# Episode:   209		score:   16.00		average:   19.55
# Episode:   210		score:   19.00		average:   19.50
# Episode:   211		score:   17.00		average:   19.54
# Episode:   212		score:   19.00		average:   19.61
# Episode:   213		score:   18.00		average:   19.68
# Episode:   214		score:   16.00		average:   19.63
# Episode:   215		score:   25.00		average:   19.73
# Episode:   216		score:   31.00		average:   19.77
# Episode:   217		score:   23.00		average:   19.88
# Episode:   218		score:   19.00		average:   19.94
# Episode:   219		score:   13.00		average:   19.91
# Episode:   220		score:   29.00		average:   19.96
# Episode:   221		score:   22.00		average:   20.07
# Episode:   222		score:   39.00		average:   20.05
# Episode:   223		score:   31.00		average:   20.13
# Episode:   224		score:   24.00		average:   20.26
# Episode:   225		score:   18.00		average:   20.32
# Episode:   226		score:   16.00		average:   20.25
# Episode:   227		score:   16.00		average:   20.32
# Episode:   228		score:   23.00		average:   20.30
# Episode:   229		score:   25.00		average:   20.37
# Episode:   230		score:   12.00		average:   20.26
# Episode:   231		score:   19.00		average:   20.35
# Episode:   232		score:   14.00		average:   20.31
# Episode:   233		score:   21.00		average:   20.27
# Episode:   234		score:   24.00		average:   20.41
# Episode:   235		score:   26.00		average:   20.50
# Episode:   236		score:   19.00		average:   20.36
# Episode:   237		score:   43.00		average:   20.62
# Episode:   238		score:   12.00		average:   20.63
# Episode:   239		score:   20.00		average:   20.65
# Episode:   240		score:   14.00		average:   20.66
# Episode:   241		score:   11.00		average:   20.51
# Episode:   242		score:   48.00		average:   20.86
# Episode:   243		score:   19.00		average:   20.94
# Episode:   244		score:   22.00		average:   20.82
# Episode:   245		score:   25.00		average:   20.85
# Episode:   246		score:   15.00		average:   20.72
# Episode:   247		score:   32.00		average:   20.90
# Episode:   248		score:   33.00		average:   20.94
# Episode:   249		score:   25.00		average:   21.08
# Episode:   250		score:   15.00		average:   20.96
# Episode:   251		score:   34.00		average:   20.82
# Episode:   252		score:   14.00		average:   20.72
# Episode:   253		score:   21.00		average:   20.82
# Episode:   254		score:   50.00		average:   20.77
# Episode:   255		score:   12.00		average:   20.77
# Episode:   256		score:   13.00		average:   20.81
# Episode:   257		score:   43.00		average:   21.13
# Episode:   258		score:   39.00		average:   21.37
# Episode:   259		score:   13.00		average:   21.39
# Episode:   260		score:   11.00		average:   21.33
# Episode:   261		score:   32.00		average:   21.49
# Episode:   262		score:   31.00		average:   21.62
# Episode:   263		score:   10.00		average:   21.49
# Episode:   264		score:   43.00		average:   21.70
# Episode:   265		score:   16.00		average:   21.76
# Episode:   266		score:   15.00		average:   21.79
# Episode:   267		score:   39.00		average:   21.63
# Episode:   268		score:   19.00		average:   21.65
# Episode:   269		score:   58.00		average:   22.08
# Episode:   270		score:   18.00		average:   22.03
# Episode:   271		score:   22.00		average:   22.16
# Episode:   272		score:   18.00		average:   22.15
# Episode:   273		score:   21.00		average:   22.25
# Episode:   274		score:   17.00		average:   22.26
# Episode:   275		score:   19.00		average:   22.05
# Episode:   276		score:   30.00		average:   22.08
# Episode:   277		score:   13.00		average:   22.00
# Episode:   278		score:   17.00		average:   21.97
# Episode:   279		score:   26.00		average:   22.11
# Episode:   280		score:   17.00		average:   22.13
# Episode:   281		score:   31.00		average:   22.25
# Episode:   282		score:   17.00		average:   22.17
# Episode:   283		score:   10.00		average:   22.11
# Episode:   284		score:   23.00		average:   22.15
# Episode:   285		score:   30.00		average:   22.21
# Episode:   286		score:   23.00		average:   22.30
# Episode:   287		score:   21.00		average:   22.41
# Episode:   288		score:   13.00		average:   22.28
# Episode:   289		score:   14.00		average:   22.26
# Episode:   290		score:   16.00		average:   22.11
# Episode:   291		score:   22.00		average:   22.25
# Episode:   292		score:   25.00		average:   22.37
# Episode:   293		score:   13.00		average:   22.28
# Episode:   294		score:   30.00		average:   22.44
# Episode:   295		score:   21.00		average:   22.54
# Episode:   296		score:   17.00		average:   22.58
# Episode:   297		score:   23.00		average:   22.68
# Episode:   298		score:   24.00		average:   22.62
# Episode:   299		score:   42.00		average:   22.84
# Episode:   300		score:   25.00		average:   22.56
# Episode:   301		score:   31.00		average:   22.60
# Episode:   302		score:   16.00		average:   22.64
# Episode:   303		score:   10.00		average:   22.36
# Episode:   304		score:   20.00		average:   22.34
# Episode:   305		score:   16.00		average:   22.38
# Episode:   306		score:   43.00		average:   22.64
# Episode:   307		score:   16.00		average:   22.63
# Episode:   308		score:   27.00		average:   22.78
# Episode:   309		score:   18.00		average:   22.80
# Episode:   310		score:   31.00		average:   22.92
# Episode:   311		score:   18.00		average:   22.93
# Episode:   312		score:   22.00		average:   22.96
# Episode:   313		score:   42.00		average:   23.20
# Episode:   314		score:   19.00		average:   23.23
# Episode:   315		score:   28.00		average:   23.26
# Episode:   316		score:   14.00		average:   23.09
# Episode:   317		score:   10.00		average:   22.96
# Episode:   318		score:   55.00		average:   23.32
# Episode:   319		score:   29.00		average:   23.48
# Episode:   320		score:   12.00		average:   23.31
# Episode:   321		score:   47.00		average:   23.56
# Episode:   322		score:   21.00		average:   23.38
# Episode:   323		score:   11.00		average:   23.18
# Episode:   324		score:   14.00		average:   23.08
# Episode:   325		score:   13.00		average:   23.03
# Episode:   326		score:   23.00		average:   23.10
# Episode:   327		score:   22.00		average:   23.16
# Episode:   328		score:   14.00		average:   23.07
# Episode:   329		score:   13.00		average:   22.95
# Episode:   330		score:   20.00		average:   23.03
# Episode:   331		score:   19.00		average:   23.03
# Episode:   332		score:   47.00		average:   23.36
# Episode:   333		score:   11.00		average:   23.26
# Episode:   334		score:   15.00		average:   23.17
# Episode:   335		score:   23.00		average:   23.14
# Episode:   336		score:   17.00		average:   23.12
# Episode:   337		score:   12.00		average:   22.81
# Episode:   338		score:   15.00		average:   22.84
# Episode:   339		score:   17.00		average:   22.81
# Episode:   340		score:   28.00		average:   22.95
# Episode:   341		score:   20.00		average:   23.04
# Episode:   342		score:   19.00		average:   22.75
# Episode:   343		score:   53.00		average:   23.09
# Episode:   344		score:   30.00		average:   23.17
# Episode:   345		score:   16.00		average:   23.08
# Episode:   346		score:   23.00		average:   23.16
# Episode:   347		score:   12.00		average:   22.96
# Episode:   348		score:   16.00		average:   22.79
# Episode:   349		score:   11.00		average:   22.65
# Episode:   350		score:   21.00		average:   22.71
# Episode:   351		score:   14.00		average:   22.51
# Episode:   352		score:   17.00		average:   22.54
# Episode:   353		score:   17.00		average:   22.50
# Episode:   354		score:   35.00		average:   22.35
# Episode:   355		score:   23.00		average:   22.46
# Episode:   356		score:   23.00		average:   22.56
# Episode:   357		score:   14.00		average:   22.27
# Episode:   358		score:   10.00		average:   21.98
# Episode:   359		score:   25.00		average:   22.10
# Episode:   360		score:   12.00		average:   22.11
# Episode:   361		score:   10.00		average:   21.89
# Episode:   362		score:   13.00		average:   21.71
# Episode:   363		score:   26.00		average:   21.87
# Episode:   364		score:   17.00		average:   21.61
# Episode:   365		score:   20.00		average:   21.65
# Episode:   366		score:   17.00		average:   21.67
# Episode:   367		score:   13.00		average:   21.41
# Episode:   368		score:   24.00		average:   21.46
# Episode:   369		score:   22.00		average:   21.10
# Episode:   370		score:   17.00		average:   21.09
# Episode:   371		score:   16.00		average:   21.03
# Episode:   372		score:   21.00		average:   21.06
# Episode:   373		score:   11.00		average:   20.96
# Episode:   374		score:   24.00		average:   21.03
# Episode:   375		score:   20.00		average:   21.04
# Episode:   376		score:   43.00		average:   21.17
# Episode:   377		score:   14.00		average:   21.18
# Episode:   378		score:   14.00		average:   21.15
# Episode:   379		score:   25.00		average:   21.14
# Episode:   380		score:   14.00		average:   21.11
# Episode:   381		score:   23.00		average:   21.03
# Episode:   382		score:   53.00		average:   21.39
# Episode:   383		score:   21.00		average:   21.50
# Episode:   384		score:   14.00		average:   21.41
# Episode:   385		score:   18.00		average:   21.29
# Episode:   386		score:   29.00		average:   21.35
# Episode:   387		score:   14.00		average:   21.28
# Episode:   388		score:   25.00		average:   21.40
# Episode:   389		score:   27.00		average:   21.53
# Episode:   390		score:   51.00		average:   21.88
# Episode:   391		score:   50.00		average:   22.16
# Episode:   392		score:   36.00		average:   22.27
# Episode:   393		score:   48.00		average:   22.62
# Episode:   394		score:   12.00		average:   22.44
# Episode:   395		score:   12.00		average:   22.35
# Episode:   396		score:   10.00		average:   22.28
# Episode:   397		score:   50.00		average:   22.55
# Episode:   398		score:   13.00		average:   22.44
# Episode:   399		score:   34.00		average:   22.36
# Episode:   400		score:   20.00		average:   22.31
# Episode:   401		score:   20.00		average:   22.20
# Episode:   402		score:   13.00		average:   22.17
# Episode:   403		score:   16.00		average:   22.23
# Episode:   404		score:   32.00		average:   22.35
# Episode:   405		score:   14.00		average:   22.33
# Episode:   406		score:   19.00		average:   22.09
# Episode:   407		score:   14.00		average:   22.07
# Episode:   408		score:   11.00		average:   21.91
# Episode:   409		score:   51.00		average:   22.24
# Episode:   410		score:   12.00		average:   22.05
# Episode:   411		score:   33.00		average:   22.20
# Episode:   412		score:   31.00		average:   22.29
# Episode:   413		score:   34.00		average:   22.21
# Episode:   414		score:   17.00		average:   22.19
# Episode:   415		score:   72.00		average:   22.63
# Episode:   416		score:   32.00		average:   22.81
# Episode:   417		score:   18.00		average:   22.89
# Episode:   418		score:   21.00		average:   22.55
# Episode:   419		score:   25.00		average:   22.51
# Episode:   420		score:   19.00		average:   22.58
# Episode:   421		score:   37.00		average:   22.48
# Episode:   422		score:   39.00		average:   22.66
# Episode:   423		score:   20.00		average:   22.75
# Episode:   424		score:   32.00		average:   22.93
# Episode:   425		score:   22.00		average:   23.02
# Episode:   426		score:   50.00		average:   23.29
# Episode:   427		score:   29.00		average:   23.36
# Episode:   428		score:   12.00		average:   23.34
# Episode:   429		score:   27.00		average:   23.48
# Episode:   430		score:   21.00		average:   23.49
# Episode:   431		score:   15.00		average:   23.45
# Episode:   432		score:   22.00		average:   23.20
# Episode:   433		score:   18.00		average:   23.27
# Episode:   434		score:   13.00		average:   23.25
# Episode:   435		score:   17.00		average:   23.19
# Episode:   436		score:   27.00		average:   23.29
# Episode:   437		score:   24.00		average:   23.41
# Episode:   438		score:   24.00		average:   23.50
# Episode:   439		score:   37.00		average:   23.70
# Episode:   440		score:   48.00		average:   23.90
# Episode:   441		score:   31.00		average:   24.01
# Episode:   442		score:   49.00		average:   24.31
# Episode:   443		score:   13.00		average:   23.91
# Episode:   444		score:   15.00		average:   23.76
# Episode:   445		score:   20.00		average:   23.80
# Episode:   446		score:   15.00		average:   23.72
# Episode:   447		score:   32.00		average:   23.92
# Episode:   448		score:   30.00		average:   24.06
# Episode:   449		score:   10.00		average:   24.05
# Episode:   450		score:   14.00		average:   23.98
# Episode:   451		score:   49.00		average:   24.33
# Episode:   452		score:   59.00		average:   24.75
# Episode:   453		score:   15.00		average:   24.73
# Episode:   454		score:   21.00		average:   24.59
# Episode:   455		score:   45.00		average:   24.81
# Episode:   456		score:   12.00		average:   24.70
# Episode:   457		score:   18.00		average:   24.74
# Episode:   458		score:   20.00		average:   24.84
# Episode:   459		score:   32.00		average:   24.91
# Episode:   460		score:   16.00		average:   24.95
# Episode:   461		score:   25.00		average:   25.10
# Episode:   462		score:   12.00		average:   25.09
# Episode:   463		score:   17.00		average:   25.00
# Episode:   464		score:   20.00		average:   25.03
# Episode:   465		score:   12.00		average:   24.95
# Episode:   466		score:   16.00		average:   24.94
# Episode:   467		score:   25.00		average:   25.06
# Episode:   468		score:  123.00		average:   26.05
# Episode:   469		score:   13.00		average:   25.96
# Episode:   470		score:   15.00		average:   25.94
# Episode:   471		score:   29.00		average:   26.07
# Episode:   472		score:   16.00		average:   26.02
# Episode:   473		score:   18.00		average:   26.09
# Episode:   474		score:   18.00		average:   26.03
# Episode:   475		score:   21.00		average:   26.04
# Episode:   476		score:   21.00		average:   25.82
# Episode:   477		score:   12.00		average:   25.80
# Episode:   478		score:   16.00		average:   25.82
# Episode:   479		score:   42.00		average:   25.99
# Episode:   480		score:   14.00		average:   25.99
# Episode:   481		score:   22.00		average:   25.98
# Episode:   482		score:   20.00		average:   25.65
# Episode:   483		score:   25.00		average:   25.69
# Episode:   484		score:   16.00		average:   25.71
# Episode:   485		score:   25.00		average:   25.78
# Episode:   486		score:   12.00		average:   25.61
# Episode:   487		score:   37.00		average:   25.84
# Episode:   488		score:   16.00		average:   25.75
# Episode:   489		score:   15.00		average:   25.63
# Episode:   490		score:   22.00		average:   25.34
# Episode:   491		score:   41.00		average:   25.25
# Episode:   492		score:   12.00		average:   25.01
# Episode:   493		score:   10.00		average:   24.63
# Episode:   494		score:   12.00		average:   24.63
# Episode:   495		score:   79.00		average:   25.30
# Episode:   496		score:   12.00		average:   25.32
# Episode:   497		score:   78.00		average:   25.60
# Episode:   498		score:   53.00		average:   26.00
# Episode:   499		score:   36.00		average:   26.02
# Episode:   500		score:   35.00		average:   26.17
# Episode:   501		score:   34.00		average:   26.31
# Episode:   502		score:   15.00		average:   26.33
# Episode:   503		score:   25.00		average:   26.42
# Episode:   504		score:   33.00		average:   26.43
# Episode:   505		score:   17.00		average:   26.46
# Episode:   506		score:   27.00		average:   26.54
# Episode:   507		score:   21.00		average:   26.61
# Episode:   508		score:   25.00		average:   26.75
# Episode:   509		score:   20.00		average:   26.44
# Episode:   510		score:   18.00		average:   26.50
# Episode:   511		score:   55.00		average:   26.72
# Episode:   512		score:   14.00		average:   26.55
# Episode:   513		score:   25.00		average:   26.46
# Episode:   514		score:   26.00		average:   26.55
# Episode:   515		score:   37.00		average:   26.20
# Episode:   516		score:   19.00		average:   26.07
# Episode:   517		score:   33.00		average:   26.22
# Episode:   518		score:   98.00		average:   26.99
# Episode:   519		score:   24.00		average:   26.98
# Episode:   520		score:   38.00		average:   27.17
# Episode:   521		score:   26.00		average:   27.06
# Episode:   522		score:   23.00		average:   26.90
# Episode:   523		score:   13.00		average:   26.83
# Episode:   524		score:   39.00		average:   26.90
# Episode:   525		score:   20.00		average:   26.88
# Episode:   526		score:   19.00		average:   26.57
# Episode:   527		score:   14.00		average:   26.42
# Episode:   528		score:   19.00		average:   26.49
# Episode:   529		score:   26.00		average:   26.48
# Episode:   530		score:   54.00		average:   26.81
# Episode:   531		score:   16.00		average:   26.82
# Episode:   532		score:   15.00		average:   26.75
# Episode:   533		score:   53.00		average:   27.10
# Episode:   534		score:   15.00		average:   27.12
# Episode:   535		score:   52.00		average:   27.47
# Episode:   536		score:   63.00		average:   27.83
# Episode:   537		score:   20.00		average:   27.79
# Episode:   538		score:   18.00		average:   27.73
# Episode:   539		score:   68.00		average:   28.04
# Episode:   540		score:   21.00		average:   27.77
# Episode:   541		score:  117.00		average:   28.63
# Episode:   542		score:   32.00		average:   28.46
# Episode:   543		score:   16.00		average:   28.49
# Episode:   544		score:   54.00		average:   28.88
# Episode:   545		score:   47.00		average:   29.15
# Episode:   546		score:   30.00		average:   29.30
# Episode:   547		score:   29.00		average:   29.27
# Episode:   548		score:   37.00		average:   29.34
# Episode:   549		score:   44.00		average:   29.68
# Episode:   550		score:   47.00		average:   30.01
# Episode:   551		score:   53.00		average:   30.05
# Episode:   552		score:   12.00		average:   29.58
# Episode:   553		score:   96.00		average:   30.39
# Episode:   554		score:   29.00		average:   30.47
# Episode:   555		score:   36.00		average:   30.38
# Episode:   556		score:   52.00		average:   30.78
# Episode:   557		score:   64.00		average:   31.24
# Episode:   558		score:   49.00		average:   31.53
# Episode:   559		score:   35.00		average:   31.56
# Episode:   560		score:   27.00		average:   31.67
# Episode:   561		score:   44.00		average:   31.86
# Episode:   562		score:   47.00		average:   32.21
# Episode:   563		score:   40.00		average:   32.44
# Episode:   564		score:  100.00		average:   33.24
# Episode:   565		score:   22.00		average:   33.34
# Episode:   566		score:   29.00		average:   33.47
# Episode:   567		score:   22.00		average:   33.44
# Episode:   568		score:   16.00		average:   32.37
# Episode:   569		score:   97.00		average:   33.21
# Episode:   570		score:   50.00		average:   33.56
# Episode:   571		score:   59.00		average:   33.86
# Episode:   572		score:   37.00		average:   34.07
# Episode:   573		score:   47.00		average:   34.36
# Episode:   574		score:  114.00		average:   35.32
# Episode:   575		score:   14.00		average:   35.25
# Episode:   576		score:   12.00		average:   35.16
# Episode:   577		score:   33.00		average:   35.37
# Episode:   578		score:   29.00		average:   35.50
# Episode:   579		score:   28.00		average:   35.36
# Episode:   580		score:   24.00		average:   35.46
# Episode:   581		score:   39.00		average:   35.63
# Episode:   582		score:   31.00		average:   35.74
# Episode:   583		score:   33.00		average:   35.82
# Episode:   584		score:  134.00		average:   37.00
# Episode:   585		score:   89.00		average:   37.64
# Episode:   586		score:   44.00		average:   37.96
# Episode:   587		score:   76.00		average:   38.35
# Episode:   588		score:   35.00		average:   38.54
# Episode:   589		score:   68.00		average:   39.07
# Episode:   590		score:   34.00		average:   39.19
# Episode:   591		score:   78.00		average:   39.56
# Episode:   592		score:   21.00		average:   39.65
# Episode:   593		score:   67.00		average:   40.22
# Episode:   594		score:   30.00		average:   40.40
# Episode:   595		score:   31.00		average:   39.92
# Episode:   596		score:   41.00		average:   40.21
# Episode:   597		score:   76.00		average:   40.19
# Episode:   598		score:   49.00		average:   40.15
# Episode:   599		score:   31.00		average:   40.10
# Episode:   600		score:   20.00		average:   39.95
# Episode:   601		score:   32.00		average:   39.93
# Episode:   602		score:   21.00		average:   39.99
# Episode:   603		score:   69.00		average:   40.43
# Episode:   604		score:   22.00		average:   40.32
# Episode:   605		score:   29.00		average:   40.44
# Episode:   606		score:   19.00		average:   40.36
# Episode:   607		score:   25.00		average:   40.40
# Episode:   608		score:   19.00		average:   40.34
# Episode:   609		score:   70.00		average:   40.84
# Episode:   610		score:   40.00		average:   41.06
# Episode:   611		score:   40.00		average:   40.91
# Episode:   612		score:   57.00		average:   41.34
# Episode:   613		score:   19.00		average:   41.28
# Episode:   614		score:   18.00		average:   41.20
# Episode:   615		score:   15.00		average:   40.98
# Episode:   616		score:   40.00		average:   41.19
# Episode:   617		score:   27.00		average:   41.13
# Episode:   618		score:   53.00		average:   40.68
# Episode:   619		score:   38.00		average:   40.82
# Episode:   620		score:   48.00		average:   40.92
# Episode:   621		score:   61.00		average:   41.27
# Episode:   622		score:   55.00		average:   41.59
# Episode:   623		score:   17.00		average:   41.63
# Episode:   624		score:  102.00		average:   42.26
# Episode:   625		score:   15.00		average:   42.21
# Episode:   626		score:   51.00		average:   42.53
# Episode:   627		score:   44.00		average:   42.83
# Episode:   628		score:   60.00		average:   43.24
# Episode:   629		score:   43.00		average:   43.41
# Episode:   630		score:   23.00		average:   43.10
# Episode:   631		score:   67.00		average:   43.61
# Episode:   632		score:   26.00		average:   43.72
# Episode:   633		score:  102.00		average:   44.21
# Episode:   634		score:   56.00		average:   44.62
# Episode:   635		score:   61.00		average:   44.71
# Episode:   636		score:   34.00		average:   44.42
# Episode:   637		score:   34.00		average:   44.56
# Episode:   638		score:   51.00		average:   44.89
# Episode:   639		score:   92.00		average:   45.13
# Episode:   640		score:   66.00		average:   45.58
# Episode:   641		score:   35.00		average:   44.76
# Episode:   642		score:   66.00		average:   45.10
# Episode:   643		score:   28.00		average:   45.22
# Episode:   644		score:   43.00		average:   45.11
# Episode:   645		score:   39.00		average:   45.03
# Episode:   646		score:   86.00		average:   45.59
# Episode:   647		score:  137.00		average:   46.67
# Episode:   648		score:   68.00		average:   46.98
# Episode:   649		score:  145.00		average:   47.99
# Episode:   650		score:  106.00		average:   48.58
# Episode:   651		score:   93.00		average:   48.98
# Episode:   652		score:   38.00		average:   49.24
# Episode:   653		score:   19.00		average:   48.47
# Episode:   654		score:   70.00		average:   48.88
# Episode:   655		score:  172.00		average:   50.24
# Episode:   656		score:   89.00		average:   50.61
# Episode:   657		score:   65.00		average:   50.62
# Episode:   658		score:   27.00		average:   50.40
# Episode:   659		score:  126.00		average:   51.31
# Episode:   660		score:   85.00		average:   51.89
# Episode:   661		score:   50.00		average:   51.95
# Episode:   662		score:   38.00		average:   51.86
# Episode:   663		score:   69.00		average:   52.15
# Episode:   664		score:   36.00		average:   51.51
# Episode:   665		score:  114.00		average:   52.43
# Episode:   666		score:   49.00		average:   52.63
# Episode:   667		score:   84.00		average:   53.25
# Episode:   668		score:   31.00		average:   53.40
# Episode:   669		score:   69.00		average:   53.12
# Episode:   670		score:   43.00		average:   53.05
# Episode:   671		score:  104.00		average:   53.50
# Episode:   672		score:   89.00		average:   54.02
# Episode:   673		score:   73.00		average:   54.28
# Episode:   674		score:   50.00		average:   53.64
# Episode:   675		score:   77.00		average:   54.27
# Episode:   676		score:   41.00		average:   54.56
# Episode:   677		score:   52.00		average:   54.75
# Episode:   678		score:   48.00		average:   54.94
# Episode:   679		score:   55.00		average:   55.21
# Episode:   680		score:   74.00		average:   55.71
# Episode:   681		score:   92.00		average:   56.24
# Episode:   682		score:   41.00		average:   56.34
# Episode:   683		score:   64.00		average:   56.65
# Episode:   684		score:   30.00		average:   55.61
# Episode:   685		score:   83.00		average:   55.55
# Episode:   686		score:   35.00		average:   55.46
# Episode:   687		score:   41.00		average:   55.11
# Episode:   688		score:   73.00		average:   55.49
# Episode:   689		score:   33.00		average:   55.14
# Episode:   690		score:   17.00		average:   54.97
# Episode:   691		score:   33.00		average:   54.52
# Episode:   692		score:  131.00		average:   55.62
# Episode:   693		score:  138.00		average:   56.33
# Episode:   694		score:  114.00		average:   57.17
# Episode:   695		score:   45.00		average:   57.31
# Episode:   696		score:  127.00		average:   58.17
# Episode:   697		score:   15.00		average:   57.56
# Episode:   698		score:  174.00		average:   58.81
# Episode:   699		score:  113.00		average:   59.63
# Episode:   700		score:   60.00		average:   60.03
# Episode:   701		score:   93.00		average:   60.64
# Episode:   702		score:   76.00		average:   61.19
# Episode:   703		score:  159.00		average:   62.09
# Episode:   704		score:   26.00		average:   62.13
# Episode:   705		score:  101.00		average:   62.85
# Episode:   706		score:  127.00		average:   63.93
# Episode:   707		score:  169.00		average:   65.37
# Episode:   708		score:   87.00		average:   66.05
# Episode:   709		score:   54.00		average:   65.89
# Episode:   710		score:  179.00		average:   67.28
# Episode:   711		score:  119.00		average:   68.07
# Episode:   712		score:   38.00		average:   67.88
# Episode:   713		score:  188.00		average:   69.57
# Episode:   714		score:  134.00		average:   70.73
# Episode:   715		score:  165.00		average:   72.23
# Episode:   716		score:  141.00		average:   73.24
# Episode:   717		score:   24.00		average:   73.21
# Episode:   718		score:  161.00		average:   74.29
# Episode:   719		score:  108.00		average:   74.99
# Episode:   720		score:  103.00		average:   75.54
# Episode:   721		score:   94.00		average:   75.87
# Episode:   722		score:  165.00		average:   76.97
# Episode:   723		score:   69.00		average:   77.49
# Episode:   724		score:   24.00		average:   76.71
# Episode:   725		score:   94.00		average:   77.50
# Episode:   726		score:   23.00		average:   77.22
# Episode:   727		score:  122.00		average:   78.00
# Episode:   728		score:  133.00		average:   78.73
# Episode:   729		score:  165.00		average:   79.95
# Episode:   730		score:  132.00		average:   81.04
# Episode:   731		score:  159.00		average:   81.96
# Episode:   732		score:  106.00		average:   82.76
# Episode:   733		score:  117.00		average:   82.91
# Episode:   734		score:  182.00		average:   84.17
# Episode:   735		score:   61.00		average:   84.17
# Episode:   736		score:   27.00		average:   84.10
# Episode:   737		score:   33.00		average:   84.09
# Episode:   738		score:  102.00		average:   84.60
# Episode:   739		score:  200.00		average:   85.68
# Episode:   740		score:   68.00		average:   85.70
# Episode:   741		score:  200.00		average:   87.35
# Episode:   742		score:   36.00		average:   87.05
# Episode:   743		score:   93.00		average:   87.70
# Episode:   744		score:  131.00		average:   88.58
# Episode:   745		score:   45.00		average:   88.64
# Episode:   746		score:  133.00		average:   89.11
# Episode:   747		score:  165.00		average:   89.39
# Episode:   748		score:  173.00		average:   90.44
# Episode:   749		score:   75.00		average:   89.74
# Episode:   750		score:  182.00		average:   90.50
# Episode:   751		score:   80.00		average:   90.37
# Episode:   752		score:   57.00		average:   90.56
# Episode:   753		score:  104.00		average:   91.41
# Episode:   754		score:  180.00		average:   92.51
# Episode:   755		score:   71.00		average:   91.50
# Episode:   756		score:  138.00		average:   91.99
# Episode:   757		score:   58.00		average:   91.92
# Episode:   758		score:  159.00		average:   93.24
# Episode:   759		score:   65.00		average:   92.63
# Episode:   760		score:   56.00		average:   92.34
# Episode:   761		score:   51.00		average:   92.35
# Episode:   762		score:  128.00		average:   93.25
# Episode:   763		score:  200.00		average:   94.56
# Episode:   764		score:  200.00		average:   96.20
# Episode:   765		score:  200.00		average:   97.06
# Episode:   766		score:   64.00		average:   97.21
# Episode:   767		score:  174.00		average:   98.11
# Episode:   768		score:  148.00		average:   99.28
# Episode:   769		score:  200.00		average:  100.59
# Episode:   770		score:   58.00		average:  100.74
# Episode:   771		score:  200.00		average:  101.70
# Episode:   772		score:  166.00		average:  102.47
# Episode:   773		score:  200.00		average:  103.74
# Episode:   774		score:  121.00		average:  104.45
# Episode:   775		score:  200.00		average:  105.68
# Episode:   776		score:  130.00		average:  106.57
# Episode:   777		score:  200.00		average:  108.05
# Episode:   778		score:  167.00		average:  109.24
# Episode:   779		score:   91.00		average:  109.60
# Episode:   780		score:  197.00		average:  110.83
# Episode:   781		score:  181.00		average:  111.72
# Episode:   782		score:  200.00		average:  113.31
# Episode:   783		score:  123.00		average:  113.90
# Episode:   784		score:  200.00		average:  115.60
# Episode:   785		score:  200.00		average:  116.77
# Episode:   786		score:  200.00		average:  118.42
# Episode:   787		score:  131.00		average:  119.32
# Episode:   788		score:  148.00		average:  120.07
# Episode:   789		score:  175.00		average:  121.49
# Episode:   790		score:   93.00		average:  122.25
# Episode:   791		score:  200.00		average:  123.92
# Episode:   792		score:  200.00		average:  124.61
# Episode:   793		score:  119.00		average:  124.42
# Episode:   794		score:  200.00		average:  125.28
# Episode:   795		score:  187.00		average:  126.70
# Episode:   796		score:  200.00		average:  127.43
# Episode:   797		score:  180.00		average:  129.08
# Episode:   798		score:  193.00		average:  129.27
# Episode:   799		score:  200.00		average:  130.14
# Episode:   800		score:  171.00		average:  131.25
# Episode:   801		score:  174.00		average:  132.06
# Episode:   802		score:  200.00		average:  133.30
# Episode:   803		score:  200.00		average:  133.71
# Episode:   804		score:  200.00		average:  135.45
# Episode:   805		score:  169.00		average:  136.13
# Episode:   806		score:  200.00		average:  136.86
# Episode:   807		score:  200.00		average:  137.17
# Episode:   808		score:  200.00		average:  138.30
# Episode:   809		score:  200.00		average:  139.76
# Episode:   810		score:  200.00		average:  139.97
# Episode:   811		score:  176.00		average:  140.54
# Episode:   812		score:  200.00		average:  142.16
# Episode:   813		score:  174.00		average:  142.02
# Episode:   814		score:  200.00		average:  142.68
# Episode:   815		score:  200.00		average:  143.03
# Episode:   816		score:  200.00		average:  143.62
# Episode:   817		score:  200.00		average:  145.38
# Episode:   818		score:  200.00		average:  145.77
# Episode:   819		score:  200.00		average:  146.69
# Episode:   820		score:  200.00		average:  147.66
# Episode:   821		score:  200.00		average:  148.72
# Episode:   822		score:  200.00		average:  149.07
# Episode:   823		score:  152.00		average:  149.90
# Episode:   824		score:  144.00		average:  151.10
# Episode:   825		score:  200.00		average:  152.16
# Episode:   826		score:  200.00		average:  153.93
# Episode:   827		score:  200.00		average:  154.71
# Episode:   828		score:  200.00		average:  155.38
# Episode:   829		score:  200.00		average:  155.73
# Episode:   830		score:  200.00		average:  156.41
# Episode:   831		score:  200.00		average:  156.82
# Episode:   832		score:  200.00		average:  157.76
# Episode:   833		score:  200.00		average:  158.59
# Episode:   834		score:  200.00		average:  158.77
# Episode:   835		score:  200.00		average:  160.16
# Episode:   836		score:  200.00		average:  161.89
# Episode:   837		score:  200.00		average:  163.56
# Episode:   838		score:  200.00		average:  164.54
# Episode:   839		score:  200.00		average:  164.54
# Episode:   840		score:  200.00		average:  165.86
# Episode:   841		score:  200.00		average:  165.86
# Episode:   842		score:  200.00		average:  167.50
# Episode:   843		score:  200.00		average:  168.57
# Episode:   844		score:  200.00		average:  169.26
# Episode:   845		score:  200.00		average:  170.81
# Episode:   846		score:  200.00		average:  171.48
# Episode:   847		score:  200.00		average:  171.83
# Episode:   848		score:  200.00		average:  172.10
# Episode:   849		score:  200.00		average:  173.35
# Episode:   850		score:  200.00		average:  173.53
# Episode:   851		score:  200.00		average:  174.73
# Episode:   852		score:  200.00		average:  176.16
# Episode:   853		score:  200.00		average:  177.12
# Episode:   854		score:  200.00		average:  177.32
# Episode:   855		score:  200.00		average:  178.61
# Episode:   856		score:  200.00		average:  179.23
# Episode:   857		score:  200.00		average:  180.65
# Episode:   858		score:  200.00		average:  181.06
# Episode:   859		score:  200.00		average:  182.41
# Episode:   860		score:  200.00		average:  183.85
# Episode:   861		score:  200.00		average:  185.34
# Episode:   862		score:  200.00		average:  186.06
# Episode:   863		score:  200.00		average:  186.06
# Episode:   864		score:  200.00		average:  186.06
# Episode:   865		score:  200.00		average:  186.06
# Episode:   866		score:  200.00		average:  187.42
# Episode:   867		score:  200.00		average:  187.68
# Episode:   868		score:  200.00		average:  188.20
# Episode:   869		score:  200.00		average:  188.20
# Episode:   870		score:  172.00		average:  189.34
# Episode:   871		score:  200.00		average:  189.34
# Episode:   872		score:  200.00		average:  189.68
# Episode:   873		score:  200.00		average:  189.68
# Episode:   874		score:  200.00		average:  190.47
# Episode:   875		score:  200.00		average:  190.47
# Episode:   876		score:  197.00		average:  191.14
# Episode:   877		score:  200.00		average:  191.14
# Episode:   878		score:  200.00		average:  191.47
# Episode:   879		score:  200.00		average:  192.56
# Episode:   880		score:  200.00		average:  192.59
# Episode:   881		score:  166.00		average:  192.44
# Episode:   882		score:  200.00		average:  192.44
# Episode:   883		score:  200.00		average:  193.21
# Episode:   884		score:  200.00		average:  193.21
# Episode:   885		score:  200.00		average:  193.21
# Episode:   886		score:  200.00		average:  193.21
# Episode:   887		score:  195.00		average:  193.85
# Episode:   888		score:  167.00		average:  194.04
# Episode:   889		score:  200.00		average:  194.29
# Episode:   890		score:  200.00		average:  195.36
# 1.9760790944099427
