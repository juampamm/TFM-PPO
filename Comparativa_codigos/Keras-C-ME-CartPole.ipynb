# %%
import os

import random
import gym
import pylab
import numpy as np
import tensorflow as tf
import time
import matplotlib.pyplot as plt

#tf.config.experimental_run_functions_eagerly(True)
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import backend as K
import copy

NUM_ENVS = 8
EPISODES = 10000 # Number of times the enviroment is ran
LOSS_CLIPPING = 0.2 # Approximated values stated in the original paper
ENTROPY_LOSS = 0 # Epochs to train the network (recommended between 3 and 30)
LR = 0.02 # Learning rate 
NUM_ACTIONS = 2 # Number of possible action in the environment
NUM_STATES = 4 # Number of possible states in the exvironment
EPOCHS = 10 # Epochs to train the network (recommended between 3 and 30)
BATCH_SIZE = 64 # Batch size for the neural nets
BUFFER_SIZE = 256 # Buffer of experiences
SHUFFLE = True # Whether to shuffle data or not while training
OPTIMIZER = Adam # Optimizer for both actor and critic
GAMMA = 0.99 # Used for the estimated reward
LAMBDA = 0.95 # Used in the original paper un the GAE
NORMALIZE = True # Whether to normalize GAE or not


# Create the actor used to select the action given an state
class Actor_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(128, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X_input)
        X = Dense(128, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X)
        X = Dense(128, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X)
        
        # Softmax as there are different probabilities depending on the action
        output = Dense(NUM_ACTIONS, activation="softmax")(X)
        
        # Compile the model with the custom loss
        self.model = Model(inputs = X_input, outputs = output)
        self.model.compile(loss=self.ppo_loss, optimizer=OPTIMIZER(lr=LR))

    # Custom loss functions for the PPO
    def ppo_loss(self, y_true, y_pred):
        # Unpack the elements given in the true label
        advantages, true_label, actions = y_true[:, :1], y_true[:, 1:1+NUM_ACTIONS], y_true[:, 1+NUM_ACTIONS:]
        
        prob = actions * y_pred
        old_prob = actions * true_label 

        ratio = K.exp(K.log(prob + 1e-10) - K.log(old_prob + 1e-10))
        
        p1 = ratio * advantages
        p2 = K.clip(ratio, min_value=1 - LOSS_CLIPPING, max_value=1 + LOSS_CLIPPING) * advantages

        actor_loss = -K.mean(K.minimum(p1, p2))

        entropy = -(y_pred * K.log(y_pred + 1e-10))
        entropy = ENTROPY_LOSS * K.mean(entropy)
        
        total_loss = actor_loss - entropy

        return total_loss

# Create the critic which will criticise how the actor is performing    
class Critic_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(128, activation="relu", kernel_initializer='he_uniform')(X_input)
        X = Dense(128, activation="relu", kernel_initializer='he_uniform')(X)
        X = Dense(128, activation="relu", kernel_initializer='he_uniform')(X)
        
        # Linear output to know how good the action is
        value = Dense(1)(X)
        
        # Compile it with mse loss and gradient descent
        self.model = Model(inputs=X_input, outputs = value)
        self.model.compile(loss='mse', optimizer=OPTIMIZER(lr=LR))

# Combine both Actor and Critic to create the agent
class PPOAgent:
    def __init__(self, env_name):
        # Environment parameters
        self.env_name = env_name       
        self.env = gym.vector.make("CartPole-v0", num_envs=NUM_ENVS)
        self.episode = 0 # used to track current number episoded since start
        self.max_average = 0 # record max average reached
        
        # Used to plot a grapgh of the train process
        self.scores_, self.average_ = [], []

        # Create Actor-Critic network models
        self.Actor = Actor_Model()
        self.Critic = Critic_Model()
    
        # Names for the models
        self.Actor_name = f"{self.env_name}_PPO_Actor.h5"
        self.Critic_name = f"{self.env_name}_PPO_Critic.h5"

    # Get the action given the current state    
    def act(self, state):
        # Use the network to predict the next action to take, using the model
        prediction = self.Actor.model.predict(state)

        # Probability based to choose the action
        action = [np.random.choice(NUM_ACTIONS, p=pred) for pred in prediction]

        action_onehot = np.zeros([NUM_ENVS, NUM_ACTIONS])
        for ii in range(NUM_ENVS):
            action_onehot[ii][action[ii]] = 1

        return action, action_onehot, prediction

    # Generalized Advantage Estimation implemented in the original paper
    def get_gaes(self, rewards, dones, values, next_values):
        # Dones are used to track when is the final step of an episode, so next values are no applied
        deltas = [r + GAMMA * (1 - d) * nv - v for r, d, nv, v in zip(rewards, dones, next_values, values)]
        
        # Convert list to array as .mean() and .std() are used later
        deltas = np.stack(deltas)
        gaes = copy.deepcopy(deltas)
        
        for t in reversed(range(len(deltas) - 1)):
            gaes[t] = gaes[t] + (1 - dones[t]) * GAMMA * LAMBDA * gaes[t + 1]

        target = gaes + values
        if NORMALIZE:
            gaes = (gaes - gaes.mean()) / (gaes.std() + 1e-8)
        return np.vstack(gaes), np.vstack(target)

    def replay(self, states, actions, rewards, predictions, dones, next_states):

        # Reshape memory to appropriate shape for training
        states = np.reshape(states, (BUFFER_SIZE*NUM_ENVS, NUM_STATES))
        next_states = np.reshape(next_states, (BUFFER_SIZE*NUM_ENVS, NUM_STATES))
        actions = np.reshape(actions, (BUFFER_SIZE*NUM_ENVS, NUM_ACTIONS))
        predictions = np.reshape(predictions, (BUFFER_SIZE*NUM_ENVS, NUM_ACTIONS))
        rewards = np.reshape(rewards, (BUFFER_SIZE*NUM_ENVS,))
        dones = np.reshape(dones, (BUFFER_SIZE*NUM_ENVS,))
        
        # Get Critic network predictions for state and next state
        values = self.Critic.model.predict(states)
        next_values = self.Critic.model.predict(next_states)
        
        # Get the advantage
        advantages_list = []
        target_list = []
        for ii in range(1, NUM_ENVS+1):
            advantages, target = self.get_gaes(rewards[BUFFER_SIZE*(ii-1):BUFFER_SIZE*(ii)], dones[BUFFER_SIZE*(ii-1):BUFFER_SIZE*(ii)], np.squeeze(values[BUFFER_SIZE*(ii-1):BUFFER_SIZE*(ii)]), np.squeeze(next_values[BUFFER_SIZE*(ii-1):BUFFER_SIZE*(ii)]))
            advantages_list.append(advantages)
            target_list.append(target)
        advantages_list = np.reshape(advantages_list, (BUFFER_SIZE*NUM_ENVS,1))
        target_list = np.reshape(target_list, (BUFFER_SIZE*NUM_ENVS,1))
        
        # Stack info to unpack it in the custom loss
        y_true = np.hstack([advantages_list, predictions, actions])

        # Training Actor and Critic networks
        a_loss = self.Actor.model.fit(states, y_true, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)
        c_loss = self.Critic.model.fit(states, target_list, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)
 
    def load(self):
        self.Actor.Actor.load_weights(self.Actor_name)
        self.Critic.Critic.load_weights(self.Critic_name)

    def save(self):
        self.Actor.model.save_weights(self.Actor_name)
        self.Critic.model.save_weights(self.Critic_name)

    def test(self):
        env_name = 'CartPole-v0'       
        env = gym.make(env_name)
        state = env.reset()
        state = np.reshape(state, [1, NUM_STATES])
        score = 0
        scores = []
        done = False
        for ii in range(10):
            while done == False:
                action, _, _ = self.act(state)
                state, reward, done, _ = env.step(action)
                state = np.reshape(state, [1, NUM_STATES])
                score += reward
            done = False
            scores.append(score)
            score = 0
            state = env.reset()
            state = np.reshape(state, [1, NUM_STATES])
        
        env.close()
        scores_step = sum(scores)/10
        return scores_step
        
    def run_batch(self): # train every self.Training_batch episodes
        start = time.time()
        global LR
        reward_step = []
        state = self.env.reset()

        state = np.reshape(state, [NUM_ENVS, NUM_STATES])
        done, score = [False*NUM_ENVS], [0*NUM_ENVS]
        finished = False
        scores = []
        for ii in range(NUM_ENVS):
            scores.append(0)
        
        while finished == False:
            # Instantiate or reset games memory
            states, next_states, actions, rewards, predictions, dones = [], [], [], [], [], []
            
            for ii in range(NUM_ENVS):
                states.append([])
                next_states.append([])
                actions.append([])
                rewards.append([])
                predictions.append([])
                dones.append([])
                
            for t in range(BUFFER_SIZE):
                #self.env.render()
                #print(states)
                # Actor picks an action
                action, action_onehot, prediction = self.act(state)
                # Retrieve new state, reward, and whether the state is terminal
                next_state, reward, done, _ = self.env.step(action)
                # Memorize (state, action, reward) for training
                for ii in range(NUM_ENVS):
                    states[ii].append(state[ii])
                    next_states[ii].append(np.reshape(next_state[ii], [1, NUM_STATES]))
                    actions[ii].append(action_onehot[ii])
                    rewards[ii].append(reward[ii])
                    dones[ii].append(done[ii])
                    predictions[ii].append(prediction[ii])
                    scores[ii] += reward[ii]
                # Update current state
                state = np.reshape(next_state, [NUM_ENVS, NUM_STATES])

                for ii in range(NUM_ENVS):
                    if done[ii]:
                        self.episode += 1
                        self.scores_.append(scores[ii])
                        
                        if self.episode >= 100:
                            average = sum(self.scores_[-100:])/100
                            print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, scores[ii], average))
                            if average > self.max_average:
                                self.max_average = average

                            if average > 195:
                                plt.plot(self.scores_)
                                plt.xlabel("Episode")
                                plt.ylabel("Score")
                                finished = True
                                break

                        else:
                            print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, scores[ii], sum(self.scores_)/len(self.scores_)))


                        done[ii], scores[ii] = False, 0
                        state = np.reshape(state, [NUM_ENVS, NUM_STATES])
                if finished == True:
                    break
                    
            #reward_step.append(self.test())
            if self.episode >= EPISODES or finished == True:
                break
            self.replay(states, actions, rewards, predictions, dones, next_states)
            
        self.env.close()
    
                    
if __name__ == "__main__":
    start = time.time()
    env_name = 'CartPole-v0'
    agent = PPOAgent(env_name)
    #agent.run() # train as PPO, train every epesode
    agent.run_batch() # train as PPO, train every batch, trains better
    print((time.time()-start)/60)
    #agent.run_multiprocesses(num_worker = 8)  # train PPO multiprocessed (fastest)
    #agent.test()
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Episode:     1		score:   15.00		average:   15.00
# Episode:     2		score:   16.00		average:   15.50
# Episode:     3		score:   18.00		average:   16.33
# Episode:     4		score:   20.00		average:   17.25
# Episode:     5		score:   25.00		average:   18.80
# Episode:     6		score:   25.00		average:   19.83
# Episode:     7		score:   32.00		average:   21.57
# Episode:     8		score:   33.00		average:   23.00
# Episode:     9		score:   19.00		average:   22.56
# Episode:    10		score:   12.00		average:   21.50
# Episode:    11		score:   17.00		average:   21.09
# Episode:    12		score:   23.00		average:   21.25
# Episode:    13		score:   29.00		average:   21.85
# Episode:    14		score:   13.00		average:   21.21
# Episode:    15		score:    9.00		average:   20.40
# Episode:    16		score:    9.00		average:   19.69
# Episode:    17		score:   22.00		average:   19.82
# Episode:    18		score:   37.00		average:   20.78
# Episode:    19		score:   45.00		average:   22.05
# Episode:    20		score:   29.00		average:   22.40
# Episode:    21		score:   38.00		average:   23.14
# Episode:    22		score:   12.00		average:   22.64
# Episode:    23		score:   18.00		average:   22.43
# Episode:    24		score:   51.00		average:   23.62
# Episode:    25		score:   20.00		average:   23.48
# Episode:    26		score:   55.00		average:   24.69
# Episode:    27		score:   27.00		average:   24.78
# Episode:    28		score:   28.00		average:   24.89
# Episode:    29		score:   12.00		average:   24.45
# Episode:    30		score:   17.00		average:   24.20
# Episode:    31		score:   15.00		average:   23.90
# Episode:    32		score:   16.00		average:   23.66
# Episode:    33		score:   36.00		average:   24.03
# Episode:    34		score:   13.00		average:   23.71
# Episode:    35		score:   14.00		average:   23.43
# Episode:    36		score:   14.00		average:   23.17
# Episode:    37		score:   44.00		average:   23.73
# Episode:    38		score:    9.00		average:   23.34
# Episode:    39		score:   18.00		average:   23.21
# Episode:    40		score:   20.00		average:   23.12
# Episode:    41		score:   24.00		average:   23.15
# Episode:    42		score:   43.00		average:   23.62
# Episode:    43		score:   19.00		average:   23.51
# Episode:    44		score:   10.00		average:   23.20
# Episode:    45		score:   20.00		average:   23.13
# Episode:    46		score:   13.00		average:   22.91
# Episode:    47		score:   35.00		average:   23.17
# Episode:    48		score:   30.00		average:   23.31
# Episode:    49		score:   22.00		average:   23.29
# Episode:    50		score:   18.00		average:   23.18
# Episode:    51		score:   14.00		average:   23.00
# Episode:    52		score:   15.00		average:   22.85
# Episode:    53		score:   20.00		average:   22.79
# Episode:    54		score:   14.00		average:   22.63
# Episode:    55		score:   23.00		average:   22.64
# Episode:    56		score:   12.00		average:   22.45
# Episode:    57		score:   32.00		average:   22.61
# Episode:    58		score:   53.00		average:   23.14
# Episode:    59		score:   42.00		average:   23.46
# Episode:    60		score:   15.00		average:   23.32
# Episode:    61		score:   19.00		average:   23.25
# Episode:    62		score:   24.00		average:   23.26
# Episode:    63		score:   16.00		average:   23.14
# Episode:    64		score:   21.00		average:   23.11
# Episode:    65		score:   44.00		average:   23.43
# Episode:    66		score:   16.00		average:   23.32
# Episode:    67		score:   44.00		average:   23.63
# Episode:    68		score:   51.00		average:   24.03
# Episode:    69		score:   14.00		average:   23.88
# Episode:    70		score:   13.00		average:   23.73
# Episode:    71		score:   21.00		average:   23.69
# Episode:    72		score:   16.00		average:   23.58
# Episode:    73		score:   47.00		average:   23.90
# Episode:    74		score:   23.00		average:   23.89
# Episode:    75		score:   15.00		average:   23.77
# Episode:    76		score:   14.00		average:   23.64
# Episode:    77		score:   56.00		average:   24.06
# Episode:    78		score:   14.00		average:   23.94
# Episode:    79		score:   13.00		average:   23.80
# Episode:    80		score:   27.00		average:   23.84
# Episode:    81		score:   31.00		average:   23.93
# Episode:    82		score:   62.00		average:   24.39
# Episode:    83		score:   24.00		average:   24.39
# Episode:    84		score:   10.00		average:   24.21
# Episode:    85		score:   13.00		average:   24.08
# Episode:    86		score:   21.00		average:   24.05
# Episode:    87		score:   14.00		average:   23.93
# Episode:    88		score:   23.00		average:   23.92
# Episode:    89		score:   26.00		average:   23.94
# Episode:    90		score:   19.00		average:   23.89
# Episode:    91		score:   34.00		average:   24.00
# Episode:    92		score:   31.00		average:   24.08
# Episode:    93		score:   19.00		average:   24.02
# Episode:    94		score:   14.00		average:   23.91
# Episode:    95		score:   33.00		average:   24.01
# Episode:    96		score:   54.00		average:   24.32
# Episode:    97		score:   13.00		average:   24.21
# Episode:    98		score:   15.00		average:   24.11
# Episode:    99		score:   74.00		average:   24.62
# Episode:   100		score:   44.00		average:   24.81
# Episode:   101		score:   33.00		average:   24.99
# Episode:   102		score:   14.00		average:   24.97
# Episode:   103		score:   65.00		average:   25.44
# Episode:   104		score:   44.00		average:   25.68
# Episode:   105		score:   29.00		average:   25.72
# Episode:   106		score:   17.00		average:   25.64
# Episode:   107		score:   18.00		average:   25.50
# Episode:   108		score:   29.00		average:   25.46
# Episode:   109		score:   29.00		average:   25.56
# Episode:   110		score:   27.00		average:   25.71
# Episode:   111		score:   17.00		average:   25.71
# Episode:   112		score:   41.00		average:   25.89
# Episode:   113		score:   22.00		average:   25.82
# Episode:   114		score:   48.00		average:   26.17
# Episode:   115		score:   11.00		average:   26.19
# Episode:   116		score:   35.00		average:   26.45
# Episode:   117		score:   17.00		average:   26.40
# Episode:   118		score:   86.00		average:   26.89
# Episode:   119		score:   68.00		average:   27.12
# Episode:   120		score:   20.00		average:   27.03
# Episode:   121		score:   17.00		average:   26.82
# Episode:   122		score:   13.00		average:   26.83
# Episode:   123		score:   17.00		average:   26.82
# Episode:   124		score:   13.00		average:   26.44
# Episode:   125		score:   27.00		average:   26.51
# Episode:   126		score:   26.00		average:   26.22
# Episode:   127		score:   25.00		average:   26.20
# Episode:   128		score:   29.00		average:   26.21
# Episode:   129		score:   12.00		average:   26.21
# Episode:   130		score:   46.00		average:   26.50
# Episode:   131		score:   78.00		average:   27.13
# Episode:   132		score:   23.00		average:   27.20
# Episode:   133		score:   25.00		average:   27.09
# Episode:   134		score:   17.00		average:   27.13
# Episode:   135		score:   22.00		average:   27.21
# Episode:   136		score:   17.00		average:   27.24
# Episode:   137		score:   19.00		average:   26.99
# Episode:   138		score:   10.00		average:   27.00
# Episode:   139		score:   18.00		average:   27.00
# Episode:   140		score:   66.00		average:   27.46
# Episode:   141		score:   16.00		average:   27.38
# Episode:   142		score:   32.00		average:   27.27
# Episode:   143		score:   15.00		average:   27.23
# Episode:   144		score:   26.00		average:   27.39
# Episode:   145		score:   29.00		average:   27.48
# Episode:   146		score:   18.00		average:   27.53
# Episode:   147		score:   94.00		average:   28.12
# Episode:   148		score:   18.00		average:   28.00
# Episode:   149		score:   14.00		average:   27.92
# Episode:   150		score:   97.00		average:   28.71
# Episode:   151		score:   26.00		average:   28.83
# Episode:   152		score:   27.00		average:   28.95
# Episode:   153		score:   41.00		average:   29.16
# Episode:   154		score:   39.00		average:   29.41
# Episode:   155		score:   33.00		average:   29.51
# Episode:   156		score:   19.00		average:   29.58
# Episode:   157		score:   62.00		average:   29.88
# Episode:   158		score:   82.00		average:   30.17
# Episode:   159		score:   59.00		average:   30.34
# Episode:   160		score:   29.00		average:   30.48
# Episode:   161		score:   23.00		average:   30.52
# Episode:   162		score:   51.00		average:   30.79
# Episode:   163		score:   35.00		average:   30.98
# Episode:   164		score:   13.00		average:   30.90
# Episode:   165		score:  102.00		average:   31.48
# Episode:   166		score:  115.00		average:   32.47
# Episode:   167		score:  102.00		average:   33.05
# Episode:   168		score:   75.00		average:   33.29
# Episode:   169		score:   24.00		average:   33.39
# Episode:   170		score:   10.00		average:   33.36
# Episode:   171		score:   19.00		average:   33.34
# Episode:   172		score:   42.00		average:   33.60
# Episode:   173		score:   18.00		average:   33.31
# Episode:   174		score:  165.00		average:   34.73
# Episode:   175		score:   50.00		average:   35.08
# Episode:   176		score:   46.00		average:   35.40
# Episode:   177		score:   28.00		average:   35.12
# Episode:   178		score:   23.00		average:   35.21
# Episode:   179		score:   13.00		average:   35.21
# Episode:   180		score:   73.00		average:   35.67
# Episode:   181		score:  103.00		average:   36.39
# Episode:   182		score:   98.00		average:   36.75
# Episode:   183		score:   38.00		average:   36.89
# Episode:   184		score:   30.00		average:   37.09
# Episode:   185		score:   35.00		average:   37.31
# Episode:   186		score:   30.00		average:   37.40
# Episode:   187		score:  196.00		average:   39.22
# Episode:   188		score:   46.00		average:   39.45
# Episode:   189		score:   98.00		average:   40.17
# Episode:   190		score:   75.00		average:   40.73
# Episode:   191		score:   13.00		average:   40.52
# Episode:   192		score:   90.00		average:   41.11
# Episode:   193		score:  100.00		average:   41.92
# Episode:   194		score:  124.00		average:   43.02
# Episode:   195		score:   48.00		average:   43.17
# Episode:   196		score:  144.00		average:   44.07
# Episode:   197		score:  103.00		average:   44.97
# Episode:   198		score:   68.00		average:   45.50
# Episode:   199		score:  171.00		average:   46.47
# Episode:   200		score:  107.00		average:   47.10
# Episode:   201		score:   72.00		average:   47.49
# Episode:   202		score:   51.00		average:   47.86
# Episode:   203		score:  155.00		average:   48.76
# Episode:   204		score:  200.00		average:   50.32
# Episode:   205		score:  138.00		average:   51.41
# Episode:   206		score:  127.00		average:   52.51
# Episode:   207		score:  200.00		average:   54.33
# Episode:   208		score:  174.00		average:   55.78
# Episode:   209		score:  200.00		average:   57.49
# Episode:   210		score:  200.00		average:   59.22
# Episode:   211		score:  175.00		average:   60.80
# Episode:   212		score:  200.00		average:   62.39
# Episode:   213		score:  200.00		average:   64.17
# Episode:   214		score:  145.00		average:   65.14
# Episode:   215		score:  120.00		average:   66.23
# Episode:   216		score:  117.00		average:   67.05
# Episode:   217		score:  183.00		average:   68.71
# Episode:   218		score:  200.00		average:   69.85
# Episode:   219		score:  107.00		average:   70.24
# Episode:   220		score:  192.00		average:   71.96
# Episode:   221		score:  200.00		average:   73.79
# Episode:   222		score:  200.00		average:   75.66
# Episode:   223		score:  121.00		average:   76.70
# Episode:   224		score:  200.00		average:   78.57
# Episode:   225		score:  200.00		average:   80.30
# Episode:   226		score:  200.00		average:   82.04
# Episode:   227		score:  200.00		average:   83.79
# Episode:   228		score:  188.00		average:   85.38
# Episode:   229		score:  150.00		average:   86.76
# Episode:   230		score:  145.00		average:   87.75
# Episode:   231		score:  170.00		average:   88.67
# Episode:   232		score:  200.00		average:   90.44
# Episode:   233		score:  148.00		average:   91.67
# Episode:   234		score:  200.00		average:   93.50
# Episode:   235		score:  200.00		average:   95.28
# Episode:   236		score:  100.00		average:   96.11
# Episode:   237		score:   82.00		average:   96.74
# Episode:   238		score:  200.00		average:   98.64
# Episode:   239		score:  200.00		average:  100.46
# Episode:   240		score:  200.00		average:  101.80
# Episode:   241		score:   22.00		average:  101.86
# Episode:   242		score:  200.00		average:  103.54
# Episode:   243		score:  200.00		average:  105.39
# Episode:   244		score:  200.00		average:  107.13
# Episode:   245		score:  200.00		average:  108.84
# Episode:   246		score:  187.00		average:  110.53
# Episode:   247		score:  200.00		average:  111.59
# Episode:   248		score:  199.00		average:  113.40
# Episode:   249		score:  200.00		average:  115.26
# Episode:   250		score:  200.00		average:  116.29
# Episode:   251		score:  200.00		average:  118.03
# Episode:   252		score:  200.00		average:  119.76
# Episode:   253		score:  200.00		average:  121.35
# Episode:   254		score:  200.00		average:  122.96
# Episode:   255		score:  200.00		average:  124.63
# Episode:   256		score:  200.00		average:  126.44
# Episode:   257		score:  200.00		average:  127.82
# Episode:   258		score:  200.00		average:  129.00
# Episode:   259		score:  200.00		average:  130.41
# Episode:   260		score:  200.00		average:  132.12
# Episode:   261		score:  196.00		average:  133.85
# Episode:   262		score:  200.00		average:  135.34
# Episode:   263		score:  200.00		average:  136.99
# Episode:   264		score:  200.00		average:  138.86
# Episode:   265		score:  200.00		average:  139.84
# Episode:   266		score:  200.00		average:  140.69
# Episode:   267		score:  200.00		average:  141.67
# Episode:   268		score:  200.00		average:  142.92
# Episode:   269		score:  200.00		average:  144.68
# Episode:   270		score:  200.00		average:  146.58
# Episode:   271		score:  200.00		average:  148.39
# Episode:   272		score:  200.00		average:  149.97
# Episode:   273		score:  200.00		average:  151.79
# Episode:   274		score:  200.00		average:  152.14
# Episode:   275		score:  200.00		average:  153.64
# Episode:   276		score:  200.00		average:  155.18
# Episode:   277		score:  200.00		average:  156.90
# Episode:   278		score:  200.00		average:  158.67
# Episode:   279		score:  182.00		average:  160.36
# Episode:   280		score:  200.00		average:  161.63
# Episode:   281		score:  200.00		average:  162.60
# Episode:   282		score:  200.00		average:  163.62
# Episode:   283		score:  200.00		average:  165.24
# Episode:   284		score:  160.00		average:  166.54
# Episode:   285		score:  200.00		average:  168.19
# Episode:   286		score:  189.00		average:  169.78
# Episode:   287		score:  200.00		average:  169.82
# Episode:   288		score:  200.00		average:  171.36
# Episode:   289		score:  200.00		average:  172.38
# Episode:   290		score:  200.00		average:  173.63
# Episode:   291		score:  200.00		average:  175.50
# Episode:   292		score:  200.00		average:  176.60
# Episode:   293		score:  200.00		average:  177.60
# Episode:   294		score:  200.00		average:  178.36
# Episode:   295		score:  200.00		average:  179.88
# Episode:   296		score:  200.00		average:  180.44
# Episode:   297		score:  200.00		average:  181.41
# Episode:   298		score:  149.00		average:  182.22
# Episode:   299		score:  200.00		average:  182.51
# Episode:   300		score:  200.00		average:  183.44
# Episode:   301		score:  200.00		average:  184.72
# Episode:   302		score:  200.00		average:  186.21
# Episode:   303		score:  200.00		average:  186.66
# Episode:   304		score:  200.00		average:  186.66
# Episode:   305		score:  170.00		average:  186.98
# Episode:   306		score:  200.00		average:  187.71
# Episode:   307		score:  164.00		average:  187.35
# Episode:   308		score:  200.00		average:  187.61
# Episode:   309		score:  200.00		average:  187.61
# Episode:   310		score:  183.00		average:  187.44
# Episode:   311		score:  200.00		average:  187.69
# Episode:   312		score:   74.00		average:  186.43
# Episode:   313		score:   64.00		average:  185.07
# Episode:   314		score:  113.00		average:  184.75
# Episode:   315		score:  200.00		average:  185.55
# Episode:   316		score:  200.00		average:  186.38
# Episode:   317		score:   82.00		average:  185.37
# Episode:   318		score:  149.00		average:  184.86
# Episode:   319		score:  185.00		average:  185.64
# Episode:   320		score:  200.00		average:  185.72
# Episode:   321		score:  200.00		average:  185.72
# Episode:   322		score:  200.00		average:  185.72
# Episode:   323		score:  200.00		average:  186.51
# Episode:   324		score:  200.00		average:  186.51
# Episode:   325		score:  200.00		average:  186.51
# Episode:   326		score:  200.00		average:  186.51
# Episode:   327		score:  200.00		average:  186.51
# Episode:   328		score:  200.00		average:  186.63
# Episode:   329		score:  200.00		average:  187.13
# Episode:   330		score:   22.00		average:  185.90
# Episode:   331		score:  200.00		average:  186.20
# Episode:   332		score:  200.00		average:  186.20
# Episode:   333		score:  200.00		average:  186.72
# Episode:   334		score:  200.00		average:  186.72
# Episode:   335		score:  200.00		average:  186.72
# Episode:   336		score:  200.00		average:  187.72
# Episode:   337		score:  200.00		average:  188.90
# Episode:   338		score:  200.00		average:  188.90
# Episode:   339		score:  200.00		average:  188.90
# Episode:   340		score:  200.00		average:  188.90
# Episode:   341		score:  200.00		average:  190.68
# Episode:   342		score:  200.00		average:  190.68
# Episode:   343		score:  200.00		average:  190.68
# Episode:   344		score:  200.00		average:  190.68
# Episode:   345		score:  200.00		average:  190.68
# Episode:   346		score:  200.00		average:  190.81
# Episode:   347		score:  200.00		average:  190.81
# Episode:   348		score:  200.00		average:  190.82
# Episode:   349		score:  200.00		average:  190.82
# Episode:   350		score:  200.00		average:  190.82
# Episode:   351		score:  200.00		average:  190.82
# Episode:   352		score:  200.00		average:  190.82
# Episode:   353		score:  200.00		average:  190.82
# Episode:   354		score:  200.00		average:  190.82
# Episode:   355		score:  200.00		average:  190.82
# Episode:   356		score:  200.00		average:  190.82
# Episode:   357		score:  200.00		average:  190.82
# Episode:   358		score:  200.00		average:  190.82
# Episode:   359		score:  200.00		average:  190.82
# Episode:   360		score:  200.00		average:  190.82
# Episode:   361		score:  200.00		average:  190.86
# Episode:   362		score:  200.00		average:  190.86
# Episode:   363		score:  200.00		average:  190.86
# Episode:   364		score:  200.00		average:  190.86
# Episode:   365		score:  200.00		average:  190.86
# Episode:   366		score:  200.00		average:  190.86
# Episode:   367		score:  200.00		average:  190.86
# Episode:   368		score:  200.00		average:  190.86
# Episode:   369		score:  200.00		average:  190.86
# Episode:   370		score:  200.00		average:  190.86
# Episode:   371		score:  200.00		average:  190.86
# Episode:   372		score:  200.00		average:  190.86
# Episode:   373		score:  113.00		average:  189.99
# Episode:   374		score:  200.00		average:  189.99
# Episode:   375		score:  200.00		average:  189.99
# Episode:   376		score:  200.00		average:  189.99
# Episode:   377		score:  200.00		average:  189.99
# Episode:   378		score:  200.00		average:  189.99
# Episode:   379		score:  200.00		average:  190.17
# Episode:   380		score:  200.00		average:  190.17
# Episode:   381		score:  200.00		average:  190.17
# Episode:   382		score:  200.00		average:  190.17
# Episode:   383		score:  200.00		average:  190.17
# Episode:   384		score:  200.00		average:  190.57
# Episode:   385		score:  200.00		average:  190.57
# Episode:   386		score:  200.00		average:  190.68
# Episode:   387		score:  200.00		average:  190.68
# Episode:   388		score:   89.00		average:  189.57
# Episode:   389		score:  200.00		average:  189.57
# Episode:   390		score:  200.00		average:  189.57
# Episode:   391		score:  200.00		average:  189.57
# Episode:   392		score:  200.00		average:  189.57
# Episode:   393		score:  200.00		average:  189.57
# Episode:   394		score:  200.00		average:  189.57
# Episode:   395		score:  200.00		average:  189.57
# Episode:   396		score:  200.00		average:  189.57
# Episode:   397		score:  200.00		average:  189.57
# Episode:   398		score:  200.00		average:  190.08
# Episode:   399		score:  200.00		average:  190.08
# Episode:   400		score:  200.00		average:  190.08
# Episode:   401		score:  200.00		average:  190.08
# Episode:   402		score:  200.00		average:  190.08
# Episode:   403		score:  200.00		average:  190.08
# Episode:   404		score:  200.00		average:  190.08
# Episode:   405		score:  200.00		average:  190.38
# Episode:   406		score:  200.00		average:  190.38
# Episode:   407		score:  200.00		average:  190.74
# Episode:   408		score:  200.00		average:  190.74
# Episode:   409		score:  200.00		average:  190.74
# Episode:   410		score:  200.00		average:  190.91
# Episode:   411		score:  200.00		average:  190.91
# Episode:   412		score:  200.00		average:  192.17
# Episode:   413		score:  200.00		average:  193.53
# Episode:   414		score:  200.00		average:  194.40
# Episode:   415		score:  200.00		average:  194.40
# Episode:   416		score:  200.00		average:  194.40
# Episode:   417		score:  200.00		average:  195.58
# 0.7927803834279378
