# %%
import os

import random
import gym
import pylab
import numpy as np
import tensorflow as tf
import time
import matplotlib.pyplot as plt

#tf.config.experimental_run_functions_eagerly(True)
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import backend as K
import copy

EPISODES = 10000 # Number of times the enviroment is ran
LOSS_CLIPPING = 0.2 # Approximated values stated in the original paper
ENTROPY_LOSS = 0 # Epochs to train the network (recommended between 3 and 30)
LR = 0.0003 # Learning rate 
NUM_ACTIONS = 4 # Number of possible action in the environment
NUM_STATES = 8 # Number of possible states in the exvironment
EPOCHS = 10 # Epochs to train the network (recommended between 3 and 30)
BATCH_SIZE = 64 # Batch size for the neural nets
BUFFER_SIZE = 2048 # Buffer of experiences
SHUFFLE = True # Whether to shuffle data or not while training
OPTIMIZER = Adam # Optimizer for both actor and critic
GAMMA = 0.99 # Used for the estimated reward
LAMBDA = 0.95 # Used in the original paper un the GAE
NORMALIZE = True # Whether to normalize GAE or not
DUMMY_ACTION, DUMMY_VALUE = np.zeros((1, NUM_ACTIONS)), np.zeros((1, 1)) # Used to feed the actor when predicting


# Custom loss functions for the PPO
def ppo_loss(advantages, actions):
    def loss(y_true, y_pred):
        prob = actions * y_pred
        old_prob = actions * y_true 
        
        ratio = K.exp(K.log(prob + 1e-10) - K.log(old_prob + 1e-10))
        p1 = ratio * advantages
        clip = K.clip(ratio, min_value=1 - LOSS_CLIPPING, max_value=1 +LOSS_CLIPPING)     
        p2 = clip * advantages
        
        actor_loss = -K.mean(K.minimum(p1, p2))
        
        entropy = -(y_pred * K.log(y_pred + 1e-10))
        entropy = ENTROPY_LOSS * K.mean(entropy)
        
        total_loss = actor_loss - entropy
        
        return total_loss
 
    return loss


# Create the actor used to select the action given an state
class Actor_Model:
    def __init__(self):
        # Define three inputs as the advantage and old prediction is used for the custom loss
        input_state = Input(shape=(NUM_STATES,))
        input_advantage = Input(shape=(1,))
        input_actions = Input(shape=(NUM_ACTIONS,))

        X = Dense(128, activation='relu', kernel_initializer=tf.random_normal_initializer(stddev=0.01))(input_state)
        X = Dense(128, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X)
        X = Dense(128, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X) 
        
        # Softmax as there are different probabilities depending on the action
        output_layer = Dense(NUM_ACTIONS, activation='softmax', name='output')(X)

        self.model = Model(inputs=[input_state, input_advantage, input_actions], outputs=[output_layer])

        # Compile the model with the custom loss
        self.model.compile(optimizer=OPTIMIZER(lr=LR), 
                           loss=[ppo_loss(advantages=input_advantage, actions=input_actions)]) 



# Create the critic which will criticise how the actor is performing    
class Critic_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(128, activation="relu", kernel_initializer='he_uniform')(X_input)
        X = Dense(128, activation="relu", kernel_initializer='he_uniform')(X)
        X = Dense(128, activation="relu", kernel_initializer='he_uniform')(X)
        
        # Linear output to know how good the action is
        value = Dense(1)(X)
        
        # Compile it with mse loss and gradient descent
        self.model = Model(inputs=X_input, outputs = value)
        self.model.compile(loss='mse', optimizer=OPTIMIZER(lr=LR))

# Combine both Actor and Critic to create the agent
class PPOAgent:
    def __init__(self, env_name):
        # Environment parameters
        self.env_name = env_name       
        self.env = gym.make(env_name)
        self.episode = 0 # used to track current number episoded since start
        self.max_average = 0 # record max average reached
        
        # Used to plot a grapgh of the train process
        self.scores_, self.average_ = [], []

        # Create Actor-Critic network models
        self.Actor = Actor_Model()
        self.Critic = Critic_Model()
    
        # Names for the models
        self.Actor_name = f"{self.env_name}_PPO_Actor.h5"
        self.Critic_name = f"{self.env_name}_PPO_Critic.h5"

    # Get the action given the current state    
    def act(self, state):
        # Use the network to predict the next action to take, using the model
        prediction = self.Actor.model.predict([state, DUMMY_VALUE, DUMMY_ACTION])[0]
        
        # Probability based to choose the action
        action = np.random.choice(NUM_ACTIONS, p=prediction)
        action_onehot = np.zeros([NUM_ACTIONS])
        action_onehot[action] = 1
        return action, action_onehot, prediction

    # Generalized Advantage Estimation implemented in the original paper
    def get_gaes(self, rewards, dones, values, next_values):
        # Dones are used to track when is the final step of an episode, so next values are no applied
        deltas = [r + GAMMA * (1 - d) * nv - v for r, d, nv, v in zip(rewards, dones, next_values, values)]
        
        # Convert list to array as .mean() and .std() are used later
        deltas = np.stack(deltas)
        gaes = copy.deepcopy(deltas)
        
        for t in reversed(range(len(deltas) - 1)):
            gaes[t] = gaes[t] + (1 - dones[t]) * GAMMA * LAMBDA * gaes[t + 1]

        target = gaes + values
        if NORMALIZE:
            gaes = (gaes - gaes.mean()) / (gaes.std() + 1e-8)
        return np.vstack(gaes), np.vstack(target)

    def replay(self, states, actions, rewards, predictions, dones, next_states):
        # Reshape memory to appropriate shape for training
        states = np.vstack(states)
        next_states = np.vstack(next_states)
        actions = np.vstack(actions)
        predictions = np.vstack(predictions)

        # Get Critic network predictions for state and next state
        values = self.Critic.model.predict(states)
        next_values = self.Critic.model.predict(next_states)

        # Get the advantage
        advantages, target = self.get_gaes(rewards, dones, np.squeeze(values), np.squeeze(next_values))

        # Stack info to unpack it in the custom loss
        y_true = np.hstack([advantages, predictions, actions])

        # Training Actor and Critic networks
        a_loss = self.Actor.model.fit([states, advantages, actions], predictions, epochs=EPOCHS, 
                                      verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)
        c_loss = self.Critic.model.fit(states, target, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)

 
    def load(self):
        self.Actor.Actor.load_weights(self.Actor_name)
        self.Critic.Critic.load_weights(self.Critic_name)

    def save(self):
        self.Actor.model.save_weights(self.Actor_name)
        self.Critic.model.save_weights(self.Critic_name)
    
    def test(self):
        state = self.env.reset()
        state = np.reshape(state, [1, NUM_STATES])
        score = 0
        scores = []
        done = False
        for ii in range(10):
            while done == False:
                action, _, _ = self.act(state)
                state, reward, done, _ = self.env.step(action)
                state = np.reshape(state, [1, NUM_STATES])
                score += reward
            done = False
            scores.append(score)
            score = 0
            state = self.env.reset()
            state = np.reshape(state, [1, NUM_STATES])
        
        self.env.close()
        scores_step = sum(scores)/10
        return scores_step

    def run_batch(self): # train every self.Training_batch episodes
        start = time.time()
        global LR
        reward_step = []
        state = self.env.reset()
        state = np.reshape(state, [1, NUM_STATES])
        done, score = False, 0
        finished = False
        while finished == False:
            # Instantiate or reset games memory
            states, next_states, actions, rewards, predictions, dones = [], [], [], [], [], []
            for t in range(BUFFER_SIZE):
                #self.env.render()
                # Actor picks an action
                action, action_onehot, prediction = self.act(state)
                # Retrieve new state, reward, and whether the state is terminal
                next_state, reward, done, _ = self.env.step(action)
                # Memorize (state, action, reward) for training
                states.append(state)
                next_states.append(np.reshape(next_state, [1, NUM_STATES]))
                actions.append(action_onehot)
                rewards.append(reward)
                dones.append(done)
                predictions.append(prediction)
                # Update current state
                state = np.reshape(next_state, [1, NUM_STATES])
                score += reward
                
                if done:
                    self.episode += 1
                    self.scores_.append(score)
                    
                    if self.episode >= 100:
                        average = sum(self.scores_[-100:])/100
                        print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, score, average))
                        if average > self.max_average:
                            self.max_average = average
                            
                        if average > 200:
                            plt.plot(self.scores_)
                            plt.xlabel("Episode")
                            plt.ylabel("Score")
                            finished = True
                            break

                    else:
                        print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, score, sum(self.scores_)/len(self.scores_)))
                    
                    
                    state, done, score = self.env.reset(), False, 0
                    state = np.reshape(state, [1, NUM_STATES])
            #reward_step.append(self.test())        
            self.replay(states, actions, rewards, predictions, dones, next_states)
            if self.episode >= EPISODES:
                break
        self.env.close()
        print((time.time() - start)/60)
        
                    
if __name__ == "__main__":
    
    env_name = 'LunarLander-v2'
    agent = PPOAgent(env_name)
    #agent.run() # train as PPO, train every epesode
    agent.run_batch() # train as PPO, train every batch, trains better
    #agent.run_multiprocesses(num_worker = 8)  # train PPO multiprocessed (fastest)
    #agent.test()
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Episode:     1		score: -367.53		average: -367.53
# Episode:     2		score: -126.62		average: -247.07
# Episode:     3		score:  -44.61		average: -179.58
# Episode:     4		score: -142.52		average: -170.32
# Episode:     5		score: -205.46		average: -177.35
# Episode:     6		score: -200.54		average: -181.21
# Episode:     7		score: -333.41		average: -202.95
# Episode:     8		score: -278.22		average: -212.36
# Episode:     9		score:  -93.48		average: -199.15
# Episode:    10		score:  -96.51		average: -188.89
# Episode:    11		score: -148.32		average: -185.20
# Episode:    12		score: -148.84		average: -182.17
# Episode:    13		score: -410.30		average: -199.72
# Episode:    14		score:  -98.90		average: -192.52
# Episode:    15		score: -227.02		average: -194.82
# Episode:    16		score: -181.43		average: -193.98
# Episode:    17		score: -125.25		average: -189.94
# Episode:    18		score: -153.46		average: -187.91
# Episode:    19		score: -230.47		average: -190.15
# Episode:    20		score: -126.15		average: -186.95
# Episode:    21		score: -219.76		average: -188.51
# Episode:    22		score: -135.42		average: -186.10
# Episode:    23		score: -144.56		average: -184.30
# Episode:    24		score:  -55.43		average: -178.93
# Episode:    25		score: -110.72		average: -176.20
# Episode:    26		score: -119.52		average: -174.02
# Episode:    27		score: -130.81		average: -172.42
# Episode:    28		score: -128.17		average: -170.84
# Episode:    29		score:  -83.98		average: -167.84
# Episode:    30		score: -165.99		average: -167.78
# Episode:    31		score: -307.31		average: -172.28
# Episode:    32		score:  -90.00		average: -169.71
# Episode:    33		score: -154.05		average: -169.24
# Episode:    34		score: -213.38		average: -170.53
# Episode:    35		score:  -96.22		average: -168.41
# Episode:    36		score: -168.83		average: -168.42
# Episode:    37		score: -156.02		average: -168.09
# Episode:    38		score:  -74.95		average: -165.64
# Episode:    39		score:  -80.50		average: -163.45
# Episode:    40		score:  -72.10		average: -161.17
# Episode:    41		score: -112.05		average: -159.97
# Episode:    42		score: -153.42		average: -159.81
# Episode:    43		score: -136.67		average: -159.28
# Episode:    44		score: -106.07		average: -158.07
# Episode:    45		score:  -84.41		average: -156.43
# Episode:    46		score: -107.24		average: -155.36
# Episode:    47		score: -116.40		average: -154.53
# Episode:    48		score:  -50.43		average: -152.36
# Episode:    49		score:  -80.23		average: -150.89
# Episode:    50		score: -121.16		average: -150.30
# Episode:    51		score:  -89.89		average: -149.11
# Episode:    52		score: -141.85		average: -148.97
# Episode:    53		score: -240.65		average: -150.70
# Episode:    54		score: -182.61		average: -151.29
# Episode:    55		score: -161.46		average: -151.48
# Episode:    56		score: -228.15		average: -152.85
# Episode:    57		score: -114.11		average: -152.17
# Episode:    58		score: -142.94		average: -152.01
# Episode:    59		score: -112.74		average: -151.34
# Episode:    60		score:  -83.30		average: -150.21
# Episode:    61		score: -119.60		average: -149.71
# Episode:    62		score:  -77.69		average: -148.55
# Episode:    63		score: -118.64		average: -148.07
# Episode:    64		score: -140.32		average: -147.95
# Episode:    65		score:  -43.64		average: -146.34
# Episode:    66		score: -112.96		average: -145.84
# Episode:    67		score:  -88.74		average: -144.99
# Episode:    68		score:  -71.34		average: -143.90
# Episode:    69		score:  -69.63		average: -142.83
# Episode:    70		score:  -76.12		average: -141.87
# Episode:    71		score: -136.65		average: -141.80
# Episode:    72		score:  -42.52		average: -140.42
# Episode:    73		score: -141.46		average: -140.44
# Episode:    74		score:  -65.32		average: -139.42
# Episode:    75		score:  -84.79		average: -138.69
# Episode:    76		score:  -89.06		average: -138.04
# Episode:    77		score: -143.36		average: -138.11
# Episode:    78		score: -102.31		average: -137.65
# Episode:    79		score:  -56.08		average: -136.62
# Episode:    80		score:  -81.99		average: -135.93
# Episode:    81		score:  -83.71		average: -135.29
# Episode:    82		score: -107.09		average: -134.95
# Episode:    83		score:  -79.08		average: -134.27
# Episode:    84		score:  -84.82		average: -133.68
# Episode:    85		score: -108.08		average: -133.38
# Episode:    86		score:  -62.68		average: -132.56
# Episode:    87		score: -127.35		average: -132.50
# Episode:    88		score:  -23.70		average: -131.26
# Episode:    89		score:  -81.68		average: -130.71
# Episode:    90		score:  -54.55		average: -129.86
# Episode:    91		score:  -63.61		average: -129.13
# Episode:    92		score:  -64.39		average: -128.43
# Episode:    93		score:  -81.09		average: -127.92
# Episode:    94		score:   -0.75		average: -126.57
# Episode:    95		score:  -77.01		average: -126.05
# Episode:    96		score:  -50.12		average: -125.25
# Episode:    97		score:  -87.92		average: -124.87
# Episode:    98		score:  -84.28		average: -124.46
# Episode:    99		score:  -55.18		average: -123.76
# Episode:   100		score:  -76.63		average: -123.28
# Episode:   101		score:  -40.36		average: -120.01
# Episode:   102		score:  -69.56		average: -119.44
# Episode:   103		score:  -90.22		average: -119.90
# Episode:   104		score:   22.46		average: -118.25
# Episode:   105		score:  -37.67		average: -116.57
# Episode:   106		score: -107.96		average: -115.64
# Episode:   107		score:  -72.71		average: -113.04
# Episode:   108		score:  -56.53		average: -110.82
# Episode:   109		score:  -16.34		average: -110.05
# Episode:   110		score:  -36.67		average: -109.45
# Episode:   111		score:  -40.36		average: -108.37
# Episode:   112		score: -120.21		average: -108.09
# Episode:   113		score:  -17.80		average: -104.16
# Episode:   114		score:    5.32		average: -103.12
# Episode:   115		score:  -40.38		average: -101.25
# Episode:   116		score:  -63.89		average: -100.08
# Episode:   117		score:   42.08		average:  -98.40
# Episode:   118		score: -202.09		average:  -98.89
# Episode:   119		score: -110.17		average:  -97.69
# Episode:   120		score:  -60.42		average:  -97.03
# Episode:   121		score:  -13.61		average:  -94.97
# Episode:   122		score:  -58.71		average:  -94.20
# Episode:   123		score:  -92.68		average:  -93.68
# Episode:   124		score: -133.19		average:  -94.46
# Episode:   125		score: -130.86		average:  -94.66
# Episode:   126		score:  -68.90		average:  -94.15
# Episode:   127		score:  -30.10		average:  -93.15
# Episode:   128		score: -186.48		average:  -93.73
# Episode:   129		score:   26.45		average:  -92.63
# Episode:   130		score: -176.62		average:  -92.73
# Episode:   131		score:  -70.05		average:  -90.36
# Episode:   132		score:   22.17		average:  -89.24
# Episode:   133		score: -206.26		average:  -89.76
# Episode:   134		score:  -33.83		average:  -87.96
# Episode:   135		score:  -36.73		average:  -87.37
# Episode:   136		score: -228.05		average:  -87.96
# Episode:   137		score: -109.82		average:  -87.50
# Episode:   138		score:   21.04		average:  -86.54
# Episode:   139		score: -233.93		average:  -88.07
# Episode:   140		score: -160.47		average:  -88.96
# Episode:   141		score: -141.86		average:  -89.26
# Episode:   142		score: -209.77		average:  -89.82
# Episode:   143		score: -124.30		average:  -89.70
# Episode:   144		score:   13.03		average:  -88.51
# Episode:   145		score: -191.21		average:  -89.57
# Episode:   146		score: -147.37		average:  -89.97
# Episode:   147		score: -129.87		average:  -90.11
# Episode:   148		score:  -27.40		average:  -89.88
# Episode:   149		score:   -3.26		average:  -89.11
# Episode:   150		score:    5.45		average:  -87.84
# Episode:   151		score:   13.74		average:  -86.81
# Episode:   152		score:   -9.65		average:  -85.48
# Episode:   153		score: -116.59		average:  -84.24
# Episode:   154		score:  -91.86		average:  -83.34
# Episode:   155		score:  -78.54		average:  -82.51
# Episode:   156		score:   -7.11		average:  -80.30
# Episode:   157		score:  -47.57		average:  -79.63
# Episode:   158		score:  -10.02		average:  -78.30
# Episode:   159		score:  -65.41		average:  -77.83
# Episode:   160		score:   -7.15		average:  -77.07
# Episode:   161		score:   -8.20		average:  -75.95
# Episode:   162		score:   19.62		average:  -74.98
# Episode:   163		score:    5.96		average:  -73.73
# Episode:   164		score:   80.48		average:  -71.53
# Episode:   165		score:  -11.94		average:  -71.21
# Episode:   166		score:   92.10		average:  -69.16
# Episode:   167		score:   87.36		average:  -67.40
# Episode:   168		score:  -24.48		average:  -66.93
# Episode:   169		score:  -69.51		average:  -66.93
# Episode:   170		score: -129.82		average:  -67.47
# Episode:   171		score:  -11.32		average:  -66.21
# Episode:   172		score:  180.45		average:  -63.98
# Episode:   173		score:   30.08		average:  -62.27
# Episode:   174		score:  134.21		average:  -60.27
# Episode:   175		score:   81.81		average:  -58.61
# Episode:   176		score:   69.52		average:  -57.02
# Episode:   177		score:   40.38		average:  -55.18
# Episode:   178		score:   89.34		average:  -53.27
# Episode:   179		score:   41.26		average:  -52.29
# Episode:   180		score:  106.62		average:  -50.41
# Episode:   181		score:   75.74		average:  -48.81
# Episode:   182		score:   79.69		average:  -46.94
# Episode:   183		score:  106.10		average:  -45.09
# Episode:   184		score:   94.97		average:  -43.29
# Episode:   185		score:   49.01		average:  -41.72
# Episode:   186		score:  -74.73		average:  -41.84
# Episode:   187		score:   51.07		average:  -40.06
# Episode:   188		score:  -61.67		average:  -40.44
# Episode:   189		score:  156.60		average:  -38.06
# Episode:   190		score:  146.94		average:  -36.04
# Episode:   191		score:  100.84		average:  -34.40
# Episode:   192		score:   53.61		average:  -33.22
# Episode:   193		score:  -37.29		average:  -32.78
# Episode:   194		score:  127.48		average:  -31.50
# Episode:   195		score:  129.87		average:  -29.43
# Episode:   196		score:  180.87		average:  -27.12
# Episode:   197		score:  153.13		average:  -24.71
# Episode:   198		score:  167.29		average:  -22.19
# Episode:   199		score:   18.52		average:  -21.46
# Episode:   200		score:  400.73		average:  -16.68
# Episode:   201		score:   -0.82		average:  -16.29
# Episode:   202		score:  132.59		average:  -14.26
# Episode:   203		score:  414.24		average:   -9.22
# Episode:   204		score:  264.99		average:   -6.79
# Episode:   205		score:  250.80		average:   -3.91
# Episode:   206		score:  109.15		average:   -1.74
# Episode:   207		score:  277.93		average:    1.77
# Episode:   208		score:    1.64		average:    2.35
# Episode:   209		score:  251.32		average:    5.03
# Episode:   210		score:  176.92		average:    7.16
# Episode:   211		score:  271.13		average:   10.28
# Episode:   212		score:  -12.74		average:   11.35
# Episode:   213		score:    8.80		average:   11.62
# Episode:   214		score:   -9.94		average:   11.46
# Episode:   215		score:   20.36		average:   12.07
# Episode:   216		score:  -29.57		average:   12.42
# Episode:   217		score:  243.93		average:   14.43
# Episode:   218		score:   -3.91		average:   16.42
# Episode:   219		score:    8.84		average:   17.61
# Episode:   220		score:  280.04		average:   21.01
# Episode:   221		score:   12.96		average:   21.28
# Episode:   222		score:  282.08		average:   24.68
# Episode:   223		score:  238.50		average:   28.00
# Episode:   224		score:  259.29		average:   31.92
# Episode:   225		score:  245.36		average:   35.68
# Episode:   226		score:  260.45		average:   38.98
# Episode:   227		score:   76.26		average:   40.04
# Episode:   228		score:  262.28		average:   44.53
# Episode:   229		score:  217.56		average:   46.44
# Episode:   230		score:  239.53		average:   50.60
# Episode:   231		score:   19.24		average:   51.49
# Episode:   232		score:  244.41		average:   53.72
# Episode:   233		score:  306.51		average:   58.84
# Episode:   234		score:  230.66		average:   61.49
# Episode:   235		score:  263.56		average:   64.49
# Episode:   236		score:   35.45		average:   67.13
# Episode:   237		score:  206.62		average:   70.29
# Episode:   238		score:  403.77		average:   74.12
# Episode:   239		score:  242.14		average:   78.88
# Episode:   240		score:  240.04		average:   82.88
# Episode:   241		score:  257.24		average:   86.87
# Episode:   242		score:  305.56		average:   92.03
# Episode:   243		score:  265.39		average:   95.92
# Episode:   244		score:   99.11		average:   96.79
# Episode:   245		score:    3.16		average:   98.73
# Episode:   246		score:   17.37		average:  100.38
# Episode:   247		score:  254.11		average:  104.22
# Episode:   248		score:   27.97		average:  104.77
# Episode:   249		score:  267.67		average:  107.48
# Episode:   250		score:  264.99		average:  110.07
# Episode:   251		score:  420.13		average:  114.14
# Episode:   252		score:  271.44		average:  116.95
# Episode:   253		score:   19.54		average:  118.31
# Episode:   254		score:  262.16		average:  121.85
# Episode:   255		score:  315.79		average:  125.79
# Episode:   256		score:  253.24		average:  128.40
# Episode:   257		score:  334.35		average:  132.22
# Episode:   258		score:   10.61		average:  132.42
# Episode:   259		score:  214.64		average:  135.22
# Episode:   260		score:  279.31		average:  138.09
# Episode:   261		score:    6.31		average:  138.23
# Episode:   262		score:  233.63		average:  140.37
# Episode:   263		score:  251.67		average:  142.83
# Episode:   264		score:  336.20		average:  145.39
# Episode:   265		score:  264.35		average:  148.15
# Episode:   266		score:   20.55		average:  147.44
# Episode:   267		score:  267.06		average:  149.23
# Episode:   268		score:  274.58		average:  152.22
# Episode:   269		score:  213.17		average:  155.05
# Episode:   270		score:   34.60		average:  156.69
# Episode:   271		score:  337.26		average:  160.18
# Episode:   272		score:  246.57		average:  160.84
# Episode:   273		score:  250.76		average:  163.05
# Episode:   274		score:  234.96		average:  164.06
# Episode:   275		score:  268.59		average:  165.92
# Episode:   276		score:   33.60		average:  165.56
# Episode:   277		score:   17.39		average:  165.33
# Episode:   278		score:  237.70		average:  166.82
# Episode:   279		score:  301.63		average:  169.42
# Episode:   280		score:  291.09		average:  171.27
# Episode:   281		score:  233.82		average:  172.85
# Episode:   282		score:  245.55		average:  174.51
# Episode:   283		score:  267.37		average:  176.12
# Episode:   284		score:  -15.32		average:  175.02
# Episode:   285		score:  257.15		average:  177.10
# Episode:   286		score:  294.84		average:  180.79
# Episode:   287		score:  240.78		average:  182.69
# Episode:   288		score:  252.52		average:  185.83
# Episode:   289		score:  255.96		average:  186.82
# Episode:   290		score:  271.97		average:  188.07
# Episode:   291		score:  359.74		average:  190.66
# Episode:   292		score:  262.49		average:  192.75
# Episode:   293		score:  231.99		average:  195.45
# Episode:   294		score:  223.53		average:  196.41
# Episode:   295		score:  272.17		average:  197.83
# Episode:   296		score:  242.94		average:  198.45
# Episode:   297		score:  -15.39		average:  196.76
# Episode:   298		score:  216.33		average:  197.25
# Episode:   299		score:  227.27		average:  199.34
# Episode:   300		score:   34.76		average:  195.68
# Episode:   301		score:  294.31		average:  198.63
# Episode:   302		score:   46.43		average:  197.77
# Episode:   303		score:  257.04		average:  196.20
# Episode:   304		score:    6.70		average:  193.62
# Episode:   305		score:   -8.85		average:  191.02
# Episode:   306		score:  -16.34		average:  189.77
# Episode:   307		score:  338.73		average:  190.37
# Episode:   308		score:  182.26		average:  192.18
# Episode:   309		score:  277.80		average:  192.45
# Episode:   310		score:  285.46		average:  193.53
# Episode:   311		score:  282.01		average:  193.64
# Episode:   312		score:   13.33		average:  193.90
# Episode:   313		score:   43.38		average:  194.25
# Episode:   314		score:   29.72		average:  194.64
# Episode:   315		score:   31.82		average:  194.76
# Episode:   316		score:  405.85		average:  199.11
# Episode:   317		score:  104.78		average:  197.72
# Episode:   318		score:  268.75		average:  200.45
# 15.616724101702372
