# %% [markdown]
# Disminuir LR

# %%
import os

import random
import gym
import pylab
import numpy as np
import tensorflow as tf
import time
import matplotlib.pyplot as plt

#tf.config.experimental_run_functions_eagerly(True)
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import backend as K
import copy

EPISODES = 100000 # Number of times the enviroment is ran
LR = 0.0055 # Learning rate 
NUM_ACTIONS = 4 # Number of possible action in the environment
NUM_STATES = 8 # Number of possible states in the exvironment
EPOCHS = 10 # Epochs to train the network (recommended between 3 and 30)
BATCH_SIZE = 64 # Batch size for the neural nets
BUFFER_SIZE = 2048 # Buffer of experiences
SHUFFLE = True # Whether to shuffle data or not while training
OPTIMIZER = Adam # Optimizer for both actor and critic
GAMMA = 0.99 # Used for the estimated reward
NORMALIZE = True # Whether to normalize GAE or not


# Create the actor used to select the action given an state
class Actor_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X_input)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        
        # Softmax as there are different probabilities depending on the action
        output = Dense(NUM_ACTIONS, activation="softmax")(X)
        
        # Compile the model with the custom loss
        self.model = Model(inputs = X_input, outputs = output)
        self.model.compile(loss='categorical_crossentropy', optimizer=OPTIMIZER(lr=LR))

# Create the critic which will criticise how the actor is performing    
class Critic_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X_input)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        
        # Linear output to know how good the action is
        value = Dense(1)(X)
        
        # Compile it with mse loss and gradient descent
        self.model = Model(inputs=X_input, outputs = value)
        self.model.compile(loss='mse', optimizer=OPTIMIZER(lr=LR))

# Combine both Actor and Critic to create the agent
class PPOAgent:
    def __init__(self, env_name):
        # Environment parameters
        self.env_name = env_name       
        self.env = gym.make(env_name)
        self.episode = 0 # used to track current number episoded since start
        self.max_average = 0 # record max average reached
        
        # Used to plot a grapgh of the train process
        self.scores_, self.average_ = [], []

        # Create Actor-Critic network models
        self.Actor = Actor_Model()
        self.Critic = Critic_Model()
    
        # Names for the models
        self.Actor_name = f"{self.env_name}_PPO_Actor.h5"
        self.Critic_name = f"{self.env_name}_PPO_Critic.h5"

    # Get the action given the current state    
    def act(self, state):
        # Use the network to predict the next action to take, using the model
        prediction = self.Actor.model.predict(state)[0]
        
        # Probability based to choose the action
        action = np.random.choice(NUM_ACTIONS, p=prediction)
        action_onehot = np.zeros([NUM_ACTIONS])
        action_onehot[action] = 1
        return action, action_onehot, prediction
    
    def discount_rewards(self, reward):#gaes is better
        # Compute the gamma-discounted rewards over an episode
        # We apply the discount and normalize it to avoid big variability of rewards
        running_add = 0
        discounted_r = np.zeros_like(reward)
        for i in reversed(range(0,len(reward))):
            running_add = running_add * GAMMA + reward[i]
            discounted_r[i] = running_add

        discounted_r -= np.mean(discounted_r) # normalizing the result
        discounted_r /= (np.std(discounted_r) + 1e-8) # divide by standard deviation
        return discounted_r
    
    def replay(self, states, actions, rewards, predictions, dones, next_states):
        # Reshape memory to appropriate shape for training
        states = np.vstack(states)
        next_states = np.vstack(next_states)
        actions = np.vstack(actions)
        predictions = np.vstack(predictions)

        # Get Critic network predictions for state and next state
        values = self.Critic.model.predict(states)
        next_values = self.Critic.model.predict(next_states)

        # Compute de discounted reward
        discounted_rewards = self.discount_rewards(rewards)

        # Stack info to unpack it in the custom loss
        y_true = actions

        values = np.reshape(values, (np.shape(values)[0],))

        advantages = np.vstack(discounted_rewards - values)
        advantages = np.reshape(advantages, (np.shape(advantages)[0],))

        start_train = time.time()
        # Training Actor and Critic networks
        a_loss = self.Actor.model.fit(states, y_true, sample_weight=advantages, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)
        c_loss = self.Critic.model.fit(states, discounted_rewards, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)
        #print('Time: ', time.time()-start_train)
 
    def load(self):
        self.Actor.Actor.load_weights(self.Actor_name)
        self.Critic.Critic.load_weights(self.Critic_name)

    def save(self):
        self.Actor.model.save_weights(self.Actor_name)
        self.Critic.model.save_weights(self.Critic_name)

    def run_batch(self): # train every self.Training_batch episodes
        global LR
        state = self.env.reset()
        state = np.reshape(state, [1, NUM_STATES])
        done, score = False, 0
        finished = False
        while finished == False:
            # Instantiate or reset games memory
            states, next_states, actions, rewards, predictions, dones = [], [], [], [], [], []
            for t in range(BUFFER_SIZE):
                #self.env.render()
                # Actor picks an action
                action, action_onehot, prediction = self.act(state)
                # Retrieve new state, reward, and whether the state is terminal
                next_state, reward, done, _ = self.env.step(action)
                # Memorize (state, action, reward) for training
                states.append(state)
                next_states.append(np.reshape(next_state, [1, NUM_STATES]))
                actions.append(action_onehot)
                rewards.append(reward)
                dones.append(done)
                predictions.append(prediction)
                # Update current state
                state = np.reshape(next_state, [1, NUM_STATES])
                score += reward
                if done:
                    self.episode += 1
                    self.scores_.append(score)
                    #average, SAVING = self.PlotModel(score, self.episode)
                    #print("episode: {}/{}, score: {}, average: {:.2f} {}".format(self.episode, EPISODES, score, average, SAVING))
                    if self.episode >= 100:
                        average = sum(self.scores_[-100:])/100
                        print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, score, average))
                        if average > self.max_average:
                            self.max_average = average
                            if self.max_average > 150:
                                self.save()
                            LR *= 0.99
                            K.set_value(self.Actor.model.optimizer.learning_rate, LR)
                            K.set_value(self.Critic.model.optimizer.learning_rate, LR)
                            
                        if average > 200:
                            plt.plot(self.scores_)
                            plt.xlabel("Episode")
                            plt.ylabel("Score")
                            finished = True
                            break

                    else:
                        print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, score, sum(self.scores_)/len(self.scores_)))
                    
                    
                    state, done, score = self.env.reset(), False, 0
                    state = np.reshape(state, [1, NUM_STATES])
                    
            self.replay(states, actions, rewards, predictions, dones, next_states)
            if self.episode >= EPISODES:
                break
        self.env.close()   
                    
if __name__ == "__main__":
    start = time.time()
    env_name = 'LunarLander-v2'
    agent = PPOAgent(env_name)
    #agent.run() # train as PPO, train every epesode
    agent.run_batch() # train as PPO, train every batch, trains better
    #agent.run_multiprocesses(num_worker = 8)  # train PPO multiprocessed (fastest)
    #agent.test()
    print((time.time() - start)/60)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Episode:     1		score: -548.49		average: -548.49
# Episode:     2		score: -183.40		average: -365.95
# Episode:     3		score: -109.52		average: -280.47
# Episode:     4		score: -169.20		average: -252.65
# Episode:     5		score:    4.80		average: -201.16
# Episode:     6		score: -272.24		average: -213.01
# Episode:     7		score: -122.58		average: -200.09
# Episode:     8		score:  -80.49		average: -185.14
# Episode:     9		score: -162.93		average: -182.67
# Episode:    10		score:  -87.83		average: -173.19
# Episode:    11		score: -146.37		average: -170.75
# Episode:    12		score:  -76.59		average: -162.90
# Episode:    13		score: -191.78		average: -165.13
# Episode:    14		score: -189.00		average: -166.83
# Episode:    15		score: -100.56		average: -162.41
# Episode:    16		score:  -89.03		average: -157.83
# Episode:    17		score: -595.47		average: -183.57
# Episode:    18		score:  -45.24		average: -175.89
# Episode:    19		score: -405.86		average: -187.99
# Episode:    20		score:  -73.97		average: -182.29
# Episode:    21		score: -232.70		average: -184.69
# Episode:    22		score:  -99.28		average: -180.81
# Episode:    23		score: -619.58		average: -199.88
# Episode:    24		score: -826.37		average: -225.99
# Episode:    25		score: -825.04		average: -249.95
# Episode:    26		score: -900.06		average: -274.95
# Episode:    27		score:  -85.05		average: -267.92
# Episode:    28		score: -677.21		average: -282.54
# Episode:    29		score: -684.49		average: -296.40
# Episode:    30		score: -212.17		average: -293.59
# Episode:    31		score: -699.93		average: -306.70
# Episode:    32		score: -676.66		average: -318.26
# Episode:    33		score: -953.93		average: -337.52
# Episode:    34		score: -672.40		average: -347.37
# Episode:    35		score: -738.42		average: -358.54
# Episode:    36		score: -215.44		average: -354.57
# Episode:    37		score: -414.61		average: -356.19
# Episode:    38		score: -956.50		average: -371.99
# Episode:    39		score: -712.66		average: -380.73
# Episode:    40		score: -508.46		average: -383.92
# Episode:    41		score: -427.68		average: -384.99
# Episode:    42		score: -712.27		average: -392.78
# Episode:    43		score: -993.07		average: -406.74
# Episode:    44		score: -1607.75		average: -434.03
# Episode:    45		score: -1248.19		average: -452.13
# Episode:    46		score: -567.07		average: -454.63
# Episode:    47		score: -260.42		average: -450.49
# Episode:    48		score: -359.05		average: -448.59
# Episode:    49		score: -669.35		average: -453.09
# Episode:    50		score: -140.03		average: -446.83
# Episode:    51		score: -706.92		average: -451.93
# Episode:    52		score: -1163.12		average: -465.61
# Episode:    53		score:  -80.41		average: -458.34
# Episode:    54		score: -153.35		average: -452.69
# Episode:    55		score: -160.78		average: -447.39
# Episode:    56		score: -111.82		average: -441.39
# Episode:    57		score: -182.10		average: -436.84
# Episode:    58		score: -160.25		average: -432.08
# Episode:    59		score: -128.77		average: -426.93
# Episode:    60		score: -147.80		average: -422.28
# Episode:    61		score:   10.73		average: -415.18
# Episode:    62		score: -182.80		average: -411.44
# Episode:    63		score: -145.71		average: -407.22
# Episode:    64		score: -151.64		average: -403.22
# Episode:    65		score: -118.00		average: -398.84
# Episode:    66		score: -111.32		average: -394.48
# Episode:    67		score:  -84.31		average: -389.85
# Episode:    68		score: -130.85		average: -386.04
# Episode:    69		score: -139.67		average: -382.47
# Episode:    70		score: -163.77		average: -379.35
# Episode:    71		score:   -3.23		average: -374.05
# Episode:    72		score: -171.97		average: -371.24
# Episode:    73		score: -126.86		average: -367.90
# Episode:    74		score: -110.07		average: -364.41
# Episode:    75		score: -134.85		average: -361.35
# Episode:    76		score: -154.88		average: -358.63
# Episode:    77		score: -129.85		average: -355.66
# Episode:    78		score: -139.12		average: -352.89
# Episode:    79		score: -144.66		average: -350.25
# Episode:    80		score: -171.03		average: -348.01
# Episode:    81		score: -129.29		average: -345.31
# Episode:    82		score: -134.55		average: -342.74
# Episode:    83		score: -162.27		average: -340.57
# Episode:    84		score: -123.94		average: -337.99
# Episode:    85		score: -151.06		average: -335.79
# Episode:    86		score: -103.85		average: -333.09
# Episode:    87		score: -140.19		average: -330.87
# Episode:    88		score: -189.40		average: -329.27
# Episode:    89		score:  -87.21		average: -326.55
# Episode:    90		score: -110.77		average: -324.15
# Episode:    91		score:  -90.57		average: -321.58
# Episode:    92		score: -127.73		average: -319.47
# Episode:    93		score: -151.57		average: -317.67
# Episode:    94		score: -137.83		average: -315.76
# Episode:    95		score: -142.90		average: -313.94
# Episode:    96		score: -175.50		average: -312.49
# Episode:    97		score:   -9.52		average: -309.37
# Episode:    98		score:  -83.58		average: -307.07
# Episode:    99		score: -131.54		average: -305.29
# Episode:   100		score: -107.96		average: -303.32
# Episode:   101		score: -162.46		average: -299.46
# Episode:   102		score: -130.92		average: -298.94
# Episode:   103		score: -165.91		average: -299.50
# Episode:   104		score: -148.40		average: -299.29
# Episode:   105		score: -171.98		average: -301.06
# Episode:   106		score: -130.67		average: -299.64
# Episode:   107		score: -138.23		average: -299.80
# Episode:   108		score: -143.11		average: -300.43
# Episode:   109		score:  -99.11		average: -299.79
# Episode:   110		score: -146.14		average: -300.37
# Episode:   111		score:  -28.79		average: -299.20
# Episode:   112		score: -186.36		average: -300.29
# Episode:   113		score: -180.19		average: -300.18
# Episode:   114		score: -104.16		average: -299.33
# Episode:   115		score: -122.53		average: -299.55
# Episode:   116		score: -179.13		average: -300.45
# Episode:   117		score: -134.13		average: -295.84
# Episode:   118		score: -156.70		average: -296.95
# Episode:   119		score: -141.93		average: -294.31
# Episode:   120		score: -127.04		average: -294.84
# Episode:   121		score: -117.38		average: -293.69
# Episode:   122		score: -103.16		average: -293.73
# Episode:   123		score: -121.61		average: -288.75
# Episode:   124		score: -160.68		average: -282.09
# Episode:   125		score: -110.83		average: -274.95
# Episode:   126		score: -136.22		average: -267.31
# Episode:   127		score: -147.67		average: -267.94
# Episode:   128		score: -137.91		average: -262.54
# Episode:   129		score: -114.90		average: -256.85
# Episode:   130		score:  -98.22		average: -255.71
# Episode:   131		score:  -60.00		average: -249.31
# Episode:   132		score: -149.30		average: -244.03
# Episode:   133		score: -177.88		average: -236.27
# Episode:   134		score:  -92.47		average: -230.47
# Episode:   135		score: -120.90		average: -224.30
# Episode:   136		score:  -95.75		average: -223.10
# Episode:   137		score: -164.08		average: -220.60
# Episode:   138		score: -131.88		average: -212.35
# Episode:   139		score: -143.28		average: -206.66
# Episode:   140		score: -125.43		average: -202.83
# Episode:   141		score: -163.32		average: -200.18
# Episode:   142		score: -139.99		average: -194.46
# Episode:   143		score: -166.55		average: -186.20
# Episode:   144		score: -125.44		average: -171.37
# Episode:   145		score: -100.60		average: -159.90
# Episode:   146		score: -121.14		average: -155.44
# Episode:   147		score:   39.40		average: -152.44
# Episode:   148		score: -124.26		average: -150.09
# Episode:   149		score: -116.72		average: -144.56
# Episode:   150		score: -106.97		average: -144.23
# Episode:   151		score:  -95.80		average: -138.12
# Episode:   152		score:  -95.32		average: -127.45
# Episode:   153		score: -110.45		average: -127.75
# Episode:   154		score: -124.62		average: -127.46
# Episode:   155		score: -110.90		average: -126.96
# Episode:   156		score:  -30.73		average: -126.15
# Episode:   157		score: -103.62		average: -125.36
# Episode:   158		score: -122.03		average: -124.98
# Episode:   159		score: -112.74		average: -124.82
# Episode:   160		score: -156.23		average: -124.91
# Episode:   161		score: -159.10		average: -126.60
# Episode:   162		score: -145.40		average: -126.23
# Episode:   163		score: -112.80		average: -125.90
# Episode:   164		score: -146.69		average: -125.85
# Episode:   165		score: -112.21		average: -125.79
# Episode:   166		score: -148.79		average: -126.17
# Episode:   167		score: -159.67		average: -126.92
# Episode:   168		score: -135.66		average: -126.97
# Episode:   169		score: -129.77		average: -126.87
# Episode:   170		score: -183.46		average: -127.07
# Episode:   171		score: -124.47		average: -128.28
# Episode:   172		score: -117.95		average: -127.74
# Episode:   173		score: -156.87		average: -128.04
# Episode:   174		score: -106.06		average: -128.00
# Episode:   175		score: -145.76		average: -128.11
# Episode:   176		score: -201.19		average: -128.57
# Episode:   177		score: -165.57		average: -128.93
# Episode:   178		score: -136.58		average: -128.90
# Episode:   179		score: -122.34		average: -128.68
# Episode:   180		score: -147.41		average: -128.44
# Episode:   181		score: -140.00		average: -128.55
# Episode:   182		score: -152.31		average: -128.73
# Episode:   183		score: -151.88		average: -128.62
# Episode:   184		score: -141.73		average: -128.80
# Episode:   185		score: -152.83		average: -128.82
# Episode:   186		score: -125.87		average: -129.04
# Episode:   187		score: -128.05		average: -128.92
# Episode:   188		score: -116.59		average: -128.19
# Episode:   189		score: -142.43		average: -128.74
# Episode:   190		score: -153.17		average: -129.17
# Episode:   191		score: -108.61		average: -129.35
# Episode:   192		score: -167.91		average: -129.75
# Episode:   193		score: -184.14		average: -130.07
# Episode:   194		score: -143.52		average: -130.13
# Episode:   195		score: -106.75		average: -129.77
# Episode:   196		score: -123.02		average: -129.25
# Episode:   197		score:  -95.53		average: -130.11
# Episode:   198		score:   19.02		average: -129.08
# Episode:   199		score: -151.34		average: -129.28
# Episode:   200		score: -108.60		average: -129.28
# Episode:   201		score: -142.48		average: -129.08
# Episode:   202		score: -139.41		average: -129.17
# Episode:   203		score: -163.14		average: -129.14
# Episode:   204		score: -100.69		average: -128.66
# Episode:   205		score: -101.98		average: -127.96
# Episode:   206		score:  -88.56		average: -127.54
# Episode:   207		score: -102.46		average: -127.19
# Episode:   208		score:  -53.38		average: -126.29
# Episode:   209		score: -151.78		average: -126.82
# Episode:   210		score: -258.97		average: -127.94
# Episode:   211		score: -116.61		average: -128.82
# Episode:   212		score: -133.50		average: -128.29
# Episode:   213		score:  -13.52		average: -126.63
# Episode:   214		score: -135.85		average: -126.94
# Episode:   215		score: -111.80		average: -126.84
# Episode:   216		score: -161.82		average: -126.66
# Episode:   217		score: -148.70		average: -126.81
# Episode:   218		score: -112.80		average: -126.37
# Episode:   219		score: -129.92		average: -126.25
# Episode:   220		score: -211.14		average: -127.09
# Episode:   221		score: -204.31		average: -127.96
# Episode:   222		score: -119.93		average: -128.13
# Episode:   223		score: -162.37		average: -128.54
# Episode:   224		score:  -55.56		average: -127.48
# Episode:   225		score: -120.76		average: -127.58
# Episode:   226		score: -147.29		average: -127.69
# Episode:   227		score: -157.67		average: -127.79
# Episode:   228		score: -142.15		average: -127.84
# Episode:   229		score: -126.23		average: -127.95
# Episode:   230		score:   26.52		average: -126.70
# Episode:   231		score: -139.04		average: -127.49
# Episode:   232		score: -106.30		average: -127.06
# Episode:   233		score: -157.77		average: -126.86
# Episode:   234		score: -133.12		average: -127.27
# Episode:   235		score: -132.30		average: -127.38
# Episode:   236		score: -134.42		average: -127.77
# Episode:   237		score: -119.10		average: -127.32
# Episode:   238		score: -138.99		average: -127.39
# Episode:   239		score: -115.81		average: -127.12
# Episode:   240		score: -150.87		average: -127.37
# Episode:   241		score: -151.46		average: -127.25
# Episode:   242		score: -115.62		average: -127.01
# Episode:   243		score:   -5.97		average: -125.40
# Episode:   244		score: -125.75		average: -125.40
# Episode:   245		score: -145.75		average: -125.86
# Episode:   246		score: -114.31		average: -125.79
# Episode:   247		score:  -90.98		average: -127.09
# Episode:   248		score: -147.03		average: -127.32
# Episode:   249		score: -117.48		average: -127.33
# Episode:   250		score:  -95.09		average: -127.21
# Episode:   251		score: -131.05		average: -127.56
# Episode:   252		score: -151.41		average: -128.12
# Episode:   253		score: -138.58		average: -128.40
# Episode:   254		score: -120.94		average: -128.37
# Episode:   255		score: -172.57		average: -128.98
# Episode:   256		score: -154.67		average: -130.22
# Episode:   257		score: -152.09		average: -130.71
# Episode:   258		score: -110.86		average: -130.60
# Episode:   259		score: -121.97		average: -130.69
# Episode:   260		score: -116.71		average: -130.29
# Episode:   261		score: -182.44		average: -130.53
# Episode:   262		score: -168.24		average: -130.75
# Episode:   263		score: -130.76		average: -130.93
# Episode:   264		score: -173.59		average: -131.20
# Episode:   265		score:  -97.30		average: -131.05
# Episode:   266		score: -149.11		average: -131.06
# Episode:   267		score: -152.04		average: -130.98
# Episode:   268		score: -175.00		average: -131.37
# Episode:   269		score: -159.08		average: -131.67
# Episode:   270		score: -149.77		average: -131.33
# Episode:   271		score: -131.12		average: -131.40
# Episode:   272		score: -134.28		average: -131.56
# Episode:   273		score: -120.38		average: -131.20
# Episode:   274		score:    3.67		average: -130.10
# Episode:   275		score: -142.69		average: -130.07
# Episode:   276		score: -138.61		average: -129.44
# Episode:   277		score: -161.56		average: -129.40
# Episode:   278		score: -181.13		average: -129.85
# Episode:   279		score: -143.31		average: -130.06
# Episode:   280		score: -149.46		average: -130.08
# Episode:   281		score: -144.76		average: -130.12
# Episode:   282		score: -126.35		average: -129.87
# Episode:   283		score: -138.92		average: -129.74
# Episode:   284		score:  -19.23		average: -128.51
# Episode:   285		score: -108.69		average: -128.07
# Episode:   286		score: -153.23		average: -128.34
# Episode:   287		score:  -79.49		average: -127.86
# Episode:   288		score: -171.79		average: -128.41
# Episode:   289		score: -116.56		average: -128.15
# Episode:   290		score: -144.20		average: -128.06
# Episode:   291		score: -132.37		average: -128.30
# Episode:   292		score: -114.21		average: -127.76
# Episode:   293		score: -136.76		average: -127.29
# Episode:   294		score: -175.93		average: -127.61
# Episode:   295		score: -115.78		average: -127.70
# Episode:   296		score:  -94.96		average: -127.42
# Episode:   297		score: -104.12		average: -127.51
# Episode:   298		score: -149.70		average: -129.19
# Episode:   299		score: -119.52		average: -128.88
# Episode:   300		score: -122.93		average: -129.02
# Episode:   301		score:  -96.00		average: -128.55
# Episode:   302		score: -106.33		average: -128.22
# Episode:   303		score: -120.38		average: -127.80
# Episode:   304		score: -122.96		average: -128.02
# Episode:   305		score: -135.35		average: -128.35
# Episode:   306		score:  -91.47		average: -128.38
# Episode:   307		score: -167.19		average: -129.03
# Episode:   308		score: -118.53		average: -129.68
# Episode:   309		score: -140.63		average: -129.57
# Episode:   310		score: -122.97		average: -128.21
# Episode:   311		score: -122.08		average: -128.26
# Episode:   312		score: -121.78		average: -128.15
# Episode:   313		score: -130.93		average: -129.32
# Episode:   314		score:  -93.87		average: -128.90
# Episode:   315		score: -113.86		average: -128.92
# Episode:   316		score: -128.57		average: -128.59
# Episode:   317		score: -157.27		average: -128.67
# Episode:   318		score: -174.90		average: -129.30
# Episode:   319		score:  -97.77		average: -128.97
# Episode:   320		score: -140.92		average: -128.27
# Episode:   321		score: -138.11		average: -127.61
# Episode:   322		score:  -21.20		average: -126.62
# Episode:   323		score: -116.41		average: -126.16
# Episode:   324		score: -110.70		average: -126.71
# Episode:   325		score:  -89.41		average: -126.40
# Episode:   326		score: -114.13		average: -126.07
# Episode:   327		score: -112.11		average: -125.61
# Episode:   328		score: -138.12		average: -125.57
# Episode:   329		score:  -79.73		average: -125.11
# Episode:   330		score: -132.66		average: -126.70
# Episode:   331		score: -107.96		average: -126.39
# Episode:   332		score: -151.47		average: -126.84
# Episode:   333		score: -110.96		average: -126.37
# Episode:   334		score: -157.03		average: -126.61
# Episode:   335		score:    4.40		average: -125.25
# Episode:   336		score: -167.37		average: -125.57
# Episode:   337		score: -224.15		average: -126.63
# Episode:   338		score:  -13.86		average: -125.37
# Episode:   339		score: -138.64		average: -125.60
# Episode:   340		score: -103.77		average: -125.13
# Episode:   341		score:  -96.31		average: -124.58
# Episode:   342		score: -159.11		average: -125.01
# Episode:   343		score: -141.68		average: -126.37
# Episode:   344		score: -126.57		average: -126.38
# Episode:   345		score: -171.84		average: -126.64
# Episode:   346		score: -134.86		average: -126.85
# Episode:   347		score: -161.10		average: -127.55
# Episode:   348		score: -188.96		average: -127.97
# Episode:   349		score:  -62.26		average: -127.41
# Episode:   350		score:  -90.99		average: -127.37
# Episode:   351		score: -122.50		average: -127.29
# Episode:   352		score:  -35.24		average: -126.13
# Episode:   353		score: -141.58		average: -126.16
# Episode:   354		score: -116.22		average: -126.11
# Episode:   355		score: -109.42		average: -125.48
# Episode:   356		score: -138.10		average: -125.31
# Episode:   357		score: -262.36		average: -126.41
# Episode:   358		score: -144.77		average: -126.75
# Episode:   359		score: -140.22		average: -126.94
# Episode:   360		score:  -92.26		average: -126.69
# Episode:   361		score: -103.02		average: -125.90
# Episode:   362		score: -139.15		average: -125.61
# Episode:   363		score: -136.18		average: -125.66
# Episode:   364		score: -148.69		average: -125.41
# Episode:   365		score: -146.58		average: -125.90
# Episode:   366		score: -109.75		average: -125.51
# Episode:   367		score: -120.15		average: -125.19
# Episode:   368		score: -113.57		average: -124.58
# Episode:   369		score: -172.28		average: -124.71
# Episode:   370		score:  -18.75		average: -123.40
# Episode:   371		score:  -68.66		average: -122.78
# Episode:   372		score:   36.44		average: -121.07
# Episode:   373		score: -263.72		average: -122.50
# Episode:   374		score: -133.49		average: -123.87
# Episode:   375		score:  -81.29		average: -123.26
# Episode:   376		score: -116.08		average: -123.03
# Episode:   377		score: -116.26		average: -122.58
# Episode:   378		score:  -87.37		average: -121.64
# Episode:   379		score: -161.99		average: -121.83
# Episode:   380		score: -146.18		average: -121.80
# Episode:   381		score: -157.01		average: -121.92
# Episode:   382		score: -204.90		average: -122.71
# Episode:   383		score: -170.54		average: -123.02
# Episode:   384		score: -138.30		average: -124.21
# Episode:   385		score: -140.71		average: -124.53
# Episode:   386		score: -114.40		average: -124.14
# Episode:   387		score:  -92.28		average: -124.27
# Episode:   388		score: -163.41		average: -124.19
# Episode:   389		score: -119.67		average: -124.22
# Episode:   390		score: -121.18		average: -123.99
# Episode:   391		score: -141.37		average: -124.08
# Episode:   392		score: -159.49		average: -124.53
# Episode:   393		score: -213.70		average: -125.30
# Episode:   394		score:  -95.40		average: -124.50
# Episode:   395		score: -130.65		average: -124.64
# Episode:   396		score: -272.86		average: -126.42
# Episode:   397		score: -120.13		average: -126.58
# Episode:   398		score: -164.99		average: -126.74
# Episode:   399		score: -165.52		average: -127.20
# Episode:   400		score: -191.60		average: -127.88
# Episode:   401		score:  -98.81		average: -127.91
# Episode:   402		score: -121.65		average: -128.06
# Episode:   403		score: -118.15		average: -128.04
# Episode:   404		score: -215.22		average: -128.97
# Episode:   405		score: -120.95		average: -128.82
# Episode:   406		score: -102.64		average: -128.93
# Episode:   407		score: -137.73		average: -128.64
# Episode:   408		score: -107.54		average: -128.53
# Episode:   409		score: -113.34		average: -128.26
# Episode:   410		score: -193.17		average: -128.96
# Episode:   411		score: -178.84		average: -129.52
# Episode:   412		score: -260.60		average: -130.91
# Episode:   413		score: -140.98		average: -131.01
# Episode:   414		score: -157.78		average: -131.65
# Episode:   415		score: -156.77		average: -132.08
# Episode:   416		score:  -93.40		average: -131.73
# Episode:   417		score: -116.94		average: -131.33
# Episode:   418		score: -122.47		average: -130.80
# Episode:   419		score: -170.68		average: -131.53
# Episode:   420		score: -143.29		average: -131.56
# Episode:   421		score: -140.58		average: -131.58
# Episode:   422		score: -114.67		average: -132.51
# Episode:   423		score: -165.77		average: -133.01
# Episode:   424		score: -135.73		average: -133.26
# Episode:   425		score: -161.93		average: -133.98
# Episode:   426		score: -137.78		average: -134.22
# Episode:   427		score: -129.15		average: -134.39
# Episode:   428		score: -172.60		average: -134.74
# Episode:   429		score: -144.04		average: -135.38
# Episode:   430		score: -116.41		average: -135.22
# Episode:   431		score: -138.29		average: -135.52
# Episode:   432		score: -118.49		average: -135.19
# Episode:   433		score: -120.79		average: -135.29
# Episode:   434		score: -118.93		average: -134.91
# Episode:   435		score: -102.63		average: -135.98
# Episode:   436		score: -149.49		average: -135.80
# Episode:   437		score: -107.65		average: -134.63
# Episode:   438		score: -150.93		average: -136.00
# Episode:   439		score: -150.85		average: -136.13
# Episode:   440		score: -108.46		average: -136.17
# Episode:   441		score: -181.84		average: -137.03
# Episode:   442		score:  -96.17		average: -136.40
# Episode:   443		score: -146.65		average: -136.45
# Episode:   444		score: -163.34		average: -136.82
# Episode:   445		score: -117.43		average: -136.27
# Episode:   446		score: -138.18		average: -136.31
# Episode:   447		score: -142.84		average: -136.12
# Episode:   448		score: -142.65		average: -135.66
# Episode:   449		score: -117.85		average: -136.22
# Episode:   450		score: -176.08		average: -137.07
# Episode:   451		score: -115.41		average: -137.00
# Episode:   452		score: -143.90		average: -138.08
# Episode:   453		score: -196.44		average: -138.63
# Episode:   454		score: -116.72		average: -138.64
# Episode:   455		score: -117.77		average: -138.72
# Episode:   456		score: -149.28		average: -138.83
# Episode:   457		score: -127.30		average: -137.48
# Episode:   458		score: -163.33		average: -137.67
# Episode:   459		score:  -40.07		average: -136.66
# Episode:   460		score: -138.89		average: -137.13
# Episode:   461		score:  -82.05		average: -136.92
# Episode:   462		score: -130.87		average: -136.84
# Episode:   463		score: -142.73		average: -136.90
# Episode:   464		score: -183.04		average: -137.25
# Episode:   465		score: -102.81		average: -136.81
# Episode:   466		score: -193.20		average: -137.64
# Episode:   467		score: -121.35		average: -137.66
# Episode:   468		score: -152.47		average: -138.05
# Episode:   469		score: -138.03		average: -137.70
# Episode:   470		score: -148.69		average: -139.00
# Episode:   471		score: -199.56		average: -140.31
# Episode:   472		score: -128.09		average: -141.96
# Episode:   473		score: -153.41		average: -140.85
# Episode:   474		score: -106.33		average: -140.58
# Episode:   475		score: -136.01		average: -141.13
# Episode:   476		score: -125.20		average: -141.22
# Episode:   477		score: -105.53		average: -141.11
# Episode:   478		score: -144.11		average: -141.68
# Episode:   479		score: -181.29		average: -141.87
# Episode:   480		score: -138.10		average: -141.79
# Episode:   481		score: -127.77		average: -141.50
# Episode:   482		score: -159.03		average: -141.04
# Episode:   483		score:  -88.07		average: -140.22
# Episode:   484		score: -152.46		average: -140.36
# Episode:   485		score: -135.35		average: -140.30
# Episode:   486		score: -115.89		average: -140.32
# Episode:   487		score:  -92.65		average: -140.32
# Episode:   488		score: -117.62		average: -139.87
# Episode:   489		score: -107.64		average: -139.74
# Episode:   490		score: -133.94		average: -139.87
# Episode:   491		score: -130.07		average: -139.76
# Episode:   492		score: -124.70		average: -139.41
# Episode:   493		score: -162.63		average: -138.90
# Episode:   494		score: -134.30		average: -139.29
# Episode:   495		score:  -82.39		average: -138.81
# Episode:   496		score: -143.22		average: -137.51
# Episode:   497		score: -139.10		average: -137.70
# Episode:   498		score: -128.68		average: -137.34
# Episode:   499		score:   45.61		average: -135.23
# Episode:   500		score: -130.50		average: -134.62
# Episode:   501		score: -135.56		average: -134.98
# Episode:   502		score: -134.72		average: -135.11
# Episode:   503		score: -149.28		average: -135.42
# Episode:   504		score: -142.37		average: -134.70
# Episode:   505		score: -141.18		average: -134.90
# Episode:   506		score: -120.36		average: -135.08
# Episode:   507		score: -183.11		average: -135.53
# Episode:   508		score: -140.19		average: -135.86
# Episode:   509		score: -159.26		average: -136.32
# Episode:   510		score: -140.54		average: -135.79
# Episode:   511		score: -137.07		average: -135.37
# Episode:   512		score:  -24.69		average: -133.01
# Episode:   513		score:  -55.62		average: -132.16
# Episode:   514		score: -136.74		average: -131.95
# Episode:   515		score: -136.63		average: -131.75
# Episode:   516		score: -117.06		average: -131.98
# Episode:   517		score: -183.17		average: -132.65
# Episode:   518		score: -127.03		average: -132.69
# Episode:   519		score: -144.20		average: -132.43
# Episode:   520		score: -116.65		average: -132.16
# Episode:   521		score: -151.03		average: -132.26
# Episode:   522		score: -132.43		average: -132.44
# Episode:   523		score: -198.87		average: -132.77
# Episode:   524		score: -145.59		average: -132.87
# Episode:   525		score: -303.10		average: -134.28
# Episode:   526		score: -135.31		average: -134.26
# Episode:   527		score:   31.51		average: -132.65
# Episode:   528		score: -159.65		average: -132.52
# Episode:   529		score: -152.53		average: -132.61
# Episode:   530		score:  -99.11		average: -132.43
# Episode:   531		score: -137.87		average: -132.43
# Episode:   532		score: -130.60		average: -132.55
# Episode:   533		score: -117.60		average: -132.52
# Episode:   534		score: -138.50		average: -132.72
# Episode:   535		score: -111.63		average: -132.81
# Episode:   536		score: -127.29		average: -132.58
# Episode:   537		score: -115.91		average: -132.67
# Episode:   538		score: -151.43		average: -132.67
# Episode:   539		score:  -95.40		average: -132.12
# Episode:   540		score: -150.85		average: -132.54
# Episode:   541		score: -154.67		average: -132.27
# Episode:   542		score: -188.37		average: -133.19
# Episode:   543		score: -112.87		average: -132.85
# Episode:   544		score: -131.27		average: -132.53
# Episode:   545		score: -151.66		average: -132.87
# Episode:   546		score:   -6.10		average: -131.55
# Episode:   547		score: -113.60		average: -131.26
# Episode:   548		score: -143.15		average: -131.27
# Episode:   549		score: -162.25		average: -131.71
# Episode:   550		score: -124.08		average: -131.19
# Episode:   551		score:  -82.48		average: -130.86
# Episode:   552		score: -171.99		average: -131.14
# Episode:   553		score: -128.93		average: -130.47
# Episode:   554		score: -107.14		average: -130.37
# Episode:   555		score:  -89.86		average: -130.09
# Episode:   556		score:  -98.95		average: -129.59
# Episode:   557		score: -152.42		average: -129.84
# Episode:   558		score: -143.11		average: -129.64
# Episode:   559		score: -132.47		average: -130.56
# Episode:   560		score: -291.38		average: -132.09
# Episode:   561		score: -115.22		average: -132.42
# Episode:   562		score:    2.26		average: -131.09
# Episode:   563		score: -108.41		average: -130.74
# Episode:   564		score: -135.17		average: -130.26
# Episode:   565		score:  -21.81		average: -129.45
# Episode:   566		score: -193.54		average: -129.46
# Episode:   567		score: -104.82		average: -129.29
# Episode:   568		score: -147.44		average: -129.24
# Episode:   569		score: -164.85		average: -129.51
# Episode:   570		score: -169.37		average: -129.72
# Episode:   571		score:    7.75		average: -127.64
# Episode:   572		score: -140.24		average: -127.77
# Episode:   573		score: -161.58		average: -127.85
# Episode:   574		score: -169.83		average: -128.48
# Episode:   575		score: -193.78		average: -129.06
# Episode:   576		score: -177.15		average: -129.58
# Episode:   577		score:    2.63		average: -128.50
# Episode:   578		score: -155.03		average: -128.61
# Episode:   579		score: -124.85		average: -128.04
# Episode:   580		score: -120.01		average: -127.86
# Episode:   581		score: -143.84		average: -128.02
# Episode:   582		score: -138.54		average: -127.82
# Episode:   583		score: -181.96		average: -128.76
# Episode:   584		score: -130.38		average: -128.54
# Episode:   585		score: -141.86		average: -128.60
# Episode:   586		score: -133.41		average: -128.78
# Episode:   587		score: -108.24		average: -128.93
# Episode:   588		score: -175.32		average: -129.51
# Episode:   589		score: -148.05		average: -129.91
# Episode:   590		score:   28.50		average: -128.29
# Episode:   591		score: -131.30		average: -128.30
# Episode:   592		score: -141.64		average: -128.47
# Episode:   593		score: -169.52		average: -128.54
# Episode:   594		score:  -20.59		average: -127.40
# Episode:   595		score: -168.11		average: -128.26
# Episode:   596		score: -122.15		average: -128.05
# Episode:   597		score: -185.86		average: -128.52
# Episode:   598		score: -163.56		average: -128.87
# Episode:   599		score: -175.28		average: -131.07
# Episode:   600		score: -110.49		average: -130.87
# Episode:   601		score: -143.38		average: -130.95
# Episode:   602		score: -163.90		average: -131.24
# Episode:   603		score: -169.67		average: -131.45
# Episode:   604		score: -163.43		average: -131.66
# Episode:   605		score: -134.90		average: -131.60
# Episode:   606		score:  -93.34		average: -131.33
# Episode:   607		score: -141.13		average: -130.91
# Episode:   608		score:   -2.06		average: -129.52
# Episode:   609		score: -108.79		average: -129.02
# Episode:   610		score: -138.87		average: -129.00
# Episode:   611		score:  -93.67		average: -128.57
# Episode:   612		score: -209.97		average: -130.42
# Episode:   613		score:  -23.94		average: -130.11
# Episode:   614		score: -146.25		average: -130.20
# Episode:   615		score: -135.76		average: -130.19
# Episode:   616		score: -117.75		average: -130.20
# Episode:   617		score: -195.56		average: -130.32
# Episode:   618		score: -194.13		average: -130.99
# Episode:   619		score: -144.97		average: -131.00
# Episode:   620		score: -110.54		average: -130.94
# Episode:   621		score:   -5.09		average: -129.48
# Episode:   622		score: -155.59		average: -129.71
# Episode:   623		score:    2.79		average: -127.70
# Episode:   624		score:  -86.79		average: -127.11
# Episode:   625		score: -148.90		average: -125.57
# Episode:   626		score:  -99.73		average: -125.21
# Episode:   627		score: -119.21		average: -126.72
# Episode:   628		score: -154.50		average: -126.67
# Episode:   629		score: -160.67		average: -126.75
# Episode:   630		score: -157.99		average: -127.34
# Episode:   631		score: -148.80		average: -127.45
# Episode:   632		score: -120.65		average: -127.35
# Episode:   633		score: -170.90		average: -127.88
# Episode:   634		score: -125.37		average: -127.75
# Episode:   635		score: -152.32		average: -128.15
# Episode:   636		score: -109.51		average: -127.98
# Episode:   637		score: -125.18		average: -128.07
# Episode:   638		score: -113.12		average: -127.69
# Episode:   639		score: -122.19		average: -127.95
# Episode:   640		score:  -91.32		average: -127.36
# Episode:   641		score: -159.08		average: -127.40
# Episode:   642		score: -172.31		average: -127.24
# Episode:   643		score:   16.54		average: -125.95
# Episode:   644		score: -147.57		average: -126.11
# Episode:   645		score: -149.40		average: -126.09
# Episode:   646		score:  -93.07		average: -126.96
# Episode:   647		score: -189.43		average: -127.72
# Episode:   648		score: -122.37		average: -127.51
# Episode:   649		score: -114.43		average: -127.03
# Episode:   650		score: -116.65		average: -126.96
# Episode:   651		score: -169.54		average: -127.83
# Episode:   652		score: -148.73		average: -127.59
# Episode:   653		score: -160.66		average: -127.91
# Episode:   654		score: -143.00		average: -128.27
# Episode:   655		score: -160.94		average: -128.98
# Episode:   656		score: -160.51		average: -129.60
# Episode:   657		score: -113.10		average: -129.20
# Episode:   658		score: -132.84		average: -129.10
# Episode:   659		score: -105.84		average: -128.83
# Episode:   660		score: -143.86		average: -127.36
# Episode:   661		score: -113.56		average: -127.34
# Episode:   662		score: -142.19		average: -128.79
# Episode:   663		score: -181.45		average: -129.52
# Episode:   664		score: -153.80		average: -129.70
# Episode:   665		score:  -92.99		average: -130.42
# Episode:   666		score: -140.29		average: -129.88
# Episode:   667		score: -124.79		average: -130.08
# Episode:   668		score: -165.96		average: -130.27
# Episode:   669		score: -124.36		average: -129.86
# Episode:   670		score: -118.26		average: -129.35
# Episode:   671		score: -106.18		average: -130.49
# Episode:   672		score: -121.79		average: -130.31
# Episode:   673		score: -145.09		average: -130.14
# Episode:   674		score: -130.82		average: -129.75
# Episode:   675		score:  -30.72		average: -128.12
# Episode:   676		score: -127.39		average: -127.62
# Episode:   677		score: -117.20		average: -128.82
# Episode:   678		score: -143.57		average: -128.71
# Episode:   679		score:  -91.71		average: -128.38
# Episode:   680		score: -166.02		average: -128.84
# Episode:   681		score:  -79.03		average: -128.19
# Episode:   682		score: -130.93		average: -128.11
# Episode:   683		score: -112.23		average: -127.41
# Episode:   684		score: -127.78		average: -127.39
# Episode:   685		score:  -86.69		average: -126.84
# Episode:   686		score: -125.94		average: -126.76
# Episode:   687		score: -154.74		average: -127.23
# Episode:   688		score: -141.51		average: -126.89
# Episode:   689		score: -141.77		average: -126.83
# Episode:   690		score: -140.87		average: -128.52
# Episode:   691		score: -116.75		average: -128.37
# Episode:   692		score: -170.54		average: -128.66
# Episode:   693		score:  -99.03		average: -127.96
# Episode:   694		score: -157.35		average: -129.33
# Episode:   695		score: -108.91		average: -128.73
# Episode:   696		score:  -95.82		average: -128.47
# Episode:   697		score: -119.35		average: -127.81
# Episode:   698		score: -120.80		average: -127.38
# Episode:   699		score: -142.62		average: -127.05
# Episode:   700		score: -124.58		average: -127.19
# Episode:   701		score: -163.36		average: -127.39
# Episode:   702		score: -124.46		average: -127.00
# Episode:   703		score:   32.56		average: -124.98
# Episode:   704		score: -177.55		average: -125.12
# Episode:   705		score:  -93.04		average: -124.70
# Episode:   706		score: -123.14		average: -125.00
# Episode:   707		score: -163.33		average: -125.22
# Episode:   708		score: -122.96		average: -126.43
# Episode:   709		score: -126.93		average: -126.61
# Episode:   710		score: -137.82		average: -126.60
# Episode:   711		score: -147.59		average: -127.14
# Episode:   712		score: -120.33		average: -126.24
# Episode:   713		score:   11.82		average: -125.88
# Episode:   714		score: -118.85		average: -125.61
# Episode:   715		score: -127.74		average: -125.53
# Episode:   716		score: -147.32		average: -125.82
# Episode:   717		score: -144.16		average: -125.31
# Episode:   718		score: -166.08		average: -125.03
# Episode:   719		score:  -31.03		average: -123.89
# Episode:   720		score:   41.16		average: -122.37
# Episode:   721		score: -101.18		average: -123.33
# Episode:   722		score: -143.07		average: -123.21
# Episode:   723		score: -156.18		average: -124.80
# Episode:   724		score: -157.41		average: -125.51
# Episode:   725		score:  -93.99		average: -124.96
# Episode:   726		score: -120.93		average: -125.17
# Episode:   727		score: -119.77		average: -125.17
# Episode:   728		score: -151.26		average: -125.14
# Episode:   729		score: -185.99		average: -125.39
# Episode:   730		score: -154.82		average: -125.36
# Episode:   731		score: -161.63		average: -125.49
# Episode:   732		score: -143.90		average: -125.72
# Episode:   733		score: -170.29		average: -125.72
# Episode:   734		score: -110.13		average: -125.56
# Episode:   735		score: -117.95		average: -125.22
# Episode:   736		score: -133.69		average: -125.46
# Episode:   737		score: -128.34		average: -125.49
# Episode:   738		score: -138.89		average: -125.75
# Episode:   739		score: -122.76		average: -125.76
# Episode:   740		score: -155.25		average: -126.40
# Episode:   741		score: -134.21		average: -126.15
# Episode:   742		score: -282.80		average: -127.25
# Episode:   743		score: -154.89		average: -128.97
# Episode:   744		score: -186.89		average: -129.36
# Episode:   745		score: -145.33		average: -129.32
# Episode:   746		score:  -37.65		average: -128.77
# Episode:   747		score: -110.51		average: -127.98
# Episode:   748		score: -138.74		average: -128.14
# Episode:   749		score: -116.53		average: -128.16
# Episode:   750		score: -136.62		average: -128.36
# Episode:   751		score:   -2.03		average: -126.69
# Episode:   752		score: -112.27		average: -126.32
# Episode:   753		score: -117.88		average: -125.89
# Episode:   754		score: -182.08		average: -126.28
# Episode:   755		score: -169.28		average: -126.37
# Episode:   756		score: -141.83		average: -126.18
# Episode:   757		score: -117.63		average: -126.23
# Episode:   758		score: -152.81		average: -126.43
# Episode:   759		score: -116.84		average: -126.54
# Episode:   760		score: -174.44		average: -126.84
# Episode:   761		score: -148.11		average: -127.19
# Episode:   762		score: -127.41		average: -127.04
# Episode:   763		score: -102.49		average: -126.25
# Episode:   764		score: -134.13		average: -126.05
# Episode:   765		score: -150.85		average: -126.63
# Episode:   766		score: -207.36		average: -127.30
# Episode:   767		score: -125.58		average: -127.31
# Episode:   768		score: -115.34		average: -126.80
# Episode:   769		score: -129.07		average: -126.85
# Episode:   770		score: -145.71		average: -127.13
# Episode:   771		score: -139.93		average: -127.46
# Episode:   772		score: -153.00		average: -127.78
# Episode:   773		score: -103.48		average: -127.36
# Episode:   774		score: -117.39		average: -127.23
# Episode:   775		score: -172.30		average: -128.64
# Episode:   776		score: -145.66		average: -128.82
# Episode:   777		score: -127.84		average: -128.93
# Episode:   778		score: -102.18		average: -128.52
# Episode:   779		score: -176.64		average: -129.37
# Episode:   780		score: -119.21		average: -128.90
# Episode:   781		score:  -27.42		average: -128.38
# Episode:   782		score: -142.31		average: -128.50
# Episode:   783		score: -144.40		average: -128.82
# Episode:   784		score: -135.57		average: -128.89
# Episode:   785		score: -149.46		average: -129.52
# Episode:   786		score: -174.14		average: -130.00
# Episode:   787		score: -144.65		average: -129.90
# Episode:   788		score: -114.82		average: -129.64
# Episode:   789		score: -138.83		average: -129.61
# Episode:   790		score: -206.42		average: -130.26
# Episode:   791		score: -183.36		average: -130.93
# Episode:   792		score: -147.52		average: -130.70
# Episode:   793		score:    0.67		average: -129.70
# Episode:   794		score: -137.22		average: -129.50
# Episode:   795		score:   -4.51		average: -128.46
# Episode:   796		score: -136.46		average: -128.86
# Episode:   797		score: -147.29		average: -129.14
# Episode:   798		score:   20.16		average: -127.73
# Episode:   799		score: -162.61		average: -127.93
# Episode:   800		score: -138.27		average: -128.07
# Episode:   801		score: -200.80		average: -128.44
# Episode:   802		score: -105.99		average: -128.26
# Episode:   803		score: -120.50		average: -129.79
# Episode:   804		score: -206.68		average: -130.08
# Episode:   805		score: -145.29		average: -130.60
# Episode:   806		score: -115.66		average: -130.53
# Episode:   807		score: -143.03		average: -130.33
# Episode:   808		score: -139.66		average: -130.49
# Episode:   809		score: -125.55		average: -130.48
# Episode:   810		score: -120.69		average: -130.31
# Episode:   811		score:  -97.84		average: -129.81
# Episode:   812		score:  -92.15		average: -129.53
# Episode:   813		score: -104.89		average: -130.70
# Episode:   814		score:    6.96		average: -129.44
# Episode:   815		score: -166.08		average: -129.82
# Episode:   816		score: -137.77		average: -129.73
# Episode:   817		score: -192.48		average: -130.21
# Episode:   818		score:  -26.80		average: -128.82
# Episode:   819		score: -119.91		average: -129.70
# Episode:   820		score: -124.07		average: -131.36
# Episode:   821		score: -121.32		average: -131.56
# Episode:   822		score: -141.86		average: -131.55
# Episode:   823		score: -192.28		average: -131.91
# Episode:   824		score: -160.42		average: -131.94
# Episode:   825		score: -114.14		average: -132.14
# Episode:   826		score: -156.70		average: -132.50
# Episode:   827		score: -104.81		average: -132.35
# Episode:   828		score: -119.98		average: -132.03
# Episode:   829		score: -173.40		average: -131.91
# Episode:   830		score: -131.45		average: -131.67
# Episode:   831		score: -103.19		average: -131.09
# Episode:   832		score:  -99.47		average: -130.65
# Episode:   833		score: -145.28		average: -130.40
# Episode:   834		score: -142.24		average: -130.72
# Episode:   835		score: -141.98		average: -130.96
# Episode:   836		score: -144.98		average: -131.07
# Episode:   837		score: -138.57		average: -131.17
# Episode:   838		score: -151.81		average: -131.30
# Episode:   839		score: -114.66		average: -131.22
# Episode:   840		score: -132.41		average: -130.99
# Episode:   841		score: -122.87		average: -130.88
# Episode:   842		score: -132.77		average: -129.38
# Episode:   843		score: -165.12		average: -129.48
# Episode:   844		score: -114.92		average: -128.76
# Episode:   845		score: -124.55		average: -128.55
# Episode:   846		score: -147.02		average: -129.65
# Episode:   847		score: -115.00		average: -129.69
# Episode:   848		score: -125.04		average: -129.55
# Episode:   849		score:  -98.03		average: -129.37
# Episode:   850		score: -173.86		average: -129.74
# Episode:   851		score: -156.49		average: -131.29
# Episode:   852		score: -144.40		average: -131.61
# Episode:   853		score: -144.67		average: -131.88
# Episode:   854		score: -144.05		average: -131.50
# Episode:   855		score: -112.40		average: -130.93
# Episode:   856		score: -167.58		average: -131.18
# Episode:   857		score: -170.79		average: -131.72
# Episode:   858		score: -123.63		average: -131.42
# Episode:   859		score: -121.82		average: -131.47
# Episode:   860		score: -113.62		average: -130.87
# Episode:   861		score: -126.83		average: -130.65
# Episode:   862		score: -110.51		average: -130.48
# Episode:   863		score: -100.40		average: -130.46
# Episode:   864		score: -131.02		average: -130.43
# Episode:   865		score: -127.34		average: -130.20
# Episode:   866		score: -131.73		average: -129.44
# Episode:   867		score: -123.43		average: -129.42
# Episode:   868		score: -147.09		average: -129.74
# Episode:   869		score: -161.02		average: -130.06
# Episode:   870		score: -138.81		average: -129.99
# Episode:   871		score: -134.36		average: -129.93
# Episode:   872		score: -109.84		average: -129.50
# Episode:   873		score: -160.73		average: -130.07
# Episode:   874		score: -155.85		average: -130.46
# Episode:   875		score: -132.75		average: -130.06
# Episode:   876		score: -161.26		average: -130.22
# Episode:   877		score: -120.72		average: -130.15
# Episode:   878		score: -105.81		average: -130.18
# Episode:   879		score: -152.77		average: -129.94
# Episode:   880		score: -206.84		average: -130.82
# Episode:   881		score: -126.49		average: -131.81
# Episode:   882		score: -161.64		average: -132.00
# Episode:   883		score: -124.21		average: -131.80
# Episode:   884		score: -125.98		average: -131.71
# Episode:   885		score: -187.40		average: -132.09
# Episode:   886		score: -126.88		average: -131.61
# Episode:   887		score: -303.85		average: -133.20
# Episode:   888		score: -161.30		average: -133.67
# Episode:   889		score: -130.35		average: -133.58
# Episode:   890		score: -173.93		average: -133.26
# Episode:   891		score: -133.64		average: -132.76
# Episode:   892		score: -159.98		average: -132.89
# Episode:   893		score: -145.77		average: -134.35
# Episode:   894		score: -153.45		average: -134.51
# Episode:   895		score: -115.87		average: -135.63
# Episode:   896		score: -124.18		average: -135.50
# Episode:   897		score: -132.13		average: -135.35
# Episode:   898		score: -130.89		average: -136.86
# Episode:   899		score: -167.53		average: -136.91
# Episode:   900		score: -129.43		average: -136.82
# Episode:   901		score:  -78.12		average: -135.60
# Episode:   902		score:  -89.96		average: -135.44
# Episode:   903		score: -119.31		average: -135.43
# Episode:   904		score:  -54.57		average: -133.90
# Episode:   905		score: -131.32		average: -133.76
# Episode:   906		score: -178.91		average: -134.40
# Episode:   907		score: -137.88		average: -134.35
# Episode:   908		score: -100.07		average: -133.95
# Episode:   909		score:  -65.05		average: -133.34
# Episode:   910		score:  -98.90		average: -133.13
# Episode:   911		score: -178.85		average: -133.94
# Episode:   912		score: -112.25		average: -134.14
# Episode:   913		score: -124.96		average: -134.34
# Episode:   914		score:  -84.74		average: -135.26
# Episode:   915		score: -200.73		average: -135.60
# Episode:   916		score: -104.03		average: -135.26
# Episode:   917		score: -143.41		average: -134.77
# Episode:   918		score: -121.37		average: -135.72
# Episode:   919		score: -308.75		average: -137.61
# Episode:   920		score:  -13.27		average: -136.50
# Episode:   921		score: -101.65		average: -136.30
# Episode:   922		score: -122.92		average: -136.11
# Episode:   923		score: -123.14		average: -135.42
# Episode:   924		score: -125.44		average: -135.07
# Episode:   925		score: -144.04		average: -135.37
# Episode:   926		score:   54.03		average: -133.26
# Episode:   927		score: -209.26		average: -134.31
# Episode:   928		score: -165.50		average: -134.76
# Episode:   929		score: -151.57		average: -134.55
# Episode:   930		score: -126.45		average: -134.50
# Episode:   931		score: -110.98		average: -134.57
# Episode:   932		score: -124.09		average: -134.82
# Episode:   933		score: -134.94		average: -134.72
# Episode:   934		score: -214.29		average: -135.44
# Episode:   935		score: -146.54		average: -135.48
# Episode:   936		score: -152.63		average: -135.56
# Episode:   937		score: -118.11		average: -135.35
# Episode:   938		score: -168.29		average: -135.52
# Episode:   939		score: -176.25		average: -136.13
# Episode:   940		score: -128.77		average: -136.10
# Episode:   941		score: -136.81		average: -136.24
# Episode:   942		score: -109.57		average: -136.01
# Episode:   943		score: -122.50		average: -135.58
# Episode:   944		score:  -84.01		average: -135.27
# Episode:   945		score: -117.56		average: -135.20
# Episode:   946		score: -102.05		average: -134.75
# Episode:   947		score: -188.62		average: -135.49
# Episode:   948		score: -116.84		average: -135.41
# Episode:   949		score: -121.66		average: -135.64
# Episode:   950		score:  -87.16		average: -134.77
# Episode:   951		score: -123.17		average: -134.44
# Episode:   952		score:  -28.17		average: -133.28
# Episode:   953		score: -164.63		average: -133.48
# Episode:   954		score: -132.28		average: -133.36
# Episode:   955		score: -188.25		average: -134.12
# Episode:   956		score:  -91.52		average: -133.36
# Episode:   957		score: -142.13		average: -133.07
# Episode:   958		score: -105.35		average: -132.89
# Episode:   959		score: -125.28		average: -132.92
# Episode:   960		score: -155.00		average: -133.34
# Episode:   961		score:  -99.12		average: -133.06
# Episode:   962		score: -155.98		average: -133.52
# Episode:   963		score: -119.48		average: -133.71
# Episode:   964		score: -169.62		average: -134.09
# Episode:   965		score: -177.99		average: -134.60
# Episode:   966		score: -153.42		average: -134.82
# Episode:   967		score: -138.15		average: -134.96
# Episode:   968		score: -159.73		average: -135.09
# Episode:   969		score: -153.78		average: -135.02
# Episode:   970		score:  -48.21		average: -134.11
# Episode:   971		score: -331.19		average: -136.08
# Episode:   972		score: -135.67		average: -136.34
# Episode:   973		score: -116.56		average: -135.90
# Episode:   974		score:  -29.01		average: -134.63
# Episode:   975		score: -158.49		average: -134.88
# Episode:   976		score:  -89.00		average: -134.16
# Episode:   977		score: -132.71		average: -134.28
# Episode:   978		score:  -94.06		average: -134.16
# Episode:   979		score: -163.02		average: -134.27
# Episode:   980		score:  -94.34		average: -133.14
# Episode:   981		score: -120.28		average: -133.08
# Episode:   982		score:  -31.77		average: -131.78
# Episode:   983		score: -122.64		average: -131.77
# Episode:   984		score: -120.38		average: -131.71
# Episode:   985		score: -126.75		average: -131.10
# Episode:   986		score: -156.07		average: -131.40
# Episode:   987		score: -140.26		average: -129.76
# Episode:   988		score: -200.51		average: -130.15
# Episode:   989		score: -152.40		average: -130.37
# Episode:   990		score: -205.77		average: -130.69
# Episode:   991		score:  -90.45		average: -130.26
# Episode:   992		score: -141.16		average: -130.07
# Episode:   993		score:  -29.51		average: -128.91
# Episode:   994		score: -151.33		average: -128.89
# Episode:   995		score: -117.59		average: -128.90
# Episode:   996		score: -158.49		average: -129.25
# Episode:   997		score: -158.05		average: -129.51
# Episode:   998		score: -181.96		average: -130.02
# Episode:   999		score: -151.14		average: -129.85
# Episode:  1000		score: -125.65		average: -129.82
# Episode:  1001		score: -123.90		average: -130.27
# Episode:  1002		score: -137.29		average: -130.75
# Episode:  1003		score: -142.12		average: -130.97
# Episode:  1004		score: -107.20		average: -131.50
# Episode:  1005		score: -130.50		average: -131.49
# Episode:  1006		score: -187.39		average: -131.58
# Episode:  1007		score: -134.45		average: -131.54
# Episode:  1008		score: -159.99		average: -132.14
# Episode:  1009		score: -118.33		average: -132.67
# Episode:  1010		score: -118.91		average: -132.87
# Episode:  1011		score: -108.51		average: -132.17
# Episode:  1012		score: -129.43		average: -132.34
# Episode:  1013		score: -175.02		average: -132.84
# Episode:  1014		score: -116.30		average: -133.16
# Episode:  1015		score: -130.02		average: -132.45
# Episode:  1016		score: -176.05		average: -133.17
# Episode:  1017		score: -150.93		average: -133.25
# Episode:  1018		score: -143.77		average: -133.47
# Episode:  1019		score: -132.26		average: -131.71
# Episode:  1020		score: -122.93		average: -132.80
# Episode:  1021		score:  -41.22		average: -132.20
# Episode:  1022		score: -212.46		average: -133.09
# Episode:  1023		score: -180.69		average: -133.67
# Episode:  1024		score: -100.89		average: -133.42
# Episode:  1025		score: -159.99		average: -133.58
# Episode:  1026		score: -128.54		average: -135.41
# Episode:  1027		score: -136.50		average: -134.68
# Episode:  1028		score: -110.37		average: -134.13
# Episode:  1029		score: -128.11		average: -133.90
# Episode:  1030		score: -158.30		average: -134.21
# Episode:  1031		score: -112.70		average: -134.23
# Episode:  1032		score:  -47.22		average: -133.46
# Episode:  1033		score: -131.14		average: -133.43
# Episode:  1034		score: -119.64		average: -132.48
# Episode:  1035		score: -312.87		average: -134.14
# Episode:  1036		score: -116.95		average: -133.79
# Episode:  1037		score:  -94.11		average: -133.55
# Episode:  1038		score: -136.11		average: -133.22
# Episode:  1039		score: -146.89		average: -132.93
# Episode:  1040		score: -164.59		average: -133.29
# Episode:  1041		score: -123.58		average: -133.16
# Episode:  1042		score: -119.40		average: -133.25
# Episode:  1043		score: -132.90		average: -133.36
# Episode:  1044		score:   21.11		average: -132.31
# Episode:  1045		score: -189.85		average: -133.03
# Episode:  1046		score: -131.63		average: -133.33
# Episode:  1047		score: -129.97		average: -132.74
# Episode:  1048		score: -129.75		average: -132.87
# Episode:  1049		score: -163.85		average: -133.29
# Episode:  1050		score: -105.56		average: -133.47
# Episode:  1051		score: -160.16		average: -133.84
# Episode:  1052		score: -154.22		average: -135.10
# Episode:  1053		score: -173.69		average: -135.20
# Episode:  1054		score: -127.55		average: -135.15
# Episode:  1055		score: -158.58		average: -134.85
# Episode:  1056		score: -127.69		average: -135.21
# Episode:  1057		score: -139.51		average: -135.19
# Episode:  1058		score: -128.59		average: -135.42
# Episode:  1059		score: -137.01		average: -135.54
# Episode:  1060		score: -108.96		average: -135.08
# Episode:  1061		score: -115.05		average: -135.24
# Episode:  1062		score: -109.83		average: -134.77
# Episode:  1063		score: -168.12		average: -135.26
# Episode:  1064		score:  -23.30		average: -133.80
# Episode:  1065		score: -133.83		average: -133.36
# Episode:  1066		score: -100.05		average: -132.82
# Episode:  1067		score: -111.29		average: -132.55
# Episode:  1068		score: -123.55		average: -132.19
# Episode:  1069		score: -152.66		average: -132.18
