# %%
import os

import random
import gym
import pylab
import numpy as np
import tensorflow as tf
import time
import matplotlib.pyplot as plt

#tf.config.experimental_run_functions_eagerly(True)
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import backend as K
import copy

EPISODES = 10000 # Number of times the enviroment is ran
LOSS_CLIPPING = 0.2 # Approximated values stated in the original paper
ENTROPY_LOSS = 0.001 # Epochs to train the network (recommended between 3 and 30)
LR = 0.0003 # Learning rate 
NUM_ACTIONS = 4 # Number of possible action in the environment
NUM_STATES = 8 # Number of possible states in the exvironment
EPOCHS = 10 # Epochs to train the network (recommended between 3 and 30)
BATCH_SIZE = 512 # Batch size for the neural nets
BUFFER_SIZE = 2048 # Buffer of experiences
SHUFFLE = True # Whether to shuffle data or not while training
OPTIMIZER = Adam # Optimizer for both actor and critic
GAMMA = 0.99 # Used for the estimated reward
LAMBDA = 0.95 # Used in the original paper un the GAE
NORMALIZE = True # Whether to normalize GAE or not



# Create the actor used to select the action given an state
class Actor_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X_input)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        
        # Softmax as there are different probabilities depending on the action
        output = Dense(NUM_ACTIONS, activation="softmax")(X)
        
        # Compile the model with the custom loss
        self.model = Model(inputs = X_input, outputs = output)
        self.model.compile(loss=self.ppo_loss, optimizer=OPTIMIZER(lr=LR))

    # Custom loss functions for the PPO
    def ppo_loss(self, y_true, y_pred):
        # Unpack the elements given in the true label
        advantages, true_label, actions = y_true[:, :1], y_true[:, 1:1+NUM_ACTIONS], y_true[:, 1+NUM_ACTIONS:]
        
        prob = actions * y_pred
        old_prob = actions * true_label 

        ratio = K.exp(K.log(prob + 1e-10) - K.log(old_prob + 1e-10))
        
        p1 = ratio * advantages
        p2 = K.clip(ratio, min_value=1 - LOSS_CLIPPING, max_value=1 + LOSS_CLIPPING) * advantages

        actor_loss = -K.mean(K.minimum(p1, p2))

        entropy = -(y_pred * K.log(y_pred + 1e-10))
        entropy = ENTROPY_LOSS * K.mean(entropy)
        
        total_loss = actor_loss - entropy

        return total_loss

# Create the critic which will criticise how the actor is performing    
class Critic_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X_input)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        
        # Linear output to know how good the action is
        value = Dense(1)(X)
        
        # Compile it with mse loss and gradient descent
        self.model = Model(inputs=X_input, outputs = value)
        self.model.compile(loss='mse', optimizer=OPTIMIZER(lr=LR))

# Combine both Actor and Critic to create the agent
class PPOAgent:
    def __init__(self, env_name):
        # Environment parameters
        self.env_name = env_name       
        self.env = gym.make(env_name)
        self.episode = 0 # used to track current number episoded since start
        self.max_average = 0 # record max average reached
        
        # Used to plot a grapgh of the train process
        self.scores_, self.average_ = [], []

        # Create Actor-Critic network models
        self.Actor = Actor_Model()
        self.Critic = Critic_Model()
    
        # Names for the models
        self.Actor_name = f"{self.env_name}_PPO_Actor.h5"
        self.Critic_name = f"{self.env_name}_PPO_Critic.h5"

    # Get the action given the current state    
    def act(self, state):
        # Use the network to predict the next action to take, using the model
        prediction = self.Actor.model.predict(state)[0]
        
        # Probability based to choose the action
        action = np.random.choice(NUM_ACTIONS, p=prediction)
        action_onehot = np.zeros([NUM_ACTIONS])
        action_onehot[action] = 1
        return action, action_onehot, prediction

    # Generalized Advantage Estimation implemented in the original paper
    def get_gaes(self, rewards, dones, values, next_values):
        # Dones are used to track when is the final step of an episode, so next values are no applied
        deltas = [r + GAMMA * (1 - d) * nv - v for r, d, nv, v in zip(rewards, dones, next_values, values)]
        
        # Convert list to array as .mean() and .std() are used later
        deltas = np.stack(deltas)
        gaes = copy.deepcopy(deltas)
        
        for t in reversed(range(len(deltas) - 1)):
            gaes[t] = gaes[t] + (1 - dones[t]) * GAMMA * LAMBDA * gaes[t + 1]

        target = gaes + values
        if NORMALIZE:
            gaes = (gaes - gaes.mean()) / (gaes.std() + 1e-8)
        return np.vstack(gaes), np.vstack(target)

    def replay(self, states, actions, rewards, predictions, dones, next_states):
        # Reshape memory to appropriate shape for training
        states = np.vstack(states)
        next_states = np.vstack(next_states)
        actions = np.vstack(actions)
        predictions = np.vstack(predictions)

        # Get Critic network predictions for state and next state
        values = self.Critic.model.predict(states)
        next_values = self.Critic.model.predict(next_states)

        # Get the advantage
        advantages, target = self.get_gaes(rewards, dones, np.squeeze(values), np.squeeze(next_values))

        # Stack info to unpack it in the custom loss
        y_true = np.hstack([advantages, predictions, actions])
        
        start_train = time.time()
        # Training Actor and Critic networks
        a_loss = self.Actor.model.fit(states, y_true, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)
        c_loss = self.Critic.model.fit(states, target, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)
        print('Time: ', time.time()-start_train)
 
    def load(self):
        self.Actor.Actor.load_weights(self.Actor_name)
        self.Critic.Critic.load_weights(self.Critic_name)

    def save(self):
        self.Actor.model.save_weights(self.Actor_name)
        self.Critic.model.save_weights(self.Critic_name)

    def run_batch(self): # train every self.Training_batch episodes
        global LR
        state = self.env.reset()
        state = np.reshape(state, [1, NUM_STATES])
        done, score = False, 0
        finished = False
        while finished == False:
            # Instantiate or reset games memory
            states, next_states, actions, rewards, predictions, dones = [], [], [], [], [], []
            for t in range(BUFFER_SIZE):
                #self.env.render()
                # Actor picks an action
                action, action_onehot, prediction = self.act(state)
                # Retrieve new state, reward, and whether the state is terminal
                next_state, reward, done, _ = self.env.step(action)
                # Memorize (state, action, reward) for training
                states.append(state)
                next_states.append(np.reshape(next_state, [1, NUM_STATES]))
                actions.append(action_onehot)
                rewards.append(reward)
                dones.append(done)
                predictions.append(prediction)
                # Update current state
                state = np.reshape(next_state, [1, NUM_STATES])
                score += reward
                if done:
                    self.episode += 1
                    self.scores_.append(score)
                    #average, SAVING = self.PlotModel(score, self.episode)
                    #print("episode: {}/{}, score: {}, average: {:.2f} {}".format(self.episode, EPISODES, score, average, SAVING))
                    if self.episode >= 100:
                        average = sum(self.scores_[-100:])/100
                        print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, score, average))
                        if average > self.max_average:
                            self.max_average = average
                            if self.max_average > 150:
                                self.save()
                            LR *= 0.95
                            K.set_value(self.Actor.model.optimizer.learning_rate, LR)
                            K.set_value(self.Critic.model.optimizer.learning_rate, LR)
                            
                        if average > 200:
                            plt.plot(self.scores_)
                            plt.xlabel("Episode")
                            plt.ylabel("Score")
                            finished = True
                            break

                    else:
                        print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, score, sum(self.scores_)/len(self.scores_)))
                    
                    
                    state, done, score = self.env.reset(), False, 0
                    state = np.reshape(state, [1, NUM_STATES])
                    
            self.replay(states, actions, rewards, predictions, dones, next_states)
            if self.episode >= EPISODES:
                break
        self.env.close()  
                    
if __name__ == "__main__":
    start = time.time()
    env_name = 'LunarLander-v2'
    agent = PPOAgent(env_name)
    #agent.run() # train as PPO, train every epesode
    agent.run_batch() # train as PPO, train every batch, trains better
    #agent.run_multiprocesses(num_worker = 8)  # train PPO multiprocessed (fastest)
# Episode:   615		score:   67.31		average:   -7.61
# Episode:   616		score:  120.30		average:   -5.16
# Episode:   617		score:  -74.39		average:   -5.01
# Time:  0.18053197860717773
# Episode:   618		score:   37.23		average:   -3.99
# Episode:   619		score:   84.04		average:   -2.69
# Time:  0.1790313720703125
# Episode:   620		score:   73.07		average:   -1.61
# Episode:   621		score:   65.39		average:   -0.31
# Time:  0.17352938652038574
# Episode:   622		score:  -59.78		average:    0.18
# Episode:   623		score:   54.66		average:    0.54
# Episode:   624		score: -118.17		average:   -0.32
# Time:  0.17853140830993652
# Episode:   625		score:   83.80		average:    0.30
# Episode:   626		score: -166.95		average:   -0.59
# Time:  0.17503070831298828
# Episode:   627		score:  165.46		average:    0.76
# Episode:   628		score: -144.20		average:   -0.09
# Episode:   629		score:  122.69		average:    1.36
# Episode:   630		score:  -81.58		average:    0.63
# Episode:   631		score:  -83.66		average:   -0.33
# Time:  0.1880326271057129
# Episode:   632		score:   64.24		average:    0.42
# Episode:   633		score:  -76.06		average:    0.64
# Episode:   634		score:   26.31		average:    0.21
# Time:  0.1880331039428711
# Episode:   635		score:   72.03		average:    1.61
# Episode:   636		score:   31.24		average:    2.74
# Time:  0.17803120613098145
# Episode:   637		score:    4.80		average:    2.94
# Episode:   638		score: -204.99		average:    1.45
# Episode:   639		score:  -79.36		average:    1.00
# Time:  0.18403220176696777
# Episode:   640		score:  -81.61		average:    0.92
# Episode:   641		score:   56.91		average:    0.54
# Time:  0.18053197860717773
# Episode:   642		score:   -1.94		average:    1.27
# Episode:   643		score:  -60.22		average:    1.66
# Episode:   644		score:  -79.77		average:    2.10
# Time:  0.18003177642822266
# Episode:   645		score:   31.35		average:    3.51
# Episode:   646		score:  -94.67		average:    1.75
# Time:  0.17653107643127441
# Episode:   647		score:  136.50		average:    3.21
# Episode:   648		score:  149.22		average:    4.52
# Episode:   649		score: -135.95		average:    3.43
# Time:  0.18003153800964355
# Episode:   650		score:  -90.16		average:    3.53
# Episode:   651		score: -122.82		average:    2.13
# Episode:   652		score:  101.47		average:    3.74
# Time:  0.17753124237060547
# Episode:   653		score:   49.84		average:    5.44
# Episode:   654		score:  -73.02		average:    3.48
# Time:  0.1765308380126953
# Episode:   655		score:   55.23		average:    4.97
# Episode:   656		score:  -60.77		average:    4.19
# Time:  0.17803144454956055
# Episode:   657		score:   54.72		average:    4.37
# Episode:   658		score:  -96.75		average:    4.39
# Time:  0.17803168296813965
# Episode:   659		score:   44.71		average:    4.13
# Episode:   660		score:   -6.10		average:    3.37
# Episode:   661		score:   41.29		average:    4.48
# Time:  0.18153166770935059
# Episode:   662		score:  165.68		average:    7.11
# Episode:   663		score:  150.57		average:    7.64
# Episode:   664		score:  -69.14		average:    7.47
# Time:  0.18403220176696777
# Episode:   665		score:   66.74		average:    7.42
# Episode:   666		score:  -61.91		average:    6.11
# Time:  0.17653107643127441
# Episode:   667		score:  -88.72		average:    4.62
# Episode:   668		score:   23.23		average:    3.98
# Time:  0.17753148078918457
# Episode:   669		score:  -47.94		average:    2.27
# Episode:   670		score:  124.77		average:    2.45
# Time:  0.18303227424621582
# Episode:   671		score:   74.66		average:    3.95
# Episode:   672		score:  161.65		average:    4.98
# Episode:   673		score:  -94.04		average:    4.96
# Time:  0.17753076553344727
# Episode:   674		score:  105.35		average:    5.04
# Episode:   675		score:   17.19		average:    4.03
# Time:  0.17603015899658203
# Episode:   676		score:    8.77		average:    3.45
# Episode:   677		score:   37.91		average:    3.42
# Time:  0.17853116989135742
# Episode:   678		score:  -62.66		average:    4.23
# Episode:   679		score:  -74.07		average:    3.05
# Episode:   680		score:  -85.14		average:    3.50
# Time:  0.18303251266479492
# Episode:   681		score:   40.96		average:    2.58
# Episode:   682		score:  -85.70		average:    2.06
# Time:  0.1815321445465088
# Episode:   683		score:   29.55		average:    0.98
# Episode:   684		score:  -86.51		average:   -0.73
# Time:  0.18053150177001953
# Episode:   685		score:   45.78		average:    0.70
# Episode:   686		score:   30.24		average:   -0.16
# Episode:   687		score:  -71.40		average:   -1.70
# Time:  0.17953157424926758
# Episode:   688		score:  -53.94		average:   -3.09
# Episode:   689		score:  -68.16		average:   -3.98
# Time:  0.18303179740905762
# Episode:   690		score:   38.82		average:   -4.22
# Episode:   691		score:   67.24		average:   -4.18
# Time:  0.17953181266784668
# Episode:   692		score:   18.93		average:   -2.80
# Episode:   693		score:  -71.15		average:   -4.80
# Episode:   694		score:   90.96		average:   -4.52
# Time:  0.17653131484985352
# Episode:   695		score:   51.41		average:   -2.95
# Episode:   696		score:  -97.12		average:   -2.94
# Time:  0.1810321807861328
# Episode:   697		score: -153.57		average:   -4.76
# Episode:   698		score: -151.73		average:   -6.75
# Episode:   699		score: -126.77		average:   -6.95
# Time:  0.18453240394592285
# Episode:   700		score:  -79.43		average:   -7.50
# Episode:   701		score:  -54.15		average:   -7.14
# Episode:   702		score:  -78.86		average:   -6.81
# Episode:   703		score: -207.25		average:  -10.31
# Time:  0.1770310401916504
# Episode:   704		score:  148.44		average:   -9.29
# Episode:   705		score:  150.01		average:   -8.19
# Episode:   706		score:  -56.58		average:   -7.45
# Time:  0.18603253364562988
# Episode:   707		score:   36.51		average:   -6.18
# Episode:   708		score: -175.93		average:   -8.25
# Time:  0.17853116989135742
# Episode:   709		score:  -70.89		average:   -7.85
# Episode:   710		score:   59.59		average:   -6.57
# Episode:   711		score:  -79.26		average:   -7.05
# Time:  0.17753148078918457
# Episode:   712		score:   80.45		average:   -6.46
# Episode:   713		score:  -87.20		average:   -6.50
# Time:  0.1855330467224121
# Episode:   714		score: -199.82		average:  -10.13
# Episode:   715		score: -187.66		average:  -12.68
# Time:  0.18103241920471191
# Episode:   716		score:   24.99		average:  -13.63
# Episode:   717		score:   73.80		average:  -12.15
# Time:  0.17953157424926758
# Episode:   718		score:   27.18		average:  -12.25
# Episode:   719		score:  -87.54		average:  -13.96
# Episode:   720		score:  -79.18		average:  -15.49
# Episode:   825		score:   65.59		average:   -6.86
# Episode:   826		score:  106.37		average:   -3.70
# Episode:   827		score:   54.96		average:   -3.53
# Time:  0.1810317039489746
# Episode:   828		score:   93.99		average:   -2.65
# Episode:   829		score:  150.55		average:   -0.41
# Time:  0.18453264236450195
# Episode:   830		score:   46.61		average:    0.75
# Episode:   831		score:   28.35		average:    1.36
# Time:  0.1790313720703125
# Episode:   832		score:  117.20		average:    3.91
# Episode:   833		score: -132.67		average:    1.41
# Episode:   834		score:  -73.09		average:    0.96
# Time:  0.18403244018554688
# Episode:   835		score:   81.53		average:    2.62
# Episode:   836		score:   53.54		average:    1.29
# Time:  0.1790316104888916
# Episode:   837		score:    4.40		average:    0.80
# Episode:   838		score:  -33.45		average:    1.26
# Time:  0.1770308017730713
# Episode:   839		score: -150.20		average:   -0.29
# Episode:   840		score:  -36.50		average:    0.17
# Time:  0.17853116989135742
# Episode:   841		score:   36.16		average:    0.44
# Episode:   842		score:  -94.51		average:   -2.31
# Time:  0.1835322380065918
# Episode:   843		score:   56.12		average:   -0.89
# Episode:   844		score:  -67.96		average:   -2.36
# Episode:   845		score:  101.19		average:   -3.16
# Time:  0.1900339126586914
# Episode:   846		score:   50.86		average:   -1.83
# Episode:   847		score:  -15.10		average:   -0.72
# Time:  0.1830308437347412
# Episode:   848		score:   93.16		average:    1.38
# Episode:   849		score:  -79.06		average:    2.77
# Episode:   850		score:  105.07		average:    2.63
# Time:  0.17853140830993652
# Episode:   851		score:  -15.37		average:    2.06
# Episode:   852		score:   21.34		average:    2.53
# Time:  0.1835324764251709
# Episode:   853		score:   89.59		average:    4.07
# Episode:   854		score:   13.25		average:    5.05
# Time:  0.1790316104888916
# Episode:   855		score:  -45.98		average:    5.70
# Episode:   856		score:   94.00		average:    6.09
# Time:  0.17853140830993652
# Episode:   857		score:   59.98		average:    7.32
# Episode:   858		score: -135.25		average:    5.52
# Time:  0.19753456115722656
# Episode:   859		score:  124.02		average:    6.24
# Episode:   860		score:   81.15		average:    7.44
# Episode:   861		score:  -86.58		average:    5.87
# Time:  0.18003201484680176
# Episode:   862		score:   98.88		average:    6.03
# Episode:   863		score:   46.52		average:    5.67
# Time:  0.1810319423675537
# Episode:   864		score:   70.50		average:    6.95
# Episode:   865		score:  136.21		average:    8.84
# Time:  0.17203021049499512
# Episode:   866		score: -232.52		average:    8.08
# Episode:   867		score:   64.69		average:    9.81
# Time:  0.18203186988830566
# Episode:   868		score:  110.20		average:   10.30
# Episode:   869		score:   90.43		average:   12.33
# Episode:   870		score:  -63.12		average:   12.47
# Time:  0.1795334815979004
# Episode:   871		score: -104.53		average:   12.19
# Episode:   872		score:  -40.05		average:   11.35
# Time:  0.18753314018249512
# Episode:   873		score:   78.78		average:   12.81
# Episode:   874		score:  -39.00		average:   11.64
# Episode:   875		score:  -91.05		average:   11.38
# Time:  0.1770312786102295
# Episode:   876		score:  -72.20		average:   10.90
# Episode:   877		score:   50.04		average:   12.12
# Time:  0.18253183364868164
# Episode:   878		score:   -6.86		average:   11.04
# Episode:   879		score:  171.32		average:   13.52
# Episode:   880		score:  -63.42		average:   13.48
# Episode:   881		score:  152.80		average:   14.66
# Time:  0.1835319995880127
# Episode:   882		score:  -52.33		average:   14.24
# Episode:   883		score: -126.39		average:   13.15
# Episode:   884		score:  -55.08		average:   12.63
# Time:  0.18203163146972656
# Episode:   885		score: -138.56		average:   11.12
# Episode:   886		score:   60.20		average:   11.88
# Episode:   887		score:  -72.10		average:    9.71
# Time:  0.1880331039428711
# Episode:   888		score:   62.53		average:   11.11
# Episode:   889		score: -135.88		average:   10.72
# Episode:   890		score:  -69.18		average:    9.74
# Time:  0.1965341567993164
# Episode:   891		score:  -83.68		average:    7.67
# Episode:   892		score: -144.92		average:    5.82
# Episode:   893		score: -110.22		average:    4.22
# Time:  0.18403220176696777
# Episode:   894		score:  128.47		average:    6.46
# Episode:   895		score:   90.09		average:    7.53
# Episode:   896		score: -129.48		average:    7.22
# Episode:   897		score:  -80.35		average:    7.08
# Time:  0.18503236770629883
# Episode:   898		score:  125.44		average:    7.30
# Episode:   899		score:   63.79		average:    7.84
# Time:  0.17603087425231934
# Episode:   900		score:  -24.57		average:    6.90
# Episode:   901		score:  -90.35		average:    5.18
# Episode:   902		score:  -67.83		average:    4.11
# Episode:   903		score:  -72.70		average:    4.01
# Time:  0.1900327205657959
# Episode:   904		score:   32.39		average:    5.18
# Episode:   905		score:  -33.04		average:    4.82
# Time:  0.18603301048278809
# Episode:   906		score:  103.40		average:    5.18
# Episode:   907		score:   78.41		average:    5.52
# Episode:   908		score:  172.49		average:    6.77
# Time:  0.18953275680541992
# Episode:   909		score: -142.50		average:    5.91
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-3332d247171a> in <module>
#     232     agent = PPOAgent(env_name)
#     233     #agent.run() # train as PPO, train every epesode
# --> 234     agent.run_batch() # train as PPO, train every batch, trains better
#     235     #agent.run_multiprocesses(num_worker = 8)  # train PPO multiprocessed (fastest)
#     236     #agent.test()
#
# <ipython-input-1-3332d247171a> in run_batch(self)
#     179                 #self.env.render()
#     180                 # Actor picks an action
# --> 181                 action, action_onehot, prediction = self.act(state)
#     182                 # Retrieve new state, reward, and whether the state is terminal
#     183                 next_state, reward, done, _ = self.env.step(action)
#
# <ipython-input-1-3332d247171a> in act(self, state)
#     111     def act(self, state):
#     112         # Use the network to predict the next action to take, using the model
# --> 113         prediction = self.Actor.model.predict(state)[0]
#     114
#     115         # Probability based to choose the action
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_v1.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     964         max_queue_size=max_queue_size,
#     965         workers=workers,
# --> 966         use_multiprocessing=use_multiprocessing)
#     967
#     968   def reset_metrics(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in predict(self, model, x, batch_size, verbose, steps, callbacks, **kwargs)
#     712         verbose=verbose,
#     713         steps=steps,
# --> 714         callbacks=callbacks)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     384
#     385         # Get outputs.
# --> 386         batch_outs = f(ins_batch)
#     387         if not isinstance(batch_outs, list):
#     388           batch_outs = [batch_outs]
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3630
#    3631     fetched = self._callable_fn(*array_vals,
# -> 3632                                 run_metadata=self.run_metadata)
#    3633     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3634     output_structure = nest.pack_sequence_as(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# Batch Size mayor, no converge
