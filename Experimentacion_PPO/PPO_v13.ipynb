# %% [markdown]
# less LR decay

# %%
import os

import random
import gym
import pylab
import numpy as np
import tensorflow as tf
import time
import matplotlib.pyplot as plt

#tf.config.experimental_run_functions_eagerly(True)
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import backend as K
import copy

EPISODES = 10000 # Number of times the enviroment is ran
LOSS_CLIPPING = 0.2 # Approximated values stated in the original paper
ENTROPY_LOSS = 0.001 # Epochs to train the network (recommended between 3 and 30)
LR = 0.02 # Learning rate 
NUM_ACTIONS = 2 # Number of possible action in the environment
NUM_STATES = 4 # Number of possible states in the exvironment
EPOCHS = 10 # Epochs to train the network (recommended between 3 and 30)
BATCH_SIZE = 64 # Batch size for the neural nets
BUFFER_SIZE = 2048 # Buffer of experiences
SHUFFLE = True # Whether to shuffle data or not while training
OPTIMIZER = Adam # Optimizer for both actor and critic
GAMMA = 0.99 # Used for the estimated reward
LAMBDA = 0.95 # Used in the original paper un the GAE
NORMALIZE = True # Whether to normalize GAE or not



# Create the actor used to select the action given an state
class Actor_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X_input)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        
        # Softmax as there are different probabilities depending on the action
        output = Dense(NUM_ACTIONS, activation="softmax")(X)
        
        # Compile the model with the custom loss
        self.model = Model(inputs = X_input, outputs = output)
        self.model.compile(loss=self.ppo_loss, optimizer=OPTIMIZER(lr=LR))

    # Custom loss functions for the PPO
    def ppo_loss(self, y_true, y_pred):
        # Unpack the elements given in the true label
        advantages, true_label, actions = y_true[:, :1], y_true[:, 1:1+NUM_ACTIONS], y_true[:, 1+NUM_ACTIONS:]
        
        prob = actions * y_pred
        old_prob = actions * true_label 

        ratio = K.exp(K.log(prob + 1e-10) - K.log(old_prob + 1e-10))
        
        p1 = ratio * advantages
        p2 = K.clip(ratio, min_value=1 - LOSS_CLIPPING, max_value=1 + LOSS_CLIPPING) * advantages

        actor_loss = -K.mean(K.minimum(p1, p2))

        entropy = -(y_pred * K.log(y_pred + 1e-10))
        entropy = ENTROPY_LOSS * K.mean(entropy)
        
        total_loss = actor_loss - entropy

        return total_loss

# Create the critic which will criticise how the actor is performing    
class Critic_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X_input)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        
        # Linear output to know how good the action is
        value = Dense(1)(X)
        
        # Compile it with mse loss and gradient descent
        self.model = Model(inputs=X_input, outputs = value)
        self.model.compile(loss='mse', optimizer=OPTIMIZER(lr=LR))

# Combine both Actor and Critic to create the agent
class PPOAgent:
    def __init__(self, env_name):
        # Environment parameters
        self.env_name = env_name       
        self.env = gym.make(env_name)
        self.episode = 0 # used to track current number episoded since start
        self.max_average = 0 # record max average reached
        
        # Used to plot a grapgh of the train process
        self.scores_, self.average_ = [], []

        # Create Actor-Critic network models
        self.Actor = Actor_Model()
        self.Critic = Critic_Model()
    
        # Names for the models
        self.Actor_name = f"{self.env_name}_PPO_Actor.h5"
        self.Critic_name = f"{self.env_name}_PPO_Critic.h5"

    # Get the action given the current state    
    def act(self, state):
        # Use the network to predict the next action to take, using the model
        prediction = self.Actor.model.predict(state)[0]
        
        # Probability based to choose the action
        action = np.random.choice(NUM_ACTIONS, p=prediction)
        action_onehot = np.zeros([NUM_ACTIONS])
        action_onehot[action] = 1
        return action, action_onehot, prediction

    # Generalized Advantage Estimation implemented in the original paper
    def get_gaes(self, rewards, dones, values, next_values):
        # Dones are used to track when is the final step of an episode, so next values are no applied
        deltas = [r + GAMMA * (1 - d) * nv - v for r, d, nv, v in zip(rewards, dones, next_values, values)]
        
        # Convert list to array as .mean() and .std() are used later
        deltas = np.stack(deltas)
        gaes = copy.deepcopy(deltas)
        
        for t in reversed(range(len(deltas) - 1)):
            gaes[t] = gaes[t] + (1 - dones[t]) * GAMMA * LAMBDA * gaes[t + 1]

        target = gaes + values
        if NORMALIZE:
            gaes = (gaes - gaes.mean()) / (gaes.std() + 1e-8)
        return np.vstack(gaes), np.vstack(target)

    def replay(self, states, actions, rewards, predictions, dones, next_states):
        # Reshape memory to appropriate shape for training
        states = np.vstack(states)
        next_states = np.vstack(next_states)
        actions = np.vstack(actions)
        predictions = np.vstack(predictions)

        # Get Critic network predictions for state and next state
        values = self.Critic.model.predict(states)
        next_values = self.Critic.model.predict(next_states)

        # Get the advantage
        advantages, target = self.get_gaes(rewards, dones, np.squeeze(values), np.squeeze(next_values))

        # Stack info to unpack it in the custom loss
        y_true = np.hstack([advantages, predictions, actions])

        # Training Actor and Critic networks
        a_loss = self.Actor.model.fit(states, y_true, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)
        c_loss = self.Critic.model.fit(states, target, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)

 
    def load(self):
        self.Actor.Actor.load_weights(self.Actor_name)
        self.Critic.Critic.load_weights(self.Critic_name)

    def save(self):
        self.Actor.model.save_weights(self.Actor_name)
        self.Critic.model.save_weights(self.Critic_name)

    def run_batch(self): # train every self.Training_batch episodes
        global LR
        state = self.env.reset()
        state = np.reshape(state, [1, NUM_STATES])
        done, score = False, 0
        finished = False
        while finished == False:
            # Instantiate or reset games memory
            states, next_states, actions, rewards, predictions, dones = [], [], [], [], [], []
            for t in range(BUFFER_SIZE):
                #self.env.render()
                # Actor picks an action
                action, action_onehot, prediction = self.act(state)
                # Retrieve new state, reward, and whether the state is terminal
                next_state, reward, done, _ = self.env.step(action)
                # Memorize (state, action, reward) for training
                states.append(state)
                next_states.append(np.reshape(next_state, [1, NUM_STATES]))
                actions.append(action_onehot)
                rewards.append(reward)
                dones.append(done)
                predictions.append(prediction)
                # Update current state
                state = np.reshape(next_state, [1, NUM_STATES])
                score += reward
                if done:
                    self.episode += 1
                    self.scores_.append(score)
                    #average, SAVING = self.PlotModel(score, self.episode)
                    #print("episode: {}/{}, score: {}, average: {:.2f} {}".format(self.episode, EPISODES, score, average, SAVING))
                    if self.episode >= 100:
                        average = sum(self.scores_[-100:])/100
                        print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, score, average))
                        if average > self.max_average:
                            self.max_average = average
                            if self.max_average > 150:
                                self.save()
                            LR *= 0.99
                            K.set_value(self.Actor.model.optimizer.learning_rate, LR)
                            K.set_value(self.Critic.model.optimizer.learning_rate, LR)
                            
                        if average > 195:
                            plt.plot(self.scores_)
                            plt.xlabel("Episode")
                            plt.ylabel("Score")
                            finished = True
                            break

                    else:
                        print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, score, sum(self.scores_)/len(self.scores_)))
                    
                    
                    state, done, score = self.env.reset(), False, 0
                    state = np.reshape(state, [1, NUM_STATES])
                    
            self.replay(states, actions, rewards, predictions, dones, next_states)
            if self.episode >= EPISODES:
                break
        self.env.close()  
                    
if __name__ == "__main__":
    start = time.time()
    env_name = 'CartPole-v0'
    agent = PPOAgent(env_name)
    #agent.run() # train as PPO, train every epesode
    agent.run_batch() # train as PPO, train every batch, trains better
    #agent.run_multiprocesses(num_worker = 8)  # train PPO multiprocessed (fastest)
    #agent.test()
    print((time.time() - start)/60)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Episode:     1		score:   33.00		average:   33.00
# Episode:     2		score:   43.00		average:   38.00
# Episode:     3		score:   28.00		average:   34.67
# Episode:     4		score:   21.00		average:   31.25
# Episode:     5		score:   24.00		average:   29.80
# Episode:     6		score:   22.00		average:   28.50
# Episode:     7		score:   36.00		average:   29.57
# Episode:     8		score:   27.00		average:   29.25
# Episode:     9		score:   14.00		average:   27.56
# Episode:    10		score:   41.00		average:   28.90
# Episode:    11		score:   16.00		average:   27.73
# Episode:    12		score:   20.00		average:   27.08
# Episode:    13		score:   14.00		average:   26.08
# Episode:    14		score:   23.00		average:   25.86
# Episode:    15		score:   24.00		average:   25.73
# Episode:    16		score:   16.00		average:   25.12
# Episode:    17		score:   15.00		average:   24.53
# Episode:    18		score:   20.00		average:   24.28
# Episode:    19		score:   17.00		average:   23.89
# Episode:    20		score:   16.00		average:   23.50
# Episode:    21		score:    8.00		average:   22.76
# Episode:    22		score:   14.00		average:   22.36
# Episode:    23		score:   32.00		average:   22.78
# Episode:    24		score:   10.00		average:   22.25
# Episode:    25		score:   38.00		average:   22.88
# Episode:    26		score:   43.00		average:   23.65
# Episode:    27		score:   39.00		average:   24.22
# Episode:    28		score:   29.00		average:   24.39
# Episode:    29		score:   22.00		average:   24.31
# Episode:    30		score:   20.00		average:   24.17
# Episode:    31		score:   14.00		average:   23.84
# Episode:    32		score:   30.00		average:   24.03
# Episode:    33		score:   15.00		average:   23.76
# Episode:    34		score:    9.00		average:   23.32
# Episode:    35		score:   33.00		average:   23.60
# Episode:    36		score:   29.00		average:   23.75
# Episode:    37		score:   43.00		average:   24.27
# Episode:    38		score:   46.00		average:   24.84
# Episode:    39		score:   22.00		average:   24.77
# Episode:    40		score:   34.00		average:   25.00
# Episode:    41		score:   21.00		average:   24.90
# Episode:    42		score:   21.00		average:   24.81
# Episode:    43		score:   78.00		average:   26.05
# Episode:    44		score:   16.00		average:   25.82
# Episode:    45		score:   15.00		average:   25.58
# Episode:    46		score:   49.00		average:   26.09
# Episode:    47		score:   13.00		average:   25.81
# Episode:    48		score:   32.00		average:   25.94
# Episode:    49		score:   14.00		average:   25.69
# Episode:    50		score:   32.00		average:   25.82
# Episode:    51		score:   14.00		average:   25.59
# Episode:    52		score:   11.00		average:   25.31
# Episode:    53		score:   12.00		average:   25.06
# Episode:    54		score:   17.00		average:   24.91
# Episode:    55		score:   22.00		average:   24.85
# Episode:    56		score:   27.00		average:   24.89
# Episode:    57		score:   33.00		average:   25.04
# Episode:    58		score:   32.00		average:   25.16
# Episode:    59		score:   31.00		average:   25.25
# Episode:    60		score:   11.00		average:   25.02
# Episode:    61		score:   21.00		average:   24.95
# Episode:    62		score:   28.00		average:   25.00
# Episode:    63		score:   44.00		average:   25.30
# Episode:    64		score:   10.00		average:   25.06
# Episode:    65		score:   17.00		average:   24.94
# Episode:    66		score:   13.00		average:   24.76
# Episode:    67		score:   31.00		average:   24.85
# Episode:    68		score:   17.00		average:   24.74
# Episode:    69		score:   27.00		average:   24.77
# Episode:    70		score:   11.00		average:   24.57
# Episode:    71		score:   13.00		average:   24.41
# Episode:    72		score:   37.00		average:   24.58
# Episode:    73		score:   47.00		average:   24.89
# Episode:    74		score:   15.00		average:   24.76
# Episode:    75		score:   15.00		average:   24.63
# Episode:    76		score:   20.00		average:   24.57
# Episode:    77		score:    9.00		average:   24.36
# Episode:    78		score:   15.00		average:   24.24
# Episode:    79		score:   21.00		average:   24.20
# Episode:    80		score:   12.00		average:   24.05
# Episode:    81		score:   10.00		average:   23.88
# Episode:    82		score:   11.00		average:   23.72
# Episode:    83		score:   22.00		average:   23.70
# Episode:    84		score:   10.00		average:   23.54
# Episode:    85		score:   19.00		average:   23.48
# Episode:    86		score:   47.00		average:   23.76
# Episode:    87		score:   11.00		average:   23.61
# Episode:    88		score:   15.00		average:   23.51
# Episode:    89		score:   40.00		average:   23.70
# Episode:    90		score:   11.00		average:   23.56
# Episode:    91		score:   13.00		average:   23.44
# Episode:    92		score:   35.00		average:   23.57
# Episode:    93		score:   10.00		average:   23.42
# Episode:    94		score:   20.00		average:   23.38
# Episode:    95		score:   12.00		average:   23.26
# Episode:    96		score:   24.00		average:   23.27
# Episode:    97		score:   18.00		average:   23.22
# Episode:    98		score:   48.00		average:   23.47
# Episode:    99		score:   17.00		average:   23.40
# Episode:   100		score:   22.00		average:   23.39
# Episode:   101		score:   79.00		average:   23.85
# Episode:   102		score:   23.00		average:   23.65
# Episode:   103		score:   49.00		average:   23.86
# Episode:   104		score:   19.00		average:   23.84
# Episode:   105		score:   55.00		average:   24.15
# Episode:   106		score:   72.00		average:   24.65
# Episode:   107		score:   61.00		average:   24.90
# Episode:   108		score:   19.00		average:   24.82
# Episode:   109		score:   34.00		average:   25.02
# Episode:   110		score:   34.00		average:   24.95
# Episode:   111		score:   24.00		average:   25.03
# Episode:   112		score:   14.00		average:   24.97
# Episode:   113		score:   31.00		average:   25.14
# Episode:   114		score:   68.00		average:   25.59
# Episode:   115		score:   55.00		average:   25.90
# Episode:   116		score:   40.00		average:   26.14
# Episode:   117		score:   18.00		average:   26.17
# Episode:   118		score:   12.00		average:   26.09
# Episode:   119		score:   10.00		average:   26.02
# Episode:   120		score:   36.00		average:   26.22
# Episode:   121		score:   16.00		average:   26.30
# Episode:   122		score:   20.00		average:   26.36
# Episode:   123		score:   17.00		average:   26.21
# Episode:   124		score:   27.00		average:   26.38
# Episode:   125		score:   11.00		average:   26.11
# Episode:   126		score:   11.00		average:   25.79
# Episode:   127		score:   24.00		average:   25.64
# Episode:   128		score:   55.00		average:   25.90
# Episode:   129		score:   16.00		average:   25.84
# Episode:   130		score:  122.00		average:   26.86
# Episode:   131		score:   56.00		average:   27.28
# Episode:   132		score:   35.00		average:   27.33
# Episode:   133		score:   15.00		average:   27.33
# Episode:   134		score:   58.00		average:   27.82
# Episode:   135		score:   49.00		average:   27.98
# Episode:   136		score:   75.00		average:   28.44
# Episode:   137		score:   37.00		average:   28.38
# Episode:   138		score:   25.00		average:   28.17
# Episode:   139		score:   62.00		average:   28.57
# Episode:   140		score:   28.00		average:   28.51
# Episode:   141		score:   52.00		average:   28.82
# Episode:   142		score:   14.00		average:   28.75
# Episode:   143		score:   19.00		average:   28.16
# Episode:   144		score:   25.00		average:   28.25
# Episode:   145		score:   43.00		average:   28.53
# Episode:   146		score:   55.00		average:   28.59
# Episode:   147		score:   62.00		average:   29.08
# Episode:   148		score:   20.00		average:   28.96
# Episode:   149		score:   62.00		average:   29.44
# Episode:   150		score:   61.00		average:   29.73
# Episode:   151		score:   75.00		average:   30.34
# Episode:   152		score:   71.00		average:   30.94
# Episode:   153		score:   47.00		average:   31.29
# Episode:   154		score:   29.00		average:   31.41
# Episode:   155		score:   28.00		average:   31.47
# Episode:   156		score:  161.00		average:   32.81
# Episode:   157		score:  109.00		average:   33.57
# Episode:   158		score:   72.00		average:   33.97
# Episode:   159		score:   71.00		average:   34.37
# Episode:   160		score:   45.00		average:   34.71
# Episode:   161		score:   59.00		average:   35.09
# Episode:   162		score:   54.00		average:   35.35
# Episode:   163		score:  136.00		average:   36.27
# Episode:   164		score:   57.00		average:   36.74
# Episode:   165		score:   85.00		average:   37.42
# Episode:   166		score:   22.00		average:   37.51
# Episode:   167		score:   60.00		average:   37.80
# Episode:   168		score:   78.00		average:   38.41
# Episode:   169		score:   82.00		average:   38.96
# Episode:   170		score:   79.00		average:   39.64
# Episode:   171		score:  104.00		average:   40.55
# Episode:   172		score:   47.00		average:   40.65
# Episode:   173		score:  188.00		average:   42.06
# Episode:   174		score:   47.00		average:   42.38
# Episode:   175		score:   92.00		average:   43.15
# Episode:   176		score:  179.00		average:   44.74
# Episode:   177		score:   27.00		average:   44.92
# Episode:   178		score:  140.00		average:   46.17
# Episode:   179		score:  112.00		average:   47.08
# Episode:   180		score:  125.00		average:   48.21
# Episode:   181		score:  178.00		average:   49.89
# Episode:   182		score:  130.00		average:   51.08
# Episode:   183		score:  107.00		average:   51.93
# Episode:   184		score:  192.00		average:   53.75
# Episode:   185		score:  144.00		average:   55.00
# Episode:   186		score:  196.00		average:   56.49
# Episode:   187		score:  200.00		average:   58.38
# Episode:   188		score:  144.00		average:   59.67
# Episode:   189		score:   90.00		average:   60.17
# Episode:   190		score:  187.00		average:   61.93
# Episode:   191		score:  162.00		average:   63.42
# Episode:   192		score:  122.00		average:   64.29
# Episode:   193		score:  153.00		average:   65.72
# Episode:   194		score:  115.00		average:   66.67
# Episode:   195		score:  129.00		average:   67.84
# Episode:   196		score:   35.00		average:   67.95
# Episode:   197		score:  200.00		average:   69.77
# Episode:   198		score:  163.00		average:   70.92
# Episode:   199		score:  191.00		average:   72.66
# Episode:   200		score:  125.00		average:   73.69
# Episode:   201		score:  181.00		average:   74.71
# Episode:   202		score:  177.00		average:   76.25
# Episode:   203		score:  182.00		average:   77.58
# Episode:   204		score:  200.00		average:   79.39
# Episode:   205		score:  200.00		average:   80.84
# Episode:   206		score:  200.00		average:   82.12
# Episode:   207		score:  179.00		average:   83.30
# Episode:   208		score:  162.00		average:   84.73
# Episode:   209		score:  131.00		average:   85.70
# Episode:   210		score:  200.00		average:   87.36
# Episode:   211		score:  200.00		average:   89.12
# Episode:   212		score:  134.00		average:   90.32
# Episode:   213		score:  200.00		average:   92.01
# Episode:   214		score:  102.00		average:   92.35
# Episode:   215		score:  115.00		average:   92.95
# Episode:   216		score:  200.00		average:   94.55
# Episode:   217		score:  200.00		average:   96.37
# Episode:   218		score:  200.00		average:   98.25
# Episode:   219		score:   92.00		average:   99.07
# Episode:   220		score:  129.00		average:  100.00
# Episode:   221		score:  185.00		average:  101.69
# Episode:   222		score:  200.00		average:  103.49
# Episode:   223		score:  200.00		average:  105.32
# Episode:   224		score:  200.00		average:  107.05
# Episode:   225		score:  200.00		average:  108.94
# Episode:   226		score:  182.00		average:  110.65
# Episode:   227		score:  180.00		average:  112.21
# Episode:   228		score:  200.00		average:  113.66
# Episode:   229		score:  200.00		average:  115.50
# Episode:   230		score:  200.00		average:  116.28
# Episode:   231		score:  200.00		average:  117.72
# Episode:   232		score:  200.00		average:  119.37
# Episode:   233		score:  200.00		average:  121.22
# Episode:   234		score:  153.00		average:  122.17
# Episode:   235		score:  200.00		average:  123.68
# Episode:   236		score:  200.00		average:  124.93
# Episode:   237		score:  186.00		average:  126.42
# Episode:   238		score:  200.00		average:  128.17
# Episode:   239		score:  200.00		average:  129.55
# Episode:   240		score:  200.00		average:  131.27
# Episode:   241		score:  200.00		average:  132.75
# Episode:   242		score:  200.00		average:  134.61
# Episode:   243		score:  200.00		average:  136.42
# Episode:   244		score:  200.00		average:  138.17
# Episode:   245		score:  189.00		average:  139.63
# Episode:   246		score:  200.00		average:  141.08
# Episode:   247		score:  200.00		average:  142.46
# Episode:   248		score:  200.00		average:  144.26
# Episode:   249		score:  200.00		average:  145.64
# Episode:   250		score:  200.00		average:  147.03
# Episode:   251		score:  200.00		average:  148.28
# Episode:   252		score:  200.00		average:  149.57
# Episode:   253		score:  200.00		average:  151.10
# Episode:   254		score:  200.00		average:  152.81
# Episode:   255		score:  200.00		average:  154.53
# Episode:   256		score:  200.00		average:  154.92
# Episode:   257		score:  200.00		average:  155.83
# Episode:   258		score:  200.00		average:  157.11
# Episode:   259		score:  200.00		average:  158.40
# Episode:   260		score:  200.00		average:  159.95
# Episode:   261		score:  200.00		average:  161.36
# Episode:   262		score:  200.00		average:  162.82
# Episode:   263		score:  200.00		average:  163.46
# Episode:   264		score:  159.00		average:  164.48
# Episode:   265		score:  200.00		average:  165.63
# Episode:   266		score:  200.00		average:  167.41
# Episode:   267		score:  200.00		average:  168.81
# Episode:   268		score:  200.00		average:  170.03
# Episode:   269		score:  200.00		average:  171.21
# Episode:   270		score:  200.00		average:  172.42
# Episode:   271		score:  200.00		average:  173.38
# Episode:   272		score:  200.00		average:  174.91
# Episode:   273		score:  200.00		average:  175.03
# Episode:   274		score:  200.00		average:  176.56
# Episode:   275		score:  200.00		average:  177.64
# Episode:   276		score:  200.00		average:  177.85
# Episode:   277		score:  144.00		average:  179.02
# Episode:   278		score:  200.00		average:  179.62
# Episode:   279		score:  200.00		average:  180.50
# Episode:   280		score:  200.00		average:  181.25
# Episode:   281		score:  200.00		average:  181.47
# Episode:   282		score:  200.00		average:  182.17
# Episode:   283		score:  200.00		average:  183.10
# Episode:   284		score:  200.00		average:  183.18
# Episode:   285		score:  200.00		average:  183.74
# Episode:   286		score:  200.00		average:  183.78
# Episode:   287		score:  200.00		average:  183.78
# Episode:   288		score:  200.00		average:  184.34
# Episode:   289		score:  200.00		average:  185.44
# Episode:   290		score:  200.00		average:  185.57
# Episode:   291		score:  200.00		average:  185.95
# Episode:   292		score:  200.00		average:  186.73
# Episode:   293		score:  200.00		average:  187.20
# Episode:   294		score:  200.00		average:  188.05
# Episode:   295		score:  200.00		average:  188.76
# Episode:   296		score:  200.00		average:  190.41
# Episode:   297		score:  200.00		average:  190.41
# Episode:   298		score:  200.00		average:  190.78
# Episode:   299		score:  200.00		average:  190.87
# Episode:   300		score:  200.00		average:  191.62
# Episode:   301		score:  200.00		average:  191.81
# Episode:   302		score:  200.00		average:  192.04
# Episode:   303		score:  200.00		average:  192.22
# Episode:   304		score:  200.00		average:  192.22
# Episode:   305		score:  200.00		average:  192.22
# Episode:   306		score:  200.00		average:  192.22
# Episode:   307		score:  200.00		average:  192.43
# Episode:   308		score:  200.00		average:  192.81
# Episode:   309		score:  200.00		average:  193.50
# Episode:   310		score:  200.00		average:  193.50
# Episode:   311		score:  200.00		average:  193.50
# Episode:   312		score:  200.00		average:  194.16
# Episode:   313		score:  200.00		average:  194.16
# Episode:   314		score:  200.00		average:  195.14
# 1.1427911678949991
