# %%
import os

import random
import gym
import pylab
import numpy as np
import tensorflow as tf
import time
import matplotlib.pyplot as plt

#tf.config.experimental_run_functions_eagerly(True)
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import backend as K
import copy

EPISODES = 10000 # Number of times the enviroment is ran
LOSS_CLIPPING = 0.2 # Approximated values stated in the original paper
ENTROPY_LOSS = 0.001 # Epochs to train the network (recommended between 3 and 30)
LR = 0.00025 # Learning rate 
NUM_ACTIONS = 4 # Number of possible action in the environment
NUM_STATES = 8 # Number of possible states in the exvironment
EPOCHS = 10 # Epochs to train the network (recommended between 3 and 30)
BATCH = 1000 # Buffer of experiences
SHUFFLE = False # Whether to shuffle data or not while training
OPTIMIZER = Adam # Optimizer for both actor and critic
GAMMA = 0.99 # Used for the estimated reward
LAMBDA = 0.9 # Used in the original paper un the GAE
NORMALIZE = True # Whether to normalize GAE or not

# Create the actor used to select the action given an state
class Actor_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(512, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X_input)
        X = Dense(256, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X)
        X = Dense(64, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X)
        
        # Softmax as there are different probabilities depending on the action
        output = Dense(NUM_ACTIONS, activation="softmax")(X)
        
        # Compile the model with the custom loss
        self.model = Model(inputs = X_input, outputs = output)
        self.model.compile(loss=self.ppo_loss, optimizer=OPTIMIZER(lr=LR))

    # Custom loss functions for the PPO
    def ppo_loss(self, y_true, y_pred):
        # Unpack the elements given in the true label
        advantages, true_label, actions = y_true[:, :1], y_true[:, 1:1+NUM_ACTIONS], y_true[:, 1+NUM_ACTIONS:]
        
        prob = actions * y_pred
        old_prob = actions * true_label 

        ratio = K.exp(K.log(prob + 1e-10) - K.log(old_prob + 1e-10))
        
        p1 = ratio * advantages
        p2 = K.clip(ratio, min_value=1 - LOSS_CLIPPING, max_value=1 + LOSS_CLIPPING) * advantages

        actor_loss = -K.mean(K.minimum(p1, p2))

        entropy = -(y_pred * K.log(y_pred + 1e-10))
        entropy = ENTROPY_LOSS * K.mean(entropy)
        
        total_loss = actor_loss - entropy

        return total_loss

# Create the critic which will criticise how the actor is performing    
class Critic_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(512, activation="relu", kernel_initializer='he_uniform')(X_input)
        X = Dense(256, activation="relu", kernel_initializer='he_uniform')(X)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        
        # Linear output to know how good the action is
        value = Dense(1)(X)
        
        # Compile it with mse loss and gradient descent
        self.model = Model(inputs=X_input, outputs = value)
        self.model.compile(loss='mse', optimizer=OPTIMIZER(lr=LR))

# Combine both Actor and Critic to create the agent
class PPOAgent:
    def __init__(self, env_name):
        # Environment parameters
        self.env_name = env_name       
        self.env = gym.make(env_name)
        self.episode = 0 # used to track current number episoded since start
        self.max_average = 0 # record max average reached
        
        # Used to plot a grapgh of the train process
        self.scores_, self.average_ = [], []

        # Create Actor-Critic network models
        self.Actor = Actor_Model()
        self.Critic = Critic_Model()
    
        # Names for the models
        self.Actor_name = f"{self.env_name}_PPO_Actor.h5"
        self.Critic_name = f"{self.env_name}_PPO_Critic.h5"

    # Get the action given the current state    
    def act(self, state):
        # Use the network to predict the next action to take, using the model
        prediction = self.Actor.model.predict(state)[0]
        
        # Probability based to choose the action
        action = np.random.choice(NUM_ACTIONS, p=prediction)
        action_onehot = np.zeros([NUM_ACTIONS])
        action_onehot[action] = 1
        return action, action_onehot, prediction

    # Generalized Advantage Estimation implemented in the original paper
    def get_gaes(self, rewards, dones, values, next_values):
        # Dones are used to track when is the final step of an episode, so next values are no applied
        deltas = [r + GAMMA * (1 - d) * nv - v for r, d, nv, v in zip(rewards, dones, next_values, values)]
        deltas = np.stack(deltas)
        gaes = copy.deepcopy(deltas)
        for t in reversed(range(len(deltas) - 1)):
            gaes[t] = gaes[t] + (1 - dones[t]) * GAMMA * LAMBDA * gaes[t + 1]

        target = gaes + values
        if NORMALIZE:
            gaes = (gaes - gaes.mean()) / (gaes.std() + 1e-8)
        return np.vstack(gaes), np.vstack(target)

    def replay(self, states, actions, rewards, predictions, dones, next_states): 
        # Reshape memory to appropriate shape for training
        states = np.vstack(states)
        next_states = np.vstack(next_states)
        actions = np.vstack(actions)
        predictions = np.vstack(predictions)

        # Get Critic network predictions for state and next state
        values = self.Critic.model.predict(states)
        next_values = self.Critic.model.predict(next_states)

        # Get the advantage
        advantages, target = self.get_gaes(rewards, dones, np.squeeze(values), np.squeeze(next_values))

        # Stack info to unpack it in the custom loss
        y_true = np.hstack([advantages, predictions, actions])

        # Training Actor and Critic networks
        a_loss = self.Actor.model.fit(states, y_true, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE)
        c_loss = self.Critic.model.fit(states, target, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE)

    # Save Actor and Critic models
    def save(self):
        self.Actor.model.save_weights(self.Actor_name)
        self.Critic.model.save_weights(self.Critic_name)

    # Run whole algorithm
    def run(self):
        # Set global learning rate to decrease when the average gets higher
        global LR
        state = self.env.reset()
        state = np.reshape(state, [1, NUM_STATES])
        done, score = False, 0
        finished = False
        
        while finished == False:
            # Lists to record info for the batch
            states, next_states, actions, rewards, predictions, dones = [], [], [], [], [], []
            
            for t in range(BATCH):
                # Get action given an state
                action, action_onehot, prediction = self.act(state)
                
                # Step in the enviroment and gather all parameters
                next_state, reward, done, _ = self.env.step(action)
                
                # Add to the episode batch the information gathered
                states.append(state)
                next_states.append(np.reshape(next_state, [1, NUM_STATES]))
                actions.append(action_onehot)
                rewards.append(reward)
                dones.append(done)
                predictions.append(prediction)
                
                # Update current state and reward
                state = np.reshape(next_state, [1, NUM_STATES])
                score += reward
                
                # If state is terminal
                if done:
                    self.episode += 1
                    self.scores_.append(score)
                    
                    if self.episode >= 100:
                        average = sum(self.scores_[-100:])/100
                        print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, score, average))
                        
                        # Verify if there is new max average, save the model and decrease the learning rate
                        if average > self.max_average:
                            self.max_average = average
                            self.save()
                            LR *= 0.95
                            K.set_value(self.Actor.model.optimizer.learning_rate, LR)
                            K.set_value(self.Critic.model.optimizer.learning_rate, LR)
                          
                        # If average is above 200 points, the game is solved
                        if average > 200:
                            plt.plot(self.scores_)
                            plt.xlabel("Episode")
                            plt.ylabel("Score")
                            finished = True
                            break

                    else:
                        print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, score, sum(self.scores_)/len(self.scores_)))
                    
                    # Reset state and variables to continue filling the batch
                    state, done, score = self.env.reset(), False, 0
                    state = np.reshape(state, [1, NUM_STATES])
            
            # Train networks to update parameters
            self.replay(states, actions, rewards, predictions, dones, next_states)
            
            if self.episode >= EPISODES:
                break
        self.env.close()  
                    
if __name__ == "__main__":
    start = time.time()
    env_name = 'LunarLander-v2'
    
    # Create Agent
    agent = PPOAgent(env_name)
    
    # Run algorithm
    agent.run()
    print((time.time() - start)/60)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
#
# Episode:   340		score:  -57.12		average:    6.21
# Episode:   341		score: -235.21		average:    4.80
# Episode:   342		score:  205.86		average:    8.26
# Episode:   343		score:  117.10		average:   10.77
# Episode:   344		score:  147.90		average:   13.70
# Episode:   345		score:  211.71		average:   16.89
# Episode:   346		score:  150.47		average:   19.63
# Episode:   347		score:  208.19		average:   24.53
# Episode:   348		score:   53.79		average:   25.96
# Episode:   349		score:  223.35		average:   29.18
# Episode:   350		score:  231.73		average:   32.56
# Episode:   351		score:  202.17		average:   35.46
# Episode:   352		score:  216.17		average:   38.81
# Episode:   353		score:   44.78		average:   40.15
# Episode:   354		score: -262.96		average:   38.29
# Episode:   355		score:  -89.80		average:   37.72
# Episode:   356		score:  222.72		average:   42.94
# Episode:   357		score:  217.54		average:   44.33
# Episode:   358		score:  158.08		average:   46.26
# Episode:   359		score:  233.31		average:   47.27
# Episode:   360		score:  -39.94		average:   47.57
# Episode:   361		score:   89.72		average:   55.59
# Episode:   362		score:  -40.19		average:   56.13
# Episode:   363		score:   51.84		average:   57.84
# Episode:   364		score:  228.12		average:   60.12
# Episode:   365		score:  211.95		average:   63.20
# Episode:   366		score:  212.73		average:   64.46
# Episode:   367		score:  102.38		average:   66.71
# Episode:   368		score:  175.26		average:   69.58
# Episode:   369		score:  198.30		average:   73.77
# Episode:   370		score:  222.40		average:   74.47
# Episode:   371		score:  169.78		average:   74.68
# Episode:   372		score:  226.83		average:   77.35
# Episode:   373		score:  233.76		average:   78.82
# Episode:   374		score:  242.64		average:   79.37
# Episode:   375		score: -111.44		average:   78.89
# Episode:   376		score:  193.25		average:   80.37
# Episode:   377		score:   68.50		average:   79.53
# Episode:   378		score:  194.47		average:   79.80
# Episode:   379		score:  126.19		average:   81.93
# Episode:   380		score:  248.64		average:   85.17
# Episode:   381		score:  231.03		average:   88.07
# Episode:   382		score:  202.87		average:   90.81
# Episode:   383		score:  171.63		average:   91.21
# Episode:   384		score:  185.61		average:   93.85
# Episode:   385		score:  185.45		average:   95.34
# Episode:   386		score:   63.12		average:   95.64
# Episode:   387		score:  212.67		average:   96.00
# Episode:   388		score:  174.91		average:   98.85
# Episode:   389		score:  190.70		average:  101.48
# Episode:   390		score:  168.63		average:  104.20
# Episode:   391		score:  154.58		average:  106.29
# Episode:   392		score:   65.02		average:  107.59
# Episode:   393		score:  147.19		average:  109.72
# Episode:   394		score:   67.35		average:  108.27
# Episode:   395		score:  202.06		average:  108.75
# Episode:   396		score:  221.82		average:  109.32
# Episode:   397		score:  206.57		average:  109.77
# Episode:   398		score:   96.47		average:  111.51
# Episode:   399		score:  157.94		average:  114.07
# Episode:   400		score:  186.24		average:  113.88
# Episode:   401		score:   75.44		average:  113.41
# Episode:   402		score:  219.80		average:  115.12
# Episode:   403		score:  229.14		average:  115.54
# Episode:   404		score:  179.87		average:  116.70
# Episode:   405		score:  232.88		average:  117.08
# Episode:   406		score:  211.87		average:  119.99
# Episode:   407		score:  199.55		average:  121.39
# Episode:   408		score:   70.82		average:  120.92
# Episode:   409		score:  157.43		average:  123.17
# Episode:   618		score:  103.77		average:  165.34
# Episode:   619		score:  141.80		average:  164.81
# Episode:   620		score:  196.65		average:  164.52
# Episode:   621		score:  217.86		average:  164.80
# Episode:   622		score:  -14.81		average:  162.95
# Episode:   623		score:  231.97		average:  163.03
# Episode:   624		score:  203.45		average:  163.04
# Episode:   625		score:  220.67		average:  163.16
# Episode:   626		score:  190.22		average:  162.85
# Episode:   627		score:  165.51		average:  163.42
# Episode:   628		score:   99.20		average:  164.41
# Episode:   629		score:  207.87		average:  164.53
# Episode:   630		score:  228.58		average:  165.93
# Episode:   631		score:  240.17		average:  167.69
# Episode:   632		score:  176.00		average:  167.18
# Episode:   633		score:  143.39		average:  166.34
# Episode:   634		score:  208.65		average:  166.59
# Episode:   635		score:  146.74		average:  165.68
# Episode:   636		score:  152.92		average:  164.96
# Episode:   637		score: -119.58		average:  162.84
# Episode:   638		score:  185.23		average:  162.51
# Episode:   639		score:  -29.89		average:  160.10
# Episode:   640		score:  199.54		average:  159.83
# Episode:   641		score:  192.89		average:  159.90
# Episode:   642		score:  219.44		average:  161.41
# Episode:   643		score:   94.73		average:  159.98
# Episode:   644		score:  -32.67		average:  157.46
# Episode:   645		score:  222.11		average:  157.32
# Episode:   646		score:  235.56		average:  157.94
# Episode:   647		score:   12.36		average:  156.62
# Episode:   648		score:  195.60		average:  157.01
# Episode:   649		score:  220.24		average:  159.55
# Episode:   650		score:  217.59		average:  159.94
# Episode:   651		score:   -9.02		average:  159.91
# Episode:   652		score:  195.13		average:  159.60
# Episode:   653		score:  118.93		average:  160.05
# Episode:   654		score:   87.68		average:  158.74
# Episode:   655		score:  186.39		average:  158.97
# Episode:   656		score:  223.02		average:  160.32
# Episode:   657		score:  190.67		average:  162.79
# Episode:   658		score:    0.74		average:  161.78
# Episode:   659		score:  104.22		average:  163.12
# Episode:   660		score: -103.95		average:  160.06
# Episode:   661		score:  207.82		average:  159.99
# Episode:   662		score:  205.12		average:  160.29
# Episode:   663		score:  241.22		average:  160.74
# Episode:   664		score:  172.89		average:  160.49
# Episode:   665		score:  216.86		average:  160.74
# Episode:   666		score:   79.42		average:  160.03
# Episode:   667		score:  221.10		average:  160.23
# Episode:   668		score:  236.69		average:  160.81
# Episode:   669		score:  215.93		average:  160.71
# Episode:   670		score:  221.01		average:  160.68
# Episode:   671		score:   79.57		average:  159.02
# Episode:   672		score:  229.89		average:  158.82
# Episode:   673		score:  217.11		average:  160.97
# Episode:   674		score:  219.73		average:  160.82
# Episode:   675		score:  177.10		average:  160.52
# Episode:   676		score:  191.78		average:  160.74
# Episode:   677		score:  221.40		average:  160.48
# Episode:   678		score:   -2.39		average:  162.25
# Episode:   679		score:  215.33		average:  163.31
# Episode:   680		score:  -64.96		average:  160.73
# Episode:   681		score:  194.14		average:  161.23
# Episode:   682		score:  102.95		average:  162.54
# Episode:   683		score:  228.42		average:  162.67
# Episode:   684		score:  191.16		average:  162.69
# Episode:   685		score:  221.21		average:  163.03
# Episode:   686		score:  223.84		average:  163.22
# Episode:   687		score:  248.16		average:  163.54
