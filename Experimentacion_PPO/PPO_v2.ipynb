# %% [markdown]
# ## Libraries

# %%
import numpy as np
import gym
import matplotlib.pyplot as plt
import time

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.python.framework.ops import disable_eager_execution
disable_eager_execution()

# %% [markdown]
# ## Hyperparameters

# %%
ENV = 'LunarLander-v2'

EPISODES = 50000 # Number of times the enviroment is ran

LOSS_CLIPPING = 0.2 # Approximated values stated in the original paper
EPOCHS = 20 # Epochs to train the network (recommended between 3 and 30)
NOISE = 1.0 # Standard deviation

GAMMA = 0.99 # Used for the estimated reward

BUFFER_SIZE = 1024 # Buffer of experiences
BATCH_SIZE = 512 # Batch size for the neural nets
NUM_ACTIONS = 4 # Number of possible action in the environment
NUM_STATES = 8 # Number of possible states in the exvironment
ENTROPY_LOSS = 0.001 # Constant value for the entropy (entropy used for exploration)
LR = 0.00025  # Learning rate

# Used to feed the actor when predicting
DUMMY_ACTION, DUMMY_VALUE = np.zeros((1, NUM_ACTIONS)), np.zeros((1, 1))

# %% [markdown]
# ## Class memory

# %%
# Memory of the experiences
class Memory:
    def __init__(self):
        self.episode_batch = [[], [], []]
        self.global_batch = [[], [], [], []]
        self.episode_rewards = []
        self.historical_rewards = []

    def reset_espisode_batch(self):
        self.global_batch = [[], [], [], []]
        self.episode_batch = [[], [], []]
        self.episode_rewards = []

# %% [markdown]
# ## Custom loss function for PPO

# %%
# Custom loss functions for the PPO
def proximal_policy_optimization_loss(advantages, prediction_picks):
    def loss(actions, y_pred):
        #advantages, prediction_picks, actions = y_true[:, :1], y_true[:, 1:1+self.action_space], y_true[:, 1+self.action_space:]
        LOSS_CLIPPING = 0.2
        ENTROPY_LOSS = 0.001
        
        prob = actions * y_pred
        old_prob = actions * prediction_picks

        prob = K.clip(prob, 1e-10, 1.0)
        old_prob = K.clip(old_prob, 1e-10, 1.0)

        ratio = K.exp(K.log(prob) - K.log(old_prob))
        
        p1 = ratio * advantages
        p2 = K.clip(ratio, min_value=1 - LOSS_CLIPPING, max_value=1 + LOSS_CLIPPING) * advantages

        actor_loss = -K.mean(K.minimum(p1, p2))

        entropy = -(y_pred * K.log(y_pred + 1e-10))
        entropy = ENTROPY_LOSS * K.mean(entropy)
        
        total_loss = actor_loss - entropy

        return total_loss
    return loss

# %% [markdown]
# ## PPO Agent

# %%
class Agent:
    # Constructor of the class
    def __init__(self):
        self.actor = self.create_actor()
        self.critic = self.create_critic()
        self.memory = Memory()

    # Create the actor used to select the action given an state
    def create_actor(self):
        # Define three inputs as the advantage and old prediction is used for the custom loss
        input_state = Input(shape=(NUM_STATES,))
        input_advantage = Input(shape=(1,))
        imput_old_prediction = Input(shape=(NUM_ACTIONS,))

        x = Dense(512, activation='relu', kernel_initializer=tf.random_normal_initializer(stddev=0.01))(input_state)
        x = Dense(256, activation='relu', kernel_initializer=tf.random_normal_initializer(stddev=0.01))(x)
        x = Dense(64, activation='relu', kernel_initializer=tf.random_normal_initializer(stddev=0.01))(x)

        # Softmax as there are different probabilities depending on the action
        output_layer = Dense(NUM_ACTIONS, activation='softmax', name='output')(x)

        model = Model(inputs=[input_state, input_advantage, imput_old_prediction], outputs=[output_layer])

        # Compile the model with the custom loss
        model.compile(optimizer=Adam(lr=LR),
                      loss=[proximal_policy_optimization_loss(
                          advantages=input_advantage,
                          prediction_picks=imput_old_prediction)])
        model.summary()

        return model

    # Create the critic which will criticise how the actor is performing
    def create_critic(self):
        # Define the architectire of the network
        input_layer = Input(shape=(NUM_STATES,))
        
        x = Dense(512, activation='relu', kernel_initializer=tf.random_normal_initializer(stddev=0.01))(input_layer)
        x = Dense(256, activation='relu', kernel_initializer=tf.random_normal_initializer(stddev=0.01))(x)
        x = Dense(64, activation='relu', kernel_initializer=tf.random_normal_initializer(stddev=0.01))(x)


        # Linear output to know how good the action is
        ouput_layer = Dense(1)(x)

        model = Model(inputs=[input_layer], outputs=[ouput_layer])

        # Compile it with mse loss and gradient descent
        model.compile(optimizer=Adam(lr=LR), 
                      loss='mse')

        return model

    # Get the action given the current state
    def get_action(self, state):
        probabilities = self.actor.predict([state.reshape(1, NUM_STATES), DUMMY_VALUE, DUMMY_ACTION])
        action = np.random.choice(NUM_ACTIONS, p=np.nan_to_num(probabilities[0]))
        action_matrix = np.zeros(NUM_ACTIONS)
        action_matrix[action] = 1
        return action, action_matrix, probabilities

    # Transform rewards of the episode as the discount has to be applied in the first ones regarding the last ones
    def transform_reward(self):
        self.memory.historical_rewards.append(sum(self.memory.episode_rewards))

        for j in range(len(self.memory.episode_rewards) - 2, -1, -1):
            self.memory.episode_rewards[j] += self.memory.episode_rewards[j + 1] * GAMMA

# %% [markdown]
# ## Environment

# %%
# Create simulated environment
def create_environment():
    environment = gym.make(ENV)
    return environment

# %%
if __name__ == '__main__':
    start = time.time()
    env = create_environment() 
    ag = Agent()
    episode = 1
    goal_reached = False

    # Iterate until the number of episodes is reached
    while episode < EPISODES:
        # Reset episode and global batch and the environment to start a new one
        ag.memory.reset_espisode_batch()
        state = env.reset()
        states = []
        next_states = []
        dones = []
        # Iterate until the global batch is bigger than the buffer
        while len(ag.memory.global_batch[0]) < BUFFER_SIZE:
            # Get the action given the current state
            action, action_matrix, predicted_action = ag.get_action(state)
            # Step in the enviroment and gather all parameters
            next_state, reward, done, info = env.step(action)
            ag.memory.episode_rewards.append(reward)
            last_reward = sum(ag.memory.episode_rewards)

            # Add to the episode batch the informetions gathered
            ag.memory.episode_batch[0].append(state)
            ag.memory.episode_batch[1].append(action_matrix)
            ag.memory.episode_batch[2].append(predicted_action)
            states.append(state)
            next_states.append(next_state)
            state = next_state
            dones.append(done)

            # If the episode has finished
            if done:
                # Transform rewards with discount rate
                ag.transform_reward()
                print('Last reward: ', ag.memory.episode_rewards[-1])
                # Iterate through all instances of the episode batch
                for i in range(len(ag.memory.episode_batch[0])):
                    obs, action, pred = ag.memory.episode_batch[0][i], ag.memory.episode_batch[1][i], ag.memory.episode_batch[2][i]
                    r = ag.memory.episode_rewards[i]

                    # Add all experienes to global batch
                    ag.memory.global_batch[0].append(obs)
                    ag.memory.global_batch[1].append(action)
                    ag.memory.global_batch[2].append(pred)
                    ag.memory.global_batch[3].append(r)
                
                # Reset the episode batch, episode reward and environment
                ag.memory.episode_batch = [[], [], []]
                ag.memory.episode_rewards = []
                state = env.reset()

                if episode >= 100:
                    print('EPISODE: ', episode, ' - SCORE: ', ag.memory.historical_rewards[-1], ' - MEAN SCORE: ', sum(ag.memory.historical_rewards[-100:])/100)

                    if sum(ag.memory.historical_rewards[-100:])/100 >= 200:
                        goal_reached = True
                        break
                else:
                    print('EPISODE: ', episode, ' - SCORE: ', ag.memory.historical_rewards[-1], ' - MEAN SCORE: ', sum(ag.memory.historical_rewards)/len(ag.memory.historical_rewards))
                
                episode += 1

        if goal_reached == True:
            break

        # Get the arrays to feed te neural nets
        obs, action, pred, reward = np.array(ag.memory.global_batch[0]), np.array(ag.memory.global_batch[1]), np.array(ag.memory.global_batch[2]), np.reshape(np.array(ag.memory.global_batch[3]), (len(ag.memory.global_batch[3]), 1))
        pred = np.reshape(pred, (pred.shape[0], pred.shape[2]))

        # Ensure that they all have the same size
        obs, action, pred, reward = obs[:BUFFER_SIZE], action[:BUFFER_SIZE], pred[:BUFFER_SIZE], reward[:BUFFER_SIZE]
        states, next_states = np.array(states[:BUFFER_SIZE]), np.array(next_states[:BUFFER_SIZE])
        old_prediction = pred

        
        
        
        values = ag.critic.predict(states)
        next_values = ag.critic.predict(next_states)
        gamma = 0.99
        lamda = 0.9
        deltas = [r + gamma * (1 - d) * nv - v for r, d, nv, v in zip(reward, dones, next_values, values)]
        
        for t in reversed(range(len(deltas) - 1)):
            deltas[t] = deltas[t] + (1 - dones[t]) * gamma * lamda * deltas[t + 1]
        #print(np.shape(deltas))
        deltas = np.array(deltas)
        
        deltas = (deltas - deltas.mean()) / (deltas.std() + 1e-8)
        
        
        # Get advantage with the rewards taken from the environment predictions of the critic given the states
        #advantage = reward - pred_values
        print('ACTUALIZA')
        # Update weights of the actor with the states, advanges obtained from the critic and predictions made. Target values are actions
        actor_loss = ag.actor.fit([obs, deltas, old_prediction], [action], batch_size=BATCH_SIZE, shuffle=True, epochs=EPOCHS, verbose=0)
        # Update weights of the critic with the states. Targe values are actual rewards
        critic_loss = ag.critic.fit([obs], [reward], batch_size=BATCH_SIZE, shuffle=True, epochs=EPOCHS, verbose=0)

    # Plot a graph with the rewards over the episodes
    plt.plot(ag.memory.historical_rewards)
    plt.xlabel("Episode")
    plt.ylabel("Score")
    
    end = time.time()
    print((end-start)/60, 'MINUTES')
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          4608        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          131328      dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           16448       dense_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 4)]          0
# __________________________________________________________________________________________________
# output (Dense)                  (None, 4)            260         dense_2[0][0]
# ==================================================================================================
# Total params: 152,644
# Trainable params: 152,644
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Last reward:  -100
# EPISODE:  1  - SCORE:  -98.88400360890923  - MEAN SCORE:  -98.88400360890923
# Last reward:  -100
# EPISODE:  2  - SCORE:  -121.4227197210192  - MEAN SCORE:  -110.15336166496422
# Last reward:  -100
# EPISODE:  3  - SCORE:  -136.74062571608692  - MEAN SCORE:  -119.01578301533846
# Last reward:  -100
# EPISODE:  4  - SCORE:  -161.13670847288506  - MEAN SCORE:  -129.5460143797251
# Last reward:  -100
# EPISODE:  5  - SCORE:  -126.05946027763753  - MEAN SCORE:  -128.84870355930758
# Last reward:  -100
# EPISODE:  6  - SCORE:  9.266646691946761  - MEAN SCORE:  -105.82947851743187
# Last reward:  -100
# EPISODE:  7  - SCORE:  -179.71816468857605  - MEAN SCORE:  -116.3850051133096
# Last reward:  -100
# EPISODE:  8  - SCORE:  -95.83401371881308  - MEAN SCORE:  -113.81613118899753
# Last reward:  -100
# EPISODE:  9  - SCORE:  -182.0824199249784  - MEAN SCORE:  -121.4012743818843
# Last reward:  -100
# EPISODE:  10  - SCORE:  -162.5263817625092  - MEAN SCORE:  -125.51378511994679
# Last reward:  -100
# EPISODE:  11  - SCORE:  -370.5126046204756  - MEAN SCORE:  -147.7864050745403
# ACTUALIZA
# Last reward:  -100
# EPISODE:  12  - SCORE:  -221.04630250392802  - MEAN SCORE:  -153.8913965269893
# Last reward:  -100
# EPISODE:  13  - SCORE:  -136.45207718196687  - MEAN SCORE:  -152.54991042352603
# Last reward:  -100
# EPISODE:  14  - SCORE:  -107.44421468803347  - MEAN SCORE:  -149.328075013848
# Last reward:  -100
# EPISODE:  15  - SCORE:  -69.46680291329355  - MEAN SCORE:  -144.00399020714437
# Last reward:  -100
# EPISODE:  16  - SCORE:  -97.53912516522985  - MEAN SCORE:  -141.09993614202472
# Last reward:  -100
# EPISODE:  17  - SCORE:  -69.72018730733222  - MEAN SCORE:  -136.9011273870428
# Last reward:  -100
# EPISODE:  18  - SCORE:  -83.20018896460644  - MEAN SCORE:  -133.91774191912967
# Last reward:  -100
# EPISODE:  19  - SCORE:  -135.80300873061458  - MEAN SCORE:  -134.0169664881552
# Last reward:  -100
# EPISODE:  20  - SCORE:  -204.20010083459084  - MEAN SCORE:  -137.52612320547698
# Last reward:  -100
# EPISODE:  21  - SCORE:  -92.3802317985111  - MEAN SCORE:  -135.3763188527643
# Last reward:  -100
# EPISODE:  22  - SCORE:  -105.69553549420118  - MEAN SCORE:  -134.027192336466
# Last reward:  -100
# EPISODE:  23  - SCORE:  -21.240934526188312  - MEAN SCORE:  -129.1234419968887
# Last reward:  -100
# EPISODE:  24  - SCORE:  -294.51359401585466  - MEAN SCORE:  -136.01469833101228
# ACTUALIZA
# Last reward:  -100
# EPISODE:  25  - SCORE:  -149.86519796114695  - MEAN SCORE:  -136.56871831621766
# Last reward:  -100
# EPISODE:  26  - SCORE:  -102.79768916649554  - MEAN SCORE:  -135.26983257968988
# Last reward:  -100
# EPISODE:  27  - SCORE:  -112.36629677006023  - MEAN SCORE:  -134.42155347562954
# Last reward:  -100
# EPISODE:  28  - SCORE:  -271.0908461128271  - MEAN SCORE:  -139.30259964124372
# Last reward:  -100
# EPISODE:  29  - SCORE:  -225.86514538897035  - MEAN SCORE:  -142.287515011855
# Last reward:  -100
# EPISODE:  30  - SCORE:  -366.29050759416464  - MEAN SCORE:  -149.7542814312653
# Last reward:  -100
# EPISODE:  31  - SCORE:  -155.2025980550724  - MEAN SCORE:  -149.93003358042037
# Last reward:  -100
# EPISODE:  32  - SCORE:  -89.9312442053163  - MEAN SCORE:  -148.05507141244837
# Last reward:  -100
# EPISODE:  33  - SCORE:  -157.77182309193356  - MEAN SCORE:  -148.34951843303884
# Last reward:  -100
# EPISODE:  34  - SCORE:  -135.11633453716988  - MEAN SCORE:  -147.96030714198386
# ACTUALIZA
# Last reward:  -100
# EPISODE:  35  - SCORE:  -333.53191998374564  - MEAN SCORE:  -153.26235322317706
# Last reward:  -100
# EPISODE:  36  - SCORE:  -144.01239806321826  - MEAN SCORE:  -153.0054100242893
# Last reward:  -100
# EPISODE:  37  - SCORE:  -184.801292138968  - MEAN SCORE:  -153.86475818955088
# Last reward:  -100
# EPISODE:  38  - SCORE:  -216.59319746309848  - MEAN SCORE:  -155.51550659148634
# Last reward:  -100
# EPISODE:  39  - SCORE:  -95.35789350266354  - MEAN SCORE:  -153.97300369177296
# Last reward:  -100
# EPISODE:  40  - SCORE:  -121.2641487581004  - MEAN SCORE:  -153.15528231843115
# Last reward:  -100
# EPISODE:  41  - SCORE:  -145.51938210968882  - MEAN SCORE:  -152.96904084992522
# Last reward:  -100
# EPISODE:  42  - SCORE:  -58.048745272944245  - MEAN SCORE:  -150.70903381237807
# Last reward:  -100
# EPISODE:  43  - SCORE:  -106.25608299099619  - MEAN SCORE:  -149.67524425839244
# Last reward:  -100
# EPISODE:  44  - SCORE:  -137.1920683840815  - MEAN SCORE:  -149.39153571579448
# Last reward:  -100
# EPISODE:  45  - SCORE:  -360.67033736833616  - MEAN SCORE:  -154.08662019696206
# Last reward:  -100
# EPISODE:  46  - SCORE:  -112.20821667724306  - MEAN SCORE:  -153.17622012044643
# Last reward:  -100
# EPISODE:  47  - SCORE:  -224.2542254023611  - MEAN SCORE:  -154.68851810516801
# ACTUALIZA
# Last reward:  -100
# EPISODE:  48  - SCORE:  -102.62144560505453  - MEAN SCORE:  -153.6037874280823
# Last reward:  -100
# EPISODE:  49  - SCORE:  -117.53488640426143  - MEAN SCORE:  -152.86768740718801
# Last reward:  -100
# EPISODE:  50  - SCORE:  -130.12008042270776  - MEAN SCORE:  -152.41273526749842
# Last reward:  -100
# EPISODE:  51  - SCORE:  30.29442554647315  - MEAN SCORE:  -148.83024191820485
# Last reward:  -100
# EPISODE:  52  - SCORE:  -104.94771851756592  - MEAN SCORE:  -147.98634723742333
# Last reward:  -100
# EPISODE:  53  - SCORE:  -136.77291093086623  - MEAN SCORE:  -147.77477296748827
# Last reward:  -100
# EPISODE:  54  - SCORE:  -209.61230439124017  - MEAN SCORE:  -148.9199124382985
# Last reward:  -100
# EPISODE:  55  - SCORE:  -135.5407675245539  - MEAN SCORE:  -148.6766552580486
# Last reward:  -100
# EPISODE:  56  - SCORE:  -165.4020251746573  - MEAN SCORE:  -148.97532257798804
# Last reward:  -100
# EPISODE:  57  - SCORE:  -230.1653472492702  - MEAN SCORE:  -150.39970897572985
# Last reward:  -100
# EPISODE:  58  - SCORE:  -7.606175905107293  - MEAN SCORE:  -147.93775150899498
# Last reward:  -100
# EPISODE:  59  - SCORE:  -109.02257835267875  - MEAN SCORE:  -147.27817230295574
# Last reward:  -100
# EPISODE:  60  - SCORE:  -171.61947546468707  - MEAN SCORE:  -147.6838606889846
# Last reward:  -100
# EPISODE:  61  - SCORE:  -276.98376009187155  - MEAN SCORE:  -149.80353117099912
# ACTUALIZA
# Last reward:  -100
# EPISODE:  62  - SCORE:  -244.83831116307974  - MEAN SCORE:  -151.33635020312946
# Last reward:  -100
# EPISODE:  63  - SCORE:  -93.56846569654215  - MEAN SCORE:  -150.41939965540584
# Last reward:  -100
# EPISODE:  64  - SCORE:  -110.493256088692  - MEAN SCORE:  -149.79555366217593
# Last reward:  -100
# EPISODE:  65  - SCORE:  -136.15373792059026  - MEAN SCORE:  -149.58567957384386
# Last reward:  -100
# EPISODE:  66  - SCORE:  -254.02221814685174  - MEAN SCORE:  -151.16805137040458
# Last reward:  -100
# EPISODE:  67  - SCORE:  -161.67726496291357  - MEAN SCORE:  -151.32490530462113
# Last reward:  -100
# EPISODE:  68  - SCORE:  -124.75863661113293  - MEAN SCORE:  -150.9342248826581
# Last reward:  -100
# EPISODE:  69  - SCORE:  -135.95922057150355  - MEAN SCORE:  -150.71719583467035
# Last reward:  -100
# EPISODE:  70  - SCORE:  -134.82254408288264  - MEAN SCORE:  -150.4901293810734
# Last reward:  -100
# EPISODE:  71  - SCORE:  -209.06617676520614  - MEAN SCORE:  -151.31514413296256
# Last reward:  -100
# EPISODE:  72  - SCORE:  -279.8032978082341  - MEAN SCORE:  -153.0997018228969
# Last reward:  -100
# EPISODE:  73  - SCORE:  -177.15455581193345  - MEAN SCORE:  -153.42922037069192
# Last reward:  -100
# EPISODE:  74  - SCORE:  -273.14984768888564  - MEAN SCORE:  -155.04706668580266
# ACTUALIZA
# Last reward:  -100
# EPISODE:  75  - SCORE:  -125.02508244098209  - MEAN SCORE:  -154.64677356253836
# Last reward:  -100
# EPISODE:  76  - SCORE:  -146.8629782841996  - MEAN SCORE:  -154.54435520361287
# Last reward:  -100
# EPISODE:  77  - SCORE:  -101.96849533780963  - MEAN SCORE:  -153.8615518287323
# Last reward:  -100
# EPISODE:  78  - SCORE:  -74.91050867830631  - MEAN SCORE:  -152.84935896782937
# Last reward:  -100
# EPISODE:  79  - SCORE:  -139.41016198584742  - MEAN SCORE:  -152.67924255033594
# Last reward:  -100
# EPISODE:  80  - SCORE:  -182.86800645268949  - MEAN SCORE:  -153.05660209911534
# Last reward:  -100
# EPISODE:  81  - SCORE:  -162.78165276523865  - MEAN SCORE:  -153.1766644530181
# Last reward:  -100
# EPISODE:  82  - SCORE:  -279.4200163990104  - MEAN SCORE:  -154.7162175255302
# Last reward:  -100
# EPISODE:  83  - SCORE:  -151.64226737196725  - MEAN SCORE:  -154.6791819815114
# Last reward:  -100
# EPISODE:  84  - SCORE:  -130.33882281786953  - MEAN SCORE:  -154.38941580099186
# Last reward:  -100
# EPISODE:  85  - SCORE:  -119.53637856329341  - MEAN SCORE:  -153.97938006878363
# Last reward:  -100
# EPISODE:  86  - SCORE:  -141.34023258915698  - MEAN SCORE:  -153.83241323762516
# ACTUALIZA
# Last reward:  -100
# EPISODE:  87  - SCORE:  -175.69674126692684  - MEAN SCORE:  -154.0837273529045
# Last reward:  -100
# EPISODE:  88  - SCORE:  -247.08773658498282  - MEAN SCORE:  -155.14059109417812
# Last reward:  -100
# EPISODE:  89  - SCORE:  -162.99415480561328  - MEAN SCORE:  -155.22883338307065
# Last reward:  -100
# EPISODE:  90  - SCORE:  -134.66934593170757  - MEAN SCORE:  -155.00039463361108
# Last reward:  -100
# EPISODE:  91  - SCORE:  -120.79711193144873  - MEAN SCORE:  -154.62453438413675
# Last reward:  -100
# EPISODE:  92  - SCORE:  -135.62010043131897  - MEAN SCORE:  -154.417964449867
# Last reward:  -100
# EPISODE:  93  - SCORE:  -128.49585432405547  - MEAN SCORE:  -154.13923208292277
# Last reward:  -100
# EPISODE:  94  - SCORE:  -150.74288681902277  - MEAN SCORE:  -154.1031007503281
# Last reward:  -100
# EPISODE:  95  - SCORE:  -189.26096480617196  - MEAN SCORE:  -154.47318352986332
# Last reward:  -100
# EPISODE:  96  - SCORE:  -177.42857450563906  - MEAN SCORE:  -154.71230218586098
# Last reward:  -100
# EPISODE:  97  - SCORE:  -111.48406042303613  - MEAN SCORE:  -154.26665020892463
# Last reward:  -100
# EPISODE:  98  - SCORE:  -114.34406642260907  - MEAN SCORE:  -153.85927690498264
# Last reward:  -100
# EPISODE:  99  - SCORE:  -118.82140688103357  - MEAN SCORE:  -153.50535902595286
# ACTUALIZA
# Last reward:  -100
# EPISODE:  100  - SCORE:  -172.95320581761493  - MEAN SCORE:  -153.69983749386947
# Last reward:  -100
# EPISODE:  101  - SCORE:  -182.31810883447076  - MEAN SCORE:  -154.5341785461251
# Last reward:  -100
# EPISODE:  102  - SCORE:  -132.11678553955056  - MEAN SCORE:  -154.6411192043104
# Last reward:  -100
# EPISODE:  103  - SCORE:  -149.0044862853295  - MEAN SCORE:  -154.76375781000283
# Last reward:  -100
# EPISODE:  104  - SCORE:  -167.17481923169382  - MEAN SCORE:  -154.8241389175909
# Last reward:  -100
# EPISODE:  105  - SCORE:  -127.28458242004602  - MEAN SCORE:  -154.83639013901498
# Last reward:  -100
# EPISODE:  106  - SCORE:  -88.90281846314214  - MEAN SCORE:  -155.81808479056588
# Last reward:  -100
# EPISODE:  107  - SCORE:  -207.8358186151139  - MEAN SCORE:  -156.09926132983125
# Last reward:  -100
# EPISODE:  108  - SCORE:  -245.66921063074557  - MEAN SCORE:  -157.5976132989506
# Last reward:  -100
# EPISODE:  109  - SCORE:  -92.22611285655431  - MEAN SCORE:  -156.69905022826634
# Last reward:  -100
# EPISODE:  110  - SCORE:  -104.75317019877272  - MEAN SCORE:  -156.12131811262898
# Last reward:  -100
# EPISODE:  111  - SCORE:  -78.2641704975012  - MEAN SCORE:  -153.19883377139925
# ACTUALIZA
# Last reward:  -100
# EPISODE:  112  - SCORE:  -142.20453878214875  - MEAN SCORE:  -152.41041613418145
# Last reward:  -100
# EPISODE:  113  - SCORE:  -293.126761181869  - MEAN SCORE:  -153.97716297418046
# Last reward:  -100
# EPISODE:  114  - SCORE:  -187.0823545867275  - MEAN SCORE:  -154.7735443731674
# Last reward:  -100
# EPISODE:  115  - SCORE:  -90.16347485270404  - MEAN SCORE:  -154.98051109256153
# Last reward:  -100
# EPISODE:  116  - SCORE:  -124.87465980503768  - MEAN SCORE:  -155.25386643895962
# Last reward:  -100
# EPISODE:  117  - SCORE:  -127.08656034108961  - MEAN SCORE:  -155.82753016929718
# Last reward:  -100
# EPISODE:  118  - SCORE:  -157.36124203899902  - MEAN SCORE:  -156.5691407000411
# Last reward:  -100
# EPISODE:  119  - SCORE:  -285.6778167051028  - MEAN SCORE:  -158.067888779786
# Last reward:  -100
# EPISODE:  120  - SCORE:  -88.96369815729739  - MEAN SCORE:  -156.91552475301305
# Last reward:  -100
# EPISODE:  121  - SCORE:  -466.25573683162816  - MEAN SCORE:  -160.65427980334422
# ACTUALIZA
# Last reward:  -100
# EPISODE:  122  - SCORE:  -223.7846326251461  - MEAN SCORE:  -161.83517077465368
# Last reward:  -100
# EPISODE:  123  - SCORE:  -125.36462027394009  - MEAN SCORE:  -162.8764076321312
# Last reward:  -100
# EPISODE:  124  - SCORE:  -213.1518305532445  - MEAN SCORE:  -162.0627899975051
# Last reward:  -100
# EPISODE:  125  - SCORE:  -130.66510118741334  - MEAN SCORE:  -161.87078902976774
# Last reward:  -100
# EPISODE:  126  - SCORE:  -145.10193413271122  - MEAN SCORE:  -162.2938314794299
# Last reward:  -100
# EPISODE:  127  - SCORE:  -120.07548648571571  - MEAN SCORE:  -162.37092337658646
# Last reward:  -100
# EPISODE:  128  - SCORE:  -208.56125013602752  - MEAN SCORE:  -161.7456274168185
# Last reward:  -100
# EPISODE:  129  - SCORE:  -117.03151407204571  - MEAN SCORE:  -160.65729110364924
# Last reward:  -100
# EPISODE:  130  - SCORE:  -82.43897439349789  - MEAN SCORE:  -157.81877577164258
# ACTUALIZA
# Last reward:  -100
# EPISODE:  131  - SCORE:  -136.55649110638043  - MEAN SCORE:  -157.63231470215567
# Last reward:  -100
# EPISODE:  132  - SCORE:  -115.50176861035436  - MEAN SCORE:  -157.88801994620604
# Last reward:  -100
# EPISODE:  133  - SCORE:  -186.1208567950752  - MEAN SCORE:  -158.17151028323747
# Last reward:  -100
# EPISODE:  134  - SCORE:  -282.1591693565277  - MEAN SCORE:  -159.64193863143103
# Last reward:  -100
# EPISODE:  135  - SCORE:  -318.44697559582363  - MEAN SCORE:  -159.49108918755178
# Last reward:  -100
# EPISODE:  136  - SCORE:  -174.507635805516  - MEAN SCORE:  -159.79604156497476
# Last reward:  -100
# EPISODE:  137  - SCORE:  -157.1509754763166  - MEAN SCORE:  -159.51953839834826
# Last reward:  -100
# EPISODE:  138  - SCORE:  -153.5042594941948  - MEAN SCORE:  -158.8886490186592
# Last reward:  -100
# EPISODE:  139  - SCORE:  -85.93780211074834  - MEAN SCORE:  -158.79444810474007
# Last reward:  -100
# EPISODE:  140  - SCORE:  -214.7471004582144  - MEAN SCORE:  -159.7292776217412
# ACTUALIZA
# Last reward:  -100
# EPISODE:  141  - SCORE:  -122.25136932999791  - MEAN SCORE:  -159.49659749394428
# Last reward:  -100
# EPISODE:  142  - SCORE:  -190.2951631445609  - MEAN SCORE:  -160.81906167266044
# Last reward:  -100
# EPISODE:  143  - SCORE:  -122.10675425754962  - MEAN SCORE:  -160.97756838532598
# Last reward:  -100
# EPISODE:  144  - SCORE:  -28.338403435436007  - MEAN SCORE:  -159.88903173583952
# Last reward:  -100
# EPISODE:  145  - SCORE:  -250.6326173010915  - MEAN SCORE:  -158.7886545351671
# Last reward:  -100
# EPISODE:  146  - SCORE:  -112.90293888865398  - MEAN SCORE:  -158.7956017572812
# Last reward:  -100
# EPISODE:  147  - SCORE:  -114.69385603229117  - MEAN SCORE:  -157.6999980635805
# Last reward:  -100
# EPISODE:  148  - SCORE:  -193.79165466356534  - MEAN SCORE:  -158.61170015416562
# Last reward:  -100
# EPISODE:  149  - SCORE:  -189.0107400082078  - MEAN SCORE:  -159.32645869020504
# Last reward:  -100
# EPISODE:  150  - SCORE:  -158.69560443526592  - MEAN SCORE:  -159.61221393033065
# ACTUALIZA
# Last reward:  -100
# EPISODE:  151  - SCORE:  -103.7049517338339  - MEAN SCORE:  -160.95220770313372
# Last reward:  -100
# EPISODE:  152  - SCORE:  -161.9045966933516  - MEAN SCORE:  -161.52177648489157
# Last reward:  -100
# EPISODE:  153  - SCORE:  -216.56246962801762  - MEAN SCORE:  -162.31967207186307
# Last reward:  -100
# EPISODE:  154  - SCORE:  -165.0332501901438  - MEAN SCORE:  -161.8738815298521
# Last reward:  -100
# EPISODE:  155  - SCORE:  -91.32957797628336  - MEAN SCORE:  -161.4317696343694
# Last reward:  -100
# EPISODE:  156  - SCORE:  -216.2479914866447  - MEAN SCORE:  -161.94022929748925
# Last reward:  -100
# EPISODE:  157  - SCORE:  -107.37509311078435  - MEAN SCORE:  -160.71232675610437
# Last reward:  -100
# EPISODE:  158  - SCORE:  -115.080371563851  - MEAN SCORE:  -161.78706871269182
# Last reward:  -100
# EPISODE:  159  - SCORE:  -140.30973642835755  - MEAN SCORE:  -162.0999402934486
# Last reward:  -100
# EPISODE:  160  - SCORE:  -108.89988912406301  - MEAN SCORE:  -161.47274443004235
# Last reward:  -100
# EPISODE:  161  - SCORE:  -176.64993482667887  - MEAN SCORE:  -160.46940617739043
# ACTUALIZA
# Last reward:  -100
# EPISODE:  162  - SCORE:  -113.02119848905836  - MEAN SCORE:  -159.1512350506502
# Last reward:  -100
# EPISODE:  163  - SCORE:  -102.0259454617279  - MEAN SCORE:  -159.23580984830207
# Last reward:  -100
# EPISODE:  164  - SCORE:  -111.64495931978452  - MEAN SCORE:  -159.24732688061303
# Last reward:  -100
# EPISODE:  165  - SCORE:  -112.80999907450507  - MEAN SCORE:  -159.01388949215215
# Last reward:  -100
# EPISODE:  166  - SCORE:  -112.76468212304333  - MEAN SCORE:  -157.60131413191405
# Last reward:  -100
# EPISODE:  167  - SCORE:  -128.24061905417173  - MEAN SCORE:  -157.26694767282663
# Last reward:  -100
# EPISODE:  168  - SCORE:  -131.73935565019576  - MEAN SCORE:  -157.33675486321727
# Last reward:  -100
# EPISODE:  169  - SCORE:  -135.2221201850573  - MEAN SCORE:  -157.32938385935282
# Last reward:  -100
# EPISODE:  170  - SCORE:  -90.47124892921721  - MEAN SCORE:  -156.88587090781618
# Last reward:  -100
# EPISODE:  171  - SCORE:  -207.46247642414284  - MEAN SCORE:  -156.86983390440554
# ACTUALIZA
# Last reward:  -100
# EPISODE:  172  - SCORE:  -83.30411103750271  - MEAN SCORE:  -154.90484203669823
# Last reward:  -100
# EPISODE:  173  - SCORE:  -104.15061557452597  - MEAN SCORE:  -154.17480263432418
# Last reward:  -100
# EPISODE:  174  - SCORE:  -118.39347740146349  - MEAN SCORE:  -152.62723893144997
# Last reward:  -100
# EPISODE:  175  - SCORE:  -118.50596813271339  - MEAN SCORE:  -152.56204778836727
# Last reward:  -100
# EPISODE:  176  - SCORE:  -129.71059278822818  - MEAN SCORE:  -152.39052393340754
# Last reward:  -100
# EPISODE:  177  - SCORE:  -123.73086570164489  - MEAN SCORE:  -152.6081476370459
# Last reward:  -100
# EPISODE:  178  - SCORE:  -166.44300340734327  - MEAN SCORE:  -153.52347258433628
# Last reward:  -100
# EPISODE:  179  - SCORE:  -195.05930085025616  - MEAN SCORE:  -154.07996397298038
# Last reward:  -100
# EPISODE:  180  - SCORE:  -183.924200424963  - MEAN SCORE:  -154.0905259127031
# Last reward:  -100
# EPISODE:  181  - SCORE:  -123.41180134805018  - MEAN SCORE:  -153.6968273985312
# Last reward:  -100
# EPISODE:  182  - SCORE:  -156.05667031408865  - MEAN SCORE:  -152.46319393768198
# ACTUALIZA
# Last reward:  -100
# EPISODE:  183  - SCORE:  -131.88799166313333  - MEAN SCORE:  -152.26565118059364
# Last reward:  -100
# EPISODE:  184  - SCORE:  -134.16128204798719  - MEAN SCORE:  -152.30387577289486
# Last reward:  -100
# EPISODE:  185  - SCORE:  -166.90858990751101  - MEAN SCORE:  -152.77759788633702
# Last reward:  -100
# EPISODE:  186  - SCORE:  -101.28567962919811  - MEAN SCORE:  -152.3770523567374
# Last reward:  -100
# EPISODE:  187  - SCORE:  -162.68327245561625  - MEAN SCORE:  -152.2469176686243
# Last reward:  -100
# EPISODE:  188  - SCORE:  -112.86217299607591  - MEAN SCORE:  -150.90466203273525
# Last reward:  -100
# EPISODE:  189  - SCORE:  -60.79626337736646  - MEAN SCORE:  -149.88268311845275
# Last reward:  -100
# EPISODE:  190  - SCORE:  -143.90105705717573  - MEAN SCORE:  -149.97500022970743
# Last reward:  -100
# EPISODE:  191  - SCORE:  -126.29580061946128  - MEAN SCORE:  -150.0299871165876
# Last reward:  -100
# EPISODE:  192  - SCORE:  -102.77221282243154  - MEAN SCORE:  -149.70150824049873
# Last reward:  -100
# EPISODE:  193  - SCORE:  -105.95133601317741  - MEAN SCORE:  -149.47606305738998
# ACTUALIZA
# Last reward:  -100
# EPISODE:  194  - SCORE:  -191.74562366314888  - MEAN SCORE:  -149.8860904258312
# Last reward:  -100
# EPISODE:  195  - SCORE:  -146.0414407751835  - MEAN SCORE:  -149.4538951855213
# Last reward:  -100
# EPISODE:  196  - SCORE:  -107.81776510675728  - MEAN SCORE:  -148.75778709153252
# Last reward:  -100
# EPISODE:  197  - SCORE:  -102.74565574162008  - MEAN SCORE:  -148.67040304471834
# Last reward:  -100
# EPISODE:  198  - SCORE:  -139.34519949869974  - MEAN SCORE:  -148.92041437547923
# Last reward:  -100
# EPISODE:  199  - SCORE:  -125.74960681078912  - MEAN SCORE:  -148.98969637477683
# Last reward:  -100
# EPISODE:  200  - SCORE:  -157.5958046888773  - MEAN SCORE:  -148.83612236348944
# Last reward:  -100
# EPISODE:  201  - SCORE:  -149.33486536451943  - MEAN SCORE:  -148.50628992878987
# Last reward:  -100
# EPISODE:  202  - SCORE:  -155.44387781916  - MEAN SCORE:  -148.739560851586
# Last reward:  -100
# EPISODE:  203  - SCORE:  -196.4227471083832  - MEAN SCORE:  -149.21374345981656
# ACTUALIZA
# Last reward:  -100
# EPISODE:  204  - SCORE:  -120.89383491382443  - MEAN SCORE:  -148.75093361663784
# Last reward:  -100
# EPISODE:  205  - SCORE:  -84.16290729967733  - MEAN SCORE:  -148.31971686543415
# Last reward:  -100
# EPISODE:  206  - SCORE:  -132.47720340433298  - MEAN SCORE:  -148.75546071484604
# Last reward:  -100
# EPISODE:  207  - SCORE:  -125.10511693616334  - MEAN SCORE:  -147.92815369805655
# Last reward:  -100
# EPISODE:  208  - SCORE:  -104.60687579937331  - MEAN SCORE:  -146.5175303497428
# Last reward:  -100
# EPISODE:  209  - SCORE:  -170.89975392857468  - MEAN SCORE:  -147.30426676046304
# Last reward:  -100
# EPISODE:  210  - SCORE:  -89.49546098574982  - MEAN SCORE:  -147.15168966833278
# Last reward:  -100
# EPISODE:  211  - SCORE:  -95.16494266616073  - MEAN SCORE:  -147.3206973900194
# Last reward:  -100
# EPISODE:  212  - SCORE:  -130.03400221898147  - MEAN SCORE:  -147.19899202438776
# Last reward:  -100
# EPISODE:  213  - SCORE:  -89.45705416499173  - MEAN SCORE:  -145.16229495421896
# Last reward:  -100
# EPISODE:  214  - SCORE:  -112.65467024951664  - MEAN SCORE:  -144.41801811084687
# Last reward:  -100
# EPISODE:  215  - SCORE:  -149.55553497852375  - MEAN SCORE:  -145.01193871210506
# ACTUALIZA
# Last reward:  -100
# EPISODE:  216  - SCORE:  -108.48154661400585  - MEAN SCORE:  -144.84800758019475
# Last reward:  -100
# EPISODE:  217  - SCORE:  -190.86181590981457  - MEAN SCORE:  -145.485760135882
# Last reward:  -100
# EPISODE:  218  - SCORE:  -91.8809080917093  - MEAN SCORE:  -144.83095679640908
# Last reward:  -100
# EPISODE:  219  - SCORE:  -74.58898893081427  - MEAN SCORE:  -142.72006851866618
# Last reward:  -100
# EPISODE:  220  - SCORE:  -115.4304442590336  - MEAN SCORE:  -142.98473597968356
# Last reward:  -100
# EPISODE:  221  - SCORE:  -150.17903957585702  - MEAN SCORE:  -139.8239690071258
# Last reward:  -100
# EPISODE:  222  - SCORE:  -126.5970257346168  - MEAN SCORE:  -138.85209293822052
# Last reward:  -100
# EPISODE:  223  - SCORE:  -223.0275126744507  - MEAN SCORE:  -139.82872186222562
# ACTUALIZA
# Last reward:  -100
# EPISODE:  224  - SCORE:  -71.54212751678719  - MEAN SCORE:  -138.41262483186105
# Last reward:  -100
# EPISODE:  225  - SCORE:  -133.92424086284285  - MEAN SCORE:  -138.44521622861535
# Last reward:  -100
# EPISODE:  226  - SCORE:  -134.48252341475757  - MEAN SCORE:  -138.33902212143582
# Last reward:  -100
# EPISODE:  227  - SCORE:  -141.07405104260684  - MEAN SCORE:  -138.54900776700472
# Last reward:  -100
# EPISODE:  228  - SCORE:  -177.2278068106695  - MEAN SCORE:  -138.23567333375112
# Last reward:  -100
# EPISODE:  229  - SCORE:  -107.46443056291423  - MEAN SCORE:  -138.1400024986598
# Last reward:  -100
# EPISODE:  230  - SCORE:  -201.85925104469186  - MEAN SCORE:  -139.33420526517176
# Last reward:  -100
# EPISODE:  231  - SCORE:  -79.60076552525611  - MEAN SCORE:  -138.76464800936049
# Last reward:  -100
# EPISODE:  232  - SCORE:  -74.04169082368523  - MEAN SCORE:  -138.35004723149382
# Last reward:  -100
# EPISODE:  233  - SCORE:  -145.66062424295944  - MEAN SCORE:  -137.94544490597266
# Last reward:  -100
# EPISODE:  234  - SCORE:  -107.95475760867842  - MEAN SCORE:  -136.20340078849418
# ACTUALIZA
# Last reward:  -100
# EPISODE:  235  - SCORE:  -165.83593919025625  - MEAN SCORE:  -134.6772904244385
# Last reward:  -100
# EPISODE:  236  - SCORE:  -63.794768830566284  - MEAN SCORE:  -133.57016175468897
# Last reward:  -100
# EPISODE:  237  - SCORE:  -73.15411234871281  - MEAN SCORE:  -132.73019312341293
# Last reward:  -100
# EPISODE:  238  - SCORE:  -197.28701002983192  - MEAN SCORE:  -133.16802062876934
# Last reward:  -100
# EPISODE:  239  - SCORE:  -125.01820213305749  - MEAN SCORE:  -133.5588246289924
# Last reward:  -100
# EPISODE:  240  - SCORE:  -111.77845091042553  - MEAN SCORE:  -132.52913813351455
# Last reward:  -100
# EPISODE:  241  - SCORE:  -82.88232228605614  - MEAN SCORE:  -132.13544766307515
# Last reward:  -100
# EPISODE:  242  - SCORE:  -175.11428788449487  - MEAN SCORE:  -131.9836389104745
# Last reward:  -100
# EPISODE:  243  - SCORE:  -86.21105637972833  - MEAN SCORE:  -131.62468193169627
# ACTUALIZA
# Last reward:  -100
# EPISODE:  244  - SCORE:  -192.27725219705005  - MEAN SCORE:  -133.26407041931242
# Last reward:  -100
# EPISODE:  245  - SCORE:  -98.20650448364779  - MEAN SCORE:  -131.739809291138
# Last reward:  -100
# EPISODE:  246  - SCORE:  -169.8719165797119  - MEAN SCORE:  -132.30949906804855
# Last reward:  -100
# EPISODE:  247  - SCORE:  -284.6308928995817  - MEAN SCORE:  -134.00886943672145
# Last reward:  -100
# EPISODE:  248  - SCORE:  -167.40465469905308  - MEAN SCORE:  -133.74499943707636
# Last reward:  -100
# EPISODE:  249  - SCORE:  -143.24099003071314  - MEAN SCORE:  -133.2873019373014
# Last reward:  -100
# EPISODE:  250  - SCORE:  -218.61430906437954  - MEAN SCORE:  -133.88648898359256
# Last reward:  -100
# EPISODE:  251  - SCORE:  -99.17410786102296  - MEAN SCORE:  -133.84118054486444
# Last reward:  -100
# EPISODE:  252  - SCORE:  -134.9773921820064  - MEAN SCORE:  -133.571908499751
# Last reward:  -100
# EPISODE:  253  - SCORE:  -182.82677050460657  - MEAN SCORE:  -133.2345515085169
# Last reward:  -100
# EPISODE:  254  - SCORE:  -144.60233789703966  - MEAN SCORE:  -133.03024238558586
# ACTUALIZA
# Last reward:  -100
# EPISODE:  255  - SCORE:  -112.26088355385738  - MEAN SCORE:  -133.2395554413616
# Last reward:  -100
# EPISODE:  256  - SCORE:  -104.83237723157877  - MEAN SCORE:  -132.12539929881095
# Last reward:  -100
# EPISODE:  257  - SCORE:  -172.4969581293284  - MEAN SCORE:  -132.7766179489964
# Last reward:  -100
# EPISODE:  258  - SCORE:  -140.8409541736773  - MEAN SCORE:  -133.03422377509466
# Last reward:  -100
# EPISODE:  259  - SCORE:  -120.46350747818978  - MEAN SCORE:  -132.83576148559297
# Last reward:  -100
# EPISODE:  260  - SCORE:  -221.2754262646628  - MEAN SCORE:  -133.95951685699896
# Last reward:  -100
# EPISODE:  261  - SCORE:  -119.45822365886053  - MEAN SCORE:  -133.3875997453208
# Last reward:  -100
# EPISODE:  262  - SCORE:  -103.9972074470641  - MEAN SCORE:  -133.29735983490085
# Last reward:  -100
# EPISODE:  263  - SCORE:  -141.889592702278  - MEAN SCORE:  -133.69599630730636
# Last reward:  -100
# EPISODE:  264  - SCORE:  -119.97305430414974  - MEAN SCORE:  -133.77927725715
# Last reward:  -100
# EPISODE:  265  - SCORE:  -135.81177156490241  - MEAN SCORE:  -134.00929498205397
# ACTUALIZA
# Last reward:  -100
# EPISODE:  266  - SCORE:  -143.17334235584363  - MEAN SCORE:  -134.313381584382
# Last reward:  -100
# EPISODE:  267  - SCORE:  -110.28055944801817  - MEAN SCORE:  -134.13378098832044
# Last reward:  -100
# EPISODE:  268  - SCORE:  -121.8393698432857  - MEAN SCORE:  -134.03478113025136
# Last reward:  -100
# EPISODE:  269  - SCORE:  -76.432789212501  - MEAN SCORE:  -133.44688782052577
# Last reward:  -100
# EPISODE:  270  - SCORE:  -88.62408042409011  - MEAN SCORE:  -133.4284161354745
# Last reward:  -100
# EPISODE:  271  - SCORE:  -21.930675243437165  - MEAN SCORE:  -131.57309812366745
# Last reward:  -100
# EPISODE:  272  - SCORE:  -91.73190889586591  - MEAN SCORE:  -131.65737610225108
# Last reward:  -100
# EPISODE:  273  - SCORE:  -122.83611733643237  - MEAN SCORE:  -131.84423111987013
# Last reward:  -100
# EPISODE:  274  - SCORE:  -127.38498858380649  - MEAN SCORE:  -131.93414623169357
# Last reward:  -100
# EPISODE:  275  - SCORE:  -139.51506542691348  - MEAN SCORE:  -132.14423720463554
# ACTUALIZA
# Last reward:  -100
# EPISODE:  276  - SCORE:  -101.73216478494385  - MEAN SCORE:  -131.86445292460272
# Last reward:  -100
# EPISODE:  277  - SCORE:  -103.7735741640075  - MEAN SCORE:  -131.66488000922635
# Last reward:  -100
# EPISODE:  278  - SCORE:  -103.16562418727514  - MEAN SCORE:  -131.03210621702567
# Last reward:  -100
# EPISODE:  279  - SCORE:  -119.62102534651422  - MEAN SCORE:  -130.27772346198827
# Last reward:  -100
# EPISODE:  280  - SCORE:  -112.67879706004352  - MEAN SCORE:  -129.56526942833906
# Last reward:  -100
# EPISODE:  281  - SCORE:  -120.02535717415668  - MEAN SCORE:  -129.53140498660014
# Last reward:  -100
# EPISODE:  282  - SCORE:  -124.9737765534858  - MEAN SCORE:  -129.2205760489941
# Last reward:  -100
# EPISODE:  283  - SCORE:  -164.1572249713246  - MEAN SCORE:  -129.54326838207604
# Last reward:  -100
# EPISODE:  284  - SCORE:  -123.74924279197825  - MEAN SCORE:  -129.43914798951596
# Last reward:  -100
# EPISODE:  285  - SCORE:  -156.58169188062547  - MEAN SCORE:  -129.33587900924707
# Last reward:  -100
# EPISODE:  286  - SCORE:  -109.97007704418873  - MEAN SCORE:  -129.42272298339697
# Last reward:  -100
# EPISODE:  287  - SCORE:  -14.92175026217221  - MEAN SCORE:  -127.94510776146254
# ACTUALIZA
# Last reward:  -100
# EPISODE:  288  - SCORE:  -101.37739651902055  - MEAN SCORE:  -127.83025999669198
# Last reward:  -100
# EPISODE:  289  - SCORE:  -145.3967674194614  - MEAN SCORE:  -128.67626503711293
# Last reward:  -100
# EPISODE:  290  - SCORE:  -123.76557391618199  - MEAN SCORE:  -128.47491020570297
# Last reward:  -100
# EPISODE:  291  - SCORE:  -147.4215348083501  - MEAN SCORE:  -128.68616754759185
# Last reward:  -100
# EPISODE:  292  - SCORE:  -116.72496964846088  - MEAN SCORE:  -128.82569511585217
# Last reward:  -100
# EPISODE:  293  - SCORE:  -205.21146656361054  - MEAN SCORE:  -129.81829642135648
# Last reward:  -100
# EPISODE:  294  - SCORE:  -122.49113358441232  - MEAN SCORE:  -129.1257515205691
# Last reward:  -100
# EPISODE:  295  - SCORE:  -138.23385495016367  - MEAN SCORE:  -129.04767566231894
# Last reward:  -100
# EPISODE:  296  - SCORE:  -125.50522678066409  - MEAN SCORE:  -129.22455027905798
# Last reward:  -100
# EPISODE:  297  - SCORE:  -76.31035421001853  - MEAN SCORE:  -128.96019726374195
# Last reward:  -100
# EPISODE:  298  - SCORE:  -239.98077163037948  - MEAN SCORE:  -129.9665529850588
# Last reward:  -100
# EPISODE:  299  - SCORE:  -102.96487001204946  - MEAN SCORE:  -129.73870561707136
# ACTUALIZA
# Last reward:  -100
# EPISODE:  300  - SCORE:  -145.4706625435412  - MEAN SCORE:  -129.61745419561802
# Last reward:  -100
# EPISODE:  301  - SCORE:  -92.49363047414147  - MEAN SCORE:  -129.04904184671423
# Last reward:  -100
# EPISODE:  302  - SCORE:  -112.15720440059368  - MEAN SCORE:  -128.61617511252857
# Last reward:  -100
# EPISODE:  303  - SCORE:  -121.71830189989863  - MEAN SCORE:  -127.86913066044372
# Last reward:  -100
# EPISODE:  304  - SCORE:  -102.3452818857678  - MEAN SCORE:  -127.68364513016313
# Last reward:  -100
# EPISODE:  305  - SCORE:  -110.15045930599587  - MEAN SCORE:  -127.94352065022633
# Last reward:  -100
# EPISODE:  306  - SCORE:  -144.6524547173269  - MEAN SCORE:  -128.06527316335627
# Last reward:  -100
# EPISODE:  307  - SCORE:  -131.9565183235252  - MEAN SCORE:  -128.1337871772299
# Last reward:  -100
# EPISODE:  308  - SCORE:  -145.67898448978644  - MEAN SCORE:  -128.544508264134
# Last reward:  -100
# EPISODE:  309  - SCORE:  -107.96989813224616  - MEAN SCORE:  -127.91520970617071
# Last reward:  -100
# EPISODE:  310  - SCORE:  -117.50641187086761  - MEAN SCORE:  -128.19531921502187
# Last reward:  -100
# EPISODE:  311  - SCORE:  -86.5698356581359  - MEAN SCORE:  -128.10936814494164
# Last reward:  -100
# EPISODE:  312  - SCORE:  -132.9592213466031  - MEAN SCORE:  -128.13862033621785
# ACTUALIZA
# Last reward:  -100
# EPISODE:  313  - SCORE:  -85.65615166612919  - MEAN SCORE:  -128.10061131122922
# Last reward:  -100
# EPISODE:  314  - SCORE:  -106.2720301367716  - MEAN SCORE:  -128.03678491010177
# Last reward:  -100
# EPISODE:  315  - SCORE:  -135.38381743403363  - MEAN SCORE:  -127.89506773465686
# Last reward:  -100
# EPISODE:  316  - SCORE:  -134.8442892656309  - MEAN SCORE:  -128.15869516117314
# Last reward:  -100
# EPISODE:  317  - SCORE:  -131.4941074938049  - MEAN SCORE:  -127.56501807701305
# Last reward:  -100
# EPISODE:  318  - SCORE:  -110.34526313535244  - MEAN SCORE:  -127.74966162744948
# Last reward:  -100
# EPISODE:  319  - SCORE:  -97.6153952236985  - MEAN SCORE:  -127.97992569037831
# Last reward:  -100
# EPISODE:  320  - SCORE:  -154.8913564484074  - MEAN SCORE:  -128.37453481227206
# Last reward:  -100
# EPISODE:  321  - SCORE:  -102.86113376979871  - MEAN SCORE:  -127.90135575421145
# Last reward:  -100
# EPISODE:  322  - SCORE:  -150.86117426010202  - MEAN SCORE:  -128.14399723946633
# Last reward:  -100
# EPISODE:  323  - SCORE:  -117.05523172336262  - MEAN SCORE:  -127.08427442995546
# Last reward:  -100
# EPISODE:  324  - SCORE:  -126.86562340100971  - MEAN SCORE:  -127.63750938879768
# Last reward:  -100
# EPISODE:  325  - SCORE:  -104.31401215205497  - MEAN SCORE:  -127.34140710168982
# Last reward:  -100
# EPISODE:  326  - SCORE:  -103.30617438905223  - MEAN SCORE:  -127.02964361143275
# ACTUALIZA
# Last reward:  -100
# EPISODE:  327  - SCORE:  -92.56641452804334  - MEAN SCORE:  -126.54456724628712
# Last reward:  -100
# EPISODE:  328  - SCORE:  -155.9607785341961  - MEAN SCORE:  -126.33189696352235
# Last reward:  -100
# EPISODE:  329  - SCORE:  -132.45720452346765  - MEAN SCORE:  -126.5818247031279
# Last reward:  -100
# EPISODE:  330  - SCORE:  29.858953163782957  - MEAN SCORE:  -124.26464266104314
# Last reward:  -100
# EPISODE:  331  - SCORE:  -89.04784376631605  - MEAN SCORE:  -124.35911344345375
# Last reward:  -100
# EPISODE:  332  - SCORE:  -143.08042266730672  - MEAN SCORE:  -125.04950076188997
# Last reward:  -100
# EPISODE:  333  - SCORE:  -117.47103545179787  - MEAN SCORE:  -124.76760487397836
# Last reward:  -100
# EPISODE:  334  - SCORE:  -103.64663934460286  - MEAN SCORE:  -124.7245236913376
# Last reward:  -100
# EPISODE:  335  - SCORE:  -133.6850003654592  - MEAN SCORE:  -124.40301430308966
# Last reward:  -100
# EPISODE:  336  - SCORE:  -113.76868450031024  - MEAN SCORE:  -124.90275345978709
# Last reward:  -100
# EPISODE:  337  - SCORE:  -129.96849813492406  - MEAN SCORE:  -125.47089731764919
# Last reward:  -100
# EPISODE:  338  - SCORE:  -142.28843900346698  - MEAN SCORE:  -124.92091160738553
# Last reward:  -100
# EPISODE:  339  - SCORE:  -131.03240208206662  - MEAN SCORE:  -124.98105360687565
# Last reward:  -100
# EPISODE:  340  - SCORE:  -121.46622097616029  - MEAN SCORE:  -125.07793130753298
# ACTUALIZA
# Last reward:  -100
# EPISODE:  341  - SCORE:  -81.77661897556361  - MEAN SCORE:  -125.06687427442806
# Last reward:  -100
# EPISODE:  342  - SCORE:  -132.03953472584624  - MEAN SCORE:  -124.63612674284158
# Last reward:  -100
# EPISODE:  343  - SCORE:  -140.1716734391825  - MEAN SCORE:  -125.17573291343614
# Last reward:  -100
# EPISODE:  344  - SCORE:  -138.57779604772674  - MEAN SCORE:  -124.6387383519429
# Last reward:  -100
# EPISODE:  345  - SCORE:  -169.54428983468085  - MEAN SCORE:  -125.35211620545324
# Last reward:  -100
# EPISODE:  346  - SCORE:  -97.86751272556677  - MEAN SCORE:  -124.6320721669118
# Last reward:  -100
# EPISODE:  347  - SCORE:  -92.12042816042275  - MEAN SCORE:  -122.70696751952019
# Last reward:  -100
# EPISODE:  348  - SCORE:  -107.51495168514563  - MEAN SCORE:  -122.10807048938109
# Last reward:  -100
# EPISODE:  349  - SCORE:  -115.09975336614427  - MEAN SCORE:  -121.82665812273542
# Last reward:  -100
# EPISODE:  350  - SCORE:  -142.42071295912118  - MEAN SCORE:  -121.06472216168284
# Last reward:  -100
# EPISODE:  351  - SCORE:  -133.40196861926734  - MEAN SCORE:  -121.40700076926528
# Last reward:  -100
# EPISODE:  352  - SCORE:  -81.75028071143211  - MEAN SCORE:  -120.87472965455956
# Last reward:  -100
# EPISODE:  353  - SCORE:  -99.92786661628207  - MEAN SCORE:  -120.04574061567631
# ACTUALIZA
# Last reward:  -100
# EPISODE:  354  - SCORE:  -126.22060085114973  - MEAN SCORE:  -119.8619232452174
# Last reward:  -100
# EPISODE:  355  - SCORE:  -91.70956777040212  - MEAN SCORE:  -119.65641008738285
# Last reward:  -100
# EPISODE:  356  - SCORE:  -107.02373879450519  - MEAN SCORE:  -119.67832370301213
# Last reward:  -100
# EPISODE:  357  - SCORE:  -104.4652355196475  - MEAN SCORE:  -118.9980064769153
# Last reward:  -100
# EPISODE:  358  - SCORE:  -100.8118888322182  - MEAN SCORE:  -118.59771582350069
# Last reward:  -100
# EPISODE:  359  - SCORE:  -121.18900360907145  - MEAN SCORE:  -118.60497078480952
# Last reward:  -100
# EPISODE:  360  - SCORE:  -101.72605470533375  - MEAN SCORE:  -117.40947706921622
# Last reward:  -100
# EPISODE:  361  - SCORE:  -75.2155810488829  - MEAN SCORE:  -116.96705064311644
# Last reward:  -100
# EPISODE:  362  - SCORE:  -111.50527458725045  - MEAN SCORE:  -117.04213131451829
# Last reward:  -100
# EPISODE:  363  - SCORE:  -135.05023122324633  - MEAN SCORE:  -116.97373769972798
# Last reward:  -100
# EPISODE:  364  - SCORE:  -92.05797557256541  - MEAN SCORE:  -116.69458691241212
# Last reward:  -100
# EPISODE:  365  - SCORE:  -124.82860592218941  - MEAN SCORE:  -116.584755255985
# Last reward:  -100
# EPISODE:  366  - SCORE:  -76.74985731354585  - MEAN SCORE:  -115.92052040556202
# ACTUALIZA
# Last reward:  -100
# EPISODE:  367  - SCORE:  -58.5435798288207  - MEAN SCORE:  -115.40315060937002
# Last reward:  -100
# EPISODE:  368  - SCORE:  -156.69384487967793  - MEAN SCORE:  -115.75169535973394
# Last reward:  -100
# EPISODE:  369  - SCORE:  -100.99665810429775  - MEAN SCORE:  -115.99733404865192
# Last reward:  -100
# EPISODE:  370  - SCORE:  -171.8533650055421  - MEAN SCORE:  -116.8296268944664
# Last reward:  -100
# EPISODE:  371  - SCORE:  -96.86871079117186  - MEAN SCORE:  -117.57900724994376
# Last reward:  -100
# EPISODE:  372  - SCORE:  -233.23773233566095  - MEAN SCORE:  -118.9940654843417
# Last reward:  -100
# EPISODE:  373  - SCORE:  -131.72106857022365  - MEAN SCORE:  -119.0829149966796
# Last reward:  -100
# EPISODE:  374  - SCORE:  -99.3292829454723  - MEAN SCORE:  -118.80235794029628
# Last reward:  -100
# EPISODE:  375  - SCORE:  -127.01528164700676  - MEAN SCORE:  -118.6773601024972
# Last reward:  -100
# EPISODE:  376  - SCORE:  -141.60608192902572  - MEAN SCORE:  -119.07609927393801
# Last reward:  -100
# EPISODE:  377  - SCORE:  -142.4139207800324  - MEAN SCORE:  -119.46250274009827
# Last reward:  -100
# EPISODE:  378  - SCORE:  -96.88370433198926  - MEAN SCORE:  -119.39968354154541
# ACTUALIZA
# Last reward:  -100
# EPISODE:  379  - SCORE:  -140.80620807323226  - MEAN SCORE:  -119.61153536881262
# Last reward:  -100
# EPISODE:  380  - SCORE:  -76.59556129174128  - MEAN SCORE:  -119.25070301112959
# Last reward:  -100
# EPISODE:  381  - SCORE:  -127.26033784004042  - MEAN SCORE:  -119.3230528177884
# Last reward:  -100
# EPISODE:  382  - SCORE:  -108.53911813687864  - MEAN SCORE:  -119.15870623362233
# Last reward:  -100
# EPISODE:  383  - SCORE:  -194.02531306310703  - MEAN SCORE:  -119.45738711454014
# Last reward:  -100
# EPISODE:  384  - SCORE:  -153.80191712273034  - MEAN SCORE:  -119.75791385784765
# Last reward:  -100
# EPISODE:  385  - SCORE:  -151.39591914535112  - MEAN SCORE:  -119.70605613049489
# Last reward:  -100
# EPISODE:  386  - SCORE:  -116.97328755965852  - MEAN SCORE:  -119.77608823564958
# Last reward:  -100
# EPISODE:  387  - SCORE:  -125.26140881309729  - MEAN SCORE:  -120.87948482115884
# Last reward:  -100
# EPISODE:  388  - SCORE:  -121.12408432501577  - MEAN SCORE:  -121.07695169921881
# Last reward:  -100
# EPISODE:  389  - SCORE:  -153.24326720231824  - MEAN SCORE:  -121.15541669704739
# ACTUALIZA
# Last reward:  -100
# EPISODE:  390  - SCORE:  -110.54262314803861  - MEAN SCORE:  -121.02318718936594
# Last reward:  -100
# EPISODE:  391  - SCORE:  -122.58179268307137  - MEAN SCORE:  -120.77478976811314
# Last reward:  -100
# EPISODE:  392  - SCORE:  -79.75945261032976  - MEAN SCORE:  -120.40513459773184
# Last reward:  -100
# EPISODE:  393  - SCORE:  -83.71208893368512  - MEAN SCORE:  -119.19014082143259
# Last reward:  -100
# EPISODE:  394  - SCORE:  -251.49920940910033  - MEAN SCORE:  -120.48022157967952
# Last reward:  -100
# EPISODE:  395  - SCORE:  -106.4848445076856  - MEAN SCORE:  -120.16273147525473
# Last reward:  -100
# EPISODE:  396  - SCORE:  -92.25025400241468  - MEAN SCORE:  -119.83018174747227
# Last reward:  -100
# EPISODE:  397  - SCORE:  -57.67696270004441  - MEAN SCORE:  -119.6438478323725
# Last reward:  -100
# EPISODE:  398  - SCORE:  -123.5856387735241  - MEAN SCORE:  -118.47989650380397
# Last reward:  -100
# EPISODE:  399  - SCORE:  -116.29080070707646  - MEAN SCORE:  -118.61315581075425
# Last reward:  -100
# EPISODE:  400  - SCORE:  -91.21994535000204  - MEAN SCORE:  -118.07064863881888
# Last reward:  -100
# EPISODE:  401  - SCORE:  -79.5309447895464  - MEAN SCORE:  -117.94102178197292
# Last reward:  -100
# EPISODE:  402  - SCORE:  -100.2926832394847  - MEAN SCORE:  -117.82237657036181
# ACTUALIZA
# Last reward:  -100
# EPISODE:  403  - SCORE:  -120.1441151754267  - MEAN SCORE:  -117.80663470311708
# Last reward:  -100
# EPISODE:  404  - SCORE:  -116.77125425022903  - MEAN SCORE:  -117.95089442676172
# Last reward:  -100
# EPISODE:  405  - SCORE:  -107.80871842694678  - MEAN SCORE:  -117.92747701797123
# Last reward:  -100
# EPISODE:  406  - SCORE:  -86.00538955555591  - MEAN SCORE:  -117.3410063663535
# Last reward:  -100
# EPISODE:  407  - SCORE:  -117.11343165699944  - MEAN SCORE:  -117.19257549968825
# Last reward:  -100
# EPISODE:  408  - SCORE:  -90.01015909241738  - MEAN SCORE:  -116.63588724571454
# Last reward:  -100
# EPISODE:  409  - SCORE:  -96.93588898403641  - MEAN SCORE:  -116.52554715423248
# Last reward:  -100
# EPISODE:  410  - SCORE:  -140.81384837852545  - MEAN SCORE:  -116.75862151930906
# Last reward:  -100
# EPISODE:  411  - SCORE:  -138.81338247300903  - MEAN SCORE:  -117.2810569874578
# Last reward:  -100
# EPISODE:  412  - SCORE:  -110.56612296707534  - MEAN SCORE:  -117.05712600366252
# Last reward:  -100
# EPISODE:  413  - SCORE:  -119.33586136860274  - MEAN SCORE:  -117.39392310068725
# Last reward:  -100
# EPISODE:  414  - SCORE:  -80.7928540289026  - MEAN SCORE:  -117.13913133960858
# ACTUALIZA
# Last reward:  -100
# EPISODE:  415  - SCORE:  -120.45805485166377  - MEAN SCORE:  -116.9898737137849
# Last reward:  -100
# EPISODE:  416  - SCORE:  -133.36846378780376  - MEAN SCORE:  -116.97511545900663
# Last reward:  -100
# EPISODE:  417  - SCORE:  -120.35211665152072  - MEAN SCORE:  -116.86369555058376
# Last reward:  -100
# EPISODE:  418  - SCORE:  -159.518386579415  - MEAN SCORE:  -117.3554267850244
# Last reward:  -100
# EPISODE:  419  - SCORE:  -134.08938794686998  - MEAN SCORE:  -117.7201667122561
# Last reward:  -100
# EPISODE:  420  - SCORE:  -106.70326688108176  - MEAN SCORE:  -117.23828581658286
# Last reward:  -100
# EPISODE:  421  - SCORE:  -93.55466191699013  - MEAN SCORE:  -117.14522109805479
# Last reward:  -100
# EPISODE:  422  - SCORE:  -79.14092644472854  - MEAN SCORE:  -116.42801861990105
# Last reward:  -100
# EPISODE:  423  - SCORE:  -168.65499123770155  - MEAN SCORE:  -116.94401621504443
# Last reward:  -100
# EPISODE:  424  - SCORE:  -152.34241447116335  - MEAN SCORE:  -117.19878412574597
# Last reward:  -100
# EPISODE:  425  - SCORE:  -102.33544472302057  - MEAN SCORE:  -117.17899845145563
# ACTUALIZA
# Last reward:  -100
# EPISODE:  426  - SCORE:  -192.7250797196948  - MEAN SCORE:  -118.07318750476203
# Last reward:  -100
# EPISODE:  427  - SCORE:  -93.8523500423958  - MEAN SCORE:  -118.08604685990557
# Last reward:  -100
# EPISODE:  428  - SCORE:  -101.21364714769774  - MEAN SCORE:  -117.53857554604056
# Last reward:  -100
# EPISODE:  429  - SCORE:  -128.65824482890014  - MEAN SCORE:  -117.5005859490949
# Last reward:  -100
# EPISODE:  430  - SCORE:  -120.13681203441575  - MEAN SCORE:  -119.0005436010769
# Last reward:  -100
# EPISODE:  431  - SCORE:  -58.33055135066709  - MEAN SCORE:  -118.69337067692038
# Last reward:  -100
# EPISODE:  432  - SCORE:  -179.86833434618237  - MEAN SCORE:  -119.06124979370914
# Last reward:  -100
# EPISODE:  433  - SCORE:  -126.08668141925148  - MEAN SCORE:  -119.14740625338366
# Last reward:  -100
# EPISODE:  434  - SCORE:  -89.95869805361814  - MEAN SCORE:  -119.01052684047383
# Last reward:  -100
# EPISODE:  435  - SCORE:  -127.81319092657952  - MEAN SCORE:  -118.95180874608505
# Last reward:  -100
# EPISODE:  436  - SCORE:  -65.84994530520962  - MEAN SCORE:  -118.47262135413406
# Last reward:  -100
# EPISODE:  437  - SCORE:  -137.1448651736799  - MEAN SCORE:  -118.54438502452162
# Last reward:  -100
# EPISODE:  438  - SCORE:  -97.31250235612491  - MEAN SCORE:  -118.09462565804819
# ACTUALIZA
# Last reward:  -100
# EPISODE:  439  - SCORE:  -101.7485856117467  - MEAN SCORE:  -117.801787493345
# Last reward:  -100
# EPISODE:  440  - SCORE:  -102.63954628392594  - MEAN SCORE:  -117.61352074642264
# Last reward:  -100
# EPISODE:  441  - SCORE:  -161.6343506735637  - MEAN SCORE:  -118.41209806340262
# Last reward:  -100
# EPISODE:  442  - SCORE:  -51.08544687101647  - MEAN SCORE:  -117.60255718485433
# Last reward:  -100
# EPISODE:  443  - SCORE:  -82.67752384736706  - MEAN SCORE:  -117.02761568893621
# Last reward:  -100
# EPISODE:  444  - SCORE:  -126.65609884042362  - MEAN SCORE:  -116.90839871686316
# Last reward:  -100
# EPISODE:  445  - SCORE:  -84.42556193103245  - MEAN SCORE:  -116.05721143782667
# Last reward:  -100
# EPISODE:  446  - SCORE:  -94.56284996380555  - MEAN SCORE:  -116.02416481020906
# Last reward:  -100
# EPISODE:  447  - SCORE:  -108.5144236827924  - MEAN SCORE:  -116.18810476543277
# Last reward:  -100
# EPISODE:  448  - SCORE:  -77.40410901046694  - MEAN SCORE:  -115.88699633868599
# Last reward:  -100
# EPISODE:  449  - SCORE:  -104.16999451441515  - MEAN SCORE:  -115.77769875016867
# Last reward:  -100
# EPISODE:  450  - SCORE:  -116.21947742292707  - MEAN SCORE:  -115.51568639480675
# ACTUALIZA
# Last reward:  -100
# EPISODE:  451  - SCORE:  -148.33570633747485  - MEAN SCORE:  -115.66502377198884
# Last reward:  -100
# EPISODE:  452  - SCORE:  -80.37462247196976  - MEAN SCORE:  -115.6512671895942
# Last reward:  -100
# EPISODE:  453  - SCORE:  -111.48120833412791  - MEAN SCORE:  -115.76680060677265
# Last reward:  -100
# EPISODE:  454  - SCORE:  -115.04897672982534  - MEAN SCORE:  -115.65508436555938
# Last reward:  -100
# EPISODE:  455  - SCORE:  -132.94419319413151  - MEAN SCORE:  -116.06743061979667
# Last reward:  -100
# EPISODE:  456  - SCORE:  -93.51266195214546  - MEAN SCORE:  -115.93231985137307
# Last reward:  -100
# EPISODE:  457  - SCORE:  -147.99564426252937  - MEAN SCORE:  -116.3676239388019
# Last reward:  -100
# EPISODE:  458  - SCORE:  -131.6849636624934  - MEAN SCORE:  -116.67635468710465
# ...
# Last reward:  -100
# EPISODE:  2508  - SCORE:  -158.61725002344676  - MEAN SCORE:  -125.90951289447709
# Last reward:  -100
# EPISODE:  2509  - SCORE:  -170.67375296718274  - MEAN SCORE:  -126.53570930932744
# Last reward:  -100
# EPISODE:  2510  - SCORE:  -145.32267924356591  - MEAN SCORE:  -126.91567568750862
# Last reward:  -100
# EPISODE:  2511  - SCORE:  -138.6110776178326  - MEAN SCORE:  -126.80445298069436
# Last reward:  -100
# EPISODE:  2512  - SCORE:  -126.97688630093334  - MEAN SCORE:  -126.74547405358113
# Last reward:  -100
# EPISODE:  2513  - SCORE:  -113.15944215378781  - MEAN SCORE:  -126.68151323496258
# Last reward:  -100
# EPISODE:  2514  - SCORE:  -121.61882677031755  - MEAN SCORE:  -126.38420108211925
# Last reward:  -100
# EPISODE:  2515  - SCORE:  -123.4330834760508  - MEAN SCORE:  -126.2926123540332
# ACTUALIZA
# Last reward:  -100
# EPISODE:  2516  - SCORE:  -137.790413959674  - MEAN SCORE:  -126.07506498632685
# Last reward:  -100
# EPISODE:  2517  - SCORE:  -145.77783378171083  - MEAN SCORE:  -126.21145932759426
# Last reward:  -100
# EPISODE:  2518  - SCORE:  -121.48084980998833  - MEAN SCORE:  -125.99420364772568
# Last reward:  -100
# EPISODE:  2519  - SCORE:  -123.72263467126744  - MEAN SCORE:  -125.87269455948385
# Last reward:  -100
# EPISODE:  2520  - SCORE:  -142.062601955495  - MEAN SCORE:  -126.2473328220982
# Last reward:  -100
# EPISODE:  2521  - SCORE:  -132.8809498438261  - MEAN SCORE:  -126.28869491697711
# Last reward:  -100
# EPISODE:  2522  - SCORE:  -126.53613132630394  - MEAN SCORE:  -125.91870313791324
# Last reward:  -100
# EPISODE:  2523  - SCORE:  -120.01257817081168  - MEAN SCORE:  -125.80247888615676
# Last reward:  -100
# EPISODE:  2524  - SCORE:  -128.52007815380432  - MEAN SCORE:  -125.86695417130008
# Last reward:  -100
# EPISODE:  2525  - SCORE:  -95.10293618833998  - MEAN SCORE:  -125.6210028230217
# Last reward:  -100
# EPISODE:  2526  - SCORE:  -108.31239924570448  - MEAN SCORE:  -125.23673896651322
# Last reward:  -100
# EPISODE:  2527  - SCORE:  -150.06052270516176  - MEAN SCORE:  -125.45996992937476
# Last reward:  -100
# EPISODE:  2528  - SCORE:  -123.4094478811036  - MEAN SCORE:  -125.40911507909637
# Last reward:  -100
# EPISODE:  2529  - SCORE:  -138.26240065506303  - MEAN SCORE:  -125.24880450698484
# ACTUALIZA
# Last reward:  -100
# EPISODE:  2530  - SCORE:  -142.31508619263712  - MEAN SCORE:  -125.51704862553468
# Last reward:  -100
# EPISODE:  2531  - SCORE:  13.513706290491456  - MEAN SCORE:  -123.98264377854561
# Last reward:  -100
# EPISODE:  2532  - SCORE:  -128.8150531004909  - MEAN SCORE:  -124.08792462456586
# Last reward:  -100
# EPISODE:  2533  - SCORE:  -90.08408779147817  - MEAN SCORE:  -123.76455427837558
# Last reward:  -100
# EPISODE:  2534  - SCORE:  -99.47442123842595  - MEAN SCORE:  -123.3620714092233
# Last reward:  -100
# EPISODE:  2535  - SCORE:  -105.91148313416022  - MEAN SCORE:  -123.51304032675202
# Last reward:  -100
# EPISODE:  2536  - SCORE:  -134.97544378667973  - MEAN SCORE:  -123.92456489151137
# Last reward:  -100
# EPISODE:  2537  - SCORE:  -103.01023036167464  - MEAN SCORE:  -123.6331766252608
# Last reward:  -100
# EPISODE:  2538  - SCORE:  -139.45717391354376  - MEAN SCORE:  -124.01993509433643
# Last reward:  -100
# EPISODE:  2539  - SCORE:  -144.00637496105182  - MEAN SCORE:  -124.31104959297791
# Last reward:  -100
# EPISODE:  2540  - SCORE:  -136.492712677374  - MEAN SCORE:  -124.10017907191906
# Last reward:  -100
# EPISODE:  2541  - SCORE:  -113.38062505704647  - MEAN SCORE:  -124.33163643924155
# Last reward:  -100
# EPISODE:  2542  - SCORE:  -105.71350378237264  - MEAN SCORE:  -124.02597453591744
# Last reward:  -100
# EPISODE:  2543  - SCORE:  -131.1433578340905  - MEAN SCORE:  -124.11231430729269
# Last reward:  -100
# EPISODE:  2544  - SCORE:  -112.3746976927915  - MEAN SCORE:  -124.17911476303496
# ACTUALIZA
# Last reward:  -100
# EPISODE:  2545  - SCORE:  -115.43797470117609  - MEAN SCORE:  -123.97637812210101
# Last reward:  -100
# EPISODE:  2546  - SCORE:  -129.31672332775847  - MEAN SCORE:  -124.10654918085038
# Last reward:  -100
# EPISODE:  2547  - SCORE:  -106.24550188680027  - MEAN SCORE:  -124.01209319063315
# Last reward:  -100
# EPISODE:  2548  - SCORE:  -161.49802372249582  - MEAN SCORE:  -124.79626308992593
# Last reward:  -100
# EPISODE:  2549  - SCORE:  -158.38791438744613  - MEAN SCORE:  -124.99222671655673
# Last reward:  -100
# EPISODE:  2550  - SCORE:  -121.71110054328145  - MEAN SCORE:  -125.06089783816287
# Last reward:  -100
# EPISODE:  2551  - SCORE:  -140.73903399258487  - MEAN SCORE:  -125.03812624754697
# Last reward:  -100
# EPISODE:  2552  - SCORE:  -136.4195532468502  - MEAN SCORE:  -124.83575476616944
# Last reward:  -100
# EPISODE:  2553  - SCORE:  -124.69342303857484  - MEAN SCORE:  -124.74121705332078
# Last reward:  -100
# EPISODE:  2554  - SCORE:  -161.3462415275505  - MEAN SCORE:  -125.13684155621027
# Last reward:  -100
# EPISODE:  2555  - SCORE:  -113.83518539927074  - MEAN SCORE:  -125.09189853439777
# Last reward:  -100
# EPISODE:  2556  - SCORE:  -107.96308636479827  - MEAN SCORE:  -124.82280933873331
# Last reward:  -100
# EPISODE:  2557  - SCORE:  -109.17636143753107  - MEAN SCORE:  -124.68221550589259
# Last reward:  -100
# EPISODE:  2558  - SCORE:  -114.22236285924905  - MEAN SCORE:  -124.69557119231948
# Last reward:  -100
# EPISODE:  2559  - SCORE:  -197.80253449413345  - MEAN SCORE:  -125.43259336457179
# ACTUALIZA
# Last reward:  -100
# EPISODE:  2560  - SCORE:  -101.50819757501128  - MEAN SCORE:  -125.05071464472343
# Last reward:  -100
# EPISODE:  2561  - SCORE:  -158.52264392612668  - MEAN SCORE:  -125.49312571431342
# Last reward:  -100
# EPISODE:  2562  - SCORE:  -104.71597149438311  - MEAN SCORE:  -125.0156253583506
# Last reward:  -100
# EPISODE:  2563  - SCORE:  -109.97361579362223  - MEAN SCORE:  -124.86631781425196
# Last reward:  -100
# EPISODE:  2564  - SCORE:  -153.63532732721487  - MEAN SCORE:  -125.40343312414787
# Last reward:  -100
# EPISODE:  2565  - SCORE:  -120.36129500438976  - MEAN SCORE:  -125.38946105334651
# Last reward:  -100
# EPISODE:  2566  - SCORE:  -123.30788409894782  - MEAN SCORE:  -125.49578357783044
# Last reward:  -100
# EPISODE:  2567  - SCORE:  -111.86605874976814  - MEAN SCORE:  -125.31277865088478
# Last reward:  -100
# EPISODE:  2568  - SCORE:  20.32383618027029  - MEAN SCORE:  -123.92687596805703
# Last reward:  -100
# EPISODE:  2569  - SCORE:  -120.05496716731308  - MEAN SCORE:  -123.749094309731
# Last reward:  -100
# EPISODE:  2570  - SCORE:  -131.41034352742525  - MEAN SCORE:  -123.84773107382607
# Last reward:  -100
# EPISODE:  2571  - SCORE:  -155.1133654651195  - MEAN SCORE:  -124.21583720233139
# Last reward:  -100
# EPISODE:  2572  - SCORE:  -127.70257934622084  - MEAN SCORE:  -123.65684770782931
# Last reward:  -100
# EPISODE:  2573  - SCORE:  -126.14126427936647  - MEAN SCORE:  -123.56120771958363
# Last reward:  -100
# EPISODE:  2574  - SCORE:  -144.2764910150689  - MEAN SCORE:  -124.03666004720284
# ACTUALIZA
# Last reward:  -100
# EPISODE:  2575  - SCORE:  -42.65745255661962  - MEAN SCORE:  -123.28911863889769
# Last reward:  -100
# EPISODE:  2576  - SCORE:  -147.498288054194  - MEAN SCORE:  -123.65063673300729
# Last reward:  -100
# EPISODE:  2577  - SCORE:  -126.74607808568337  - MEAN SCORE:  -124.5675164953713
# Last reward:  -100
# EPISODE:  2578  - SCORE:  -169.4965908460449  - MEAN SCORE:  -124.79739719847686
# Last reward:  -100
# EPISODE:  2579  - SCORE:  -140.57038358717767  - MEAN SCORE:  -124.77907195687294
# Last reward:  -100
# EPISODE:  2580  - SCORE:  -128.9726353372846  - MEAN SCORE:  -124.98353390468912
# Last reward:  -100
# EPISODE:  2581  - SCORE:  -132.08108258338518  - MEAN SCORE:  -125.42560550825493
# Last reward:  -100
# EPISODE:  2582  - SCORE:  0.6639244208719788  - MEAN SCORE:  -124.71799816217207
# Last reward:  -100
# EPISODE:  2583  - SCORE:  -164.3708394847123  - MEAN SCORE:  -125.23074651653776
# Last reward:  -100
# EPISODE:  2584  - SCORE:  -171.3408059775662  - MEAN SCORE:  -125.85235800304795
# Last reward:  -100
# EPISODE:  2585  - SCORE:  -150.06098343394086  - MEAN SCORE:  -126.30100966505609
# Last reward:  -100
# EPISODE:  2586  - SCORE:  -151.7250426007302  - MEAN SCORE:  -126.55121628377142
# Last reward:  -100
# EPISODE:  2587  - SCORE:  -131.28412982343497  - MEAN SCORE:  -126.60070638525357
# Last reward:  -100
# EPISODE:  2588  - SCORE:  -106.2914147110783  - MEAN SCORE:  -126.63364632336317
# ACTUALIZA
# Last reward:  -100
# EPISODE:  2589  - SCORE:  -137.58904380596172  - MEAN SCORE:  -126.99310547330924
# Last reward:  -100
# EPISODE:  2590  - SCORE:  -192.06711240671584  - MEAN SCORE:  -127.44191936128549
# Last reward:  -100
# EPISODE:  2591  - SCORE:  -97.38336667026482  - MEAN SCORE:  -127.39357043616124
# Last reward:  -100
# EPISODE:  2592  - SCORE:  -113.72862064676873  - MEAN SCORE:  -127.43552101194088
# Last reward:  -100
# EPISODE:  2593  - SCORE:  -181.64657492237012  - MEAN SCORE:  -128.09870779458407
# Last reward:  -100
# EPISODE:  2594  - SCORE:  -166.10806625676736  - MEAN SCORE:  -128.2128846366116
# Last reward:  -100
# EPISODE:  2595  - SCORE:  -138.42151536703483  - MEAN SCORE:  -128.2456848825339
# Last reward:  -100
# EPISODE:  2596  - SCORE:  -156.6956098315389  - MEAN SCORE:  -128.19085765163095
# Last reward:  -100
# EPISODE:  2597  - SCORE:  -110.03089605204971  - MEAN SCORE:  -127.91828194801664
# Last reward:  -100
# EPISODE:  2598  - SCORE:  -142.87746240200218  - MEAN SCORE:  -128.1408814441562
# Last reward:  -100
# EPISODE:  2599  - SCORE:  -37.91588428136818  - MEAN SCORE:  -127.15605022962956
# Last reward:  -100
# EPISODE:  2600  - SCORE:  -213.6169860206929  - MEAN SCORE:  -127.92010750493938
# Last reward:  -100
# EPISODE:  2601  - SCORE:  -150.00897268966816  - MEAN SCORE:  -127.97999571463052
# Last reward:  -100
# EPISODE:  2602  - SCORE:  -155.88743851676108  - MEAN SCORE:  -128.19609332544985
# ACTUALIZA
# Last reward:  -100
# EPISODE:  2603  - SCORE:  -129.40465075636325  - MEAN SCORE:  -128.1263275450768
# Last reward:  -100
# EPISODE:  2604  - SCORE:  -133.49979427374038  - MEAN SCORE:  -128.45595293205665
# Last reward:  -100
# EPISODE:  2605  - SCORE:  -115.58976741890807  - MEAN SCORE:  -127.98307618430498
# Last reward:  -100
# EPISODE:  2606  - SCORE:  -143.09082690275122  - MEAN SCORE:  -127.99633901336387
# Last reward:  -100
# EPISODE:  2607  - SCORE:  -183.09385119185833  - MEAN SCORE:  -127.94134754728475
# Last reward:  -100
# EPISODE:  2608  - SCORE:  -118.54812025384577  - MEAN SCORE:  -127.54065624958874
# Last reward:  -100
# EPISODE:  2609  - SCORE:  -130.85777454646424  - MEAN SCORE:  -127.14249646538156
# Last reward:  -100
# EPISODE:  2610  - SCORE:  -125.63412456738135  - MEAN SCORE:  -126.94561091861969
# Last reward:  -100
# EPISODE:  2611  - SCORE:  -117.9377807113748  - MEAN SCORE:  -126.73887794955512
# Last reward:  -100
# EPISODE:  2612  - SCORE:  -120.21163161532432  - MEAN SCORE:  -126.67122540269902
# Last reward:  -100
# EPISODE:  2613  - SCORE:  -117.03946017054282  - MEAN SCORE:  -126.71002558286658
# Last reward:  -100
# EPISODE:  2614  - SCORE:  -183.05886767594728  - MEAN SCORE:  -127.32442599192287
# Last reward:  -100
# EPISODE:  2615  - SCORE:  -126.31706324900424  - MEAN SCORE:  -127.35326578965241
# Last reward:  -100
# EPISODE:  2616  - SCORE:  -151.11146364748458  - MEAN SCORE:  -127.4864762865305
# Last reward:  -100
# EPISODE:  2617  - SCORE:  -131.94027305195863  - MEAN SCORE:  -127.34810067923297
# ACTUALIZA
# Last reward:  -100
# EPISODE:  2618  - SCORE:  -141.73880339584883  - MEAN SCORE:  -127.55068021509157
# Last reward:  -100
# EPISODE:  2619  - SCORE:  -102.1869963109824  - MEAN SCORE:  -127.33532383148874
# Last reward:  -100
# EPISODE:  2620  - SCORE:  -316.20580749502915  - MEAN SCORE:  -129.0767558868841
# Last reward:  -100
# EPISODE:  2621  - SCORE:  -114.35762557800071  - MEAN SCORE:  -128.89152264422583
# Last reward:  -100
# EPISODE:  2622  - SCORE:  -135.12624474587554  - MEAN SCORE:  -128.97742377842155
# Last reward:  -100
# EPISODE:  2623  - SCORE:  -339.5937161278782  - MEAN SCORE:  -131.17323515799222
# Last reward:  -100
# EPISODE:  2624  - SCORE:  -170.2644042490739  - MEAN SCORE:  -131.59067841894492
# Last reward:  -100
# EPISODE:  2625  - SCORE:  -141.65276269862852  - MEAN SCORE:  -132.05617668404778
# Last reward:  -100
# EPISODE:  2626  - SCORE:  -108.56167442064654  - MEAN SCORE:  -132.0586694357972
# Last reward:  -100
# EPISODE:  2627  - SCORE:  -232.6845139274206  - MEAN SCORE:  -132.88490934801982
# Last reward:  -100
# EPISODE:  2628  - SCORE:  -120.56623745667457  - MEAN SCORE:  -132.85647724377552
# Last reward:  -100
# EPISODE:  2629  - SCORE:  -126.12945164579965  - MEAN SCORE:  -132.7351477536829
# Last reward:  -100
# EPISODE:  2630  - SCORE:  -174.6564372479065  - MEAN SCORE:  -133.05856126423558
# Last reward:  -100
# EPISODE:  2631  - SCORE:  -167.02926004104054  - MEAN SCORE:  -134.8639909275509
# Last reward:  -100
# EPISODE:  2632  - SCORE:  -122.49211195756087  - MEAN SCORE:  -134.80076151612158
# ACTUALIZA
# Last reward:  -100
# EPISODE:  2633  - SCORE:  -170.19853649958407  - MEAN SCORE:  -135.60190600320263
# Last reward:  -100
# EPISODE:  2634  - SCORE:  -110.38818573964812  - MEAN SCORE:  -135.71104364821485
# Last reward:  -100
# EPISODE:  2635  - SCORE:  -125.2286883630847  - MEAN SCORE:  -135.9042157005041
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e74cadf140a6> in <module>
#      17         while len(ag.memory.global_batch[0]) < BUFFER_SIZE:
#      18             # Get the action given the current state
# ---> 19             action, action_matrix, predicted_action = ag.get_action(state)
#      20             # Step in the enviroment and gather all parameters
#      21             next_state, reward, done, info = env.step(action)
#
# <ipython-input-5-02d22916377d> in get_action(self, state)
#      54     # Get the action given the current state
#      55     def get_action(self, state):
# ---> 56         probabilities = self.actor.predict([state.reshape(1, NUM_STATES), DUMMY_VALUE, DUMMY_ACTION])
#      57         action = np.random.choice(NUM_ACTIONS, p=np.nan_to_num(probabilities[0]))
#      58         action_matrix = np.zeros(NUM_ACTIONS)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_v1.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     964         max_queue_size=max_queue_size,
#     965         workers=workers,
# --> 966         use_multiprocessing=use_multiprocessing)
#     967
#     968   def reset_metrics(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in predict(self, model, x, batch_size, verbose, steps, callbacks, **kwargs)
#     712         verbose=verbose,
#     713         steps=steps,
# --> 714         callbacks=callbacks)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     384
#     385         # Get outputs.
# --> 386         batch_outs = f(ins_batch)
#     387         if not isinstance(batch_outs, list):
#     388           batch_outs = [batch_outs]
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3630
#    3631     fetched = self._callable_fn(*array_vals,
# -> 3632                                 run_metadata=self.run_metadata)
#    3633     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3634     output_structure = nest.pack_sequence_as(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
