# %% [markdown]
# Cartpole v0 prueba

# %%
import os

import random
import gym
import pylab
import numpy as np
import tensorflow as tf
import time
import matplotlib.pyplot as plt

#tf.config.experimental_run_functions_eagerly(True)
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import backend as K
import copy

EPISODES = 10000 # Number of times the enviroment is ran
LOSS_CLIPPING = 0.2 # Approximated values stated in the original paper
ENTROPY_LOSS = 0.001 # Epochs to train the network (recommended between 3 and 30)
LR = 0.0003 # Learning rate 
NUM_ACTIONS = 2 # Number of possible action in the environment
NUM_STATES = 4 # Number of possible states in the exvironment
EPOCHS = 10 # Epochs to train the network (recommended between 3 and 30)
BATCH_SIZE = 64 # Batch size for the neural nets
BUFFER_SIZE = 2048 # Buffer of experiences
SHUFFLE = True # Whether to shuffle data or not while training
OPTIMIZER = Adam # Optimizer for both actor and critic
GAMMA = 0.99 # Used for the estimated reward
LAMBDA = 0.95 # Used in the original paper un the GAE
NORMALIZE = True # Whether to normalize GAE or not



# Create the actor used to select the action given an state
class Actor_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X_input)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        
        # Softmax as there are different probabilities depending on the action
        output = Dense(NUM_ACTIONS, activation="softmax")(X)
        
        # Compile the model with the custom loss
        self.model = Model(inputs = X_input, outputs = output)
        self.model.compile(loss=self.ppo_loss, optimizer=OPTIMIZER(lr=LR))

    # Custom loss functions for the PPO
    def ppo_loss(self, y_true, y_pred):
        # Unpack the elements given in the true label
        advantages, true_label, actions = y_true[:, :1], y_true[:, 1:1+NUM_ACTIONS], y_true[:, 1+NUM_ACTIONS:]
        
        prob = actions * y_pred
        old_prob = actions * true_label 

        ratio = K.exp(K.log(prob + 1e-10) - K.log(old_prob + 1e-10))
        
        p1 = ratio * advantages
        p2 = K.clip(ratio, min_value=1 - LOSS_CLIPPING, max_value=1 + LOSS_CLIPPING) * advantages

        actor_loss = -K.mean(K.minimum(p1, p2))

        entropy = -(y_pred * K.log(y_pred + 1e-10))
        entropy = ENTROPY_LOSS * K.mean(entropy)
        
        total_loss = actor_loss - entropy

        return total_loss

# Create the critic which will criticise how the actor is performing    
class Critic_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X_input)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
        
        # Linear output to know how good the action is
        value = Dense(1)(X)
        
        # Compile it with mse loss and gradient descent
        self.model = Model(inputs=X_input, outputs = value)
        self.model.compile(loss='mse', optimizer=OPTIMIZER(lr=LR))

# Combine both Actor and Critic to create the agent
class PPOAgent:
    def __init__(self, env_name):
        # Environment parameters
        self.env_name = env_name       
        self.env = gym.make(env_name)
        self.episode = 0 # used to track current number episoded since start
        self.max_average = 0 # record max average reached
        
        # Used to plot a grapgh of the train process
        self.scores_, self.average_ = [], []

        # Create Actor-Critic network models
        self.Actor = Actor_Model()
        self.Critic = Critic_Model()
    
        # Names for the models
        self.Actor_name = f"{self.env_name}_PPO_Actor.h5"
        self.Critic_name = f"{self.env_name}_PPO_Critic.h5"

    # Get the action given the current state    
    def act(self, state):
        # Use the network to predict the next action to take, using the model
        prediction = self.Actor.model.predict(state)[0]
        
        # Probability based to choose the action
        action = np.random.choice(NUM_ACTIONS, p=prediction)
        action_onehot = np.zeros([NUM_ACTIONS])
        action_onehot[action] = 1
        return action, action_onehot, prediction

    # Generalized Advantage Estimation implemented in the original paper
    def get_gaes(self, rewards, dones, values, next_values):
        # Dones are used to track when is the final step of an episode, so next values are no applied
        deltas = [r + GAMMA * (1 - d) * nv - v for r, d, nv, v in zip(rewards, dones, next_values, values)]
        
        # Convert list to array as .mean() and .std() are used later
        deltas = np.stack(deltas)
        gaes = copy.deepcopy(deltas)
        
        for t in reversed(range(len(deltas) - 1)):
            gaes[t] = gaes[t] + (1 - dones[t]) * GAMMA * LAMBDA * gaes[t + 1]

        target = gaes + values
        if NORMALIZE:
            gaes = (gaes - gaes.mean()) / (gaes.std() + 1e-8)
        return np.vstack(gaes), np.vstack(target)

    def replay(self, states, actions, rewards, predictions, dones, next_states):
        # Reshape memory to appropriate shape for training
        states = np.vstack(states)
        next_states = np.vstack(next_states)
        actions = np.vstack(actions)
        predictions = np.vstack(predictions)

        # Get Critic network predictions for state and next state
        values = self.Critic.model.predict(states)
        next_values = self.Critic.model.predict(next_states)

        # Get the advantage
        advantages, target = self.get_gaes(rewards, dones, np.squeeze(values), np.squeeze(next_values))

        # Stack info to unpack it in the custom loss
        y_true = np.hstack([advantages, predictions, actions])

        # Training Actor and Critic networks
        a_loss = self.Actor.model.fit(states, y_true, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)
        c_loss = self.Critic.model.fit(states, target, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)

 
    def load(self):
        self.Actor.Actor.load_weights(self.Actor_name)
        self.Critic.Critic.load_weights(self.Critic_name)

    def save(self):
        self.Actor.model.save_weights(self.Actor_name)
        self.Critic.model.save_weights(self.Critic_name)

    def run_batch(self): # train every self.Training_batch episodes
        global LR
        state = self.env.reset()
        state = np.reshape(state, [1, NUM_STATES])
        done, score = False, 0
        finished = False
        while finished == False:
            # Instantiate or reset games memory
            states, next_states, actions, rewards, predictions, dones = [], [], [], [], [], []
            for t in range(BUFFER_SIZE):
                #self.env.render()
                # Actor picks an action
                action, action_onehot, prediction = self.act(state)
                # Retrieve new state, reward, and whether the state is terminal
                next_state, reward, done, _ = self.env.step(action)
                # Memorize (state, action, reward) for training
                states.append(state)
                next_states.append(np.reshape(next_state, [1, NUM_STATES]))
                actions.append(action_onehot)
                rewards.append(reward)
                dones.append(done)
                predictions.append(prediction)
                # Update current state
                state = np.reshape(next_state, [1, NUM_STATES])
                score += reward
                if done:
                    self.episode += 1
                    self.scores_.append(score)
                    #average, SAVING = self.PlotModel(score, self.episode)
                    #print("episode: {}/{}, score: {}, average: {:.2f} {}".format(self.episode, EPISODES, score, average, SAVING))
                    if self.episode >= 100:
                        average = sum(self.scores_[-100:])/100
                        print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, score, average))
                        if average > self.max_average:
                            self.max_average = average
                            if self.max_average > 150:
                                self.save()
                            LR *= 0.95
                            K.set_value(self.Actor.model.optimizer.learning_rate, LR)
                            K.set_value(self.Critic.model.optimizer.learning_rate, LR)
                            
                        if average > 200:
                            plt.plot(self.scores_)
                            plt.xlabel("Episode")
                            plt.ylabel("Score")
                            finished = True
                            break

                    else:
                        print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, score, sum(self.scores_)/len(self.scores_)))
                    
                    
                    state, done, score = self.env.reset(), False, 0
                    state = np.reshape(state, [1, NUM_STATES])
                    
            self.replay(states, actions, rewards, predictions, dones, next_states)
            if self.episode >= EPISODES:
                break
        self.env.close()  
                    
if __name__ == "__main__":
    start = time.time()
    env_name = 'CartPole-v0'
    agent = PPOAgent(env_name)
    #agent.run() # train as PPO, train every epesode
    agent.run_batch() # train as PPO, train every batch, trains better
    #agent.run_multiprocesses(num_worker = 8)  # train PPO multiprocessed (fastest)
    #agent.test()
    print((time.time() - start)/60)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Episode:     1		score:   20.00		average:   20.00
# Episode:     2		score:   54.00		average:   37.00
# Episode:     3		score:   20.00		average:   31.33
# Episode:     4		score:   23.00		average:   29.25
# Episode:     5		score:   27.00		average:   28.80
# Episode:     6		score:   21.00		average:   27.50
# Episode:     7		score:   17.00		average:   26.00
# Episode:     8		score:   23.00		average:   25.62
# Episode:     9		score:   34.00		average:   26.56
# Episode:    10		score:   12.00		average:   25.10
# Episode:    11		score:   24.00		average:   25.00
# Episode:    12		score:   29.00		average:   25.33
# Episode:    13		score:   21.00		average:   25.00
# Episode:    14		score:   26.00		average:   25.07
# Episode:    15		score:   14.00		average:   24.33
# Episode:    16		score:   27.00		average:   24.50
# Episode:    17		score:   26.00		average:   24.59
# Episode:    18		score:   28.00		average:   24.78
# Episode:    19		score:   12.00		average:   24.11
# Episode:    20		score:   23.00		average:   24.05
# Episode:    21		score:   44.00		average:   25.00
# Episode:    22		score:   16.00		average:   24.59
# Episode:    23		score:   31.00		average:   24.87
# Episode:    24		score:   17.00		average:   24.54
# Episode:    25		score:   13.00		average:   24.08
# Episode:    26		score:   17.00		average:   23.81
# Episode:    27		score:   44.00		average:   24.56
# Episode:    28		score:   63.00		average:   25.93
# Episode:    29		score:   36.00		average:   26.28
# Episode:    30		score:   43.00		average:   26.83
# Episode:    31		score:   30.00		average:   26.94
# Episode:    32		score:   22.00		average:   26.78
# Episode:    33		score:   18.00		average:   26.52
# Episode:    34		score:    9.00		average:   26.00
# Episode:    35		score:   19.00		average:   25.80
# Episode:    36		score:   18.00		average:   25.58
# Episode:    37		score:   13.00		average:   25.24
# Episode:    38		score:   14.00		average:   24.95
# Episode:    39		score:   21.00		average:   24.85
# Episode:    40		score:   37.00		average:   25.15
# Episode:    41		score:   21.00		average:   25.05
# Episode:    42		score:    9.00		average:   24.67
# Episode:    43		score:   11.00		average:   24.35
# Episode:    44		score:   45.00		average:   24.82
# Episode:    45		score:   10.00		average:   24.49
# Episode:    46		score:   19.00		average:   24.37
# Episode:    47		score:   23.00		average:   24.34
# Episode:    48		score:   75.00		average:   25.40
# Episode:    49		score:   14.00		average:   25.16
# Episode:    50		score:   13.00		average:   24.92
# Episode:    51		score:   21.00		average:   24.84
# Episode:    52		score:   29.00		average:   24.92
# Episode:    53		score:   15.00		average:   24.74
# Episode:    54		score:   20.00		average:   24.65
# Episode:    55		score:   33.00		average:   24.80
# Episode:    56		score:   13.00		average:   24.59
# Episode:    57		score:   42.00		average:   24.89
# Episode:    58		score:   15.00		average:   24.72
# Episode:    59		score:   22.00		average:   24.68
# Episode:    60		score:   29.00		average:   24.75
# Episode:    61		score:   28.00		average:   24.80
# Episode:    62		score:   11.00		average:   24.58
# Episode:    63		score:   16.00		average:   24.44
# Episode:    64		score:   19.00		average:   24.36
# Episode:    65		score:   44.00		average:   24.66
# Episode:    66		score:   21.00		average:   24.61
# Episode:    67		score:   30.00		average:   24.69
# Episode:    68		score:   22.00		average:   24.65
# Episode:    69		score:   27.00		average:   24.68
# Episode:    70		score:   23.00		average:   24.66
# Episode:    71		score:   13.00		average:   24.49
# Episode:    72		score:   62.00		average:   25.01
# Episode:    73		score:   16.00		average:   24.89
# Episode:    74		score:   10.00		average:   24.69
# Episode:    75		score:   23.00		average:   24.67
# Episode:    76		score:   11.00		average:   24.49
# Episode:    77		score:   20.00		average:   24.43
# Episode:    78		score:   16.00		average:   24.32
# Episode:    79		score:   56.00		average:   24.72
# Episode:    80		score:   28.00		average:   24.76
# Episode:    81		score:   34.00		average:   24.88
# Episode:    82		score:   14.00		average:   24.74
# Episode:    83		score:   12.00		average:   24.59
# Episode:    84		score:   31.00		average:   24.67
# Episode:    85		score:   18.00		average:   24.59
# Episode:    86		score:   30.00		average:   24.65
# Episode:    87		score:   33.00		average:   24.75
# Episode:    88		score:   44.00		average:   24.97
# Episode:    89		score:   42.00		average:   25.16
# Episode:    90		score:   19.00		average:   25.09
# Episode:    91		score:   22.00		average:   25.05
# Episode:    92		score:   18.00		average:   24.98
# Episode:    93		score:   27.00		average:   25.00
# Episode:    94		score:   21.00		average:   24.96
# Episode:    95		score:   53.00		average:   25.25
# Episode:    96		score:   14.00		average:   25.14
# Episode:    97		score:   47.00		average:   25.36
# Episode:    98		score:   22.00		average:   25.33
# Episode:    99		score:   18.00		average:   25.25
# Episode:   100		score:   59.00		average:   25.59
# Episode:   101		score:   19.00		average:   25.58
# Episode:   102		score:   39.00		average:   25.43
# Episode:   103		score:   28.00		average:   25.51
# Episode:   104		score:   48.00		average:   25.76
# Episode:   105		score:   57.00		average:   26.06
# Episode:   106		score:   32.00		average:   26.17
# Episode:   107		score:   57.00		average:   26.57
# Episode:   108		score:   27.00		average:   26.61
# Episode:   109		score:   44.00		average:   26.71
# Episode:   110		score:   25.00		average:   26.84
# Episode:   111		score:   53.00		average:   27.13
# Episode:   112		score:   24.00		average:   27.08
# Episode:   113		score:   55.00		average:   27.42
# Episode:   114		score:   23.00		average:   27.39
# Episode:   115		score:   15.00		average:   27.40
# Episode:   116		score:   34.00		average:   27.47
# Episode:   117		score:   32.00		average:   27.53
# Episode:   118		score:   55.00		average:   27.80
# Episode:   119		score:   41.00		average:   28.09
# Episode:   120		score:   33.00		average:   28.19
# Episode:   121		score:   28.00		average:   28.03
# Episode:   122		score:   29.00		average:   28.16
# Episode:   123		score:   33.00		average:   28.18
# Episode:   124		score:   25.00		average:   28.26
# Episode:   125		score:   19.00		average:   28.32
# Episode:   126		score:   33.00		average:   28.48
# Episode:   127		score:   15.00		average:   28.19
# Episode:   128		score:   18.00		average:   27.74
# Episode:   129		score:   26.00		average:   27.64
# Episode:   130		score:   21.00		average:   27.42
# Episode:   131		score:   11.00		average:   27.23
# Episode:   132		score:   23.00		average:   27.24
# Episode:   133		score:   28.00		average:   27.34
# Episode:   134		score:   42.00		average:   27.67
# Episode:   135		score:   49.00		average:   27.97
# Episode:   136		score:   24.00		average:   28.03
# Episode:   137		score:   47.00		average:   28.37
# Episode:   138		score:   12.00		average:   28.35
# Episode:   139		score:   17.00		average:   28.31
# Episode:   140		score:   39.00		average:   28.33
# Episode:   141		score:   37.00		average:   28.49
# Episode:   142		score:   66.00		average:   29.06
# Episode:   143		score:   48.00		average:   29.43
# Episode:   144		score:   43.00		average:   29.41
# Episode:   145		score:   39.00		average:   29.70
# Episode:   146		score:   83.00		average:   30.34
# Episode:   147		score:   35.00		average:   30.46
# Episode:   148		score:   74.00		average:   30.45
# Episode:   149		score:   28.00		average:   30.59
# Episode:   150		score:   50.00		average:   30.96
# Episode:   151		score:   20.00		average:   30.95
# Episode:   152		score:   40.00		average:   31.06
# Episode:   153		score:   16.00		average:   31.07
# Episode:   154		score:   28.00		average:   31.15
# Episode:   155		score:   53.00		average:   31.35
# Episode:   156		score:   83.00		average:   32.05
# Episode:   157		score:   21.00		average:   31.84
# Episode:   158		score:   22.00		average:   31.91
# Episode:   159		score:   72.00		average:   32.41
# Episode:   160		score:   89.00		average:   33.01
# Episode:   161		score:  138.00		average:   34.11
# Episode:   162		score:   37.00		average:   34.37
# Episode:   163		score:   47.00		average:   34.68
# Episode:   164		score:   43.00		average:   34.92
# Episode:   165		score:   47.00		average:   34.95
# Episode:   166		score:   43.00		average:   35.17
# Episode:   167		score:   70.00		average:   35.57
# Episode:   168		score:   21.00		average:   35.56
# Episode:   169		score:   93.00		average:   36.22
# Episode:   170		score:   40.00		average:   36.39
# Episode:   171		score:   27.00		average:   36.53
# Episode:   172		score:   50.00		average:   36.41
# Episode:   173		score:   30.00		average:   36.55
# Episode:   174		score:   27.00		average:   36.72
# Episode:   175		score:   67.00		average:   37.16
# Episode:   176		score:   30.00		average:   37.35
# Episode:   177		score:   36.00		average:   37.51
# Episode:   178		score:   96.00		average:   38.31
# Episode:   179		score:   74.00		average:   38.49
# Episode:   180		score:   33.00		average:   38.54
# Episode:   181		score:   19.00		average:   38.39
# Episode:   182		score:   24.00		average:   38.49
# Episode:   183		score:   55.00		average:   38.92
# Episode:   184		score:   60.00		average:   39.21
# Episode:   185		score:   64.00		average:   39.67
# Episode:   186		score:  156.00		average:   40.93
# Episode:   187		score:  100.00		average:   41.60
# Episode:   188		score:   41.00		average:   41.57
# Episode:   189		score:   40.00		average:   41.55
# Episode:   190		score:   34.00		average:   41.70
# Episode:   191		score:  118.00		average:   42.66
# Episode:   192		score:  200.00		average:   44.48
# Episode:   193		score:   77.00		average:   44.98
# Episode:   194		score:   48.00		average:   45.25
# Episode:   195		score:   66.00		average:   45.38
# Episode:   196		score:   89.00		average:   46.13
# Episode:   197		score:   42.00		average:   46.08
# Episode:   198		score:   65.00		average:   46.51
# Episode:   199		score:   99.00		average:   47.32
# Episode:   200		score:   94.00		average:   47.67
# Episode:   201		score:   46.00		average:   47.94
# Episode:   202		score:  126.00		average:   48.81
# Episode:   203		score:   78.00		average:   49.31
# Episode:   204		score:  115.00		average:   49.98
# Episode:   205		score:  131.00		average:   50.72
# Episode:   206		score:   36.00		average:   50.76
# Episode:   207		score:  149.00		average:   51.68
# Episode:   208		score:   45.00		average:   51.86
# Episode:   209		score:  119.00		average:   52.61
# Episode:   210		score:  119.00		average:   53.55
# Episode:   211		score:  187.00		average:   54.89
# Episode:   212		score:  108.00		average:   55.73
# Episode:   213		score:   27.00		average:   55.45
# Episode:   214		score:   66.00		average:   55.88
# Episode:   215		score:   43.00		average:   56.16
# Episode:   216		score:  128.00		average:   57.10
# Episode:   217		score:   87.00		average:   57.65
# Episode:   218		score:   35.00		average:   57.45
# Episode:   219		score:   83.00		average:   57.87
# Episode:   220		score:  168.00		average:   59.22
# Episode:   221		score:  114.00		average:   60.08
# Episode:   222		score:   33.00		average:   60.12
# Episode:   223		score:   20.00		average:   59.99
# Episode:   224		score:  101.00		average:   60.75
# Episode:   225		score:   72.00		average:   61.28
# Episode:   226		score:   44.00		average:   61.39
# Episode:   227		score:   65.00		average:   61.89
# Episode:   228		score:   77.00		average:   62.48
# Episode:   229		score:   47.00		average:   62.69
# Episode:   230		score:   38.00		average:   62.86
# Episode:   231		score:   74.00		average:   63.49
# Episode:   232		score:   55.00		average:   63.81
# Episode:   233		score:   48.00		average:   64.01
# Episode:   234		score:   71.00		average:   64.30
# Episode:   235		score:  200.00		average:   65.81
# Episode:   236		score:   51.00		average:   66.08
# Episode:   237		score:  121.00		average:   66.82
# Episode:   238		score:   37.00		average:   67.07
# Episode:   239		score:   30.00		average:   67.20
# Episode:   240		score:  151.00		average:   68.32
# Episode:   241		score:   70.00		average:   68.65
# Episode:   242		score:   35.00		average:   68.34
# Episode:   243		score:   61.00		average:   68.47
# Episode:   244		score:  116.00		average:   69.20
# Episode:   245		score:   83.00		average:   69.64
# Episode:   246		score:   24.00		average:   69.05
# Episode:   247		score:   33.00		average:   69.03
# Episode:   248		score:  143.00		average:   69.72
# Episode:   249		score:  101.00		average:   70.45
# Episode:   250		score:   85.00		average:   70.80
# Episode:   251		score:  103.00		average:   71.63
# Episode:   252		score:   78.00		average:   72.01
# Episode:   253		score:   55.00		average:   72.40
# Episode:   254		score:  149.00		average:   73.61
# Episode:   255		score:  116.00		average:   74.24
# Episode:   256		score:  103.00		average:   74.44
# Episode:   257		score:   64.00		average:   74.87
# Episode:   258		score:   67.00		average:   75.32
# Episode:   259		score:   72.00		average:   75.32
# Episode:   260		score:  101.00		average:   75.44
# Episode:   261		score:  200.00		average:   76.06
# Episode:   262		score:   87.00		average:   76.56
# Episode:   263		score:  113.00		average:   77.22
# Episode:   264		score:   70.00		average:   77.49
# Episode:   265		score:   22.00		average:   77.24
# Episode:   266		score:   40.00		average:   77.21
# Episode:   267		score:   79.00		average:   77.30
# Episode:   268		score:  200.00		average:   79.09
# Episode:   269		score:   40.00		average:   78.56
# Episode:   270		score:  152.00		average:   79.68
# Episode:   271		score:  108.00		average:   80.49
# Episode:   272		score:   64.00		average:   80.63
# Episode:   273		score:   80.00		average:   81.13
# Episode:   274		score:  121.00		average:   82.07
# Episode:   275		score:   65.00		average:   82.05
# Episode:   276		score:   32.00		average:   82.07
# Episode:   277		score:   36.00		average:   82.07
# Episode:   278		score:   71.00		average:   81.82
# Episode:   279		score:   77.00		average:   81.85
# Episode:   280		score:   49.00		average:   82.01
# Episode:   281		score:  113.00		average:   82.95
# Episode:   282		score:   85.00		average:   83.56
# Episode:   283		score:   25.00		average:   83.26
# Episode:   284		score:  125.00		average:   83.91
# Episode:   285		score:   84.00		average:   84.11
# Episode:   286		score:   24.00		average:   82.79
# Episode:   287		score:  126.00		average:   83.05
# Episode:   288		score:   24.00		average:   82.88
# Episode:   289		score:   54.00		average:   83.02
# Episode:   290		score:   44.00		average:   83.12
# Episode:   291		score:  103.00		average:   82.97
# Episode:   292		score:   28.00		average:   81.25
# Episode:   293		score:  147.00		average:   81.95
# Episode:   294		score:   79.00		average:   82.26
# Episode:   295		score:   28.00		average:   81.88
# Episode:   296		score:   55.00		average:   81.54
# Episode:   297		score:   80.00		average:   81.92
# Episode:   298		score:  158.00		average:   82.85
# Episode:   299		score:   49.00		average:   82.35
# Episode:   300		score:  106.00		average:   82.47
# Episode:   301		score:   77.00		average:   82.78
# Episode:   302		score:  104.00		average:   82.56
# Episode:   303		score:   38.00		average:   82.16
# Episode:   304		score:  107.00		average:   82.08
# Episode:   305		score:   95.00		average:   81.72
# Episode:   306		score:   38.00		average:   81.74
# Episode:   307		score:   65.00		average:   80.90
# Episode:   308		score:  130.00		average:   81.75
# Episode:   309		score:  158.00		average:   82.14
# Episode:   310		score:  109.00		average:   82.04
# Episode:   311		score:   44.00		average:   80.61
# Episode:   312		score:   49.00		average:   80.02
# Episode:   313		score:   71.00		average:   80.46
# Episode:   314		score:   80.00		average:   80.60
# Episode:   315		score:   94.00		average:   81.11
# Episode:   316		score:   98.00		average:   80.81
# Episode:   317		score:   49.00		average:   80.43
# Episode:   318		score:  103.00		average:   81.11
# Episode:   319		score:   94.00		average:   81.22
# Episode:   320		score:  108.00		average:   80.62
# Episode:   321		score:  136.00		average:   80.84
# Episode:   322		score:   24.00		average:   80.75
# Episode:   323		score:   37.00		average:   80.92
# Episode:   324		score:  117.00		average:   81.08
# Episode:   325		score:   69.00		average:   81.05
# Episode:   326		score:  185.00		average:   82.46
# Episode:   327		score:   91.00		average:   82.72
# Episode:   328		score:   30.00		average:   82.25
# Episode:   329		score:   57.00		average:   82.35
# Episode:   330		score:   40.00		average:   82.37
# Episode:   331		score:   45.00		average:   82.08
# Episode:   332		score:  142.00		average:   82.95
# Episode:   333		score:   44.00		average:   82.91
# Episode:   334		score:   66.00		average:   82.86
# Episode:   335		score:   89.00		average:   81.75
# Episode:   336		score:   53.00		average:   81.77
# Episode:   337		score:   11.00		average:   80.67
# Episode:   338		score:   72.00		average:   81.02
# Episode:   339		score:   49.00		average:   81.21
# Episode:   340		score:   62.00		average:   80.32
# Episode:   341		score:   76.00		average:   80.38
# Episode:   342		score:  107.00		average:   81.10
# Episode:   343		score:   59.00		average:   81.08
# Episode:   344		score:   78.00		average:   80.70
# Episode:   345		score:  200.00		average:   81.87
# Episode:   346		score:  200.00		average:   83.63
# Episode:   347		score:   55.00		average:   83.85
# Episode:   348		score:   41.00		average:   82.83
# Episode:   349		score:   53.00		average:   82.35
# Episode:   350		score:   29.00		average:   81.79
# Episode:   351		score:   46.00		average:   81.22
# Episode:   352		score:   66.00		average:   81.10
# Episode:   353		score:  200.00		average:   82.55
# Episode:   354		score:   57.00		average:   81.63
# Episode:   355		score:   91.00		average:   81.38
# Episode:   356		score:   60.00		average:   80.95
# Episode:   357		score:  102.00		average:   81.33
# Episode:   358		score:   31.00		average:   80.97
# Episode:   359		score:  130.00		average:   81.55
# Episode:   360		score:   30.00		average:   80.84
# Episode:   361		score:   39.00		average:   79.23
# Episode:   362		score:   63.00		average:   78.99
# Episode:   363		score:  121.00		average:   79.07
# Episode:   364		score:   41.00		average:   78.78
# Episode:   365		score:   85.00		average:   79.41
# Episode:   366		score:   29.00		average:   79.30
# Episode:   367		score:   61.00		average:   79.12
# Episode:   368		score:   51.00		average:   77.63
# Episode:   369		score:   42.00		average:   77.65
# Episode:   370		score:   79.00		average:   76.92
# Episode:   371		score:   18.00		average:   76.02
# Episode:   372		score:  125.00		average:   76.63
# Episode:   373		score:  165.00		average:   77.48
# Episode:   374		score:  104.00		average:   77.31
# Episode:   375		score:  154.00		average:   78.20
# Episode:   376		score:  109.00		average:   78.97
# Episode:   377		score:   50.00		average:   79.11
# Episode:   378		score:   40.00		average:   78.80
# Episode:   379		score:   82.00		average:   78.85
# Episode:   380		score:   36.00		average:   78.72
# Episode:   381		score:   37.00		average:   77.96
# Episode:   382		score:  163.00		average:   78.74
# Episode:   383		score:   96.00		average:   79.45
# Episode:   384		score:   38.00		average:   78.58
# Episode:   385		score:   50.00		average:   78.24
# Episode:   386		score:   88.00		average:   78.88
# Episode:   387		score:   86.00		average:   78.48
# Episode:   388		score:  117.00		average:   79.41
# Episode:   389		score:   60.00		average:   79.47
# Episode:   390		score:   21.00		average:   79.24
# Episode:   391		score:   61.00		average:   78.82
# Episode:   392		score:   81.00		average:   79.35
# Episode:   393		score:  111.00		average:   78.99
# Episode:   394		score:   33.00		average:   78.53
# Episode:   395		score:  157.00		average:   79.82
# Episode:   396		score:  118.00		average:   80.45
# Episode:   397		score:   86.00		average:   80.51
# Episode:   398		score:  142.00		average:   80.35
# Episode:   399		score:  130.00		average:   81.16
# Episode:   400		score:   35.00		average:   80.45
# Episode:   401		score:   72.00		average:   80.40
# Episode:   402		score:   64.00		average:   80.00
# Episode:   403		score:   45.00		average:   80.07
# Episode:   404		score:  164.00		average:   80.64
# Episode:   405		score:   49.00		average:   80.18
# Episode:   406		score:   35.00		average:   80.15
# Episode:   407		score:  125.00		average:   80.75
# Episode:   408		score:   53.00		average:   79.98
# Episode:   409		score:   88.00		average:   79.28
# Episode:   410		score:   41.00		average:   78.60
# Episode:   411		score:   33.00		average:   78.49
# Episode:   412		score:  110.00		average:   79.10
# Episode:   413		score:   51.00		average:   78.90
# Episode:   414		score:  101.00		average:   79.11
# Episode:   415		score:  111.00		average:   79.28
# Episode:   416		score:   49.00		average:   78.79
# Episode:   417		score:   54.00		average:   78.84
# Episode:   418		score:   93.00		average:   78.74
# Episode:   419		score:   16.00		average:   77.96
# Episode:   420		score:  194.00		average:   78.82
# Episode:   421		score:  153.00		average:   78.99
# Episode:   422		score:  183.00		average:   80.58
# Episode:   423		score:   81.00		average:   81.02
# Episode:   424		score:  158.00		average:   81.43
# Episode:   425		score:   67.00		average:   81.41
# Episode:   426		score:   86.00		average:   80.42
# Episode:   427		score:   63.00		average:   80.14
# Episode:   428		score:  100.00		average:   80.84
# Episode:   429		score:  107.00		average:   81.34
# Episode:   430		score:  113.00		average:   82.07
# Episode:   431		score:   92.00		average:   82.54
# Episode:   432		score:   56.00		average:   81.68
# Episode:   433		score:   16.00		average:   81.40
# Episode:   434		score:   35.00		average:   81.09
# Episode:   435		score:  162.00		average:   81.82
# Episode:   436		score:  132.00		average:   82.61
# Episode:   437		score:   80.00		average:   83.30
# Episode:   438		score:   75.00		average:   83.33
# Episode:   439		score:   97.00		average:   83.81
# Episode:   440		score:   83.00		average:   84.02
# Episode:   441		score:   96.00		average:   84.22
# Episode:   442		score:   34.00		average:   83.49
# Episode:   443		score:   19.00		average:   83.09
# Episode:   444		score:   45.00		average:   82.76
# Episode:   445		score:   98.00		average:   81.74
# Episode:   446		score:   99.00		average:   80.73
# Episode:   447		score:  123.00		average:   81.41
# Episode:   448		score:   73.00		average:   81.73
# Episode:   449		score:   28.00		average:   81.48
# Episode:   450		score:   31.00		average:   81.50
# Episode:   451		score:   30.00		average:   81.34
# Episode:   452		score:   51.00		average:   81.19
# Episode:   453		score:  132.00		average:   80.51
# Episode:   454		score:   85.00		average:   80.79
# Episode:   455		score:   64.00		average:   80.52
# Episode:   456		score:   52.00		average:   80.44
# Episode:   457		score:   62.00		average:   80.04
# Episode:   458		score:   39.00		average:   80.12
# Episode:   459		score:   43.00		average:   79.25
# Episode:   460		score:   49.00		average:   79.44
# Episode:   461		score:   30.00		average:   79.35
# Episode:   462		score:   91.00		average:   79.63
# Episode:   463		score:   66.00		average:   79.08
# Episode:   464		score:   28.00		average:   78.95
# Episode:   465		score:   43.00		average:   78.53
# Episode:   466		score:  129.00		average:   79.53
# Episode:   467		score:   18.00		average:   79.10
# Episode:   468		score:  200.00		average:   80.59
# Episode:   469		score:  200.00		average:   82.17
# Episode:   470		score:   52.00		average:   81.90
# Episode:   471		score:   88.00		average:   82.60
# Episode:   472		score:   80.00		average:   82.15
# Episode:   473		score:   46.00		average:   80.96
# Episode:   474		score:  165.00		average:   81.57
# Episode:   475		score:  105.00		average:   81.08
# Episode:   476		score:   77.00		average:   80.76
# Episode:   477		score:  200.00		average:   82.26
# Episode:   478		score:  144.00		average:   83.30
# Episode:   479		score:  126.00		average:   83.74
# Episode:   480		score:   66.00		average:   84.04
# Episode:   481		score:  161.00		average:   85.28
# Episode:   482		score:   89.00		average:   84.54
# Episode:   483		score:  189.00		average:   85.47
# Episode:   484		score:   67.00		average:   85.76
# Episode:   485		score:   55.00		average:   85.81
# Episode:   486		score:  102.00		average:   85.95
# Episode:   487		score:   46.00		average:   85.55
# Episode:   488		score:   30.00		average:   84.68
# Episode:   489		score:   51.00		average:   84.59
# Episode:   490		score:  101.00		average:   85.39
# Episode:   491		score:   81.00		average:   85.59
# Episode:   492		score:   97.00		average:   85.75
# Episode:   493		score:   41.00		average:   85.05
# Episode:   494		score:  121.00		average:   85.93
# Episode:   495		score:   27.00		average:   84.63
# Episode:   496		score:   59.00		average:   84.04
# Episode:   497		score:   74.00		average:   83.92
# Episode:   498		score:   61.00		average:   83.11
# Episode:   499		score:   84.00		average:   82.65
# Episode:   500		score:   40.00		average:   82.70
# Episode:   501		score:  165.00		average:   83.63
# Episode:   502		score:   54.00		average:   83.53
# Episode:   503		score:  200.00		average:   85.08
# Episode:   504		score:   68.00		average:   84.12
# Episode:   505		score:   51.00		average:   84.14
# Episode:   506		score:  129.00		average:   85.08
# Episode:   507		score:   40.00		average:   84.23
# Episode:   508		score:   79.00		average:   84.49
# Episode:   509		score:   69.00		average:   84.30
# Episode:   510		score:   32.00		average:   84.21
# Episode:   511		score:  127.00		average:   85.15
# Episode:   512		score:  160.00		average:   85.65
# Episode:   513		score:  114.00		average:   86.28
# Episode:   514		score:  107.00		average:   86.34
# Episode:   515		score:   62.00		average:   85.85
# Episode:   516		score:   42.00		average:   85.78
# Episode:   517		score:  103.00		average:   86.27
# Episode:   518		score:   30.00		average:   85.64
# Episode:   519		score:  144.00		average:   86.92
# Episode:   520		score:   48.00		average:   85.46
# Episode:   521		score:   79.00		average:   84.72
# Episode:   522		score:   50.00		average:   83.39
# Episode:   523		score:   87.00		average:   83.45
# Episode:   524		score:  199.00		average:   83.86
# Episode:   525		score:  148.00		average:   84.67
# Episode:   526		score:  101.00		average:   84.82
# Episode:   527		score:   94.00		average:   85.13
# Episode:   528		score:  103.00		average:   85.16
# Episode:   529		score:  114.00		average:   85.23
# Episode:   530		score:   39.00		average:   84.49
# Episode:   531		score:  120.00		average:   84.77
# Episode:   532		score:   84.00		average:   85.05
# Episode:   533		score:   49.00		average:   85.38
# Episode:   534		score:   45.00		average:   85.48
# Episode:   535		score:   29.00		average:   84.15
# Episode:   536		score:   70.00		average:   83.53
# Episode:   537		score:   51.00		average:   83.24
# Episode:   538		score:  111.00		average:   83.60
# Episode:   539		score:   63.00		average:   83.26
# Episode:   540		score:  200.00		average:   84.43
# Episode:   541		score:  168.00		average:   85.15
# Episode:   542		score:   44.00		average:   85.25
# Episode:   543		score:   80.00		average:   85.86
# Episode:   544		score:   24.00		average:   85.65
# Episode:   545		score:   76.00		average:   85.43
# Episode:   546		score:   79.00		average:   85.23
# Episode:   547		score:   78.00		average:   84.78
# Episode:   548		score:   26.00		average:   84.31
# Episode:   549		score:   42.00		average:   84.45
# Episode:   550		score:   30.00		average:   84.44
# Episode:   551		score:  123.00		average:   85.37
# Episode:   552		score:  172.00		average:   86.58
# Episode:   553		score:  174.00		average:   87.00
# Episode:   554		score:   36.00		average:   86.51
# Episode:   555		score:   36.00		average:   86.23
# Episode:   556		score:   38.00		average:   86.09
# Episode:   557		score:   65.00		average:   86.12
# Episode:   558		score:   41.00		average:   86.14
# Episode:   559		score:   23.00		average:   85.94
# Episode:   560		score:   58.00		average:   86.03
# Episode:   561		score:   40.00		average:   86.13
# Episode:   562		score:  200.00		average:   87.22
# Episode:   563		score:   69.00		average:   87.25
# Episode:   564		score:  159.00		average:   88.56
# Episode:   565		score:  116.00		average:   89.29
# Episode:   566		score:  100.00		average:   89.00
# Episode:   567		score:   38.00		average:   89.20
# Episode:   568		score:  170.00		average:   88.90
# Episode:   569		score:   31.00		average:   87.21
# Episode:   570		score:  133.00		average:   88.02
# Episode:   571		score:   76.00		average:   87.90
# Episode:   572		score:  109.00		average:   88.19
# Episode:   573		score:   30.00		average:   88.03
# Episode:   574		score:   33.00		average:   86.71
# Episode:   575		score:  173.00		average:   87.39
# Episode:   576		score:  168.00		average:   88.30
# Episode:   577		score:  142.00		average:   87.72
# Episode:   578		score:   39.00		average:   86.67
# Episode:   579		score:   96.00		average:   86.37
# Episode:   580		score:   95.00		average:   86.66
# Episode:   581		score:   47.00		average:   85.52
# Episode:   582		score:   93.00		average:   85.56
# Episode:   583		score:   69.00		average:   84.36
# Episode:   584		score:  138.00		average:   85.07
# Episode:   585		score:   74.00		average:   85.26
# Episode:   586		score:  177.00		average:   86.01
# Episode:   587		score:   67.00		average:   86.22
# Episode:   588		score:  110.00		average:   87.02
# Episode:   589		score:  124.00		average:   87.75
# Episode:   590		score:  122.00		average:   87.96
# Episode:   591		score:   32.00		average:   87.47
# Episode:   592		score:   60.00		average:   87.10
# Episode:   593		score:   77.00		average:   87.46
# Episode:   594		score:  177.00		average:   88.02
# Episode:   595		score:   27.00		average:   88.02
# Episode:   596		score:  108.00		average:   88.51
# Episode:   597		score:  135.00		average:   89.12
# Episode:   598		score:   34.00		average:   88.85
# Episode:   599		score:   78.00		average:   88.79
# Episode:   600		score:   36.00		average:   88.75
# Episode:   601		score:  139.00		average:   88.49
# Episode:   602		score:  153.00		average:   89.48
# Episode:   603		score:   38.00		average:   87.86
# Episode:   604		score:  153.00		average:   88.71
# Episode:   605		score:   50.00		average:   88.70
# Episode:   606		score:  109.00		average:   88.50
# Episode:   607		score:   52.00		average:   88.62
# Episode:   608		score:   59.00		average:   88.42
# Episode:   609		score:  128.00		average:   89.01
# Episode:   610		score:   91.00		average:   89.60
# Episode:   611		score:  104.00		average:   89.37
# Episode:   612		score:  121.00		average:   88.98
# Episode:   613		score:  168.00		average:   89.52
# Episode:   614		score:   41.00		average:   88.86
# Episode:   615		score:  200.00		average:   90.24
# Episode:   616		score:   48.00		average:   90.30
# Episode:   617		score:   39.00		average:   89.66
# Episode:   618		score:   41.00		average:   89.77
# Episode:   619		score:  127.00		average:   89.60
# Episode:   620		score:   55.00		average:   89.67
# Episode:   621		score:   91.00		average:   89.79
# Episode:   622		score:   43.00		average:   89.72
# Episode:   623		score:  200.00		average:   90.85
# Episode:   624		score:  116.00		average:   90.02
# Episode:   625		score:  132.00		average:   89.86
# Episode:   626		score:   43.00		average:   89.28
# Episode:   627		score:   30.00		average:   88.64
# Episode:   628		score:   80.00		average:   88.41
# Episode:   629		score:   51.00		average:   87.78
# Episode:   630		score:  101.00		average:   88.40
# Episode:   631		score:   23.00		average:   87.43
# Episode:   632		score:   38.00		average:   86.97
# Episode:   633		score:   44.00		average:   86.92
# Episode:   634		score:  142.00		average:   87.89
# Episode:   635		score:   25.00		average:   87.85
# Episode:   636		score:   30.00		average:   87.45
# Episode:   637		score:  121.00		average:   88.15
# Episode:   638		score:  110.00		average:   88.14
# Episode:   639		score:   60.00		average:   88.11
# Episode:   640		score:   26.00		average:   86.37
# Episode:   641		score:  158.00		average:   86.27
# Episode:   642		score:   39.00		average:   86.22
# Episode:   643		score:  119.00		average:   86.61
# Episode:   644		score:  130.00		average:   87.67
# Episode:   645		score:  199.00		average:   88.90
# Episode:   646		score:  117.00		average:   89.28
# Episode:   647		score:   75.00		average:   89.25
# Episode:   648		score:  101.00		average:   90.00
# Episode:   649		score:  114.00		average:   90.72
# Episode:   650		score:  135.00		average:   91.77
# Episode:   651		score:   77.00		average:   91.31
# Episode:   652		score:  102.00		average:   90.61
# Episode:   653		score:   71.00		average:   89.58
# Episode:   654		score:   64.00		average:   89.86
# Episode:   655		score:   50.00		average:   90.00
# Episode:   656		score:   84.00		average:   90.46
# Episode:   657		score:  120.00		average:   91.01
# Episode:   658		score:   69.00		average:   91.29
# Episode:   659		score:  200.00		average:   93.06
# Episode:   660		score:  106.00		average:   93.54
# Episode:   661		score:   38.00		average:   93.52
# Episode:   662		score:   36.00		average:   91.88
# Episode:   663		score:   40.00		average:   91.59
# Episode:   664		score:   86.00		average:   90.86
# Episode:   665		score:   44.00		average:   90.14
# Episode:   666		score:  200.00		average:   91.14
# Episode:   667		score:   63.00		average:   91.39
# Episode:   668		score:   42.00		average:   90.11
# Episode:   669		score:  133.00		average:   91.13
# Episode:   670		score:   98.00		average:   90.78
# Episode:   671		score:  154.00		average:   91.56
# Episode:   672		score:  156.00		average:   92.03
# Episode:   673		score:   85.00		average:   92.58
# Episode:   674		score:   72.00		average:   92.97
# Episode:   675		score:   68.00		average:   91.92
# Episode:   676		score:  110.00		average:   91.34
# Episode:   677		score:  112.00		average:   91.04
# Episode:   678		score:   33.00		average:   90.98
# Episode:   679		score:   84.00		average:   90.86
# Episode:   680		score:   59.00		average:   90.50
# Episode:   681		score:   78.00		average:   90.81
# Episode:   682		score:  152.00		average:   91.40
# Episode:   683		score:  119.00		average:   91.90
# Episode:   684		score:  104.00		average:   91.56
# Episode:   685		score:   22.00		average:   91.04
# Episode:   686		score:   35.00		average:   89.62
# Episode:   687		score:  136.00		average:   90.31
# Episode:   688		score:   67.00		average:   89.88
# Episode:   689		score:   99.00		average:   89.63
# Episode:   690		score:  101.00		average:   89.42
# Episode:   691		score:   54.00		average:   89.64
# Episode:   692		score:  126.00		average:   90.30
# Episode:   693		score:  132.00		average:   90.85
# Episode:   694		score:   58.00		average:   89.66
# Episode:   695		score:  103.00		average:   90.42
# Episode:   696		score:   31.00		average:   89.65
# Episode:   697		score:   74.00		average:   89.04
# Episode:   698		score:  200.00		average:   90.70
# Episode:   699		score:  111.00		average:   91.03
# Episode:   700		score:   80.00		average:   91.47
# Episode:   701		score:    9.00		average:   90.17
# Episode:   702		score:   55.00		average:   89.19
# Episode:   703		score:   27.00		average:   89.08
# Episode:   704		score:   25.00		average:   87.80
# Episode:   705		score:  133.00		average:   88.63
# Episode:   706		score:  144.00		average:   88.98
# Episode:   707		score:   26.00		average:   88.72
# Episode:   708		score:   38.00		average:   88.51
# Episode:   709		score:   95.00		average:   88.18
# Episode:   710		score:  137.00		average:   88.64
# Episode:   711		score:   59.00		average:   88.19
# Episode:   712		score:  133.00		average:   88.31
# Episode:   713		score:   35.00		average:   86.98
# Episode:   714		score:   84.00		average:   87.41
# Episode:   715		score:  112.00		average:   86.53
# Episode:   716		score:   84.00		average:   86.89
# Episode:   717		score:  104.00		average:   87.54
# Episode:   718		score:   80.00		average:   87.93
# Episode:   719		score:  150.00		average:   88.16
# Episode:   720		score:   24.00		average:   87.85
# Episode:   721		score:   40.00		average:   87.34
# Episode:   722		score:  158.00		average:   88.49
# Episode:   723		score:  128.00		average:   87.77
# Episode:   724		score:  171.00		average:   88.32
# Episode:   725		score:   41.00		average:   87.41
# Episode:   726		score:   24.00		average:   87.22
# Episode:   727		score:  122.00		average:   88.14
# Episode:   728		score:   95.00		average:   88.29
# Episode:   729		score:   47.00		average:   88.25
# Episode:   730		score:   46.00		average:   87.70
# Episode:   731		score:   43.00		average:   87.90
# Episode:   732		score:  116.00		average:   88.68
# Episode:   733		score:   54.00		average:   88.78
# Episode:   734		score:   77.00		average:   88.13
# Episode:   735		score:   46.00		average:   88.34
# Episode:   736		score:   95.00		average:   88.99
# Episode:   737		score:   33.00		average:   88.11
# Episode:   738		score:  134.00		average:   88.35
# Episode:   739		score:   62.00		average:   88.37
# Episode:   740		score:   70.00		average:   88.81
# Episode:   741		score:   57.00		average:   87.80
# Episode:   742		score:   40.00		average:   87.81
# Episode:   743		score:  200.00		average:   88.62
# Episode:   744		score:  113.00		average:   88.45
# Episode:   745		score:  105.00		average:   87.51
# Episode:   746		score:   34.00		average:   86.68
# Episode:   747		score:  160.00		average:   87.53
# Episode:   748		score:   56.00		average:   87.08
# Episode:   749		score:   63.00		average:   86.57
# Episode:   750		score:  158.00		average:   86.80
# Episode:   751		score:  200.00		average:   88.03
# Episode:   752		score:   61.00		average:   87.62
# Episode:   753		score:   70.00		average:   87.61
# Episode:   754		score:  120.00		average:   88.17
# Episode:   755		score:   36.00		average:   88.03
# Episode:   756		score:   57.00		average:   87.76
# Episode:   757		score:   84.00		average:   87.40
# Episode:   758		score:   60.00		average:   87.31
# Episode:   759		score:   84.00		average:   86.15
# Episode:   760		score:  115.00		average:   86.24
# Episode:   761		score:  142.00		average:   87.28
# Episode:   762		score:  107.00		average:   87.99
# Episode:   763		score:  147.00		average:   89.06
# Episode:   764		score:   83.00		average:   89.03
# Episode:   765		score:   39.00		average:   88.98
# Episode:   766		score:   68.00		average:   87.66
# Episode:   767		score:  136.00		average:   88.39
# Episode:   768		score:   20.00		average:   88.17
# Episode:   769		score:  166.00		average:   88.50
# Episode:   770		score:   32.00		average:   87.84
# Episode:   771		score:   29.00		average:   86.59
# Episode:   772		score:   33.00		average:   85.36
# Episode:   773		score:   68.00		average:   85.19
# Episode:   774		score:   90.00		average:   85.37
# Episode:   775		score:  158.00		average:   86.27
# Episode:   776		score:  148.00		average:   86.65
# Episode:   777		score:  118.00		average:   86.71
# Episode:   778		score:   58.00		average:   86.96
# Episode:   779		score:   63.00		average:   86.75
# Episode:   780		score:   63.00		average:   86.79
# Episode:   781		score:   95.00		average:   86.96
# Episode:   782		score:   46.00		average:   85.90
# Episode:   783		score:   36.00		average:   85.07
# Episode:   784		score:  200.00		average:   86.03
# Episode:   785		score:   37.00		average:   86.18
# Episode:   786		score:   75.00		average:   86.58
# Episode:   787		score:  146.00		average:   86.68
# Episode:   788		score:  122.00		average:   87.23
# Episode:   789		score:   31.00		average:   86.55
# Episode:   790		score:   83.00		average:   86.37
# Episode:   791		score:   95.00		average:   86.78
# Episode:   792		score:   49.00		average:   86.01
# Episode:   793		score:   84.00		average:   85.53
# Episode:   794		score:  167.00		average:   86.62
# Episode:   795		score:   66.00		average:   86.25
# Episode:   796		score:   82.00		average:   86.76
# Episode:   797		score:  123.00		average:   87.25
# Episode:   798		score:   52.00		average:   85.77
# Episode:   799		score:   62.00		average:   85.28
# Episode:   800		score:  160.00		average:   86.08
# Episode:   801		score:  158.00		average:   87.57
# Episode:   802		score:   40.00		average:   87.42
# Episode:   803		score:  119.00		average:   88.34
# Episode:   804		score:   61.00		average:   88.70
# Episode:   805		score:  115.00		average:   88.52
# Episode:   806		score:   39.00		average:   87.47
# Episode:   807		score:   22.00		average:   87.43
# Episode:   808		score:   49.00		average:   87.54
# Episode:   809		score:   66.00		average:   87.25
# Episode:   810		score:   79.00		average:   86.67
# Episode:   811		score:   88.00		average:   86.96
# Episode:   812		score:   54.00		average:   86.17
# Episode:   813		score:   76.00		average:   86.58
# Episode:   814		score:   43.00		average:   86.17
# Episode:   815		score:   21.00		average:   85.26
# Episode:   816		score:  151.00		average:   85.93
# Episode:   817		score:   84.00		average:   85.73
# Episode:   818		score:  153.00		average:   86.46
# Episode:   819		score:  124.00		average:   86.20
# Episode:   820		score:  111.00		average:   87.07
# Episode:   821		score:  144.00		average:   88.11
# Episode:   822		score:  137.00		average:   87.90
# Episode:   823		score:   84.00		average:   87.46
# Episode:   824		score:   33.00		average:   86.08
# Episode:   825		score:  189.00		average:   87.56
# Episode:   826		score:  105.00		average:   88.37
# Episode:   827		score:   80.00		average:   87.95
# Episode:   828		score:  196.00		average:   88.96
# Episode:   829		score:   38.00		average:   88.87
# Episode:   830		score:   36.00		average:   88.77
# Episode:   831		score:  187.00		average:   90.21
# Episode:   832		score:   34.00		average:   89.39
# Episode:   833		score:   42.00		average:   89.27
# Episode:   834		score:   15.00		average:   88.65
# Episode:   835		score:   42.00		average:   88.61
# Episode:   836		score:   59.00		average:   88.25
# Episode:   837		score:  128.00		average:   89.20
# Episode:   838		score:  134.00		average:   89.20
# Episode:   839		score:   85.00		average:   89.43
# Episode:   840		score:   50.00		average:   89.23
# Episode:   841		score:  175.00		average:   90.41
# Episode:   842		score:  144.00		average:   91.45
# Episode:   843		score:   81.00		average:   90.26
# Episode:   844		score:  131.00		average:   90.44
# Episode:   845		score:   70.00		average:   90.09
# Episode:   846		score:  114.00		average:   90.89
# Episode:   847		score:   90.00		average:   90.19
# Episode:   848		score:   98.00		average:   90.61
# Episode:   849		score:  123.00		average:   91.21
# Episode:   850		score:   70.00		average:   90.33
# Episode:   851		score:  200.00		average:   90.33
# Episode:   852		score:   77.00		average:   90.49
# Episode:   853		score:   26.00		average:   90.05
# Episode:   854		score:   40.00		average:   89.25
# Episode:   855		score:   75.00		average:   89.64
# Episode:   856		score:   69.00		average:   89.76
# Episode:   857		score:   64.00		average:   89.56
# Episode:   858		score:   80.00		average:   89.76
# Episode:   859		score:  160.00		average:   90.52
# Episode:   860		score:   93.00		average:   90.30
# Episode:   861		score:  167.00		average:   90.55
# Episode:   862		score:   56.00		average:   90.04
# Episode:   863		score:   76.00		average:   89.33
# Episode:   864		score:   34.00		average:   88.84
# Episode:   865		score:  141.00		average:   89.86
# Episode:   866		score:   52.00		average:   89.70
# Episode:   867		score:  123.00		average:   89.57
# Episode:   868		score:   68.00		average:   90.05
# Episode:   869		score:   62.00		average:   89.01
# Episode:   870		score:  158.00		average:   90.27
# Episode:   871		score:   69.00		average:   90.67
# Episode:   872		score:  127.00		average:   91.61
# Episode:   873		score:   91.00		average:   91.84
# Episode:   874		score:  134.00		average:   92.28
# Episode:   875		score:  139.00		average:   92.09
# Episode:   876		score:  100.00		average:   91.61
# Episode:   877		score:   58.00		average:   91.01
# Episode:   878		score:   86.00		average:   91.29
# Episode:   879		score:   84.00		average:   91.50
# Episode:   880		score:   19.00		average:   91.06
# Episode:   881		score:   99.00		average:   91.10
# Episode:   882		score:  173.00		average:   92.37
# Episode:   883		score:   52.00		average:   92.53
# Episode:   884		score:  131.00		average:   91.84
# Episode:   885		score:  139.00		average:   92.86
# Episode:   886		score:   45.00		average:   92.56
# Episode:   887		score:  100.00		average:   92.10
# Episode:   888		score:  125.00		average:   92.13
# Episode:   889		score:  188.00		average:   93.70
# Episode:   890		score:  150.00		average:   94.37
# Episode:   891		score:   28.00		average:   93.70
# Episode:   892		score:  126.00		average:   94.47
# Episode:   893		score:   37.00		average:   94.00
# Episode:   894		score:  100.00		average:   93.33
# Episode:   895		score:   66.00		average:   93.33
# Episode:   896		score:   41.00		average:   92.92
# Episode:   897		score:   47.00		average:   92.16
# Episode:   898		score:   22.00		average:   91.86
# Episode:   899		score:   56.00		average:   91.80
# Episode:   900		score:   45.00		average:   90.65
# Episode:   901		score:   62.00		average:   89.69
# Episode:   902		score:   33.00		average:   89.62
# Episode:   903		score:  106.00		average:   89.49
# Episode:   904		score:  186.00		average:   90.74
# Episode:   905		score:   66.00		average:   90.25
# Episode:   906		score:  109.00		average:   90.95
# Episode:   907		score:   51.00		average:   91.24
# Episode:   908		score:   70.00		average:   91.45
# Episode:   909		score:  104.00		average:   91.83
# Episode:   910		score:  113.00		average:   92.17
# Episode:   911		score:   38.00		average:   91.67
# Episode:   912		score:   71.00		average:   91.84
# Episode:   913		score:   62.00		average:   91.70
# Episode:   914		score:  124.00		average:   92.51
# Episode:   915		score:   36.00		average:   92.66
# Episode:   916		score:  160.00		average:   92.75
# Episode:   917		score:   70.00		average:   92.61
# Episode:   918		score:   88.00		average:   91.96
# Episode:   919		score:   81.00		average:   91.53
# Episode:   920		score:   35.00		average:   90.77
# Episode:   921		score:  145.00		average:   90.78
# Episode:   922		score:   98.00		average:   90.39
# Episode:   923		score:   90.00		average:   90.45
# Episode:   924		score:   35.00		average:   90.47
# Episode:   925		score:  113.00		average:   89.71
# Episode:   926		score:   95.00		average:   89.61
# Episode:   927		score:  113.00		average:   89.94
# Episode:   928		score:   83.00		average:   88.81
# Episode:   929		score:  121.00		average:   89.64
# Episode:   930		score:  104.00		average:   90.32
# Episode:   931		score:  136.00		average:   89.81
# Episode:   932		score:   57.00		average:   90.04
# Episode:   933		score:   83.00		average:   90.45
# Episode:   934		score:   36.00		average:   90.66
# Episode:   935		score:   98.00		average:   91.22
# Episode:   936		score:  132.00		average:   91.95
# Episode:   937		score:   26.00		average:   90.93
# Episode:   938		score:   61.00		average:   90.20
# Episode:   939		score:   59.00		average:   89.94
# Episode:   940		score:   67.00		average:   90.11
# Episode:   941		score:   23.00		average:   88.59
# Episode:   942		score:  176.00		average:   88.91
# Episode:   943		score:  118.00		average:   89.28
# Episode:   944		score:  104.00		average:   89.01
# Episode:   945		score:   49.00		average:   88.80
# Episode:   946		score:   35.00		average:   88.01
# Episode:   947		score:   15.00		average:   87.26
# Episode:   948		score:  127.00		average:   87.55
# Episode:   949		score:   76.00		average:   87.08
# Episode:   950		score:   99.00		average:   87.37
# Episode:   951		score:  155.00		average:   86.92
# Episode:   952		score:   92.00		average:   87.07
# Episode:   953		score:   42.00		average:   87.23
# Episode:   954		score:   25.00		average:   87.08
# Episode:   955		score:  186.00		average:   88.19
# Episode:   956		score:  123.00		average:   88.73
# Episode:   957		score:   21.00		average:   88.30
# Episode:   958		score:   41.00		average:   87.91
# Episode:   959		score:  187.00		average:   88.18
# Episode:   960		score:   28.00		average:   87.53
# Episode:   961		score:  103.00		average:   86.89
# Episode:   962		score:   49.00		average:   86.82
# Episode:   963		score:   78.00		average:   86.84
# Episode:   964		score:   95.00		average:   87.45
# Episode:   965		score:  122.00		average:   87.26
# Episode:   966		score:   25.00		average:   86.99
# Episode:   967		score:   80.00		average:   86.56
# Episode:   968		score:   44.00		average:   86.32
# Episode:   969		score:   72.00		average:   86.42
# Episode:   970		score:  138.00		average:   86.22
# Episode:   971		score:   71.00		average:   86.24
# Episode:   972		score:   95.00		average:   85.92
# ...
# Episode:  3345		score:   26.00		average:   97.18
# Episode:  3346		score:   81.00		average:   97.31
# Episode:  3347		score:   61.00		average:   96.66
# Episode:  3348		score:   46.00		average:   96.32
# Episode:  3349		score:   87.00		average:   96.23
# Episode:  3350		score:  116.00		average:   96.35
# Episode:  3351		score:   39.00		average:   96.02
# Episode:  3352		score:  102.00		average:   95.96
# Episode:  3353		score:   39.00		average:   95.05
# Episode:  3354		score:  100.00		average:   95.54
# Episode:  3355		score:  132.00		average:   96.27
# Episode:  3356		score:  151.00		average:   96.97
# Episode:  3357		score:  126.00		average:   96.39
# Episode:  3358		score:   67.00		average:   95.75
# Episode:  3359		score:   92.00		average:   96.33
# Episode:  3360		score:   78.00		average:   96.61
# Episode:  3361		score:   74.00		average:   96.88
# Episode:  3362		score:  158.00		average:   98.07
# Episode:  3363		score:   71.00		average:   97.02
# Episode:  3364		score:  131.00		average:   97.45
# Episode:  3365		score:   86.00		average:   97.53
# Episode:  3366		score:   35.00		average:   97.61
# Episode:  3367		score:   49.00		average:   97.24
# Episode:  3368		score:   77.00		average:   97.55
# Episode:  3369		score:  154.00		average:   98.47
# Episode:  3370		score:  126.00		average:   99.17
# Episode:  3371		score:  156.00		average:   99.22
# Episode:  3372		score:   39.00		average:   98.32
# Episode:  3373		score:   74.00		average:   97.29
# Episode:  3374		score:  177.00		average:   98.89
# Episode:  3375		score:   19.00		average:   97.71
# Episode:  3376		score:  124.00		average:   97.59
# Episode:  3377		score:   34.00		average:   96.44
# Episode:  3378		score:   35.00		average:   95.63
# Episode:  3379		score:   45.00		average:   94.56
# Episode:  3380		score:  200.00		average:   95.43
# Episode:  3381		score:   31.00		average:   93.96
# Episode:  3382		score:   48.00		average:   93.33
# Episode:  3383		score:   43.00		average:   92.76
# Episode:  3384		score:  156.00		average:   92.32
# Episode:  3385		score:   32.00		average:   92.21
# Episode:  3386		score:  100.00		average:   92.68
# Episode:  3387		score:   23.00		average:   92.10
# Episode:  3388		score:  156.00		average:   92.51
# Episode:  3389		score:   79.00		average:   92.77
# Episode:  3390		score:   34.00		average:   92.64
# Episode:  3391		score:   49.00		average:   92.34
# Episode:  3392		score:   72.00		average:   92.42
# Episode:  3393		score:   42.00		average:   90.94
# Episode:  3394		score:  108.00		average:   91.65
# Episode:  3395		score:  133.00		average:   92.69
# Episode:  3396		score:  110.00		average:   93.58
# Episode:  3397		score:   43.00		average:   93.44
# Episode:  3398		score:  160.00		average:   94.51
# Episode:  3399		score:   60.00		average:   94.60
# Episode:  3400		score:   41.00		average:   94.54
# Episode:  3401		score:   22.00		average:   94.01
# Episode:  3402		score:   99.00		average:   94.13
# Episode:  3403		score:   34.00		average:   93.80
# Episode:  3404		score:  139.00		average:   94.69
# Episode:  3405		score:  157.00		average:   95.12
# Episode:  3406		score:   29.00		average:   94.58
# Episode:  3407		score:   76.00		average:   94.51
# Episode:  3408		score:   76.00		average:   94.39
# Episode:  3409		score:   91.00		average:   95.09
# Episode:  3410		score:   69.00		average:   93.78
# Episode:  3411		score:   68.00		average:   93.35
# Episode:  3412		score:  102.00		average:   93.90
# Episode:  3413		score:   61.00		average:   93.19
# Episode:  3414		score:  102.00		average:   92.80
# Episode:  3415		score:   68.00		average:   91.48
# Episode:  3416		score:   35.00		average:   90.95
# Episode:  3417		score:  132.00		average:   90.81
# Episode:  3418		score:   26.00		average:   90.62
# Episode:  3419		score:   79.00		average:   90.44
# Episode:  3420		score:   22.00		average:   89.29
# Episode:  3421		score:  151.00		average:   89.27
# Episode:  3422		score:   36.00		average:   89.19
# Episode:  3423		score:  158.00		average:   89.63
# Episode:  3424		score:   82.00		average:   89.35
# Episode:  3425		score:   77.00		average:   89.37
# Episode:  3426		score:   43.00		average:   88.22
# Episode:  3427		score:   92.00		average:   87.69
# Episode:  3428		score:   56.00		average:   87.40
# Episode:  3429		score:  134.00		average:   87.47
# Episode:  3430		score:   77.00		average:   86.24
# Episode:  3431		score:  155.00		average:   86.42
# Episode:  3432		score:  125.00		average:   86.33
# Episode:  3433		score:   30.00		average:   85.13
# Episode:  3434		score:   44.00		average:   85.16
# Episode:  3435		score:   82.00		average:   84.27
# Episode:  3436		score:   69.00		average:   84.51
# Episode:  3437		score:  127.00		average:   85.58
# Episode:  3438		score:   75.00		average:   84.80
# Episode:  3439		score:   35.00		average:   84.76
# Episode:  3440		score:   67.00		average:   85.13
# Episode:  3441		score:   77.00		average:   83.90
# Episode:  3442		score:  141.00		average:   84.82
# Episode:  3443		score:  173.00		average:   84.55
# Episode:  3444		score:  125.00		average:   84.45
# Episode:  3445		score:   53.00		average:   84.72
# Episode:  3446		score:   56.00		average:   84.47
# Episode:  3447		score:   79.00		average:   84.65
# Episode:  3448		score:  200.00		average:   86.19
# Episode:  3449		score:   77.00		average:   86.09
# Episode:  3450		score:   82.00		average:   85.75
# Episode:  3451		score:  141.00		average:   86.77
# Episode:  3452		score:  150.00		average:   87.25
# Episode:  3453		score:  158.00		average:   88.44
# Episode:  3454		score:  200.00		average:   89.44
# Episode:  3455		score:   26.00		average:   88.38
# Episode:  3456		score:   46.00		average:   87.33
# Episode:  3457		score:  189.00		average:   87.96
# Episode:  3458		score:   33.00		average:   87.62
# Episode:  3459		score:  150.00		average:   88.20
# Episode:  3460		score:   23.00		average:   87.65
# Episode:  3461		score:   42.00		average:   87.33
# Episode:  3462		score:   42.00		average:   86.17
# Episode:  3463		score:  108.00		average:   86.54
# Episode:  3464		score:  144.00		average:   86.67
# Episode:  3465		score:  117.00		average:   86.98
# Episode:  3466		score:  121.00		average:   87.84
# Episode:  3467		score:  137.00		average:   88.72
# Episode:  3468		score:   34.00		average:   88.29
# Episode:  3469		score:  175.00		average:   88.50
# Episode:  3470		score:   66.00		average:   87.90
# Episode:  3471		score:  117.00		average:   87.51
# Episode:  3472		score:   53.00		average:   87.65
# Episode:  3473		score:   63.00		average:   87.54
# Episode:  3474		score:  135.00		average:   87.12
# Episode:  3475		score:  152.00		average:   88.45
# Episode:  3476		score:  125.00		average:   88.46
# Episode:  3477		score:  101.00		average:   89.13
# Episode:  3478		score:   43.00		average:   89.21
# Episode:  3479		score:   98.00		average:   89.74
# Episode:  3480		score:  107.00		average:   88.81
# Episode:  3481		score:   65.00		average:   89.15
# Episode:  3482		score:  196.00		average:   90.63
# Episode:  3483		score:  129.00		average:   91.49
# Episode:  3484		score:  115.00		average:   91.08
# Episode:  3485		score:  186.00		average:   92.62
# Episode:  3486		score:  159.00		average:   93.21
# Episode:  3487		score:  108.00		average:   94.06
# Episode:  3488		score:   45.00		average:   92.95
# Episode:  3489		score:  127.00		average:   93.43
# Episode:  3490		score:   76.00		average:   93.85
# Episode:  3491		score:   40.00		average:   93.76
# Episode:  3492		score:   32.00		average:   93.36
# Episode:  3493		score:   30.00		average:   93.24
# Episode:  3494		score:   90.00		average:   93.06
# Episode:  3495		score:  143.00		average:   93.16
# Episode:  3496		score:   81.00		average:   92.87
# Episode:  3497		score:  120.00		average:   93.64
# Episode:  3498		score:  190.00		average:   93.94
# Episode:  3499		score:   21.00		average:   93.55
# Episode:  3500		score:  200.00		average:   95.14
# Episode:  3501		score:  133.00		average:   96.25
# Episode:  3502		score:   44.00		average:   95.70
# Episode:  3503		score:  162.00		average:   96.98
# Episode:  3504		score:  137.00		average:   96.96
# Episode:  3505		score:  135.00		average:   96.74
# Episode:  3506		score:  200.00		average:   98.45
# Episode:  3507		score:   83.00		average:   98.52
# Episode:  3508		score:  100.00		average:   98.76
# Episode:  3509		score:  136.00		average:   99.21
# Episode:  3510		score:   94.00		average:   99.46
# Episode:  3511		score:   49.00		average:   99.27
# Episode:  3512		score:   30.00		average:   98.55
# Episode:  3513		score:   37.00		average:   98.31
# Episode:  3514		score:   45.00		average:   97.74
# Episode:  3515		score:   51.00		average:   97.57
# Episode:  3516		score:  182.00		average:   99.04
# Episode:  3517		score:  112.00		average:   98.84
# Episode:  3518		score:  136.00		average:   99.94
# Episode:  3519		score:  140.00		average:  100.55
# Episode:  3520		score:  200.00		average:  102.33
# Episode:  3521		score:   61.00		average:  101.43
# Episode:  3522		score:  152.00		average:  102.59
# Episode:  3523		score:   75.00		average:  101.76
# Episode:  3524		score:  107.00		average:  102.01
# Episode:  3525		score:   60.00		average:  101.84
# Episode:  3526		score:  172.00		average:  103.13
# Episode:  3527		score:  111.00		average:  103.32
# Episode:  3528		score:   48.00		average:  103.24
# Episode:  3529		score:   30.00		average:  102.20
# Episode:  3530		score:   60.00		average:  102.03
# Episode:  3531		score:   81.00		average:  101.29
# Episode:  3532		score:   36.00		average:  100.40
# Episode:  3533		score:   44.00		average:  100.54
# Episode:  3534		score:  123.00		average:  101.33
# Episode:  3535		score:   40.00		average:  100.91
# Episode:  3536		score:   96.00		average:  101.18
# Episode:  3537		score:   41.00		average:  100.32
# Episode:  3538		score:  200.00		average:  101.57
# Episode:  3539		score:   24.00		average:  101.46
# Episode:  3540		score:   39.00		average:  101.18
# Episode:  3541		score:  188.00		average:  102.29
# Episode:  3542		score:   92.00		average:  101.80
# Episode:  3543		score:  140.00		average:  101.47
# Episode:  3544		score:  113.00		average:  101.35
# Episode:  3545		score:  106.00		average:  101.88
# Episode:  3546		score:   80.00		average:  102.12
# Episode:  3547		score:  200.00		average:  103.33
# Episode:  3548		score:  137.00		average:  102.70
# Episode:  3549		score:  145.00		average:  103.38
# Episode:  3550		score:   76.00		average:  103.32
# Episode:  3551		score:   87.00		average:  102.78
# Episode:  3552		score:   64.00		average:  101.92
# Episode:  3553		score:   31.00		average:  100.65
# Episode:  3554		score:   28.00		average:   98.93
# Episode:  3555		score:   94.00		average:   99.61
# Episode:  3556		score:  200.00		average:  101.15
# Episode:  3557		score:   84.00		average:  100.10
# Episode:  3558		score:   92.00		average:  100.69
# Episode:  3559		score:  112.00		average:  100.31
# Episode:  3560		score:  120.00		average:  101.28
# Episode:  3561		score:  128.00		average:  102.14
# Episode:  3562		score:   37.00		average:  102.09
# Episode:  3563		score:  143.00		average:  102.44
# Episode:  3564		score:   53.00		average:  101.53
# Episode:  3565		score:   40.00		average:  100.76
# Episode:  3566		score:  160.00		average:  101.15
# Episode:  3567		score:   38.00		average:  100.16
# Episode:  3568		score:   71.00		average:  100.53
# Episode:  3569		score:   25.00		average:   99.03
# Episode:  3570		score:   91.00		average:   99.28
# Episode:  3571		score:   34.00		average:   98.45
# Episode:  3572		score:   66.00		average:   98.58
# Episode:  3573		score:   72.00		average:   98.67
# Episode:  3574		score:  111.00		average:   98.43
# Episode:  3575		score:   39.00		average:   97.30
# Episode:  3576		score:   93.00		average:   96.98
# Episode:  3577		score:   63.00		average:   96.60
# Episode:  3578		score:   62.00		average:   96.79
# Episode:  3579		score:   29.00		average:   96.10
# Episode:  3580		score:   28.00		average:   95.31
# Episode:  3581		score:   27.00		average:   94.93
# Episode:  3582		score:  167.00		average:   94.64
# Episode:  3583		score:  101.00		average:   94.36
# Episode:  3584		score:   24.00		average:   93.45
# Episode:  3585		score:   93.00		average:   92.52
# Episode:  3586		score:   77.00		average:   91.70
# Episode:  3587		score:   89.00		average:   91.51
# Episode:  3588		score:   38.00		average:   91.44
# Episode:  3589		score:   31.00		average:   90.48
# Episode:  3590		score:  110.00		average:   90.82
# Episode:  3591		score:   87.00		average:   91.29
# Episode:  3592		score:   75.00		average:   91.72
# Episode:  3593		score:   55.00		average:   91.97
# Episode:  3594		score:  100.00		average:   92.07
# Episode:  3595		score:  104.00		average:   91.68
# Episode:  3596		score:   65.00		average:   91.52
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-0a2b0cff1805> in <module>
#     231     agent = PPOAgent(env_name)
#     232     #agent.run() # train as PPO, train every epesode
# --> 233     agent.run_batch() # train as PPO, train every batch, trains better
#     234     #agent.run_multiprocesses(num_worker = 8)  # train PPO multiprocessed (fastest)
#     235     #agent.test()
#
# <ipython-input-1-0a2b0cff1805> in run_batch(self)
#     221                     state = np.reshape(state, [1, NUM_STATES])
#     222
# --> 223             self.replay(states, actions, rewards, predictions, dones, next_states)
#     224             if self.episode >= EPISODES:
#     225                 break
#
# <ipython-input-1-0a2b0cff1805> in replay(self, states, actions, rewards, predictions, dones, next_states)
#     155         # Training Actor and Critic networks
#     156         a_loss = self.Actor.model.fit(states, y_true, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)
# --> 157         c_loss = self.Critic.model.fit(states, target, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)
#     158
#     159
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_v1.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     783         max_queue_size=max_queue_size,
#     784         workers=workers,
# --> 785         use_multiprocessing=use_multiprocessing)
#     786
#     787   def evaluate(self,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     664         validation_steps=validation_steps,
#     665         validation_freq=validation_freq,
# --> 666         steps_name='steps_per_epoch')
#     667
#     668   def evaluate(self,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     384
#     385         # Get outputs.
# --> 386         batch_outs = f(ins_batch)
#     387         if not isinstance(batch_outs, list):
#     388           batch_outs = [batch_outs]
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3630
#    3631     fetched = self._callable_fn(*array_vals,
# -> 3632                                 run_metadata=self.run_metadata)
#    3633     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3634     output_structure = nest.pack_sequence_as(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
