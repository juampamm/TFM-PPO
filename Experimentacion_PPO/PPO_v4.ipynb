# %%
import os

import random
import gym
import pylab
import numpy as np
import tensorflow as tf
import time
import matplotlib.pyplot as plt

#tf.config.experimental_run_functions_eagerly(True)
tf.compat.v1.disable_eager_execution()
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import backend as K
import copy

EPISODES = 10000 # Number of times the enviroment is ran
LOSS_CLIPPING = 0.2 # Approximated values stated in the original paper
ENTROPY_LOSS = 0.001 # Epochs to train the network (recommended between 3 and 30)
LR = 0.0003 # Learning rate 
NUM_ACTIONS = 4 # Number of possible action in the environment
NUM_STATES = 8 # Number of possible states in the exvironment
EPOCHS = 10 # Epochs to train the network (recommended between 3 and 30)
BATCH_SIZE = 64 # Batch size for the neural nets
BUFFER_SIZE = 2048 # Buffer of experiences
SHUFFLE = True # Whether to shuffle data or not while training
OPTIMIZER = Adam # Optimizer for both actor and critic
GAMMA = 0.99 # Used for the estimated reward
LAMBDA = 0.95 # Used in the original paper un the GAE
NORMALIZE = True # Whether to normalize GAE or not



# Create the actor used to select the action given an state
class Actor_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(128, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X_input)
        X = Dense(128, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X)
        X = Dense(128, activation="relu", kernel_initializer=tf.random_normal_initializer(stddev=0.01))(X)
        
        # Softmax as there are different probabilities depending on the action
        output = Dense(NUM_ACTIONS, activation="softmax")(X)
        
        # Compile the model with the custom loss
        self.model = Model(inputs = X_input, outputs = output)
        self.model.compile(loss=self.ppo_loss, optimizer=OPTIMIZER(lr=LR))

    # Custom loss functions for the PPO
    def ppo_loss(self, y_true, y_pred):
        # Unpack the elements given in the true label
        advantages, true_label, actions = y_true[:, :1], y_true[:, 1:1+NUM_ACTIONS], y_true[:, 1+NUM_ACTIONS:]
        
        prob = actions * y_pred
        old_prob = actions * true_label 

        ratio = K.exp(K.log(prob + 1e-10) - K.log(old_prob + 1e-10))
        
        p1 = ratio * advantages
        p2 = K.clip(ratio, min_value=1 - LOSS_CLIPPING, max_value=1 + LOSS_CLIPPING) * advantages

        actor_loss = -K.mean(K.minimum(p1, p2))

        entropy = -(y_pred * K.log(y_pred + 1e-10))
        entropy = ENTROPY_LOSS * K.mean(entropy)
        
        total_loss = actor_loss - entropy

        return total_loss

# Create the critic which will criticise how the actor is performing    
class Critic_Model:
    def __init__(self):
        X_input = Input(NUM_STATES)

        X = Dense(128, activation="relu", kernel_initializer='he_uniform')(X_input)
        X = Dense(128, activation="relu", kernel_initializer='he_uniform')(X)
        X = Dense(128, activation="relu", kernel_initializer='he_uniform')(X)
        
        # Linear output to know how good the action is
        value = Dense(1)(X)
        
        # Compile it with mse loss and gradient descent
        self.model = Model(inputs=X_input, outputs = value)
        self.model.compile(loss='mse', optimizer=OPTIMIZER(lr=LR))

# Combine both Actor and Critic to create the agent
class PPOAgent:
    def __init__(self, env_name):
        # Environment parameters
        self.env_name = env_name       
        self.env = gym.make(env_name)
        self.episode = 0 # used to track current number episoded since start
        self.max_average = 0 # record max average reached
        
        # Used to plot a grapgh of the train process
        self.scores_, self.average_ = [], []

        # Create Actor-Critic network models
        self.Actor = Actor_Model()
        self.Critic = Critic_Model()
    
        # Names for the models
        self.Actor_name = f"{self.env_name}_PPO_Actor.h5"
        self.Critic_name = f"{self.env_name}_PPO_Critic.h5"

    # Get the action given the current state    
    def act(self, state):
        # Use the network to predict the next action to take, using the model
        prediction = self.Actor.model.predict(state)[0]
        
        # Probability based to choose the action
        action = np.random.choice(NUM_ACTIONS, p=prediction)
        action_onehot = np.zeros([NUM_ACTIONS])
        action_onehot[action] = 1
        return action, action_onehot, prediction

    # Generalized Advantage Estimation implemented in the original paper
    def get_gaes(self, rewards, dones, values, next_values):
        # Dones are used to track when is the final step of an episode, so next values are no applied
        deltas = [r + GAMMA * (1 - d) * nv - v for r, d, nv, v in zip(rewards, dones, next_values, values)]
        deltas = np.stack(deltas)
        gaes = copy.deepcopy(deltas)
        for t in reversed(range(len(deltas) - 1)):
            gaes[t] = gaes[t] + (1 - dones[t]) * GAMMA * LAMBDA * gaes[t + 1]

        target = gaes + values
        if NORMALIZE:
            gaes = (gaes - gaes.mean()) / (gaes.std() + 1e-8)
        return np.vstack(gaes), np.vstack(target)

    def replay(self, states, actions, rewards, predictions, dones, next_states):
        # Reshape memory to appropriate shape for training
        states = np.vstack(states)
        next_states = np.vstack(next_states)
        actions = np.vstack(actions)
        predictions = np.vstack(predictions)

        # Get Critic network predictions for state and next state
        values = self.Critic.model.predict(states)
        next_values = self.Critic.model.predict(next_states)

        # Get the advantage
        advantages, target = self.get_gaes(rewards, dones, np.squeeze(values), np.squeeze(next_values))

        # Stack info to unpack it in the custom loss
        y_true = np.hstack([advantages, predictions, actions])

        # Training Actor and Critic networks
        a_loss = self.Actor.model.fit(states, y_true, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)
        c_loss = self.Critic.model.fit(states, target, epochs=EPOCHS, verbose=0, shuffle=SHUFFLE, batch_size=BATCH_SIZE)

 
    def load(self):
        self.Actor.Actor.load_weights(self.Actor_name)
        self.Critic.Critic.load_weights(self.Critic_name)

    def save(self):
        self.Actor.model.save_weights(self.Actor_name)
        self.Critic.model.save_weights(self.Critic_name)

    def run_batch(self): # train every self.Training_batch episodes
        global LR
        state = self.env.reset()
        state = np.reshape(state, [1, NUM_STATES])
        done, score = False, 0
        finished = False
        while finished == False:
            # Instantiate or reset games memory
            states, next_states, actions, rewards, predictions, dones = [], [], [], [], [], []
            for t in range(BUFFER_SIZE):
                #self.env.render()
                # Actor picks an action
                action, action_onehot, prediction = self.act(state)
                # Retrieve new state, reward, and whether the state is terminal
                next_state, reward, done, _ = self.env.step(action)
                # Memorize (state, action, reward) for training
                states.append(state)
                next_states.append(np.reshape(next_state, [1, NUM_STATES]))
                actions.append(action_onehot)
                rewards.append(reward)
                dones.append(done)
                predictions.append(prediction)
                # Update current state
                state = np.reshape(next_state, [1, NUM_STATES])
                score += reward
                if done:
                    self.episode += 1
                    self.scores_.append(score)
                    #average, SAVING = self.PlotModel(score, self.episode)
                    #print("episode: {}/{}, score: {}, average: {:.2f} {}".format(self.episode, EPISODES, score, average, SAVING))
                    if self.episode >= 100:
                        average = sum(self.scores_[-100:])/100
                        print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, score, average))
                        if average > self.max_average:
                            self.max_average = average
                            if self.max_average > 150:
                                self.save()
                            LR *= 0.95
                            K.set_value(self.Actor.model.optimizer.learning_rate, LR)
                            K.set_value(self.Critic.model.optimizer.learning_rate, LR)
                            
                        if average > 200:
                            plt.plot(self.scores_)
                            plt.xlabel("Episode")
                            plt.ylabel("Score")
                            finished = True
                            break

                    else:
                        print('Episode: {:>5}\t\tscore: {:>7.2f}\t\taverage: {:>7.2f}'.format(self.episode, score, sum(self.scores_)/len(self.scores_)))
                    
                    
                    state, done, score = self.env.reset(), False, 0
                    state = np.reshape(state, [1, NUM_STATES])
                    
            self.replay(states, actions, rewards, predictions, dones, next_states)
            if self.episode >= EPISODES:
                break
        self.env.close()  
                    
if __name__ == "__main__":
    start = time.time()
    env_name = 'LunarLander-v2'
    agent = PPOAgent(env_name)
    #agent.run() # train as PPO, train every epesode
    agent.run_batch() # train as PPO, train every batch, trains better
    #agent.run_multiprocesses(num_worker = 8)  # train PPO multiprocessed (fastest)
    #agent.test()
    print((time.time() - start)/60)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Episode:     1		score:  -87.65		average:  -87.65
# Episode:     2		score: -282.00		average: -184.82
# Episode:     3		score: -104.95		average: -158.20
# Episode:     4		score: -124.88		average: -149.87
# Episode:     5		score: -469.92		average: -213.88
# Episode:     6		score: -325.57		average: -232.49
# Episode:     7		score: -104.14		average: -214.16
# Episode:     8		score: -412.26		average: -238.92
# Episode:     9		score: -381.17		average: -254.73
# Episode:    10		score: -126.19		average: -241.87
# Episode:    11		score: -121.62		average: -230.94
# Episode:    12		score:  -92.07		average: -219.37
# Episode:    13		score: -106.37		average: -210.68
# Episode:    14		score: -484.16		average: -230.21
# Episode:    15		score:  -99.45		average: -221.49
# Episode:    16		score:  -92.50		average: -213.43
# Episode:    17		score:  -76.51		average: -205.38
# Episode:    18		score: -366.43		average: -214.32
# Episode:    19		score: -253.53		average: -216.39
# Episode:    20		score: -102.98		average: -210.72
# Episode:    21		score: -119.07		average: -206.35
# Episode:    22		score: -150.43		average: -203.81
# Episode:    23		score: -106.83		average: -199.59
# Episode:    24		score: -432.58		average: -209.30
# Episode:    25		score: -112.11		average: -205.41
# Episode:    26		score:  -76.77		average: -200.47
# Episode:    27		score:  -73.36		average: -195.76
# Episode:    28		score:  -55.75		average: -190.76
# Episode:    29		score: -138.64		average: -188.96
# Episode:    30		score: -320.16		average: -193.34
# Episode:    31		score: -261.78		average: -195.54
# Episode:    32		score: -111.76		average: -192.92
# Episode:    33		score: -120.30		average: -190.72
# Episode:    34		score: -137.72		average: -189.17
# Episode:    35		score:  -87.80		average: -186.27
# Episode:    36		score:  -95.80		average: -183.76
# Episode:    37		score: -335.18		average: -187.85
# Episode:    38		score: -102.95		average: -185.61
# Episode:    39		score: -463.36		average: -192.74
# Episode:    40		score: -112.83		average: -190.74
# Episode:    41		score: -184.74		average: -190.59
# Episode:    42		score:  -95.49		average: -188.33
# Episode:    43		score: -162.23		average: -187.72
# Episode:    44		score: -108.56		average: -185.92
# Episode:    45		score: -226.83		average: -186.83
# Episode:    46		score: -173.59		average: -186.54
# Episode:    47		score: -112.31		average: -184.96
# Episode:    48		score:  -91.55		average: -183.02
# Episode:    49		score: -115.12		average: -181.63
# Episode:    50		score: -151.09		average: -181.02
# Episode:    51		score: -239.53		average: -182.17
# Episode:    52		score: -281.02		average: -184.07
# Episode:    53		score: -130.62		average: -183.06
# Episode:    54		score: -133.97		average: -182.15
# Episode:    55		score:   13.72		average: -178.59
# Episode:    56		score:  -99.66		average: -177.18
# Episode:    57		score:  -86.19		average: -175.58
# Episode:    58		score: -208.22		average: -176.15
# Episode:    59		score: -101.39		average: -174.88
# Episode:    60		score: -162.44		average: -174.67
# Episode:    61		score: -193.68		average: -174.98
# Episode:    62		score: -116.86		average: -174.05
# Episode:    63		score: -120.94		average: -173.20
# Episode:    64		score: -121.73		average: -172.40
# Episode:    65		score:  -98.23		average: -171.26
# Episode:    66		score:  -66.51		average: -169.67
# Episode:    67		score: -170.98		average: -169.69
# Episode:    68		score: -104.91		average: -168.74
# Episode:    69		score:  -97.97		average: -167.71
# Episode:    70		score: -238.59		average: -168.73
# Episode:    71		score: -145.28		average: -168.39
# Episode:    72		score: -110.10		average: -167.59
# Episode:    73		score: -171.75		average: -167.64
# Episode:    74		score:  -87.96		average: -166.57
# Episode:    75		score: -203.05		average: -167.05
# Episode:    76		score: -119.57		average: -166.43
# Episode:    77		score:  -67.82		average: -165.15
# Episode:    78		score: -171.03		average: -165.22
# Episode:    79		score: -101.65		average: -164.42
# Episode:    80		score:  -51.65		average: -163.01
# Episode:    81		score: -303.61		average: -164.74
# Episode:    82		score:  -42.13		average: -163.25
# Episode:    83		score: -184.14		average: -163.50
# Episode:    84		score: -195.74		average: -163.88
# Episode:    85		score: -102.28		average: -163.16
# Episode:    86		score:  -90.27		average: -162.31
# Episode:    87		score:  -73.28		average: -161.29
# Episode:    88		score:  -65.68		average: -160.20
# Episode:    89		score:  -87.53		average: -159.39
# Episode:    90		score: -100.29		average: -158.73
# Episode:    91		score:  -69.29		average: -157.75
# Episode:    92		score:  -58.59		average: -156.67
# Episode:    93		score:  -16.62		average: -155.16
# Episode:    94		score: -124.72		average: -154.84
# Episode:    95		score: -109.06		average: -154.36
# Episode:    96		score:  -66.92		average: -153.45
# Episode:    97		score: -133.01		average: -153.23
# Episode:    98		score: -231.45		average: -154.03
# Episode:    99		score:   -9.79		average: -152.58
# Episode:   100		score:  -34.69		average: -151.40
# Episode:   101		score: -179.65		average: -152.32
# Episode:   102		score: -313.54		average: -152.63
# Episode:   103		score:  -76.65		average: -152.35
# Episode:   104		score:  -72.99		average: -151.83
# Episode:   105		score:  -56.52		average: -147.70
# Episode:   106		score:  -67.77		average: -145.12
# Episode:   107		score:  -45.33		average: -144.53
# Episode:   108		score:    9.39		average: -140.31
# Episode:   109		score:  -15.96		average: -136.66
# Episode:   110		score:  -37.46		average: -135.77
# Episode:   111		score:  -68.68		average: -135.25
# Episode:   112		score:  -58.74		average: -134.91
# Episode:   113		score:  -88.98		average: -134.74
# Episode:   114		score:  -76.74		average: -130.66
# Episode:   115		score:  -18.77		average: -129.86
# Episode:   116		score:  -46.32		average: -129.40
# Episode:   117		score:  -35.83		average: -128.99
# Episode:   118		score:  -64.01		average: -125.96
# Episode:   119		score:  -61.46		average: -124.04
# Episode:   120		score:  -85.61		average: -123.87
# Episode:   121		score:  -95.70		average: -123.64
# Episode:   122		score:  -57.08		average: -122.70
# Episode:   123		score:  -14.34		average: -121.78
# Episode:   124		score:  -27.38		average: -117.73
# Episode:   125		score:  -44.24		average: -117.05
# Episode:   126		score:  -31.10		average: -116.59
# Episode:   127		score:  -20.14		average: -116.06
# Episode:   128		score:  -28.24		average: -115.78
# Episode:   129		score:   30.79		average: -114.09
# Episode:   130		score:  -28.71		average: -111.17
# Episode:   131		score:  -32.88		average: -108.88
# Episode:   132		score:    0.98		average: -107.76
# Episode:   133		score:  -50.46		average: -107.06
# Episode:   134		score:  -62.04		average: -106.30
# Episode:   135		score:  -50.00		average: -105.92
# Episode:   136		score:  -65.70		average: -105.62
# Episode:   137		score:  -83.39		average: -103.11
# Episode:   138		score:  -43.78		average: -102.51
# Episode:   139		score:    7.53		average:  -97.80
# Episode:   140		score:  -24.82		average:  -96.92
# Episode:   141		score:   10.09		average:  -94.98
# Episode:   142		score:  -24.72		average:  -94.27
# Episode:   143		score:   28.15		average:  -92.37
# Episode:   144		score:   24.08		average:  -91.04
# Episode:   145		score:   44.42		average:  -88.33
# Episode:   146		score:   -1.60		average:  -86.61
# Episode:   147		score:    9.01		average:  -85.39
# Episode:   148		score:   66.60		average:  -83.81
# Episode:   149		score:  -89.90		average:  -83.56
# Episode:   150		score:   35.43		average:  -81.69
# Episode:   151		score:   86.64		average:  -78.43
# Episode:   152		score:  -20.24		average:  -75.82
# Episode:   153		score: -112.44		average:  -75.64
# Episode:   154		score:   37.64		average:  -73.93
# Episode:   155		score:   34.54		average:  -73.72
# Episode:   156		score:   61.36		average:  -72.11
# Episode:   157		score:   80.40		average:  -70.44
# Episode:   158		score:  103.11		average:  -67.33
# Episode:   159		score:   85.90		average:  -65.46
# Episode:   160		score:  107.96		average:  -62.75
# Episode:   161		score:   67.24		average:  -60.14
# Episode:   162		score:  140.93		average:  -57.57
# Episode:   163		score:   12.76		average:  -56.23
# Episode:   164		score:  125.84		average:  -53.75
# Episode:   165		score:  102.03		average:  -51.75
# Episode:   166		score:  135.72		average:  -49.73
# Episode:   167		score:   38.03		average:  -47.64
# Episode:   168		score:   83.47		average:  -45.75
# Episode:   169		score:   65.91		average:  -44.12
# Episode:   170		score:  121.82		average:  -40.51
# Episode:   171		score:  137.35		average:  -37.68
# Episode:   172		score:  181.57		average:  -34.77
# Episode:   173		score:   81.20		average:  -32.24
# Episode:   174		score:  105.09		average:  -30.31
# Episode:   175		score:  120.64		average:  -27.07
# Episode:   176		score:  112.26		average:  -24.75
# Episode:   177		score:  145.81		average:  -22.62
# Episode:   178		score:   50.47		average:  -20.40
# Episode:   179		score:  111.04		average:  -18.27
# Episode:   180		score:   40.86		average:  -17.35
# Episode:   181		score:  151.25		average:  -12.80
# Episode:   182		score:  146.09		average:  -10.92
# Episode:   183		score:    4.50		average:   -9.03
# Episode:   184		score:   12.06		average:   -6.95
# Episode:   185		score:  114.17		average:   -4.79
# Episode:   186		score:  145.69		average:   -2.43
# Episode:   187		score:   33.63		average:   -1.36
# Episode:   188		score:  147.59		average:    0.77
# Episode:   189		score:  129.92		average:    2.95
# Episode:   190		score:  127.77		average:    5.23
# Episode:   191		score:   91.78		average:    6.84
# Episode:   192		score:  111.20		average:    8.54
# Episode:   193		score:  182.21		average:   10.52
# Episode:   194		score:  134.60		average:   13.12
# Episode:   195		score:   73.04		average:   14.94
# Episode:   196		score:   93.92		average:   16.55
# Episode:   197		score:  135.03		average:   19.23
# Episode:   198		score:  115.46		average:   22.70
# Episode:   199		score:   96.46		average:   23.76
# Episode:   200		score:   70.19		average:   24.81
# Episode:   201		score:   31.44		average:   26.92
# Episode:   202		score:  149.82		average:   31.55
# Episode:   203		score:  148.75		average:   33.81
# Episode:   204		score:  233.32		average:   36.87
# Episode:   205		score:  -24.28		average:   37.19
# Episode:   206		score:  175.70		average:   39.63
# Episode:   207		score:  144.91		average:   41.53
# Episode:   208		score:  136.39		average:   42.80
# Episode:   209		score:  177.27		average:   44.73
# Episode:   210		score:  178.96		average:   46.89
# Episode:   211		score:  132.28		average:   48.90
# Episode:   212		score:  141.30		average:   50.90
# Episode:   213		score:  -17.98		average:   51.61
# Episode:   214		score:  196.84		average:   54.35
# Episode:   215		score:  133.92		average:   55.88
# Episode:   216		score:  174.30		average:   58.08
# Episode:   217		score:  164.03		average:   60.08
# Episode:   218		score:  155.48		average:   62.28
# Episode:   219		score:   86.99		average:   63.76
# Episode:   220		score:  115.26		average:   65.77
# Episode:   221		score:  -28.91		average:   66.44
# Episode:   222		score:  112.92		average:   68.14
# Episode:   223		score:  141.08		average:   69.69
# Episode:   224		score:   17.50		average:   70.14
# Episode:   225		score:    5.98		average:   70.64
# Episode:   226		score:   15.97		average:   71.11
# Episode:   227		score:  184.26		average:   73.16
# Episode:   228		score:  164.97		average:   75.09
# Episode:   229		score:  117.62		average:   75.96
# Episode:   230		score:   33.89		average:   76.58
# Episode:   231		score:  189.51		average:   78.81
# Episode:   232		score:  148.01		average:   80.28
# Episode:   233		score:   -0.47		average:   80.78
# Episode:   234		score:  123.27		average:   82.63
# Episode:   235		score:  146.91		average:   84.60
# Episode:   236		score:   28.81		average:   85.55
# Episode:   237		score:  131.12		average:   87.69
# Episode:   238		score:   39.10		average:   88.52
# Episode:   239		score:   28.71		average:   88.73
# Episode:   240		score:  172.85		average:   90.71
# Episode:   241		score:  278.45		average:   93.39
# Episode:   242		score:  251.67		average:   96.16
# Episode:   243		score:  152.75		average:   97.40
# Episode:   244		score:  170.15		average:   98.86
# Episode:   245		score:  148.60		average:   99.90
# Episode:   246		score:   -5.26		average:   99.87
# Episode:   247		score:  163.85		average:  101.42
# Episode:   248		score:    9.16		average:  100.84
# Episode:   249		score:    2.02		average:  101.76
# Episode:   250		score:  152.02		average:  102.93
# Episode:   251		score:  159.46		average:  103.65
# Episode:   252		score:  -35.34		average:  103.50
# Episode:   253		score:    9.02		average:  104.72
# Episode:   254		score:  148.25		average:  105.82
# Episode:   255		score:   97.16		average:  106.45
# Episode:   256		score:  245.78		average:  108.29
# Episode:   257		score:  124.73		average:  108.74
# Episode:   258		score:  266.87		average:  110.38
# Episode:   259		score:  196.27		average:  111.48
# Episode:   260		score:  236.72		average:  112.77
# Episode:   261		score:  268.65		average:  114.78
# Episode:   262		score:  158.98		average:  114.96
# Episode:   263		score:  169.89		average:  116.53
# Episode:   264		score:  178.34		average:  117.06
# Episode:   265		score:  209.91		average:  118.14
# Episode:   266		score:  274.33		average:  119.52
# Episode:   267		score:   -5.82		average:  119.08
# Episode:   268		score:  281.45		average:  121.06
# Episode:   269		score:  -41.16		average:  119.99
# Episode:   270		score:  251.19		average:  121.29
# Episode:   271		score:   19.91		average:  120.11
# Episode:   272		score:  231.94		average:  120.62
# Episode:   273		score:    8.45		average:  119.89
# Episode:   274		score:   54.59		average:  119.38
# Episode:   275		score:  249.68		average:  120.67
# Episode:   276		score:    8.50		average:  119.64
# Episode:   277		score:  250.47		average:  120.68
# Episode:   278		score:  114.41		average:  121.32
# Episode:   279		score:  263.48		average:  122.85
# Episode:   280		score:   90.64		average:  123.35
# Episode:   281		score:   42.22		average:  122.25
# Episode:   282		score:   20.95		average:  121.00
# Episode:   283		score:    4.85		average:  121.01
# Episode:   284		score:   17.41		average:  121.06
# Episode:   285		score:   22.16		average:  120.14
# Episode:   286		score:  262.05		average:  121.30
# Episode:   287		score:  255.40		average:  123.52
# Episode:   288		score:  251.62		average:  124.56
# Episode:   289		score:  244.87		average:  125.71
# Episode:   290		score:  275.95		average:  127.19
# Episode:   291		score:  141.02		average:  127.69
# Episode:   292		score:  266.77		average:  129.24
# Episode:   293		score:  202.30		average:  129.44
# Episode:   294		score:    0.01		average:  128.10
# Episode:   295		score:  235.07		average:  129.72
# Episode:   296		score:  235.96		average:  131.14
# Episode:   297		score:  240.51		average:  132.19
# Episode:   298		score: -111.13		average:  129.93
# Episode:   299		score:  224.71		average:  131.21
# Episode:   300		score:  211.18		average:  132.62
# Episode:   301		score:  216.06		average:  134.46
# Episode:   302		score:  252.40		average:  135.49
# Episode:   303		score:  262.59		average:  136.63
# Episode:   304		score:  288.68		average:  137.18
# Episode:   305		score:   19.05		average:  137.62
# Episode:   306		score:  299.96		average:  138.86
# Episode:   307		score:  157.90		average:  138.99
# Episode:   308		score:  272.35		average:  140.35
# Episode:   309		score:  178.21		average:  140.36
# Episode:   310		score:   24.54		average:  138.81
# Episode:   311		score:  293.33		average:  140.42
# Episode:   312		score:  272.77		average:  141.74
# Episode:   313		score:  -18.47		average:  141.73
# Episode:   314		score:  257.55		average:  142.34
# Episode:   315		score:  220.70		average:  143.21
# Episode:   316		score:  262.51		average:  144.09
# Episode:   317		score:  270.24		average:  145.15
# Episode:   318		score:  292.86		average:  146.53
# Episode:   319		score:   -0.73		average:  145.65
# Episode:   320		score:  104.10		average:  145.54
# Episode:   321		score:   25.03		average:  146.08
# Episode:   322		score:  254.53		average:  147.49
# Episode:   323		score:  216.90		average:  148.25
# Episode:   324		score:  262.05		average:  150.70
# Episode:   325		score:   19.03		average:  150.83
# Episode:   326		score:  201.23		average:  152.68
# Episode:   327		score:  198.89		average:  152.83
# Episode:   328		score:  144.85		average:  152.63
# Episode:   329		score:  274.46		average:  154.19
# Episode:   330		score:  263.17		average:  156.49
# Episode:   331		score:  242.81		average:  157.02
# Episode:   332		score:   17.12		average:  155.71
# Episode:   333		score:  273.47		average:  158.45
# Episode:   334		score:  118.46		average:  158.40
# Episode:   335		score:  292.48		average:  159.86
# Episode:   336		score:  281.59		average:  162.39
# Episode:   337		score:  249.13		average:  163.57
# Episode:   338		score:  275.08		average:  165.93
# Episode:   339		score:   45.38		average:  166.09
# Episode:   340		score:  263.54		average:  167.00
# Episode:   341		score:  252.04		average:  166.73
# Episode:   342		score:  273.17		average:  166.95
# Episode:   343		score:   10.44		average:  165.53
# Episode:   344		score:   96.41		average:  164.79
# Episode:   345		score:  190.80		average:  165.21
# Episode:   346		score:  264.91		average:  167.91
# Episode:   347		score:  275.03		average:  169.02
# Episode:   348		score:  250.87		average:  171.44
# Episode:   349		score:   23.60		average:  171.66
# Episode:   350		score:  201.50		average:  172.15
# Episode:   351		score:  259.88		average:  173.16
# Episode:   352		score:  273.91		average:  176.25
# Episode:   353		score:   -1.32		average:  176.15
# Episode:   354		score:  268.26		average:  177.35
# Episode:   355		score:  234.27		average:  178.72
# Episode:   356		score:   82.89		average:  177.09
# Episode:   357		score:  290.08		average:  178.74
# Episode:   358		score:  254.59		average:  178.62
# Episode:   359		score:   30.90		average:  176.96
# Episode:   360		score:  261.38		average:  177.21
# Episode:   361		score:  222.03		average:  176.75
# Episode:   362		score:  244.04		average:  177.60
# Episode:   363		score:  136.15		average:  177.26
# Episode:   364		score:  227.73		average:  177.75
# Episode:   365		score:  265.00		average:  178.30
# Episode:   366		score: -116.67		average:  174.39
# Episode:   367		score:  271.08		average:  177.16
# Episode:   368		score:   15.91		average:  174.51
# Episode:   369		score:  251.67		average:  177.43
# Episode:   370		score:  250.70		average:  177.43
# Episode:   371		score:   32.18		average:  177.55
# Episode:   372		score:  228.60		average:  177.52
# Episode:   373		score:  261.97		average:  180.05
# Episode:   374		score:   18.04		average:  179.69
# Episode:   375		score:   33.56		average:  177.53
# Episode:   376		score:  197.59		average:  179.42
# Episode:   377		score:  209.33		average:  179.01
# Episode:   378		score:  273.62		average:  180.60
# Episode:   379		score:  271.64		average:  180.68
# Episode:   380		score:  202.85		average:  181.80
# Episode:   381		score:  262.19		average:  184.00
# Episode:   382		score:  252.90		average:  186.32
# Episode:   383		score:  270.37		average:  188.98
# Episode:   384		score:   -6.81		average:  188.74
# Episode:   385		score:  260.64		average:  191.12
# Episode:   386		score:  263.42		average:  191.13
# Episode:   387		score:  223.28		average:  190.81
# Episode:   388		score:   46.17		average:  188.76
# Episode:   389		score:   27.14		average:  186.58
# Episode:   390		score:  272.69		average:  186.55
# Episode:   391		score:  250.64		average:  187.64
# Episode:   392		score:   22.65		average:  185.20
# Episode:   393		score:  252.52		average:  185.71
# Episode:   394		score:  172.61		average:  187.43
# Episode:   395		score:  254.77		average:  187.63
# Episode:   396		score:   17.98		average:  185.45
# Episode:   397		score:  150.65		average:  184.55
# Episode:   398		score:  241.14		average:  188.07
# Episode:   399		score:  255.45		average:  188.38
# Episode:   400		score:   19.31		average:  186.46
# Episode:   401		score:  102.43		average:  185.33
# Episode:   402		score:  260.06		average:  185.40
# Episode:   403		score:    0.13		average:  182.78
# Episode:   404		score:   55.04		average:  180.44
# Episode:   405		score:  265.82		average:  182.91
# Episode:   406		score:   55.99		average:  180.47
# Episode:   407		score:  -17.38		average:  178.72
# Episode:   408		score:  278.13		average:  178.77
# Episode:   409		score:  171.90		average:  178.71
# Episode:   410		score:  257.35		average:  181.04
# Episode:   411		score:  166.03		average:  179.77
# Episode:   412		score:  133.71		average:  178.38
# Episode:   413		score:  261.94		average:  181.18
# Episode:   414		score:  272.14		average:  181.33
# Episode:   415		score: -122.19		average:  177.90
# Episode:   416		score:  212.66		average:  177.40
# Episode:   417		score:    2.64		average:  174.72
# Episode:   418		score:  252.10		average:  174.31
# Episode:   419		score:   50.23		average:  174.82
# Episode:   420		score:  256.01		average:  176.34
# Episode:   421		score:  260.13		average:  178.69
# Episode:   422		score:  252.38		average:  178.67
# Episode:   423		score:  228.25		average:  178.79
# Episode:   424		score:   55.78		average:  176.72
# Episode:   425		score:  246.68		average:  179.00
# Episode:   426		score:  258.68		average:  179.57
# Episode:   427		score:  245.19		average:  180.04
# Episode:   428		score:  258.51		average:  181.17
# Episode:   429		score:  236.25		average:  180.79
# Episode:   430		score:  268.74		average:  180.85
# Episode:   431		score:  168.61		average:  180.11
# Episode:   432		score:  240.18		average:  182.34
# Episode:   433		score:  301.43		average:  182.62
# Episode:   434		score:  221.93		average:  183.65
# Episode:   435		score:    0.68		average:  180.73
# Episode:   436		score:  266.74		average:  180.58
# Episode:   437		score:  257.01		average:  180.66
# Episode:   438		score:    6.14		average:  177.97
# Episode:   439		score:  267.90		average:  180.20
# Episode:   440		score:  221.47		average:  179.78
# Episode:   441		score:  212.90		average:  179.39
# Episode:   442		score:  276.75		average:  179.42
# Episode:   443		score:   75.86		average:  180.08
# Episode:   444		score:  255.62		average:  181.67
# Episode:   445		score:  -81.05		average:  178.95
# Episode:   446		score:  294.23		average:  179.24
# Episode:   447		score:  187.86		average:  178.37
# Episode:   448		score:   10.20		average:  175.96
# Episode:   449		score:   22.00		average:  175.95
# Episode:   450		score:  263.46		average:  176.57
# Episode:   451		score:  249.24		average:  176.46
# Episode:   452		score:  280.35		average:  176.53
# Episode:   453		score:  243.38		average:  178.97
# Episode:   454		score:  240.86		average:  178.70
# Episode:   455		score:  241.17		average:  178.77
# Episode:   456		score:  274.97		average:  180.69
# Episode:   457		score:  193.84		average:  179.73
# Episode:   458		score:  262.45		average:  179.80
# Episode:   459		score:  264.28		average:  182.14
# Episode:   460		score:  293.01		average:  182.46
# Episode:   461		score:  278.81		average:  183.02
# Episode:   462		score:   84.14		average:  181.42
# Episode:   463		score:  243.03		average:  182.49
# Episode:   464		score:  132.54		average:  181.54
# Episode:   465		score:  260.97		average:  181.50
# Episode:   466		score:   32.93		average:  183.00
# Episode:   467		score:  288.24		average:  183.17
# Episode:   468		score:  279.55		average:  185.80
# Episode:   469		score:   51.15		average:  183.80
# Episode:   470		score:   32.75		average:  181.62
# Episode:   471		score:  266.17		average:  183.96
# Episode:   472		score:  -23.18		average:  181.44
# Episode:   473		score:  228.33		average:  181.11
# Episode:   474		score:  173.61		average:  182.66
# Episode:   475		score:   39.19		average:  182.72
# Episode:   476		score:   25.71		average:  181.00
# Episode:   477		score:  275.74		average:  181.66
# Episode:   478		score:   59.06		average:  179.52
# Episode:   479		score:  236.73		average:  179.17
# Episode:   480		score:  236.41		average:  179.50
# Episode:   481		score:  -11.80		average:  176.76
# Episode:   482		score:   -2.62		average:  174.21
# Episode:   483		score:   40.07		average:  171.91
# Episode:   484		score:  258.26		average:  174.56
# Episode:   485		score:  217.90		average:  174.13
# Episode:   486		score:   12.55		average:  171.62
# Episode:   487		score:  235.58		average:  171.74
# Episode:   488		score:  228.31		average:  173.56
# Episode:   489		score:  240.95		average:  175.70
# Episode:   490		score:  278.84		average:  175.76
# Episode:   491		score:  269.94		average:  175.96
# Episode:   492		score:  270.98		average:  178.44
# Episode:   493		score:  216.59		average:  178.08
# Episode:   494		score:  246.26		average:  178.82
# Episode:   495		score:  -50.45		average:  175.77
# Episode:   496		score:   55.17		average:  176.14
# Episode:   497		score:  183.42		average:  176.47
# Episode:   498		score:  264.13		average:  176.70
# Episode:   499		score:   18.69		average:  174.33
# Episode:   500		score:    2.39		average:  174.16
# Episode:   501		score:  262.93		average:  175.76
# Episode:   502		score:  233.59		average:  175.50
# Episode:   503		score:  268.08		average:  178.18
# Episode:   504		score:  260.90		average:  180.24
# Episode:   505		score:  222.19		average:  179.80
# Episode:   506		score:  269.25		average:  181.93
# Episode:   507		score:  245.88		average:  184.57
# Episode:   508		score:   20.00		average:  181.98
# Episode:   509		score:   15.05		average:  180.42
# Episode:   510		score:  263.02		average:  180.47
# Episode:   511		score:  229.83		average:  181.11
# Episode:   512		score:    9.67		average:  179.87
# Episode:   513		score:  276.92		average:  180.02
# Episode:   514		score:  234.53		average:  179.64
# Episode:   515		score:  215.10		average:  183.02
# Episode:   516		score:   37.81		average:  181.27
# Episode:   517		score:   60.05		average:  181.84
# Episode:   518		score:  257.11		average:  181.89
# Episode:   519		score:  258.54		average:  183.98
# Episode:   520		score:  213.15		average:  183.55
# Episode:   521		score:  233.33		average:  183.28
# Episode:   522		score:  249.65		average:  183.25
# Episode:   523		score:  145.93		average:  182.43
# Episode:   524		score:  197.58		average:  183.85
# Episode:   525		score:  249.64		average:  183.88
# Episode:   526		score:  124.77		average:  182.54
# Episode:   527		score:  186.18		average:  181.95
# Episode:   528		score:  276.37		average:  182.13
# Episode:   529		score:   28.18		average:  180.04
# Episode:   530		score:  239.01		average:  179.75
# Episode:   531		score:  222.37		average:  180.29
# Episode:   532		score:  250.65		average:  180.39
# Episode:   533		score:  196.38		average:  179.34
# Episode:   534		score:   34.81		average:  177.47
# Episode:   535		score:  242.07		average:  179.88
# Episode:   536		score:  259.00		average:  179.80
# Episode:   537		score:  275.03		average:  179.98
# Episode:   538		score:  236.20		average:  182.29
# Episode:   539		score:  272.15		average:  182.33
# Episode:   540		score:  239.88		average:  182.51
# Episode:   541		score:   -1.37		average:  180.37
# Episode:   542		score:  295.45		average:  180.56
# Episode:   543		score:   54.42		average:  180.34
# Episode:   544		score:  197.78		average:  179.76
# Episode:   545		score:  268.64		average:  183.26
# Episode:   546		score:  -17.56		average:  180.14
# Episode:   547		score:  284.86		average:  181.11
# Episode:   548		score:   17.33		average:  181.18
# Episode:   549		score:  287.42		average:  183.84
# Episode:   550		score:  134.56		average:  182.55
# Episode:   551		score:  297.46		average:  183.03
# Episode:   552		score:   48.02		average:  180.71
# Episode:   553		score:  295.93		average:  181.23
# Episode:   554		score:  240.25		average:  181.23
# Episode:   555		score:  254.01		average:  181.36
# Episode:   556		score:   26.52		average:  178.87
# Episode:   557		score:  184.78		average:  178.78
# Episode:   558		score:  159.89		average:  177.76
# Episode:   559		score:  256.26		average:  177.67
# Episode:   560		score:  251.61		average:  177.26
# Episode:   561		score:  256.28		average:  177.04
# Episode:   562		score:  297.29		average:  179.17
# Episode:   563		score:  265.95		average:  179.40
# Episode:   564		score:  269.55		average:  180.77
# Episode:   565		score:   52.70		average:  178.68
# Episode:   566		score:  235.10		average:  180.71
# Episode:   567		score:  263.47		average:  180.46
# Episode:   568		score:  274.95		average:  180.41
# Episode:   569		score:  239.75		average:  182.30
# Episode:   570		score:   22.14		average:  182.19
# Episode:   571		score:    6.98		average:  179.60
# Episode:   572		score:   10.94		average:  179.94
# Episode:   573		score:  278.56		average:  180.44
# Episode:   574		score:  235.91		average:  181.07
# Episode:   575		score:  251.59		average:  183.19
# Episode:   576		score:    4.69		average:  182.98
# Episode:   577		score:   -0.79		average:  180.21
# Episode:   578		score:  247.46		average:  182.10
# Episode:   579		score:  -36.66		average:  179.36
# Episode:   580		score:  269.54		average:  179.70
# Episode:   581		score:  255.55		average:  182.37
# Episode:   582		score:  237.45		average:  184.77
# Episode:   583		score:  104.81		average:  185.42
# Episode:   584		score:  213.75		average:  184.97
# Episode:   585		score:  162.19		average:  184.42
# Episode:   586		score:  252.69		average:  186.82
# Episode:   587		score:  257.76		average:  187.04
# Episode:   588		score:  264.03		average:  187.40
# Episode:   589		score:  270.27		average:  187.69
# Episode:   590		score:  232.35		average:  187.22
# Episode:   591		score:   30.68		average:  184.83
# Episode:   592		score:  244.30		average:  184.56
# Episode:   593		score:  258.01		average:  184.98
# Episode:   594		score:   27.11		average:  182.79
# Episode:   595		score:   17.14		average:  183.46
# Episode:   596		score:  281.12		average:  185.72
# Episode:   597		score:  212.46		average:  186.01
# Episode:   598		score:  242.98		average:  185.80
# Episode:   599		score:  283.31		average:  188.45
# Episode:   600		score:  239.66		average:  190.82
# Episode:   601		score:   41.05		average:  188.60
# Episode:   602		score:  262.55		average:  188.89
# Episode:   603		score:  260.96		average:  188.82
# Episode:   604		score:  224.89		average:  188.46
# Episode:   605		score:    4.38		average:  186.28
# Episode:   606		score:  265.32		average:  186.24
# Episode:   607		score:  250.22		average:  186.29
# Episode:   608		score:  141.42		average:  187.50
# Episode:   609		score:  206.25		average:  189.41
# Episode:   610		score:  243.42		average:  189.22
# Episode:   611		score:  245.99		average:  189.38
# Episode:   612		score:  -14.92		average:  189.13
# Episode:   613		score:  269.17		average:  189.05
# Episode:   614		score:  271.67		average:  189.43
# Episode:   615		score:  274.16		average:  190.02
# Episode:   616		score:  253.82		average:  192.18
# Episode:   617		score:   32.69		average:  191.90
# Episode:   618		score:   27.96		average:  189.61
# Episode:   619		score:  263.51		average:  189.66
# Episode:   620		score:   16.33		average:  187.69
# Episode:   621		score:  226.25		average:  187.62
# Episode:   622		score:  245.17		average:  187.58
# Episode:   623		score:  233.87		average:  188.46
# Episode:   624		score:  258.88		average:  189.07
# Episode:   625		score:  263.08		average:  189.20
# Episode:   626		score:   -2.27		average:  187.93
# Episode:   627		score:  273.93		average:  188.81
# Episode:   628		score:   19.24		average:  186.24
# Episode:   629		score:   41.23		average:  186.37
# Episode:   630		score:  263.13		average:  186.61
# Episode:   631		score:  -23.78		average:  184.15
# Episode:   632		score:  248.87		average:  184.13
# Episode:   633		score:  244.86		average:  184.62
# Episode:   634		score:  275.12		average:  187.02
# Episode:   635		score:  253.22		average:  187.13
# Episode:   636		score:  245.64		average:  187.00
# Episode:   637		score:   95.15		average:  185.20
# Episode:   638		score:  208.88		average:  184.93
# Episode:   639		score:  272.22		average:  184.93
# Episode:   640		score:  231.85		average:  184.85
# Episode:   641		score:  194.91		average:  186.81
# Episode:   642		score:  267.53		average:  186.53
# Episode:   643		score:   34.99		average:  186.34
# Episode:   644		score:  238.52		average:  186.74
# Episode:   645		score:  290.38		average:  186.96
# Episode:   646		score:  240.87		average:  189.55
# Episode:   647		score:  249.48		average:  189.19
# Episode:   648		score:   29.21		average:  189.31
# Episode:   649		score:  261.23		average:  189.05
# Episode:   650		score:    9.02		average:  187.79
# Episode:   651		score:  209.08		average:  186.91
# Episode:   652		score:   39.68		average:  186.83
# Episode:   653		score:  281.68		average:  186.68
# Episode:   654		score:  217.34		average:  186.45
# Episode:   655		score:  263.11		average:  186.54
# Episode:   656		score:  253.39		average:  188.81
# Episode:   657		score:  257.73		average:  189.54
# Episode:   658		score:   39.01		average:  188.33
# Episode:   659		score:   17.10		average:  185.94
# Episode:   660		score:  256.26		average:  185.99
# Episode:   661		score:   45.48		average:  183.88
# Episode:   662		score:  -20.20		average:  180.71
# Episode:   663		score:   13.15		average:  178.18
# Episode:   664		score:  243.65		average:  177.92
# Episode:   665		score:  257.20		average:  179.96
# Episode:   666		score:   26.66		average:  177.88
# Episode:   667		score:   22.12		average:  175.47
# Episode:   668		score:  236.10		average:  175.08
# Episode:   669		score:  270.04		average:  175.38
# Episode:   670		score:   86.83		average:  176.03
# Episode:   671		score:  249.89		average:  178.46
# Episode:   672		score:  -12.12		average:  178.23
# Episode:   673		score:  263.87		average:  178.08
# Episode:   674		score:   -9.29		average:  175.63
# Episode:   675		score:  134.28		average:  174.45
# Episode:   676		score:   28.77		average:  174.69
# Episode:   677		score:  -11.85		average:  174.58
# Episode:   678		score:  259.37		average:  174.70
# Episode:   679		score:   22.28		average:  175.29
# Episode:   680		score:  249.48		average:  175.09
# Episode:   681		score:  154.21		average:  174.08
# Episode:   682		score:  258.14		average:  174.29
# Episode:   683		score:  260.27		average:  175.84
# Episode:   684		score:   17.36		average:  173.88
# Episode:   685		score:   11.27		average:  172.37
# Episode:   686		score:  -15.28		average:  169.69
# Episode:   687		score:  303.00		average:  170.14
# Episode:   688		score:  260.42		average:  170.10
# Episode:   689		score:  270.30		average:  170.10
# Episode:   690		score:  264.52		average:  170.43
# Episode:   691		score:    0.84		average:  170.13
# Episode:   692		score:  254.02		average:  170.22
# Episode:   693		score:  252.01		average:  170.16
# Episode:   694		score:  228.82		average:  172.18
# Episode:   695		score:  -15.49		average:  171.86
# Episode:   696		score:  245.52		average:  171.50
# Episode:   697		score:   38.03		average:  169.76
# Episode:   698		score:  253.80		average:  169.86
# Episode:   699		score:  151.83		average:  168.55
# Episode:   700		score:  247.57		average:  168.63
# Episode:   701		score:   18.23		average:  168.40
# Episode:   702		score:  266.26		average:  168.44
# Episode:   703		score:  255.13		average:  168.38
# Episode:   704		score:  262.83		average:  168.76
# Episode:   705		score:  276.60		average:  171.48
# Episode:   706		score:  207.30		average:  170.90
# Episode:   707		score:  244.28		average:  170.84
# Episode:   708		score:  248.90		average:  171.92
# Episode:   709		score:  245.32		average:  172.31
# Episode:   710		score:    1.01		average:  169.88
# Episode:   711		score:  202.55		average:  169.45
# Episode:   712		score:  244.78		average:  172.04
# Episode:   713		score:  170.28		average:  171.06
# Episode:   714		score:  290.45		average:  171.24
# Episode:   715		score:  260.80		average:  171.11
# Episode:   716		score:   54.15		average:  169.11
# Episode:   717		score:  258.38		average:  171.37
# Episode:   718		score:   90.66		average:  172.00
# Episode:   719		score:  -15.84		average:  169.20
# Episode:   720		score:  282.78		average:  171.87
# Episode:   721		score:  -18.38		average:  169.42
# Episode:   722		score:  239.65		average:  169.37
# Episode:   723		score:  261.48		average:  169.64
# Episode:   724		score:  250.44		average:  169.56
# Episode:   725		score:  254.30		average:  169.47
# Episode:   726		score:  242.79		average:  171.92
# Episode:   727		score:   27.20		average:  169.45
# Episode:   728		score:   51.10		average:  169.77
# Episode:   729		score:  234.07		average:  171.70
# Episode:   730		score:    9.65		average:  169.17
# Episode:   731		score:   16.62		average:  169.57
# Episode:   732		score:  140.45		average:  168.49
# Episode:   733		score:   36.92		average:  166.41
# Episode:   734		score:   12.89		average:  163.78
# Episode:   735		score:   38.07		average:  161.63
# Episode:   736		score:  223.13		average:  161.41
# Episode:   737		score:  129.57		average:  161.75
# Episode:   738		score:  243.46		average:  162.10
# Episode:   739		score:   17.38		average:  159.55
# Episode:   740		score:  257.39		average:  159.80
# Episode:   741		score:  165.22		average:  159.51
# Episode:   742		score:  242.40		average:  159.26
# Episode:   743		score:  -29.54		average:  158.61
# Episode:   744		score:   29.83		average:  156.52
# Episode:   745		score:  259.20		average:  156.21
# Episode:   746		score:  245.20		average:  156.26
# Episode:   747		score:  244.47		average:  156.21
# Episode:   748		score:  278.75		average:  158.70
# Episode:   749		score:   30.62		average:  156.39
# Episode:   750		score:   -9.84		average:  156.21
# Episode:   751		score:  184.43		average:  155.96
# Episode:   752		score:  269.97		average:  158.26
# Episode:   753		score:  276.87		average:  158.21
# Episode:   754		score:  226.79		average:  158.31
# Episode:   755		score:   17.16		average:  155.85
# Episode:   756		score:  231.89		average:  155.63
# Episode:   757		score:  257.98		average:  155.64
# Episode:   758		score:  227.43		average:  157.52
# Episode:   759		score:  -17.30		average:  157.18
# Episode:   760		score:  256.56		average:  157.18
# Episode:   761		score:  151.60		average:  158.24
# Episode:   762		score:   30.26		average:  158.75
# Episode:   763		score:  243.25		average:  161.05
# Episode:   764		score:  249.61		average:  161.11
# Episode:   765		score:   27.77		average:  158.81
# Episode:   766		score:  -11.72		average:  158.43
# Episode:   767		score:  -34.81		average:  157.86
# Episode:   768		score:  246.26		average:  157.96
# Episode:   769		score:  269.51		average:  157.96
# Episode:   770		score:  241.62		average:  159.50
# Episode:   771		score:  241.88		average:  159.42
# Episode:   772		score:  218.88		average:  161.73
# Episode:   773		score:   40.35		average:  159.50
# Episode:   774		score:  243.63		average:  162.03
# Episode:   775		score:    6.20		average:  160.75
# Episode:   776		score:  273.66		average:  163.20
# Episode:   777		score:  234.62		average:  165.66
# Episode:   778		score:    3.62		average:  163.10
# Episode:   779		score:  243.87		average:  165.32
# Episode:   780		score:   28.89		average:  163.11
# Episode:   781		score:  258.73		average:  164.16
# Episode:   782		score:  268.85		average:  164.26
# Episode:   783		score:  265.85		average:  164.32
# Episode:   784		score:  240.16		average:  166.55
# Episode:   785		score:   74.10		average:  167.18
# Episode:   786		score:  244.19		average:  169.77
# Episode:   787		score:  257.63		average:  169.32
# Episode:   788		score:  193.68		average:  168.65
# Episode:   789		score:  195.06		average:  167.90
# Episode:   790		score:  232.51		average:  167.58
# Episode:   791		score:  257.18		average:  170.14
# Episode:   792		score:  -94.32		average:  166.66
# Episode:   793		score:  268.74		average:  166.83
# Episode:   794		score:  272.70		average:  167.26
# Episode:   795		score:   -1.71		average:  167.40
# Episode:   796		score:  147.22		average:  166.42
# Episode:   797		score:  283.16		average:  168.87
# Episode:   798		score:  241.31		average:  168.75
# Episode:   799		score:  218.24		average:  169.41
# Episode:   800		score:  288.73		average:  169.82
# Episode:   801		score:  133.67		average:  170.98
# Episode:   802		score:  262.63		average:  170.94
# Episode:   803		score:  278.19		average:  171.17
# Episode:   804		score:  209.04		average:  170.63
# Episode:   805		score:  264.90		average:  170.51
# Episode:   806		score:  203.35		average:  170.48
# Episode:   807		score:  225.23		average:  170.28
# Episode:   808		score:   27.90		average:  168.07
# Episode:   809		score:   37.96		average:  166.00
# Episode:   810		score:    2.87		average:  166.02
# Episode:   811		score:    5.07		average:  164.05
# Episode:   812		score:  -22.28		average:  161.37
# Episode:   813		score:  286.32		average:  162.53
# Episode:   814		score:  243.27		average:  162.06
# Episode:   815		score:   19.46		average:  159.65
# Episode:   816		score:  169.41		average:  160.80
# Episode:   817		score:  274.26		average:  160.96
# Episode:   818		score:  265.06		average:  162.70
# Episode:   819		score:  252.35		average:  165.39
# Episode:   820		score:  264.54		average:  165.20
# Episode:   821		score:   16.20		average:  165.55
# Episode:   822		score:   16.52		average:  163.32
# Episode:   823		score:    8.37		average:  160.79
# Episode:   824		score:  254.92		average:  160.83
# Episode:   825		score:  236.87		average:  160.66
# Episode:   826		score:  166.05		average:  159.89
# Episode:   827		score:  258.40		average:  162.20
# Episode:   828		score:  270.29		average:  164.39
# Episode:   829		score:  262.02		average:  164.67
# Episode:   830		score:  257.07		average:  167.15
# Episode:   831		score:   25.46		average:  167.24
# Episode:   832		score:  -29.92		average:  165.53
# Episode:   833		score:  199.48		average:  167.16
# Episode:   834		score:  145.43		average:  168.48
# Episode:   835		score:  154.78		average:  169.65
# Episode:   836		score:  278.12		average:  170.20
# Episode:   837		score:  142.13		average:  170.33
# Episode:   838		score:  237.10		average:  170.26
# Episode:   839		score:  251.92		average:  172.61
# Episode:   840		score:  151.58		average:  171.55
# Episode:   841		score:  244.86		average:  172.35
# Episode:   842		score:  228.00		average:  172.20
# Episode:   843		score:  268.58		average:  175.18
# Episode:   844		score:  224.91		average:  177.13
# Episode:   845		score:  290.89		average:  177.45
# Episode:   846		score:   -3.74		average:  174.96
# Episode:   847		score:  295.13		average:  175.47
# Episode:   848		score:  213.45		average:  174.82
# Episode:   849		score:  259.22		average:  177.10
# Episode:   850		score:  139.43		average:  178.59
# Episode:   851		score:  248.57		average:  179.24
# Episode:   852		score:   -7.04		average:  176.47
# Episode:   853		score:   57.55		average:  174.27
# Episode:   854		score:  271.23		average:  174.72
# Episode:   855		score:  204.52		average:  176.59
# Episode:   856		score:  252.35		average:  176.80
# Episode:   857		score:  244.31		average:  176.66
# Episode:   858		score:  188.03		average:  176.26
# Episode:   859		score:  -15.17		average:  176.29
# Episode:   860		score:  253.46		average:  176.25
# Episode:   861		score:  259.98		average:  177.34
# Episode:   862		score:  270.31		average:  179.74
# Episode:   863		score:  240.80		average:  179.71
# Episode:   864		score:    6.23		average:  177.28
# Episode:   865		score:  273.68		average:  179.74
# Episode:   866		score:  273.41		average:  182.59
# Episode:   867		score:  266.62		average:  185.61
# Episode:   868		score:  245.17		average:  185.59
# Episode:   869		score:   63.44		average:  183.53
# Episode:   870		score:  266.56		average:  183.78
# Episode:   871		score:   45.43		average:  181.82
# Episode:   872		score:  168.13		average:  181.31
# Episode:   873		score:   67.96		average:  181.59
# Episode:   874		score:  267.18		average:  181.82
# Episode:   875		score:  238.00		average:  184.14
# Episode:   876		score:  239.74		average:  183.80
# Episode:   877		score:  242.05		average:  183.88
# Episode:   878		score:  251.65		average:  186.36
# Episode:   879		score:  251.64		average:  186.43
# Episode:   880		score:  256.38		average:  188.71
# Episode:   881		score:  -15.11		average:  185.97
# Episode:   882		score:  252.62		average:  185.81
# Episode:   883		score:   56.36		average:  183.71
# Episode:   884		score:   19.73		average:  181.51
# Episode:   885		score:  233.92		average:  183.11
# Episode:   886		score:  140.37		average:  182.07
# Episode:   887		score:  263.49		average:  182.13
# Episode:   888		score:  200.20		average:  182.19
# Episode:   889		score:  266.42		average:  182.91
# Episode:   890		score:  238.15		average:  182.96
# Episode:   891		score:  -10.78		average:  180.28
# Episode:   892		score:  267.68		average:  183.90
# Episode:   893		score:  201.36		average:  183.23
# Episode:   894		score:  -10.50		average:  180.40
# Episode:   895		score:  205.30		average:  182.47
# Episode:   896		score:   42.03		average:  181.42
# Episode:   897		score: -129.35		average:  177.29
# Episode:   898		score:  275.19		average:  177.63
# Episode:   899		score:  195.30		average:  177.40
# Episode:   900		score:  226.55		average:  176.78
# Episode:   901		score:  190.68		average:  177.35
# Episode:   902		score:  246.45		average:  177.19
# Episode:   903		score:    9.31		average:  174.50
# Episode:   904		score:  278.94		average:  175.20
# Episode:   905		score:   47.12		average:  173.02
# Episode:   906		score:   57.68		average:  171.56
# Episode:   907		score:  270.23		average:  172.01
# Episode:   908		score:    4.77		average:  171.78
# Episode:   909		score:  244.21		average:  173.84
# Episode:   910		score:    5.14		average:  173.87
# Episode:   911		score:  -12.34		average:  173.69
# Episode:   912		score:  281.70		average:  176.73
# Episode:   913		score:  252.64		average:  176.39
# Episode:   914		score:  271.50		average:  176.68
# Episode:   915		score:  275.01		average:  179.23
# Episode:   916		score:   32.26		average:  177.86
# Episode:   917		score:  277.29		average:  177.89
# Episode:   918		score:  257.61		average:  177.82
# Episode:   919		score:   14.49		average:  175.44
# Episode:   920		score:  252.84		average:  175.32
# Episode:   921		score:  242.56		average:  177.59
# Episode:   922		score:  252.76		average:  179.95
# Episode:   923		score:  167.83		average:  181.54
# Episode:   924		score:  258.02		average:  181.57
# Episode:   925		score:   74.30		average:  179.95
# Episode:   926		score:   32.37		average:  178.61
# Episode:   927		score:  -43.69		average:  175.59
# Episode:   928		score:  240.25		average:  175.29
# Episode:   929		score:  237.88		average:  175.05
# Episode:   930		score:  249.78		average:  174.98
# Episode:   931		score:  227.50		average:  177.00
# Episode:   932		score:  288.12		average:  180.18
# Episode:   933		score:  272.84		average:  180.91
# Episode:   934		score:   32.38		average:  179.78
# Episode:   935		score:   -6.45		average:  178.17
# Episode:   936		score:  246.21		average:  177.85
# Episode:   937		score: -154.37		average:  174.88
# Episode:   938		score:  242.08		average:  174.93
# Episode:   939		score:  -33.56		average:  172.08
# Episode:   940		score:    1.07		average:  170.57
# Episode:   941		score:  249.39		average:  170.62
# Episode:   942		score:  260.04		average:  170.94
# Episode:   943		score:   41.47		average:  168.67
# Episode:   944		score:   40.69		average:  166.82
# Episode:   945		score:    1.13		average:  163.93
# Episode:   946		score:  285.51		average:  166.82
# Episode:   947		score:   20.05		average:  164.07
# Episode:   948		score:  250.34		average:  164.44
# Episode:   949		score:   16.64		average:  162.01
# Episode:   950		score:  275.99		average:  163.38
# Episode:   951		score:  263.87		average:  163.53
# Episode:   952		score:  251.27		average:  166.11
# Episode:   953		score:  259.80		average:  168.14
# Episode:   954		score:   38.39		average:  165.81
# Episode:   955		score:  252.84		average:  166.29
# Episode:   956		score:  188.27		average:  165.65
# Episode:   957		score:  271.28		average:  165.92
# Episode:   958		score: -130.67		average:  162.73
# Episode:   959		score:   28.72		average:  163.17
# Episode:   960		score:  265.50		average:  163.29
# Episode:   961		score:  -18.97		average:  160.50
# Episode:   962		score:  -15.02		average:  157.65
# Episode:   963		score:  250.71		average:  157.75
# Episode:   964		score:  268.63		average:  160.37
# Episode:   965		score:  297.43		average:  160.61
# Episode:   966		score:   -0.54		average:  157.87
# Episode:   967		score:  280.24		average:  158.01
# Episode:   968		score:  256.17		average:  158.12
# Episode:   969		score:  259.65		average:  160.08
# Episode:   970		score:  241.88		average:  159.83
# Episode:   971		score:   35.78		average:  159.74
# Episode:   972		score:   11.30		average:  158.17
# Episode:   973		score:  261.39		average:  160.10
# Episode:   974		score:  203.47		average:  159.46
# Episode:   975		score:  -25.34		average:  156.83
# Episode:   976		score:   79.44		average:  155.23
# Episode:   977		score:  280.16		average:  155.61
# Episode:   978		score:  208.20		average:  155.17
# Episode:   979		score:   23.78		average:  152.90
# Episode:   980		score:    8.63		average:  150.42
# Episode:   981		score:  251.52		average:  153.08
# Episode:   982		score:   15.81		average:  150.72
# Episode:   983		score:   -1.39		average:  150.14
# Episode:   984		score:  238.25		average:  152.32
# Episode:   985		score:  253.91		average:  152.52
# Episode:   986		score:  246.41		average:  153.58
# Episode:   987		score:  277.42		average:  153.72
# Episode:   988		score:  245.69		average:  154.18
# Episode:   989		score:  262.77		average:  154.14
# Episode:   990		score:  176.02		average:  153.52
# Episode:   991		score:  261.40		average:  156.24
# Episode:   992		score:  243.27		average:  156.00
# Episode:   993		score:  253.03		average:  156.52
# Episode:   994		score:  262.37		average:  159.24
# Episode:   995		score:  241.46		average:  159.61
# Episode:   996		score:  232.20		average:  161.51
# Episode:   997		score:  -17.27		average:  162.63
# Episode:   998		score:  269.72		average:  162.57
# Episode:   999		score:  132.90		average:  161.95
# Episode:  1000		score:  -58.29		average:  159.10
# Episode:  1001		score:  260.64		average:  159.80
# Episode:  1002		score:  237.12		average:  159.71
# Episode:  1003		score:  233.04		average:  161.94
# Episode:  1004		score:  276.46		average:  161.92
# Episode:  1005		score:  135.32		average:  162.80
# Episode:  1006		score:  243.46		average:  164.66
# Episode:  1007		score:    2.91		average:  161.99
# Episode:  1008		score:  260.11		average:  164.54
# Episode:  1009		score:  249.38		average:  164.59
# Episode:  1010		score:  166.72		average:  166.21
# Episode:  1011		score:  234.73		average:  168.68
# Episode:  1012		score:  253.00		average:  168.39
# Episode:  1013		score:  263.79		average:  168.50
# Episode:  1014		score:  236.74		average:  168.16
# Episode:  1015		score:  262.53		average:  168.03
# Episode:  1016		score:  248.94		average:  170.20
# Episode:  1017		score:  231.09		average:  169.73
# Episode:  1018		score:  264.47		average:  169.80
# Episode:  1019		score:  -24.11		average:  169.42
# Episode:  1020		score:  232.78		average:  169.22
# Episode:  1021		score:  239.84		average:  169.19
# Episode:  1022		score:  260.67		average:  169.27
# Episode:  1023		score:  248.89		average:  170.08
# Episode:  1024		score:   10.75		average:  167.61
# Episode:  1025		score:  218.81		average:  169.05
# Episode:  1026		score:   37.07		average:  169.10
# Episode:  1027		score:   36.08		average:  169.90
# Episode:  1028		score:   47.83		average:  167.97
# Episode:  1029		score:  249.15		average:  168.09
# Episode:  1030		score:  227.98		average:  167.87
# Episode:  1031		score:  244.33		average:  168.04
# Episode:  1032		score:   -5.05		average:  165.10
# Episode:  1033		score:    5.18		average:  162.43
# Episode:  1034		score:    4.34		average:  162.15
# Episode:  1035		score:   20.68		average:  162.42
# Episode:  1036		score:  158.05		average:  161.54
# Episode:  1037		score:  -14.75		average:  162.93
# Episode:  1038		score:  220.52		average:  162.72
# Episode:  1039		score:   11.93		average:  163.17
# Episode:  1040		score:  260.52		average:  165.77
# Episode:  1041		score:  226.17		average:  165.53
# Episode:  1042		score:  157.48		average:  164.51
# Episode:  1043		score:  246.58		average:  166.56
# Episode:  1044		score:  149.21		average:  167.64
# Episode:  1045		score:  261.16		average:  170.25
# Episode:  1046		score:  210.31		average:  169.49
# Episode:  1047		score:  258.90		average:  171.88
# Episode:  1048		score:  235.20		average:  171.73
# Episode:  1049		score:  119.57		average:  172.76
# Episode:  1050		score:  188.76		average:  171.89
# Episode:  1051		score:  268.26		average:  171.93
# Episode:  1052		score:  235.05		average:  171.77
# Episode:  1053		score:  219.48		average:  171.37
# Episode:  1054		score:  241.51		average:  173.40
# Episode:  1055		score:  226.17		average:  173.13
# Episode:  1056		score:  236.83		average:  173.62
# Episode:  1057		score:  240.70		average:  173.31
# Episode:  1058		score:    1.49		average:  174.63
# Episode:  1059		score:   43.64		average:  174.78
# Episode:  1060		score:   46.75		average:  172.59
# Episode:  1061		score:  -24.64		average:  172.54
# Episode:  1062		score:  234.11		average:  175.03
# Episode:  1063		score:  252.27		average:  175.04
# Episode:  1064		score:   45.54		average:  172.81
# Episode:  1065		score:   34.85		average:  170.19
# Episode:  1066		score:  262.46		average:  172.82
# Episode:  1067		score:  275.12		average:  172.77
# Episode:  1068		score:   -1.05		average:  170.19
# Episode:  1069		score:  237.77		average:  169.98
# Episode:  1070		score:  248.48		average:  170.04
# Episode:  1071		score:  253.08		average:  172.21
# Episode:  1072		score:  252.60		average:  174.63
# Episode:  1073		score:  248.51		average:  174.50
# Episode:  1074		score:  263.33		average:  175.10
# Episode:  1075		score:  257.31		average:  177.92
# Episode:  1076		score:  131.30		average:  178.44
# Episode:  1077		score:  185.42		average:  177.49
# Episode:  1078		score:  253.33		average:  177.95
# Episode:  1079		score:  251.84		average:  180.23
# Episode:  1080		score:  239.66		average:  182.54
# Episode:  1081		score:  259.07		average:  182.61
# Episode:  1082		score:  247.52		average:  184.93
# Episode:  1083		score:  273.02		average:  187.67
# Episode:  1084		score:  252.15		average:  187.81
# Episode:  1085		score:  216.75		average:  187.44
# Episode:  1086		score:  278.51		average:  187.76
# Episode:  1087		score:  303.68		average:  188.02
# Episode:  1088		score:  264.04		average:  188.21
# Episode:  1089		score:  248.35		average:  188.06
# Episode:  1090		score:  278.20		average:  189.09
# Episode:  1091		score:  241.78		average:  188.89
# Episode:  1092		score:    6.40		average:  186.52
# Episode:  1093		score:  275.05		average:  186.74
# Episode:  1094		score:  239.12		average:  186.51
# Episode:  1095		score:  -31.02		average:  183.78
# Episode:  1096		score:  267.68		average:  184.14
# Episode:  1097		score:  250.63		average:  186.82
# Episode:  1098		score:  248.46		average:  186.60
# Episode:  1099		score:  282.31		average:  188.10
# Episode:  1100		score:  258.05		average:  191.26
# Episode:  1101		score:  279.65		average:  191.45
# Episode:  1102		score:   16.91		average:  189.25
# Episode:  1103		score:  240.59		average:  189.33
# Episode:  1104		score:  230.54		average:  188.87
# Episode:  1105		score:   13.39		average:  187.65
# Episode:  1106		score:   34.49		average:  185.56
# Episode:  1107		score:  249.93		average:  188.03
# Episode:  1108		score:   14.48		average:  185.57
# Episode:  1109		score:   23.55		average:  183.31
# Episode:  1110		score:  268.43		average:  184.33
# Episode:  1111		score:  245.95		average:  184.44
# Episode:  1112		score:  309.31		average:  185.01
# Episode:  1113		score:  192.03		average:  184.29
# Episode:  1114		score:  138.04		average:  183.30
# Episode:  1115		score:   -0.34		average:  180.67
# Episode:  1116		score:  283.65		average:  181.02
# Episode:  1117		score:  242.30		average:  181.13
# Episode:  1118		score:   24.70		average:  178.73
# Episode:  1119		score:    4.48		average:  179.02
# Episode:  1120		score:  264.31		average:  179.33
# Episode:  1121		score:  274.83		average:  179.68
# Episode:  1122		score:  257.42		average:  179.65
# Episode:  1123		score:  231.17		average:  179.47
# Episode:  1124		score:  263.24		average:  182.00
# Episode:  1125		score:  250.88		average:  182.32
# Episode:  1126		score:   51.96		average:  182.47
# Episode:  1127		score:  250.13		average:  184.61
# Episode:  1128		score:  284.07		average:  186.97
# Episode:  1129		score:    0.25		average:  184.48
# Episode:  1130		score:  252.02		average:  184.72
# Episode:  1131		score:  282.77		average:  185.11
# Episode:  1132		score:  246.89		average:  187.63
# Episode:  1133		score:  244.03		average:  190.02
# Episode:  1134		score:   30.48		average:  190.28
# Episode:  1135		score:  -15.47		average:  189.92
# Episode:  1136		score:  273.26		average:  191.07
# Episode:  1137		score:  250.78		average:  193.72
# Episode:  1138		score:   17.47		average:  191.69
# Episode:  1139		score:  -26.18		average:  191.31
# Episode:  1140		score:  266.42		average:  191.37
# Episode:  1141		score:  257.68		average:  191.69
# Episode:  1142		score:  119.06		average:  191.30
# Episode:  1143		score:  256.89		average:  191.40
# Episode:  1144		score:   38.90		average:  190.30
# Episode:  1145		score:  252.42		average:  190.21
# Episode:  1146		score:   38.40		average:  188.49
# Episode:  1147		score:  236.98		average:  188.28
# Episode:  1148		score:  273.19		average:  188.66
# Episode:  1149		score:  253.83		average:  190.00
# Episode:  1150		score:  241.39		average:  190.52
# Episode:  1151		score:   40.49		average:  188.25
# Episode:  1152		score:  225.60		average:  188.15
# Episode:  1153		score:  268.75		average:  188.64
# Episode:  1154		score:  222.73		average:  188.46
# Episode:  1155		score:  265.16		average:  188.85
# Episode:  1156		score:  258.91		average:  189.07
# Episode:  1157		score:  292.22		average:  189.58
# Episode:  1158		score:  250.23		average:  192.07
# Episode:  1159		score:  275.87		average:  194.39
# Episode:  1160		score:  252.04		average:  196.45
# Episode:  1161		score:  248.84		average:  199.18
# Episode:  1162		score:  257.63		average:  199.42
# Episode:  1163		score:  258.67		average:  199.48
# Episode:  1164		score:  202.06		average:  201.04
# 17.050989405314127
